# %% [markdown]
# # Importing and Installing Necessary Things

# %%
# Will be using this to get information on each app based on appid

#pip install google_play_scraper

# %%
# Will help me scroll down a page to get all the possible html

#pip install selenium

# %%
import requests
import datetime
import time
import pandas as pd

from bs4 import BeautifulSoup
from selenium import webdriver

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# # Getting List of App IDs per category

# %%
#Categories, focusing on top free and top paid apps of each.

#Action
ActionFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfZnJlZV9HQU1FX0FDVElPThAHGAM%3D:S:ANO1ljKHNjI&gsr=CibSDiMKIQobdG9wc2VsbGluZ19mcmVlX0dBTUVfQUNUSU9OEAcYAw%3D%3D:S:ANO1ljLUxfQ&hl=en_US'
ActionPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfcGFpZF9HQU1FX0FDVElPThAHGAM%3D:S:ANO1ljLH0kM&gsr=CibSDiMKIQobdG9wc2VsbGluZ19wYWlkX0dBTUVfQUNUSU9OEAcYAw%3D%3D:S:ANO1ljIdBNk&hl=en_US'

#Adventure
AdventureFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4mCiQKHnRvcHNlbGxpbmdfZnJlZV9HQU1FX0FEVkVOVFVSRRAHGAM%3D:S:ANO1ljJV7FQ&gsr=CinSDiYKJAoedG9wc2VsbGluZ19mcmVlX0dBTUVfQURWRU5UVVJFEAcYAw%3D%3D:S:ANO1ljIcQUo&hl=en_US'
AdventurePaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4mCiQKHnRvcHNlbGxpbmdfcGFpZF9HQU1FX0FEVkVOVFVSRRAHGAM%3D:S:ANO1ljKjB_A&gsr=CinSDiYKJAoedG9wc2VsbGluZ19wYWlkX0dBTUVfQURWRU5UVVJFEAcYAw%3D%3D:S:ANO1ljJuB_8&hl=en_US'

#Arcade
ArcadeFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfZnJlZV9HQU1FX0FSQ0FERRAHGAM%3D:S:ANO1ljIshgI&gsr=CibSDiMKIQobdG9wc2VsbGluZ19mcmVlX0dBTUVfQVJDQURFEAcYAw%3D%3D:S:ANO1ljJq_Gc&hl=en_US'
ArcadePaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfcGFpZF9HQU1FX0FSQ0FERRAHGAM%3D:S:ANO1ljIhZHI&gsr=CibSDiMKIQobdG9wc2VsbGluZ19wYWlkX0dBTUVfQVJDQURFEAcYAw%3D%3D:S:ANO1ljKAU-U&hl=en_US'

#Board
BoardFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4iCiAKGnRvcHNlbGxpbmdfZnJlZV9HQU1FX0JPQVJEEAcYAw%3D%3D:S:ANO1ljL4-C4&gsr=CiXSDiIKIAoadG9wc2VsbGluZ19mcmVlX0dBTUVfQk9BUkQQBxgD:S:ANO1ljKCMxA&hl=en_US'
TriviaPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfcGFpZF9HQU1FX1RSSVZJQRAHGAM%3D:S:ANO1ljJeZh8&gsr=CibSDiMKIQobdG9wc2VsbGluZ19wYWlkX0dBTUVfVFJJVklBEAcYAw%3D%3D:S:ANO1ljKHdVE&hl=en_US'

#Word
WordFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4hCh8KGXRvcHNlbGxpbmdfZnJlZV9HQU1FX1dPUkQQBxgD:S:ANO1ljLuO2k&gsr=CiTSDiEKHwoZdG9wc2VsbGluZ19mcmVlX0dBTUVfV09SRBAHGAM%3D:S:ANO1ljIqSWE&hl=en_US'
WordPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4hCh8KGXRvcHNlbGxpbmdfcGFpZF9HQU1FX1dPUkQQBxgD:S:ANO1ljJM7Hg&gsr=CiTSDiEKHwoZdG9wc2VsbGluZ19wYWlkX0dBTUVfV09SRBAHGAM%3D:S:ANO1ljJLmvc&hl=en_US'

# %%
#List of Categories to run function through later.

listofcateg = [ActionFree, ActionPaid, AdventureFree, AdventurePaid, ArcadeFree, ArcadePaid, BoardFree, BoardPaid, CardFree, CardPaid, CasinoFree, CasinoPaid, CasualFree, CasualPaid, EducationalFree, EducationalPaid, MusicFree, MusicPaid, PuzzleFree, PuzzlePaid, RacingFree, RacingPaid, RolePlayingFree, RolePlayingPaid, SimulationFree, SimulationPaid, SportsFree, SportsPaid, StrategyFree, StrategyPaid, TriviaFree, TriviaPaid, WordFree, WordPaid]

# %% [markdown]
# ### Creating Function to return list of appids

# %%
# Testing a link in this bottom example to see if I can get the link I need.

#driver = webdriver.Safari()
#driver.get('https://play.google.com/store/apps/collection/cluster?clp=0g4fCh0KF3RvcGdyb3NzaW5nX0dBTUVfQUNUSU9OEAcYAw%3D%3D:S:ANO1ljIOh7o&gsr=CiLSDh8KHQoXdG9wZ3Jvc3NpbmdfR0FNRV9BQ1RJT04QBxgD:S:ANO1ljLWGVQ&hl=en_US')

def scroll_to_bottom(driver):

    old_position = 0
    new_position = None

    while new_position != old_position:
        # Get old scroll position
        old_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                 " window.pageYOffset : (document.documentElement ||"
                 " document.body.parentNode || document.body);"))
        
        # Sleep and Scroll
        time.sleep(1)
        driver.execute_script((
                "var scrollingElement = (document.scrollingElement ||"
                " document.body);scrollingElement.scrollTop ="
                " scrollingElement.scrollHeight;"))
        
        # Get new position
        new_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                 " window.pageYOffset : (document.documentElement ||"
                 " document.body.parentNode || document.body);"))

#scroll_to_bottom(driver)

#html = driver.page_source

#soup = BeautifulSoup(html, 'lxml')

#driver.quit()

# %%
def cleaner(stuff):
    # Only looking for href links as this is where our appid is.
    links = [a['href'] for a in stuff.find_all('a', href=True)]
    
    # Only looking for unique links as game links show up several times.
    uniquelinks = []
    for x in links:
        if x not in uniquelinks:
            uniquelinks.append(x)
            
    # Only want links with that specific prefix as there are a lot of useless href links.            
    uniqueappidlinks = list(filter(lambda k: '/store/apps/details?id=' in k, uniquelinks))
    
    # Removing the front part now that we have the link we need.
    uniqueappid = [s.replace('/store/apps/details?id=', '') for s in uniqueappidlinks]
    
    return uniqueappid

# %%
# Putting everything together.

def giveappid(link):
    driver = webdriver.Safari()
    driver.get(link)
    
    scroll_to_bottom(driver)
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    
    driver.quit()
    
    return cleaner(soup)

# %%
# Applying function to the list of categories we made earlier.

listoflistofappids = list(map(lambda link: giveappid(link), listofcateg))
listoflistofappids
# Out:
# [['com.innersloth.spacemafia',
#   'com.tapped.drawrider',
#   'com.activision.callofduty.shooter',
#   'com.playgendary.hitmasters',
#   'com.drawprotector.wavy.ios',
#   'com.fungames.sniper3d',
#   'com.cassette.aquapark',
#   'com.rkgames.basisgame',
#   'air.com.hypah.io.slither',
#   'com.playgendary.kickthebuddy',
#   'com.dts.freefireth',
#   'com.YummyGames.SamuraiFlash',
#   'com.cg.fanofguns',
#   'com.nintendo.zaka',
#   'lol.onevone',
#   'com.jtsniper.game',
#   'com.Neurononfire.SupremeDuelist',
#   'com.rubygames.assassin',
#   'com.ducky.slicethemall',
#   'com.geishatokyo.trafficrun',
#   'com.tencent.ig',
#   'com.outfit7.herodash',
#   'com.supercell.brawlstars',
#   'spider.rope.hero.frogninja.gangstar.crime.herogame',
#   'ru.galya.drawjoust',
#   'com.groogadgets.swipefight',
#   'com.jpgroup.pocketsniper',
#   'com.PoxelStudios.DudeTheftAuto',
#   'com.amelosinteractive.snake',
#   'com.miniclip.bowmasters',
#   'com.playgendary.tom',
#   'games.nerf.epic.pranks.free',
#   'com.outfit7.talkingtomgoldrun',
#   'com.stealthgame.master',
#   'com.time.trigger',
#   'mobi.gameguru.slapkings',
#   'com.ohmgames.crowdshooter',
#   'com.miniclip.agar.io',
#   'com.ohbibi.fps',
#   'com.ohmgames.knockdolls',
#   'com.netboom.cloudgaming.vortex_stadia_shadow_GeForce',
#   'com.wildlife.games.battle.royale.free.zooba',
#   'com.nintendo.zara',
#   'com.seenax.HideAndSeek',
#   'com.fungames.battletanksbeta',
#   'com.gamestart.protectthevip',
#   'com.crazylabs.lady.bug',
#   'com.hgamesart.hurricanehero',
#   'com.habby.archero',
#   'com.Deven.Arrow3D',
#   'vh.one',
#   'com.geishatokyo.snowballio',
#   'com.pixel.gun3d',
#   'com.sandboxol.indiegame.bedwar',
#   'com.kabam.marvelbattle',
#   'com.edkongames.mobs',
#   'zombie.survival.craft.z',
#   'com.studio501.curvypunch3d',
#   'com.imangi.templerun2',
#   'com.mgc.RopeHero.ViceTown',
#   'com.yodo1.crossyroad',
#   'com.playgendary.tombpaint',
#   'com.pixonic.wwr',
#   'com.wildspike.wormszone',
#   'black.mafia.ironboy.stickman.rope.heros',
#   'com.mobile.legends',
#   'com.dangernoodle.killerbee',
#   'com.chaloapps.strikefortressbox',
#   'com.gamehivecorp.beattheboss4',
#   'com.Bingo.Football',
#   'com.Snow.Golf',
#   'com.stickman.warriors.stickwarriors.dragon.shadow.fight',
#   'com.stickman.shadow.battle',
#   'com.tikitaka.folk',
#   'com.funnii.maskofstick',
#   'com.hitrock.hideonline',
#   'com.vng.g6.a.zombie',
#   'com.gamedevltd.wwh',
#   'com.hgamesart.blackholehero',
#   'com.generagames.resistance',
#   'com.geishatokyo.dinosaur',
#   'com.bandainamcoent.dblegends_ww',
#   'com.chillyroom.zhmr.gp',
#   'com.mousemobile.explorationcraft',
#   'air.com.ubisoft.brawl.halla.platform.fighting.action.pvp',
#   'com.gta.truck.driver.city.crush',
#   'com.Eageron.apps.RealTimeShields',
#   'com.fcnaud.robbery',
#   'com.ohmgames.smashthemall',
#   'com.cec.skateuniverse',
#   'me.modernator.stickWarfareBloodStrike',
#   'com.os.falcon.yogame.stickfighter',
#   'com.lalonde.upstream',
#   'com.h8games.helixjump',
#   'com.freegamesstudio.thesurvivalhuntergames2',
#   'com.wb.goog.mkx',
#   'com.gta.real.gangster.crime',
#   'com.bhvr.deadbydaylight',
#   'com.dive.bed.game',
#   'games.noho.gungang',
#   'com.chaloapps.roosterrudy',
#   'com.onetongames.rocketroyale',
#   'com.nekki.shadowfight',
#   'com.gameloft.android.ANMP.GloftGGHM',
#   'com.sega.sonic1px',
#   'com.titan.cd.gb',
#   'jpark.AOS5',
#   'com.zeptolab.bulletecho.google',
#   'com.netease.ddsfna',
#   'com.stick.fight.battle.warrior',
#   'com.rage.road',
#   'com.ZenithGames.CrowdBomber',
#   'com.bandainamcoent.ninjavoltage_app',
#   'com.hgamesart.snowstorm',
#   'com.skygo.stickfight2',
#   'com.mizo.robot.fps.shooting.game',
#   'rs.pwn.zombielike',
#   'com.cheshirex.stickmanthefight',
#   'com.ivy.garfield.run',
#   'com.aryasgames.zombieseverywhere',
#   'com.desert.riders',
#   'com.playstack.svtc',
#   'com.zeptolab.robotics',
#   'com.junesoftware.maskgun',
#   'sniper.gun.zombie.shooting',
#   'io.painkiller.battle.royale',
#   'com.tomo.pushbattle',
#   'com.my.warface.online.fps.pvp.action.shooter',
#   'com.gun.black.ops',
#   'com.yuriychechulin.throwio',
#   'com.matte.rushcrush',
#   'com.rubygames.slingdrift',
#   'com.cg.cowboy',
#   'com.grandgangster.crimecity.prisonescape',
#   'com.glu.zbs',
#   'com.funnii.robotsuper.offlinegames',
#   'sniper.honor.real3d.shooter.assassin.free.android',
#   'com.gsgames.pixel.combat',
#   'com.flaregames.zgs',
#   'com.chaloapps.memeswars',
#   'fi.twomenandadog.zombiecatchers',
#   'com.PuzzleOnly.KnockoutRace',
#   'com.ChillyRoom.DungeonShooter',
#   'com.mtvn.superbrawlapp',
#   'com.criticalforceentertainment.criticalops',
#   'com.joydo.minestrikenew',
#   'com.babil.archers.tale.bow.hunter.battle.action',
#   'com.fun.games.commando.black.shadow',
#   'com.gamedevltd.modernstrike',
#   'com.madfingergames.deadtrigger2',
#   'com.aurecas.stickmanzombieshooter',
#   'com.panzerdog.tacticool',
#   'com.hgamesart.superhero',
#   'com.aldagames.zombieshooter',
#   'com.lf.sniper.gun.shooter.free.apps',
#   'com.bandainamcogames.dbzdokkanww',
#   'com.hgamesart.ropemummy',
#   'com.funnii.galaxyofstick',
#   'com.bloop.food',
#   'com.clement.ballmayhem',
#   'com.pikpok.dr2.play',
#   'com.zg.dinosaur.hunter.wild.jungle.animals.hunting.sniper.safari.free.apps',
#   'com.zeptolab.omnomrun.google',
#   'com.roadglider.game',
#   'com.madfingergames.wargames.shooter',
#   'com.doctor.surgerymaster',
#   'com.Floor18.Zombiner',
#   'com.azurgames.BattleGroundRoyale',
#   'com.kwalee.superherosunset',
#   'com.spider.ropeman.superhero.gangster.vegas.crimecity',
#   'com.hasbro.beybladesenterprise',
#   'com.sega.soniccd.classic',
#   'com.anfagames.sodaguys',
#   'com.DCGEntertainment.EnergyBlast',
#   'com.rkgames.smashywanted',
#   'com.soneraltincit.cityfightvsstreetgang',
#   'com.nway.powerrangerslegacywars',
#   'org.ppsspp.ppsspp',
#   'com.mgs.sniper1',
#   'com.stick.hero.fighter.saiyan.supreme.dragon.warrios',
#   'com.assassingames.ninjafrogrope',
#   'com.alienshooter.galaxy.attack2',
#   'com.kotobagames.namelesscat',
#   'com.turborilla.bmx2',
#   'com.sgs.urb.versuspixels',
#   'com.miniclip.diep.io',
#   'com.sunnybaria.collabgame',
#   'com.axlebolt.standoff2',
#   'com.herogame.gplay.lastdayrulessurvival',
#   'com.crazylabs.mr.bullet.puzzle.game3d',
#   'com.kabam.bigrobot',
#   'com.gamedevltd.destinywarfare',
#   'com.lf.frontline.elite.war.free.apps',
#   'com.ggv.grand.city.thug.crime.gangester',
#   'com.gameloft.android.ANMP.GloftOLHM',
#   'se.itatake.gumslinger',
#   'com.chillingo.robberybobfree.android.row',
#   'com.feelingtouch.zf3d',
#   'com.gameloft.android.ANMP.GloftM5HM',
#   'com.autumn.skullgirls'],
#  ['com.scottgames.fivenightsatfreddys',
#   'com.clickteam.ultimatecustomnight',
#   'com.rockstargames.gtasa',
#   'com.dsemu.drastic',
#   'com.scottgames.sisterlocation',
#   'com.ubisoft.assassinscreed.identity',
#   'com.scottgames.fnaf4',
#   'com.squareenixmontreal.hitmansniperandroid',
#   'com.scottgames.fnaf3',
#   'com.activision.boz',
#   'jp.konami.epjCastlevania2',
#   'com.rockstargames.bully',
#   'com.rockstar.gta3',
#   'com.bethsoft.DOOM',
#   'com.damonplay.damonps2.pro.ppsspp',
#   'com.wb.lego.marvel',
#   'com.GameCoaster.ProtectDungeon',
#   'org.ppsspp.ppssppgold',
#   'com.playdigious.deadcells.mobile',
#   'com.tipsworks.android.pascalswager.google',
#   'com.turner.ttgfigures2',
#   'com.bethsoft.DOOMII',
#   'com.rockstargames.gtactw',
#   'com.jdroid.gtasacheater',
#   'com.jumpgames.RealSteel',
#   'com.venomizedArt.SlaughterRebels',
#   'com.nekki.shadowfight2.paid',
#   'com.turner.b10runner',
#   'com.EvilTortillaGames.cookiesvclaus',
#   'com.agaming.thesun.origin',
#   'com.coffeestainstudios.goatsimulator.goatz',
#   'com.MikaMobile.Zombieville2',
#   'com.MortalCrusade.SwordOfKnight',
#   'com.khg.actionsquad',
#   'com.oddworld.Stranger',
#   'com.limbic.ac130',
#   'com.altavite.ps2emu',
#   'com.dotemu.titanquest',
#   'com.foursakenmedia.heroesandcastles2',
#   'com.pastagames.ro1mobile',
#   'com.ubisoft.rayman.fiestarun',
#   'com.Zonmob.Stickman.FightingGames.ShadowOfDeath',
#   'com.gameloft.android.ANMP.GloftM4HM',
#   'com.devolver.downwell_rerelease',
#   'air.com.sfbgames.HauntTheHouseTerrortown',
#   'com.mtvn.tmntpp',
#   'com.oddworld.NNT',
#   'com.archi701.elchapo',
#   'com.ThoriumGameLab.BattleOfVicksburg3',
#   'com.tequilabyte.walker.main',
#   'com.gameloft.android.ANMP.GloftG4HM',
#   'com.ThoriumGameLab.EastFront',
#   'com.gameloft.android.ANMP.GloftM3HM',
#   'com.FYQD.BrightMemory',
#   'com.candyrufusgames.survivalcraft',
#   'com.outerminds.pewdiepie',
#   'com.ThoriumGameLab.WinterWar',
#   'com.mtvn.tmntMovieGame',
#   'com.DastroGamesStudio.FateZ',
#   'com.dingogames.tastyplanet2',
#   'com.mygdx.digtochina.android',
#   'com.mtvn.tmntrooftoprun',
#   'jp.co.capcom.rockman1en',
#   'com.dingogames.tastyplanet1',
#   'com.IvanPanasenko.EndurancePremium',
#   'com.ThoriumGameLab.Petrolia',
#   'com.blinigames.lus',
#   'com.vblank.RCRDX',
#   'com.pixelbite.sg',
#   'com.Drool.ThumperPocketEdition',
#   'jp.co.capcom.rockman6en',
#   'air.com.oranginalplan.weaphones2020',
#   'com.opentouchgaming.deltatouch',
#   'com.jdroid.gta3modder',
#   'jp.co.capcom.rockman2en',
#   'com.fansipan.stickman.shadow.knights.fightinggames',
#   'com.starshipstudio.thesurvivorremastered',
#   'com.dotemu.raidenlegacy',
#   'com.opentouchgaming.quadtouch',
#   'com.Dexus.Dinosaur.TRexFights.Dinosaurs.Dominator',
#   'com.kylebarrett.Immortal',
#   'com.doublethink.ofdp2',
#   'com.sigmateam.alienshooter2reloaded',
#   'com.littlegamesstudio.Gauntlet',
#   'com.foursakenmedia.heroesandcastles',
#   'com.square_enix.secret',
#   'com.companyname.LetThemCome',
#   'jp.co.capcom.rockman4en',
#   'jp.co.capcom.rockman3en',
#   'com.stickman.warriors.dragon',
#   'com.zitga.ninja.stickman.legends.shadow.wars',
#   'com.VenomizedArt.Mindcell',
#   'com.unimob.stickman.ghost2.pay',
#   'com.the10tons.teslavslovecraft',
#   'com.the10tons.neonchrome',
#   'com.foursakenmedia.bugheroes2',
#   'com.venomizedart.Slaughter',
#   'de.kamibox.seesaw',
#   'com.nvidia.valvesoftware.halflife2',
#   'com.venomizedArt.Slaughter2',
#   'com.blabberf.gunroundsandroid',
#   'jp.halegg.nazcaf',
#   'com.imcrazy.ds2',
#   'com.sigmateam.alienshootermobile',
#   'com.hgamesart.catsimulatorpro',
#   'com.agaming.reporter',
#   'com.TinyDevbox.DeadRain',
#   'com.Majorariatto.GolfingOverIt',
#   'com.gameloft.android.ANMP.GloftWBHM',
#   'com.Bornthrupieces.Bond007',
#   'com.gsm.overdrivepremium',
#   'com.turner.trutv.wheelofdoom',
#   'com.redantz.game.za3p',
#   'com.AlexeySuslin.RunicCurse',
#   'com.darkarrow.stickfighter.saiyan.vip',
#   'com.Nariworks.VirusZombie',
#   'com.entwell.rk_org',
#   'com.the10tons.jydge',
#   'com.tenbirds.animus',
#   'com.agaming.mentalhospitaliv',
#   'com.agaming.zonaprojectx',
#   'com.tenbirds.animus2c',
#   'com.atypicalgames.chernobyl',
#   'com.dormroom.cyberpunk2069',
#   'com.skyfox.foxoneAdv',
#   'com.pixelstar.PixelFBladeVIP',
#   'com.DefStudio.BattleGunVRGold',
#   'com.mtvn.dafrainforest.google',
#   'com.id.doom3bfg',
#   'com.reeltoreal.survivor_adventure_pro',
#   'com.RideAndCrash.AmonAmarthBerserkerGame',
#   'com.eyesright.amb',
#   'com.atypicalgames.radiationcity',
#   'com.devolverdigital.swredux.play',
#   'com.atypicalgames.radiationisland',
#   'jp.co.capcom.rockman5en',
#   'com.foursakenmedia.nyz2',
#   'com.zitga.cyberfighters.shadow.hunter.legends',
#   'com.impact_studios.superbrawlsmash',
#   'com.the10tons.crimsonland',
#   'co.electrictoy.dig'],
#  ['com.roblox.client',
#   'com.multicraft.game',
#   'com.BlissGames.Juego23',
#   'com.nianticlabs.pokemongo',
#   'com.oneway.Deathcoming',
#   'com.movile.playkids.pkxd',
#   'com.eers.kraft.eerskraft',
#   'com.jockeygames.rampcar.stuntsfree.impossibletracks.stuntdriving.mega.car',
#   'com.cleverturtle.brickbuilder',
#   'free.os.jump.superbros.adventure.world',
#   'com.sega.sprint',
#   'com.neighbors.darkriddle',
#   'com.tinyco.potter',
#   'com.deuscraft.TurboTeam',
#   'net.wooga.junes_journey_hidden_object_mystery_game',
#   'com.lioncel.NoOneEscape',
#   'com.grand.speed.hero.highway.gangster.chase',
#   'com.grand.police.transport.truck',
#   'com.os.falcon.bob2.adventure.world',
#   'org.nanobit.hollywood',
#   'com.randonautica.app',
#   'com.playrix.manormatters',
#   'com.apps2us.slither.slink.io',
#   'com.gameinsight.gplay.mmanor',
#   'com.sgs.antiterrorism.counterattack.commandomissiongame',
#   'com.naturalmotion.clumsyninja',
#   'com.hitcents.drawastickmanepic2free',
#   'com.superbinogo.jungleboyadventure',
#   'com.gf.extreme.gtracing.car.stunts.impossiblecarstunts.stuntdriving',
#   'com.tinybuildgames.helloneighbor',
#   'com.aidungeon',
#   'com.tellurionmobile.realmcraft',
#   'com.cradley.bee.robot.games',
#   'com.Earthkwak.Platformer',
#   'com.mytona.seekersnotes.android',
#   'com.fa.gym.fighting.game',
#   'com.secg.jurassiccraft',
#   'com.sandboxol.indiegame.eggwars',
#   'air.SuperCity',
#   'com.bl.critical.strike',
#   'com.pocapp.dungeondogsgame',
#   'com.fgz.us.police.flying.helicopter.car.transform.robot.games',
#   'com.doctor.robot.rescue.mission',
#   'com.StickPage.diamant',
#   'com.bigag.bike.stunt.master',
#   'com.craftgames.plntcrft',
#   'com.impp.construction.simulator.forklift',
#   'com.cdt.basic.math.teacher',
#   'air.HardTime',
#   'com.spider.ropehero.superhero.gangstercrime',
#   'com.crazylabs.jumanji',
#   'com.blyts.nobodies',
#   'com.secg.earthcraft',
#   'com.ghs.dino.robot.car.robot.game',
#   'com.mojang.minecraftearth',
#   'com.buildingcraftinggames.fun.kid.games.boys.block.craft.minecraft.story.mode.lego.create.build.marvel.hero.dc.legends.mcpe.mod',
#   'com.hitcents.drawastickmanepic3',
#   'com.jagex.oldscape.android',
#   'com.prettysimple.criminalcaseandroid',
#   'com.buntoo.drone.robot.transformation',
#   'com.tinydragonadventuregames.crafting.building.exploration.blocky.cube.lite.boy.girl.love.date.game.chat.minecraft.boyfriend',
#   'com.craftgames.worldcrft',
#   'com.gun.fun.anti.shoot',
#   'com.gangstar.crime.fps',
#   'com.mustardgames.topspeed.formulacar.racinggames',
#   'com.play.io.monster.truck.demolition.derby.crash.stunts',
#   'games.fatlion.building.mycraft.surfing.craft.free.simulator.jetski.games.surf.league',
#   'com.upjers.zoo2animalpark',
#   'com.us.police.car.transform.robot.war',
#   'com.candyrufusgames.survivalcraft2trial',
#   'com.red.ball.ballgames.bounceball.redball5',
#   'com.RetrostyleGames.LastPirate.deadthieves',
#   'com.animal.attack.simulator2019.wild.hunting.games',
#   'com.tinydragonadventuregames.doll.house.craft.princess.fashion.girls.minecraft.barbie.creative.exploration.lite.build.mine.free',
#   'com.studiowildcard.wardrumstudios.ark',
#   'com.YovoGames.carwash4',
#   'com.rds.bike.racer.highway.rider.traffic.bike.racing.game',
#   'air.com.pixelfederation.diggy',
#   'com.playmini.miniworld',
#   'com.sandboxol.indiegame.skywar',
#   'com.glu.stardomkim',
#   'com.ugen.playquirk',
#   'com.survivalcrafting.scary.theme.park.craft.horror.ghost.zombie.monster',
#   'com.cgs.offroad.farm.animal.transport.trailer.truck.driving.game',
#   'com.happy.family.limousine.robot.game',
#   'com.gs.lightspeed.superhero.rescue.mission.doctor.robot.games',
#   'de.codestream.horus',
#   'com.FoxieGames.DinoProject',
#   'com.impp.city.traindriver.simulator',
#   'com.YovoGames.babyCare2',
#   'com.pm.mega.ramp.impossible.car',
#   'com.nag.pet.dog.virtual.family.adventure',
#   'com.gz.deer.hunting.shooting',
#   'com.wb.goog.legoswtfa',
#   'com.gaminglegends.taxigame.taxisimulator.grand.car.driving2020',
#   'com.sandboxol.indiegame.luckyblock',
#   'freedom.bubble',
#   'com.indigokids.mim',
#   'com.bandagames.miner',
#   'com.fgz.flying.fire.truck.engine.rescue.firefighter.robot.games',
#   'com.mustardgames.muscle.car.stunts.mega.ramp.stunt.car.impossibletracks',
#   'com.frenzygames.fgs.shooting.anti.terrorism.combat.mission',
#   'com.cgs.sea.animal.transport.trailer.truck.driving.game',
#   'com.cradley.jungle.robot.shooting.game',
#   'com.appstrend.police.robot.bus.transform',
#   'com.gamesunion.idleracingtycoon',
#   'com.spider.ropehero.gangster.crimecity',
#   'com.doctor.robot.human.rescue',
#   'com.minecrafting.miniworldcrafting',
#   'com.freerange.goosebumps',
#   'com.eyesthegame.eyes',
#   'com.crazylabs.hotel.transylvania.adventure',
#   'jonessamuelren.far.home.spider.hero.run',
#   'com.EZTECK.brannyTeacherMath',
#   'com.FumbGames.DragonMerge',
#   'com.ludia.jw2',
#   'com.offlinegames.police.racing',
#   'com.rlg.flying.tiger.bike.robot.transform',
#   'com.SGS.DrivingSchoolGames.RealCarParkingSimulator',
#   'com.buildtownn.skimlyblock',
#   'com.appstrend.flying.eagle.robot.car.games',
#   'com.amongus.us',
#   'com.kongregate.mobile.throwdown.google',
#   'com.g5e.homicidesquadpg.android',
#   'com.nag.home.manager.working.virtual.mom',
#   'com.monstergamesproductions.ramp.moto.rider',
#   'com.hanako.mcpe_mods',
#   'com.spinmaster.enterprise.colleggtibles',
#   'com.spider.ropehero.crimecity',
#   'com.gamefeast.bigcity.limousine.car.driver',
#   'air.com.RustyLake.SamsaraRoom',
#   'com.reeltoreal.survivor_adventure',
#   'com.flying.tractor.simulator',
#   'com.igoldtech.streetchaser',
#   'freegames.zombiesniper.deadtrigger',
#   'com.mustardgames.bmx.cycle.stunt.mega.ramp.impossibletracks',
#   'biggiant.prisonescape',
#   'com.HuaYiGame.DeliveryFromThePain',
#   'air.com.moviestarplanet.roboblastplanet',
#   'com.delworkhard1.minecrafting2020',
#   'com.xjoy.mermaid',
#   'com.wooga.pearlsperil',
#   'com.minecraftpe.minicraft.multicraft.blockart',
#   'com.tohsoft.arashi.ninja.shadow',
#   'com.YovoGames.doctorBear',
#   'air.ExtraLives',
#   'com.gametornado.short_life',
#   'com.darksacygames.sirenheadhorrorgame',
#   'com.CoolGames.MazeGame',
#   'com.budgestudios.googleplay.ThomasAndFriendsMagicalTracks',
#   'com.iron.flying.man.rope.hero.vegas.crime.simulator.gta',
#   'com.grand.theft.cheat.codes.five',
#   'com.haiku.adventure.escape.game.mystery.stories',
#   'com.bikesstunt.motomaster.racing.game.trial.trick.bikeRacing',
#   'com.secg.robocraft',
#   'com.wild.animals.transport.simulator',
#   'games.dali.adventure.point.click.lucid.dream.witch.planet.riddle',
#   'com.mastercraft.minecrafting',
#   'com.colto.cknrunner',
#   'com.KidsGames.SuperHippo',
#   'com.fgz.us.police.eagle.robot.transform.flying.bike.game',
#   'games.fatlion.crafting.building.mine.theme.park.games.roller.coaster.tycoon.boys.girls.exploration.lite.roblox.zoo.water',
#   'com.budgestudios.TransformersRescueBotsHeroAdventures',
#   'vegas.craftvegas2.adventuregame2020',
#   'com.superbinogo.jungleboyadventure2',
#   'com.armorgames.sodadungeon2',
#   'com.heliogames.westland',
#   'com.gunshooting.counterstrike.fps',
#   'com.us.army.humvee.jeep.car.transporter.parking.game',
#   'com.survivalcrafting.airport.city.pilot.plane.craft.fly.simulator.flight.air.traffic.control.airline.commander.building.flying',
#   'com.blackpanther.ninjaarashi',
#   'com.RbwInteractive.fortyfourCats',
#   'com.cgs.us.flying.police.robot.speed.hero.crime.city.hero.games',
#   'com.myappz.firegirlWaterboy',
#   'com.runefall.match3.puzzle.adventure.gp',
#   'com.netease.lztgglobal',
#   'com.door.glass.bottle.shooter.expert',
#   'com.nordcurrent.murderinalps',
#   'com.amazing.spider.rope.hero.ninja.gangster.crimecity',
#   'com.aldagames.craftingdead',
#   'com.pacific.wildlands',
#   'com.backstreet.police.panda.robot.transform.robotwar',
#   'com.baldi.horror.escape.basics',
#   'com.happy.family.tiger.robot.games',
#   'com.LiliJoy.DragonLand',
#   'com.PSVStudio.HippoBabyBall',
#   'com.mustardgames.army.prison.transport',
#   'com.pocapp.castlecats',
#   'com.nianticlabs.hpwu.prod',
#   'com.secg.terracraft2',
#   'com.te.virtual.mother.family.simulator',
#   'com.happy.family.deer.robot.game',
#   'es.socialpoint.dragonland',
#   'com.PSVStudio.BirthdayParty',
#   'com.aleson.casefiveanimatronicsfnaf',
#   'com.g5e.hiddencity.android',
#   'com.miniworldblock.krafting202',
#   'com.fivebn.LL1_f2p',
#   'com.scary.siren.head.haunted.town',
#   'com.enteriosoft.extremebalancer3'],
#  ['com.and.games505.TerrariaPaid',
#   'com.pixelcurves.terlauncher',
#   'com.jds.batim',
#   'com.robotgentleman.game60seconds',
#   'com.wb.goog.legojurassicworld',
#   'com.RobotGentleman.sixtyParsecs.mobile',
#   'com.D3Go.mendel',
#   'com.kleientertainment.doNotStarvePocket',
#   'com.seven2.pawapp2',
#   'com.bscotch.crashlands',
#   'com.rockstargames.gtalcs',
#   'air.com.RustyLake.RustyLakeHotel',
#   'com.gameloft.android.ANMP.GloftICHM',
#   'com.wb.goog.lnjgo',
#   'air.com.RustyLake.RustyLakeParadise',
#   'com.AngryNeighbor',
#   'com.jds.batds',
#   'games.dali.adventure.lucid.dream.part.two',
#   'com.wb.goog.legobdc',
#   'air.com.RustyLake.WhiteDoor',
#   'air.com.RustyLake.RustyLakeRoots',
#   'com.disney.castleofillusion_goo',
#   'com.playdead.limbo.full',
#   'air.com.amanitadesign.chuchel.gp',
#   'com.younghorses.octodad',
#   'jp.co.spike_chunsoft.DR2',
#   'eu.bandainamcoent.verylittlenightmares',
#   'com.wb.goog.lbbg',
#   'com.candyrufusgames.survivalcraft2',
#   'com.wb.goog.legohp1',
#   'com.noodlecake.realmyst',
#   'com.wb.goog.legohp2',
#   'jp.co.spike_chunsoft.DR1',
#   'com.wb.goog.lego.movievideogame',
#   'com.square_enix.FFIXww.android_googleplay',
#   'com.BestFreeGames2k20.PixelcraftPixelmonandpokecraft',
#   'com.blyts.infamousmachine',
#   'edu.terc.zoombinis',
#   'com.leosfortune',
#   'com.devolver.grispaid',
#   'games.dali.adventure.lucid.dream.part.three',
#   'air.net.machinarium.Machinarium.GP',
#   'com.kleientertainment.doNotStarveShipwrecked',
#   'com.Level5.LT1RNA',
#   'com.bonusxp.fate',
#   'com.hitcents.drawastickmanepic2',
#   'com.and.games505.portal_knights',
#   'com.noodlecake.drtc',
#   'com.terribletoybox.thimbleweedparkandroid',
#   'com.creativemobile.beholder',
#   'com.KillmondayGames.LittleMisfortune',
#   'com.peppapig.goldenboots',
#   'jp.co.capcom.gyakusai6en',
#   'com.oddworld.Munch',
#   'com.hitcents.stickmanepic',
#   'com.wb.goog.llotr',
#   'com.pjmasks.superchase',
#   'com.artifexmundi.scarlettmysteries.gp.full',
#   'com.noodlecake.riven',
#   'jp.co.capcom.gyakusai5en',
#   'com.Level5.LT3RNB',
#   'com.feemodev.cat',
#   'com.bigfishgames.pbtmgoogfull',
#   'com.threeminutegames.lifeline.google',
#   'com.lonewolfgames.rescueenchanter',
#   'com.KillmondayGames.FranBowCh3',
#   'com.mojotouch.t7g',
#   'com.NightSchool.Oxenfree',
#   'amanita_design.samorost3.GP',
#   'com.pgstudio.survival.evo.pro',
#   'com.KillmondayGames.FranBowCh1',
#   'com.etterstudio.pnp',
#   'com.KillmondayGames.FranBowCh2',
#   'co.uk.wixgames.ducklifebattle',
#   'com.firemaplegames.returntogrislymanor',
#   'com.Level5.LT2RNA',
#   'jp.co.capcom.kenji1en',
#   'air.com.amanitadesign.botanicula',
#   'com.lonewolfgames.blackthorncastle',
#   'com.and.games505.brothers',
#   'com.happyvolcano.games.thealmostgone',
#   'com.explorationbase.Exploration',
#   'com.dotemu.ys1x',
#   'com.artifexmundi.queensquest2.gp.full',
#   'ru.buka.dville01',
#   'com.sharpen.storm',
#   'com.KillmondayGames.FranBowCh4',
#   'com.Pixelatto.Reventure',
#   'com.foxandsheep.Dinotrux2',
#   'com.noodlecake.suzycube',
#   'com.pgstudio.survivalpro',
#   'com.Tasharen.Windward',
#   'com.antlerinteractive.KrystopiaNovasJourney',
#   'air.com.noodlecake.luminocity',
#   'com.bbg.tiwdroid',
#   'jp.co.capcom.gyakusai4en',
#   'com.econo.gcemulator',
#   'com.specialbit.dreams.android.full',
#   'com.fivebn.daf4.full',
#   'com.psychoseinteractive.forgottenmemories',
#   'com.rawfury.longhathouse.Dandara',
#   'com.dotemu.sanitarium',
#   'com.ProjectTheGalaxy',
#   'com.bigfishgames.mcrugoogfull',
#   'com.eg.antarctica88pro',
#   'com.fgrfg.grgw',
#   'com.glitchgames.theForgottenRoom',
#   'com.lonewolfgames.losttreasure',
#   'com.gtafrogstresstfighter.frogamazinggangster.thefrogsimulator20',
#   'com.pgstudio.siepro',
#   'com.artifexmundi.grimlegends2.gp.full',
#   'com.KillmondayGames.FranBowCh5',
#   'com.KickBack.LostEchoAdventure',
#   'com.MrSamBarlow.HerStoryGame',
#   'com.chorusworldwide.bertramep1',
#   'com.artifexmundi.ghostfiles2.gp.full',
#   'com.threeminutegames.lifeline2.goog',
#   'com.Level5.LaytonMJNA',
#   'net.fmstudio.forgottenhilldisillusion',
#   'com.ludosity.ittledew',
#   'com.studiopango.pangopirate',
#   'com.TenderClaws.VVR',
#   'co.uk.wixgames.ducklifeadventure',
#   'com.glitchgames.allthatremains.part1',
#   'com.artifexmundi.grimlegends.gp.full',
#   'com.cm.whipseey',
#   'com.dynamiczero.survivingtitan',
#   'com.divmob.epicheroeswar.en.freemium',
#   'com.rawfury.woam',
#   'kr.co.sonnori.whiteday.g',
#   'com.threeminutegames.lifelinesilentnight.goog',
#   'com.tribeplay.pandafirestation',
#   'com.mediacitygames.lostfountain',
#   'com.glitchgames.veritas',
#   'com.eline.neveralonemobile',
#   'com.pointclickgames.mysteryofhauntedhollow',
#   'com.makario.vigilos',
#   'com.animationarts.secretfiles2',
#   'com.glitchgames.foreverlostepisode1sd',
#   'com.mediacitygames.alicetrapped2',
#   'de.stollenmayer.philipp.SometimesYouDie',
#   'com.LoopyMood.AntVentor',
#   'com.winterveilstudios.DISTRAINT2',
#   'com.accidentalqueens.anormallostphone',
#   'com.senspark.darkland',
#   'com.pointclickgames.lostadventure',
#   'com.defas.naruto',
#   'com.devolver.hatofulboyfriend',
#   'com.bigfishgames.mwwmgoogfull',
#   'com.bigfishgames.pdogoogfull',
#   'com.devolver.Swordsofditto',
#   'com.artifexmundi.clockwork.gp.full',
#   'com.fivebn.new_york_mysteries_hd_full',
#   'com.buffstudio.sevendays',
#   'com.artifexmundi.thesecretorder7.gp.full',
#   'com.fivebn.ll5.full',
#   'com.artifexmundi.tso8.gp.full',
#   'com.headupgames.anybodyouttheredeadcity',
#   'com.capybaragames.sworcery',
#   'com.deadmage.shadowblade.paid',
#   'com.firemaplegames.games.the_secretofgrislymanor',
#   'com.firemaplegames.Thickety_Creek',
#   'com.accidentalqueens.anotherlostphone',
#   'com.doublefine.thecave',
#   'com.artifexmundi.familymysteries1.gp.full',
#   'com.plug_in_digital.emma',
#   'com.nvidia.valvesoftware.portal',
#   'net.lonewolfgames.games.thelostship',
#   'com.StupaX.Flight',
#   'com.pixbits.junkjack',
#   'com.threeminutegames.lifelinecrisislinegoog',
#   'uk.co.revolution.bs1dc',
#   'com.MarsusProject',
#   'com.artifexmundi.vampirelegends.gp.full',
#   'com.artifexmundi.pathofsin1.gp.full',
#   'com.crescentmoongames.skyfish',
#   'com.kochmedia.secretfiles',
#   'com.threeminutegames.lifelineflatlinegoog',
#   'com.nightlightinteractive.ww',
#   'com.specialbit.angelo.deemon.full',
#   'com.bigfishgames.dmllgoogfull',
#   'com.bigfishgames.dpfsgoogfull',
#   'com.artifexmundi.thesecretorder1.gp.full',
#   'com.fivebn.nym2.full',
#   'com.threeminutegames.lifelinehalftoinfinitygoog',
#   'es.brokenrul.oldmansjourney',
#   'com.dotemu.ihnmaims',
#   'net.playables.kidsgame',
#   'com.arachnowopunk.revolution',
#   'com.fivebn.nym04.full',
#   'air.com.ohnoo.tormentum',
#   'com.mediacitygames.alicetrapped1',
#   'com.theand.OddeyePaid',
#   'com.fivebn.ll6.full',
#   'com.alawar.beholder2',
#   'com.artifexmundi.mybrotherrabbit.gp',
#   'com.artifexmundi.enigmatis3.gp.full',
#   'com.artifexmundi.tso3.gp.full',
#   'com.soladv.game',
#   'jp.co.izanagigames.deathcometrue'],
#  ['fall.race.io',
#   'com.Atinon.PassOver',
#   'com.kiloo.subwaysurf',
#   'com.fencinggame.master',
#   'com.hanna.bodyguard.expert',
#   'com.games.smashersio',
#   'com.ua.building.Lokicraft',
#   'com.freeplay.runandfight',
#   'com.Tastypill.BallSlide3D',
#   'com.igutso.killphil',
#   'com.Celltop.SpiralRoll',
#   'com.appadvisory.wtfight',
#   'com.mikhailp.logthrower',
#   'com.alien.shooter.galaxy.attack',
#   'com.sega.sonicdash',
#   'com.LightBeam.Demolish',
#   'com.azurgames.stackball',
#   'com.playgendary.creamaster',
#   'com.robtopx.geometryjumplite',
#   'com.fgol.HungrySharkEvolution',
#   'com.iposedon.bricksbreakerballs',
#   'com.dvloper.granny',
#   'com.gamestart.dodgeaction3d',
#   'com.playgendary.tanks',
#   'com.games.bottle',
#   'com.topchopgames.skyroller',
#   'com.dvloper.grannychaptertwo',
#   'com.os.airforce',
#   'io.voodoo.paper2',
#   'com.lightneer.goodslice',
#   'io.voodoo.holeio',
#   'com.timuzgames.savethefish',
#   'io.voodoo.crowdcity',
#   'com.bigdog.games.buddyfitness',
#   'com.pizza.dough',
#   'com.gamepie.airpolice',
#   'com.court.guilty',
#   'com.mindy.grap1',
#   'com.game.space.shooter2',
#   'com.ua.vikos.world',
#   'com.superstar.rollingdice.gp',
#   'com.keplerians.icescream3',
#   'com.mikhailp.perfectsnipe',
#   'com.ubisoft.hungrysharkworld',
#   'com.isl.stairrun',
#   'com.supergame.ohmycar',
#   'com.rmg.idle.tap.strong.granny',
#   'com.keplerians.icescream',
#   'com.halfbrick.fruitninjafree',
#   'com.hyper.plinko.coin',
#   'com.imangi.templerun',
#   'com.appadvisory.drawclimber',
#   'com.miniworld.mastercrafting.survivalboxbuilding20',
#   'com.colorhole.game',
#   'com.natenai.glowhockey',
#   'com.nordcurrent.canteenhd',
#   'com.rioo.runnersubway',
#   'com.riseup.game',
#   'com.namcobandaigames.pacmantournaments',
#   'com.kalipsogames.psychopathhunt',
#   'com.PepUpStudios.FallGuys3D',
#   'com.crazylabs.sausage.run',
#   'com.FDGEntertainment.redball4.gp',
#   'com.boomhits.rampcarjumping',
#   'com.halfbrick.jetpackjoyride',
#   'com.biglime.cookingmadness',
#   'com.ihari.escapetheprison',
#   'net.apex_designs.payback2',
#   'com.YsoCorp.WoodCutter',
#   'bike.hop.fall',
#   'com.sega.sonicboomandroid',
#   'com.team70.gangsterking',
#   'com.keplerians.icescreamtwo',
#   'net.mobigame.zombietsunami',
#   'com.orbitalknight.castlewreck',
#   'com.vincentb.RollyLegs',
#   'com.fungame.casual.fishing.master',
#   'com.colorswitch.switch2',
#   'com.germanicus.cmioo',
#   'io.voodoo.paper3',
#   'com.colorup.game',
#   'com.PlayMax.playergames',
#   'com.playgendary.sportmasters',
#   'com.sega.sonic2.runner',
#   'com.mix.color.paint.game',
#   'com.robtopx.geometrydashsubzero',
#   'com.orbitalknight.ridiculousfreekick',
#   'com.aldagames.zombero.bullet.hell',
#   'com.halfbrick.dantheman',
#   'com.kunpo.virus',
#   'com.feelnside.touchdownmaster',
#   'tdcgame.zombie.idle.defense',
#   'com.robtopx.geometrydashworld',
#   'com.barsstudios.crazyarrow',
#   'bcom.rrdianshiase.table',
#   'com.sandboxol.blockymods',
#   'invaders.os.galaxy.space.shooter.attack.classic',
#   'com.mediocre.smashhit',
#   'com.slash.girl.redfish',
#   'com.agent.action',
#   'com.nekki.vector',
#   'com.YsoCorp.FuryCars',
#   'com.ketchapp.knifehit',
#   'com.crazylabs.light.it.up',
#   'com.kongregate.mobile.run.google',
#   'com.kwalee.gofish1',
#   'com.gigantic.clawee',
#   'com.supersolid.snake',
#   'com.bentostudio.ballsvsblocks',
#   'com.kobgames.skaterrace',
#   'com.triwin.cash.dozer',
#   'com.superwings.jettrun',
#   'com.eg.deathpark',
#   'com.honeyponey.catjump',
#   'com.highcore.hoopstars',
#   'com.kongregate.mobile.burritobison3.google',
#   'com.deerslab.dinoTREX',
#   'com.turner.cnplay',
#   'com.lego.friends.heartlake',
#   'com.os.space.force.galaxy.alien',
#   'com.keplerians.evilnun',
#   'com.robtopx.geometrydashmeltdown',
#   'com.crazylabs.sausage.io',
#   'com.rovio.angrybirdsfriends',
#   'slingshot.building.destroy',
#   'com.JindoBlu.TwoPlayerGamesChallenge',
#   'com.cscmobi.merge.plant',
#   'com.bigframes.color_road',
#   'com.blobbyfishgames.apechase',
#   'com.sdsd.adsh',
#   'net.updategames.granny',
#   'misplayer.games.archery',
#   'com.crazylabs.coin.rush',
#   'comme.dragondrill.minigame',
#   'com.playsidestudios.monkeyropes',
#   'com.acoin.ballz.bricks.breaker',
#   'com.ketchapp.bikerush',
#   'com.mobirix.swipebrick2',
#   'com.bike.jump',
#   'com.bigfishgames.cookingcrazegooglef2p',
#   'com.sega.sonic4episode2',
#   'myandroid.fphoenix.fastspinner',
#   'com.cookingcity.chef.kitchen.craze.fever',
#   'com.custom.goescape',
#   'com.CubeCubeSports.Cubic234PlayerGames',
#   'io.voodoo.dune',
#   'com.eg.antarctica88',
#   'com.rocket.dragon.epic',
#   'com.kwalee.wantedgp',
#   'com.outfit7.talkingtomcandyrun',
#   'games.airion.townfights',
#   'com.mobirix.abmon',
#   'com.attackgalaxyshooter.galaxyspaceshooter2020',
#   'com.linkdesks.jewellegend',
#   'com.devsisters.gb',
#   'com.playgendary.polyspherecoolgame',
#   'com.nomonkeys.ballblast',
#   'com.sonypicturestelevision.qbert',
#   'com.johnemulators.johngbalite',
#   'com.spungegames.failybrakes',
#   'com.mnightt.slices',
#   'com.waterdrop.stickman.global',
#   'com.superluckycasino.hotvegas.slots.vegas.android.free',
#   'com.rocket.dragon',
#   'com.azurinteractive.humanevolution',
#   'com.martinmagni.fancade',
#   'line.color.adventure',
#   'com.jds.binr',
#   'com.dpspace.rocketsky',
#   'com.ubisoft.hungrydragon',
#   'com.coolmath_games.coolmath',
#   'bts.kpop.piano.music.tiles',
#   'com.smartstudygames.babyshark8bit.googlemarket',
#   'com.raongames.growcastle',
#   'io.voodoo.paperio',
#   'com.istomgames.engine',
#   'eu.bandainamcoent.pacman256',
#   'com.redsunpro.fallguyshexagone',
#   'com.match3blaster.DropStackBallFall',
#   'com.my.cooking.chef.kitchen.craze.fever',
#   'mini.zoo.crafting.exploration.creative.survival',
#   'com.wolvesinteractive.motortour',
#   'com.ketchapp.rider',
#   'com.ivy.winwing',
#   'com.vl.rollyhill',
#   'com.ankama.dragnboom',
#   'com.sausageflip.game',
#   'com.bigair.FBENG',
#   'com.mtsfreegames.princessrun3d',
#   'com.InkosGames.HoleIn',
#   'com.abi.move.stop.io',
#   'io.voodoo.stackjump',
#   'at.ner.lepsWorld2',
#   'com.setsnail.daddylonglegs',
#   'com.lawson.tower',
#   'com.baspin.barbershop',
#   'com.game.beerpong',
#   'com.kwalee.drawit',
#   'com.playgendary.coffeeshop3d',
#   'com.XTechStudios.snakeIO'],
#  ['com.mojang.minecraftpe',
#   'xyz.deeppipes',
#   'com.robtopx.geometryjump',
#   'com.fastemulator.gba',
#   'com.epsxe.ePSXe',
#   'com.rockstargames.gtavc',
#   'com.johnemulators.johngba',
#   'com.fastemulator.gbc',
#   'com.rockstar.maxpayne',
#   'it.dbtecno.pizzaboygbapro',
#   'com.ngmoco.pocketgod',
#   'com.halfbrick.fruitninja',
#   'com.icorewwwi.vDS',
#   'com.sega.sonic4epi',
#   'com.johnemulators.johngbc',
#   'com.retroloungelab.resetcollection',
#   'com.mtvn.SBmoviegame',
#   'com.nekki.vector.paid',
#   'com.worms3.app',
#   'com.explusalpha.NesEmu',
#   'com.NamcoNetworks.MsPacMan',
#   'com.madfingergames.SamuraiIIAll',
#   'com.snkplaymore.kof2012a',
#   'cc.peacedeath.peacedeath',
#   'com.explusalpha.MdEmu',
#   'com.flukedude.impossiblegame',
#   'com.snkplaymore.android007',
#   'com.snkplaymore.android001',
#   'com.jdroid.gtavccheater',
#   'org.mupen64plusae.v3.fzurita.pro',
#   'com.mediocre.grannysmith',
#   'net.kairosoft.android.bouken_en',
#   'com.zenstudios.MarvelPinball',
#   'com.dotemu.neogeo.mslug3',
#   'com.fms.emu',
#   'net.floatingpoint.android.arcturus',
#   'com.sonicjump.sonicjump',
#   'com.stevesnyderart.BalanceTheBeam2',
#   'com.dotemu.ddtrilogy',
#   'com.nostalgiaemulators.nesfull',
#   'com.neutronemulation.retro8',
#   'com.explusalpha.GbaEmu',
#   'com.grapefrukt.games.bore',
#   'com.crescentmoongames.swordshot',
#   'org.lukeallen.bomberfull',
#   'com.square_enix.android_googleplay.finalfantasy2',
#   'com.dotemu.neogeo.mslug',
#   'it.dbtecno.pizzaboypro',
#   'paulscode.android.mupen64plus',
#   'com.square_enix.android_googleplay.subarashikikonosekai_solo',
#   'com.herocraft.game.hyperforma.cyber.hack.arcade.premium',
#   'org.uoyabause.uranus.pro',
#   'jp.co.taito.am.spaceinvaders',
#   'com.dotemu.neogeo.samsho2',
#   'nl.palatamedia.miner',
#   'com.explusalpha.GbcEmu',
#   'com.mightykingdom.shopkinsrun',
#   'jp.co.capcom.mobilemakaiwd',
#   'com.explusalpha.NeoEmu',
#   'com.PceEmu',
#   'com.doragongames.danmakuunlimited3',
#   'com.dotemu.rtype',
#   'com.magicwach.rdefense',
#   'com.explusalpha.A2600Emu',
#   'com.dotemu.neogeo.mslug2',
#   'jp.co.capcom.mobiledaimakaiwd',
#   'com.atypicalgames.sgsr',
#   'com.zenstudios.StarWarsPinball',
#   'com.space.shooter.alien.galaxyattack',
#   'com.flukedude.impossiblegamelevelpack',
#   'com.dotemu.neogeo.mslugx',
#   'com.doragongames.danmakuunlimited2',
#   'com.playcreek.DeathWorm',
#   'com.nekki.vector2.paid',
#   'com.lojugames.android.Ordia',
#   'com.interrupt.dungeoneer',
#   'com.nostalgiaemulators.gbafull',
#   'net.kairosoft.android.ninja_en',
#   'com.noodlecake.chameleonrun',
#   'com.snkplaymore.android013',
#   'com.atypicalgames.sgsr2',
#   'es.jdbc.n64retroplus',
#   'com.craftgames.worldcrft.premium',
#   'at.nerbrothers.SuperJumpPlus',
#   'pl.idreams.jellydefense',
#   'com.DefiantDev.SkiSafari',
#   'com.alien.shooter.galaxy.attack.premium',
#   'com.apdconsultinginc.defender1',
#   'com.skyvu.battlebearszombies',
#   'com.digitalleisure.dragonslair',
#   'com.explusalpha.C64Emu',
#   'fishnoodle.canabalt',
#   'com.dvloper.slendrinacellar',
#   'jp.co.capcom.mobile1942wd',
#   'com.fluffycat.sanandreaskeyboard.full',
#   'com.turbomonad.galaxdefender',
#   'com.moose.shoppiedash',
#   'com.tinybuild.PartyHardGO',
#   'net.kairosoft.android.horse_en',
#   'net.hexage.radiant',
#   'com.snkplaymore.android012',
#   'com.os.falcon.galaxy.space.shooter.attack.vip',
#   'com.coldbeamgames.beathazardultragooglefull',
#   'com.springgames.onepunch.spring.paid',
#   'com.pixelsontoast.impossibleroad',
#   'com.muandheyo.bosonx',
#   'com.sig.PingOrPong',
#   'com.endspacevr',
#   'com.DVloper.HouseOfSlendrina',
#   'com.epicpixel.Grow',
#   'com.naquatic.guncrafterpro',
#   'com.super8bit.pro',
#   'com.squareenixmontreal.avssi',
#   'jp.co.taito.am.dariusBurstSP',
#   'com.zenstudios.PortalPinball',
#   'com.deckeleven.pmbdmarket',
#   'com.fms.mg',
#   'com.freetoolsassociation.karateka',
#   'com.digitalleisure.spaceace',
#   'com.topsecretdevelopments.games.bomberFighterPro',
#   'com.Doyodo.Moorhuhn',
#   'com.explusalpha.NgpEmu',
#   'com.fluffycat.vicecitykeyboard.full',
#   'com.angrymobgames.muffinknight',
#   'air.com.kongregate.mobile.fancypants.google',
#   'com.jyaif.pewpew2',
#   'com.Chorrus.UnbrokenSoul',
#   'com.mumbojumbo.wonders4',
#   'com.romansixvigaming.rainbowdash',
#   'com.crescentmoongames.monkeyboxing',
#   'com.deceasedpixel.megaworm',
#   'com.dotemu.neogeo.blazstar',
#   'com.SmartBomb.AJJump',
#   'com.noodlecake.bugbutcher',
#   'com.onemanleft.tilttolive2',
#   'com.nostalgiaemulators.ggfull',
#   'air.Anodyne.mobile',
#   'com.valorware.ninthdawn',
#   'com.TeamCoil.PUSS',
#   'abyxentertainment.brick_breaker_classic_plus',
#   'com.mangobile.kingturn',
#   'com.ZephirothGames.AsteroidStorm',
#   'jp.co.capcom.mobileikusawd',
#   'com.qeorge.fumpop',
#   'com.Patitoyazilim.TowerBuild',
#   'com.microids.google.bcnorthvssouth',
#   'com.mediocre.dirac',
#   'com.dotemu.rtype2',
#   'com.TripleTopping.TTSpitkiss'],
#  ['com.pixel.art.coloring.color.number',
#   'com.tilemaster.puzzle.block.match',
#   'link.merge.puzzle.onnect.number',
#   'paint.by.number.pixel.art.coloring.drawing.puzzle',
#   'com.artlife.coloringbook',
#   'bp.free.puzzle.game.mahjong.onet',
#   'com.gamebility.onet',
#   'com.scopely.yux',
#   'air.com.buffalo_studios.newflashbingo',
#   'com.huuuge.domino',
#   'com.clipwiregames.bingostory',
#   'com.llx.chess',
#   'com.jetstartgames.chess',
#   'com.appcraft.number.puzzle',
#   'onext.boombox',
#   'com.free.drawing.coloring.book.paint.by.number',
#   'com.yalla.yallagames',
#   'solitaire.card.games.klondike.solitaire.classic.free',
#   'com.two31play.mahjongcity',
#   'paintist.pixel.art.color.paint.by.number.coloring.paint.drawing.book',
#   'com.LoopGames.Domino',
#   'com.dimcoms.checkers',
#   'com.pixel.art.coloring.by.number',
#   'com.ludo.king',
#   'com.coloring.lwapps',
#   'com.kiaora.dominoes',
#   'uk.co.aifactory.chessfree',
#   'loppipoppi.dominoes',
#   'com.superluckycasino.epicjackpot.slots.vegas.android.free',
#   'com.pixel.art.happy.color.by.number.paint.coloring.free',
#   'com.starsprite.tilecraft',
#   'com.qybteck.color.by.number.paint',
#   'com.chess',
#   'com.crossfield.bingotreasure',
#   'com.sngict.bingo',
#   'com.hasbro.riskbigscreen',
#   'com.mobilegame.dominoes',
#   'com.playcus.crossstitchcoloringbook',
#   'com.gdv.uno',
#   'air.com.spicerackmedia.bingoshowdown',
#   'com.superking.parchisi.star',
#   'com.mochess.online',
#   'air.com.bitrhymes.bingo',
#   'com.kristanix.android.mahjongsolitairetitan',
#   'onnect.connect.pair.matching.line.puzzle.match3d.tilemaster',
#   'pl.lukok.draughts',
#   'com.bingo.tour.party.crazy.free',
#   'athena.studio.woody.sudoku.block.puzzle.brain.training.mind.games.free.happy.offline',
#   'thinkcube.project312',
#   'com.superluckycasino.viponly.slots.vegas.android.free',
#   'com.twelvegigs.heaven.bingo',
#   'com.abradoodle.bingo',
#   'lu.zvasoft.lotto.free',
#   'com.fungamesforfree.colorfy',
#   'com.sng.yatzy',
#   'com.moonfrog.ludo.club',
#   'de.smuttlewerk.fleetbattle',
#   'com.pcoloring.art.puzzle.color.by.number',
#   'com.withbuddies.dice.free',
#   'com.dg.puzzlebrothers.mahjong.solitaire.holiday.fun',
#   'com.fiogonia.dominoes',
#   'com.dg.puzzlebrothers.mahjong.mysterymansion',
#   'com.blackout.match3d',
#   'com.TikGames.DominoMaster',
#   'loppipoppi.yatzy',
#   'com.flyclops.domino.android',
#   'com.xten.starfall',
#   'air.com.beachbumgammon',
#   'ru.skillcap.dominoes',
#   'com.LoopGames.Yatzy',
#   'com.agedstudio.board.game.dominoes',
#   'com.europosit.polygon2d.coloringpuzzle',
#   'paint.by.number.relax.pixel.art.drawing.book.free',
#   'com.mintgames.pocket.color.world.paintnumber.games3d',
#   'com.chess.chesscoach',
#   'mahjong.solitaire.games.puzzle.mahjong.classic.free',
#   'com.rummikubfree',
#   'com.gameberry.ludo.star2',
#   'com.noodlecake.reallybadchess',
#   'com.lemongame.matchtwo.mahjong',
#   'dev.marosi.gregbox',
#   'uk.co.aifactory.backgammonfree',
#   'com.tictactoe.wintrino',
#   'net.skillcap.farkle',
#   'com.dg.puzzlebrothers.mahjong.holiday.magic.christmas',
#   'com.chef.ollect',
#   'com.playcus.bingostar',
#   'org.lichess.mobileapp',
#   'com.ahoygames.backgammon',
#   'com.hagstrom.henrik.chess',
#   'fr.apprize.actionouverite.enfants',
#   'com.usm.catanuniverse',
#   'air.bg.lan.Monopoli',
#   'com.quge.bingopowerball',
#   'com.dg.turbonuke.my.bingo.life',
#   'com.blacklightsw.ludo',
#   'com.alignit.fourinarow',
#   'io.yarsa.games.ludo',
#   'com.sngict.dominoes',
#   'com.idz.snakes.and.ladders.dice.board.games',
#   'com.blackcircleapps.tropicalbingo',
#   'pl.lukok.chess',
#   'com.qhost.aceanddice_domino',
#   'com.pixel.coloring.color.by.number',
#   'com.gbgames.mahjongunlimited',
#   'air.com.jogatina.domino.android',
#   'air.br.com.domino.mobile',
#   'com.koga.domino',
#   'com.blackcircleapps.halloweenbingo',
#   'com.wixot.bingo',
#   'com.one1line.onetouch.onestroke.dotgame',
#   'org.softmotion.fpack.lite',
#   'com.zynga.chess.googleplay',
#   'com.Offs.Games.The.Clue.Do.Crime.Detective.Investigation.Solve.and.Discover.Mystery.Criminal.Cases',
#   'com.games.lucky.dice.win.bonus.big.master.prize.rewards.free',
#   'com.dg.turbonuke.tradbingo.elvenwoods',
#   'com.hama.universe',
#   'com.renatus.hittheboard',
#   'com.playcus.findthedifferences2',
#   'com.dg.turbonuke.rainbowbingoadventure',
#   'com.magic.paint.pixel.art.color.by.number',
#   'com.dunjegame.andrecastany.fourinarow',
#   'com.rottzgames.logic',
#   'com.kristanix.android.mahjongsolitaireepic',
#   'com.UmiringoStudio.FunColor',
#   'com.quarzo.fourinarow',
#   'uk.co.aifactory.gofree',
#   'com.rottzgames.findobject',
#   'air.com.playcus.bingocountryboys',
#   'com.mobirix.connectfour',
#   'com.mobirix.SnakeGame',
#   'com.humblelogicgames.tilematch',
#   'com.Alienforcegames.ChessFusionFree',
#   'au.com.imagination.familyfeudbuzzerus.full',
#   'com.superluckycasino.fortunespin.slots.vegas.android.free',
#   'com.turbolabz.instantchess.android.googleplay',
#   'com.blackcircleapps.wonderlandbingo',
#   'com.blackout.connect',
#   'com.northstargames.evolutiongame',
#   'com.platsera.freebingoworld',
#   'company.greenergrass.goldenroll',
#   'com.Offs.WhoIAm',
#   'com.maysalward.Dominoes',
#   'com.yoozoogames.ludogameallstar',
#   'com.dg.puzzlebrothers.mahjong.solitaire.grand.autumn.harvest',
#   'com.njbee.candy.sort.m',
#   'com.IguazuGames.Mahjong',
#   'com.emflag.mahjongmaster',
#   'com.sngict.backgammon',
#   'solitaire.arcadegames.freecard.solitaireplus.epic.klodike',
#   'com.daygames.five.seconds',
#   'air.com.come2play.backgammon',
#   'com.dg.puzzlebrothers.mahjong.king',
#   'com.oneup.treasure.map.mahjongg',
#   'com.bss.game.DicastRoc',
#   'com.dg.puzzlebrothers.mahjong.halloween',
#   'air.com.playcus.free.bingo.games.casino.slots.country.days.game',
#   'com.ruby.coloring.pages.art.games.anime.manga',
#   'com.bigwinlab.bingolegends',
#   'lu.zvasoft.lotto.free.bbc',
#   'com.ludo.master.hippo',
#   'lu.zvasoft.lotto.free.emo',
#   'glowingeye.mexican_train_dominoes_gold',
#   'com.blackzen.BingoMania',
#   'com.PPGame.Onnect',
#   'sg.bigo.ludolegend',
#   'com.seavus.yatzyultimate.droid',
#   'com.ignacemaes.fourinarow',
#   'us.digitalsmoke.yatzymaster',
#   'com.game.roleplaying18',
#   'com.alpg.bingo',
#   'com.joycity.god',
#   'com.optimesoftware.checkers.free',
#   'com.crossfield.shogi',
#   'com.alignit.sixteenbead',
#   'com.dg.turbonuke.bingo.quest.crazy.candy.kingdom',
#   'com.dg.turbonuke.bingo.quest.summer.garden',
#   'com.kingsofgames.chessuniverse',
#   'com.tellmewow.senior.dominoes',
#   'air.com.ievogames.superbingo',
#   'com.foxelpix.crossstitchclub',
#   'com.ludo.multiplayer',
#   'com.litegames.farkle',
#   'com.alpg.yatzy',
#   'board.tictactoe.glow.puzzle.lite',
#   'com.bestlis.farkle',
#   'com.blacklight.carrom.multiplayer',
#   'com.modiphius.fallout.wastelandwarfare',
#   'net.ninjagames.clash',
#   'com.tilecraft.matchgame',
#   'air.com.playcus.bingocountryways',
#   'com.tellmewow.senior.battleship',
#   'com.lein.pppoker.android',
#   'com.winrgames.doubledouble',
#   'com.bingo.games.online.offline.free.slots.lotto.keno.casino.adventure',
#   'com.bumblebox.coloring.animeboys',
#   'com.tig.oil.painting',
#   'com.kemigogames.chesscoach',
#   'com.haptic.chesstime'],
#  ['com.marmalade.monopoly',
#   'com.marmalade.gol2',
#   'com.marmalade.cluedogame',
#   'com.marmalade.golmobile',
#   'com.marmalade.golv',
#   'com.daysofwonder.tt.android',
#   'uk.co.aifactory.chess',
#   'com.handelabra.OneDeckDungeon',
#   'com.playdekgames.waterdeep',
#   'com.exozet.android.catan',
#   'com.asmodeedigital.carcassonne',
#   'number.link',
#   'com.marmalade.battleship',
#   'com.asmodeedigital.terraformingmars',
#   'com.daysofwonder.Splendor.gp',
#   'com.StudioGoya.MiracleSudokuCTC',
#   'com.templegatesgames.RollAndroid',
#   'uk.co.aifactory.backgammon',
#   'com.nomadgames.talisman',
#   'com.handelabra.AeonsEnd',
#   'de.brettspielwelt.cartographers',
#   'com.StudioGoya.ClassicSudoku',
#   'com.StudioGoya.ChessSudoku',
#   'uk.co.aifactory.go',
#   'com.asmodeedigital.mysterium',
#   'com.fantasyflightgames.ESAndroid',
#   'com.direwolfdigital.sagrada',
#   'com.asmodeedigital.millebornes',
#   'com.daysofwonder.smallworld2',
#   'com.f2zentertainment.pandemic',
#   'techmasterplus.sudokupuzzlepro',
#   'net.gowrite',
#   'com.czechgames.tta',
#   'com.funforgedigital.tokaido',
#   'com.czechgames.galaxytrucker',
#   'com.StudioGoya.ThermoSudoku',
#   'com.steelcrategames.keeptalkingandnobodyexplodes',
#   'com.youdagames.stratego',
#   'com.beadapps.chessrepertoiretrainer.paid',
#   'com.templegatesgames.RaceAndroid',
#   'com.kemigogames.chesscoachpro',
#   'com.StudioGoya.SandwichSudoku',
#   'com.horriblegames.similo',
#   'com.acram.Charterstone',
#   'com.asmodeedigital.potionexplosion',
#   'de.brettspielwelt.ganzschoenclever',
#   'com.digidiced.vxcrelease',
#   'com.playdekgames.twilightstruggle',
#   'com.nextchessmove',
#   'com.digidiced.txmrelease',
#   'com.direwolfdigital.raiders',
#   'com.digidiced.ixsrelease',
#   'uk.co.aifactory.checkers',
#   'com.mobilecastles.castles',
#   'com.nomadgames.loveletterdev',
#   'com.asmodeedigital.takenoko',
#   'com.SandersApps.Moanopoly',
#   'com.hiddenachievement.dfco',
#   'com.direwolfdigital.lanterns',
#   'com.meepletouch.jaipur',
#   'uk.co.aifactory.rr',
#   'com.handelabra.Sentinels',
#   'com.Roxley.SantoriniGame',
#   'se.sweetstone.yatzy',
#   'com.chessgenius.android.chess',
#   'com.gmail.codesbyjandt.Bingo75App',
#   'com.ayelmarc.chessormpro',
#   'pl.portalgames.isrw',
#   'com.pereira.analysis.paid',
#   'jp.co.unbalance.IgoKouza01',
#   'com.PeterKossits.FootballHighlights',
#   'pl.portalgames.convoy',
#   'de.brettspielwelt.coffee_roaster',
#   'com.randomsaladgames.simpledominoes',
#   'com.digidiced.sxprelease',
#   'uk.co.aifactory.sudoku',
#   'mallusofts.blockpuzzleclassic',
#   'com.blacklistgamesllc.StreetMasters.pro',
#   'com.digidiced.bvbrelease',
#   'jp.co.unbalance.android.gocsdl',
#   'com.boardgametables.ontour',
#   'com.komodochess.komodo13',
#   'chessbase.android.chessdb',
#   'com.asmodeedigital.perudoofficial',
#   'com.windowsgames.conquest',
#   'com.Thunderbox.Tsuro',
#   'com.suburbiagame.suburbia',
#   'com.asmodeedigital.coltexpress',
#   'com.youdagames.strategomp.premium',
#   'com.cublo.brass',
#   'com.amuseware.mexicantrain',
#   'de.brettspielwelt.doppeltsoclever',
#   'com.usm.andorsecret',
#   'de.brettspielwelt.freitag',
#   'com.digidiced.cxgrelease',
#   'com.nomadgames.talismanchronicles',
#   'com.PeterKossits.BBall2045',
#   'com.gokgs.client.android',
#   'com.digidiced.insrelease'],
#  ['net.solitaireff.tripeaks',
#   'net.supertreat.solitaire',
#   'com.smilerlee.klondike',
#   'com.gsn.android.tripeaks',
#   'com.cardgame.solitaire.fishdom',
#   'com.mattel163.phase10',
#   'com.playtika.wsop.gp',
#   'com.fiogonia.spades',
#   'com.solitaire.klondike.patience.ocean.aquarium',
#   'beetles.puzzle.solitaire',
#   'com.solitaire.card',
#   'com.bbumgames.spadesroyale',
#   'com.tripledot.blackjack',
#   'net.peakgames.mobile.spades.android',
#   'com.mobilityware.solitaire',
#   'com.matteljv.uno',
#   'com.me2zen.tripeaks.v4.and',
#   'com.mobilityware.spider',
#   'com.bigc.solitaire.spider',
#   'com.agedstudio.card.solitaire.klondike',
#   'com.forevernine.texaspoker.android',
#   'com.freegame.solitaire.basic2',
#   'com.tripledot.solitaire',
#   'com.reachjunction.card.game.solitaire',
#   'com.solitaire.real',
# ...
#   'com.db.tabletrenches.release',
#   'age.of.civilizations.americas.lukasz.jakowski',
#   'com.ariton.spacewardho',
#   'ru.gamedevteam.mechcom2',
#   'com.tsomogyi.gc',
#   'com.gyorgyszucs.colonizerul',
#   'com.asmodeedigital.zombicidev2',
#   'air.com.flipline.papaspancakeriahd',
#   'com.tresebrothers.games.factionwarselite',
#   'air.air.ExpansePremium',
#   'com.pageboy.oraiah',
#   'com.BaronnerieGames.ElectromazeDefense',
#   'com.perchang.wq',
#   'com.MikaMobile.LostFrontier',
#   'com.jusckeux.frontarmies',
#   'com.birdshel.Uciana',
#   'com.windowsgames.slay',
#   'com.jollypixel.saratoga.android',
#   'com.easytech.wc1',
#   'com.hexwar.twilightslastgleaming',
#   'com.hg.rebelcops',
#   'com.homemadegames.frontwars',
#   'com.sgg.archipelago_kr',
#   'smpxg.mythdefdf_pt',
#   'age.of.civilizations.asia.jakowski',
#   'net.kairosoft.android.noujou_en',
#   'smpxg.mythdefense',
#   'air.com.mediadivision.sparkchessphone',
#   'air.com.flipline.papaswingeriahd',
#   'com.cloudworth.patwar',
#   'air.com.clarusvictoria.preciv.ba',
#   'com.blueplop.StarColoniesFull',
#   'air.com.clarusvictoria.preciv.ma',
#   'com.amtgames.ewtd2',
#   'com.hexwar.acwgettysburg',
#   'com.tropicalstormfront.android.full',
#   'com.pokulan.aliveinshelteradult',
#   'com.sidelesscubestudios.lazysweettycoon',
#   'com.hg.burningbridges',
#   'com.Lilith.Abi',
#   'ru.gamedevteam.wz',
#   'com.HighlandStudio.HeroesOfFlatlandia1',
#   'com.Origin8.Sentinel4'],
#  ['com.unicostudio.whois',
#   'com.trivia.star.android',
#   'com.unicostudio.braintest',
#   'com.unicostudio.braintest2new',
#   'tr.com.apps.trivia.race',
#   'com.wangcheng.logo',
#   'com.etermax.preguntados.trivia.cars',
#   'com.sonypicturestelevision.millionaire',
#   'app.free.lucky.quiz.us',
#   'com.etermax.trivia.preguntados2',
#   'com.submarineapps.mill',
#   'com.red.answer.hw',
#   'com.etermax.preguntados.lite',
#   'com.umi.feudlive',
#   'com.xmonetize.quizzland',
#   'start.boss',
#   'com.eightsec.TriviaIO',
#   'com.magmic.android.ScattergoriesBlitz',
#   'com.nixgames.truthordare',
#   'com.tozzmedia.trickme',
#   'com.aquaman.braincrack',
#   'com.crestvisuals.gp.dirtyriddles',
#   'com.sonypicturestelevision.jeopardy2',
#   'com.msi.logogame',
#   'com.angry.granny.simulator.fight',
#   'com.hiride.social',
#   'battle.royalechapter2quiz',
#   'com.relaxingbraintraining.triviamillion',
#   'word.riddles.guess.brain.test.tricky.puzzle.quiz.game.free',
#   'com.cookie.swirl.tikentdev',
#   'lemmingsatwork.quiz',
#   'quess.song.music.pop.quiz',
#   'com.grandmas.cookie.swirl.love.erikadev',
#   'com.YsoCorp.ThisOrThat',
#   'com.wb.goog.ellen.gameofgames',
#   'com.theangrykraken.trivial',
#   'com.niceteen.games.dtbam',
#   'com.onehundredpics.onehundredpicsquiz',
#   'com.dreamlabentertainment.wouldyourather',
#   'com.oyeapps.logotestworld2',
#   'com.taplane.logoquizm',
#   'com.timleg.quiz',
#   'com.magmic.android.squash',
#   'com.taplane.triviaquizm',
#   'aasuited.net.word',
#   'com.reddream.game.trickybrain',
#   'com.age.usa.appspot',
#   'fr.two4tea.fightlist',
#   'yesorno.sb.org.yesorno',
#   'com.intermedia.hq',
#   'minicraft.eers.kraft.eerskraft.crafting.building.games',
#   'com.escapefun.the100roomiv',
#   'com.quizup.core',
#   'dh3games.wouldyourather',
#   'com.us.wouldyourather.game',
#   'logo.quiz.guess.movie',
#   'com.HeyNau.MegaQuizGaming',
#   'dh3games.doeshelikeme',
#   'com.imagzle',
#   'com.danpanichev.kissmarrykillnext',
#   'com.feelinggame.pluckit',
#   'com.internetdesignzone.triviaquizzes',
#   'com.maxcraft.big.max.craft.city.prime.builder.aadia',
#   'macrostudios.howwelldoyouknowme',
#   'co.palang.QuizOfKingss',
#   'games.teatime.trivia',
#   'com.daygames.kob.would.you.rather',
#   'com.age.wgg.appspot',
#   'com.gmail.troylyndon.PlayTrivia',
#   'io.gartic.Gartic',
#   'macrostudios.guessmynickname',
#   'marcostudios.yesorno',
#   'com.creactive.quemquersermilionario.millonario.lite',
#   'com.playstation.knowledge',
#   'com.happeningnow.blebrity',
#   'smartowlapps.com.quiz360',
#   'com.lotum.quizplanet',
#   'com.diacoipj.picopool',
#   'com.works.timeglass.logoquiz',
#   'com.us.wouldyourather.trivia.quiz',
#   'us.christiangames.bibletrivia',
#   'com.cookie.swirl.candy.land.obby',
#   'com.volley.voicecompanion.songquiz',
#   'app.game.flashcraft.exploration',
#   'com.gmail.ramosmarbella.squizme',
#   'bubbleshooter.classic',
#   'logos.quiz.companies.game',
#   'jail.escape.robux.jailbreak.studio',
#   'us.christiangames.trueorfalse',
#   'com.maestro.craftingbuilding',
#   'com.tellmewow.senior.wheel.fortune',
#   'com.asmolgam.states',
#   'com.freevbx.quiztruefalse',
#   'com.cadev.presstheluck',
#   'com.edujoy.skills',
#   'com.orangenose.trick',
#   'com.danpanichev.topanimecharacters',
#   'com.niceteen.games.milliondeal',
#   'com.tymedia.us.KnowItOrBlowIt',
#   'nuea.apps.hexws',
#   'com.qbis.guessthecountry',
#   'eerskraft.crafting.pro.building.games.exploration.lite.rojo',
#   'com.ninetyfour.degrees.app',
#   'com.yunbu.brain.boom',
#   'com.prodege.swagiq',
#   'com.goldrushgames.triviatiles',
#   'com.goxal.eighties',
#   'free.robux.master.freerobuxmaster',
#   'com.halloween.h23',
#   'com.knowledgequizgames.justriddles',
#   'pl.swiatquizu.disneyquiz.android',
#   'com.trivia.quizfordescendants.trixtengames',
#   'com.taplane.emojisquiz',
#   'com.cashquizz.cashquizz',
#   'com.openmygame.games.android.pics',
#   'com.educ8s.triviaquiz2015',
#   'com.champapps.gtp',
#   'com.asmolgam.flags',
#   'io.edia.quizfortnite',
#   'com.vns.three.quiz.logo.quiz.flag.quiz.capital.quiz',
#   'com.bogaziciapps.mapgameus',
#   'com.junkers.hellopiggyscarychapter',
#   'boyansoft.bogmix.millionaire',
#   'com.cadev.primaria',
#   'com.PlayShow.tv',
#   'foodquiz.guessthefood',
#   'com.scimob.ninetyfour.percent',
#   'com.topquizgames.triviaquiz',
#   'nineties.quiz.pub.trivia.questions.games',
#   'com.ncm.noovietrivia',
#   'com.gsn.chasefree',
#   'com.taplane.fourpics',
#   'com.taplane.iconquizm',
#   'com.finjanapps.syla',
#   'com.nixgames.neverdid',
#   'braintest.iq.quiz.brain.out.mind.challenge.pass.tricky.puzzles',
#   'com.peoresnada.mental',
#   'com.quickcandy.guesstheyoutuber',
#   'com.SKORBcorporation.JournalsGFAndroid',
#   'macrostudios.whichanimalareyou',
#   'com.taplane.logoquiz',
#   'com.blockpuzzle.brick2020',
#   'com.k128ailmatwasla.alghazmota9ati3a',
#   'com.msi.icongame',
#   'dh3games.stupidtest',
#   'live.brainbattle',
#   'com.taplane.twopics',
#   'com.yourmillionaire.befristmillionaire',
#   'com.free.craft.craftlegend.legend.crafting.android.building.games',
#   'net.wouldyouratherapp.wouldyourather',
#   'app.playandwinapp.com',
#   'com.asmolgam.dogs',
#   'com.mtapps.quiz.flags_off_the_world_quiz',
#   'com.playstation.kipdecades',
#   'borralloespinarrafael.wouldyouratherharrypotter',
#   'com.biblia.aprende.ingles',
#   'com.app3arabi.trueorfalsev1',
#   'com.pch.ilab.wincredible',
#   'uk.co.huntthegoose.app',
#   'battle.royalechapter2qseason13',
#   'com.appigeon.guessairbenderelement',
#   'com.knowledgequizgames.guessthesong',
#   'com.qbisstudio.usaquiz',
#   'com.sporcle.party',
#   'skribbl.io.drawing.game',
#   'wouldyouratherkids.com.would_you_rather_kids',
#   'com.givling.givling',
#   'com.snakezone.wormbatle.cusdux',
#   'com.etermax.kingdoms',
#   'com.amientertainment.TapTVController',
#   'air.com.superbook.bible.trivia.quiz.game.android.app',
#   'com.dmvcompany.guessthefortniteskin',
#   'com.aelahhd.guessmyheroacademia',
#   'com.guess.games.bts.song.quiz',
#   'com.luckytrivialive',
#   'com.smart.brain.riddles',
#   'com.sopelus.elements',
#   'com.goxal.restaurant',
#   'com.xmonetize.quizzclub',
#   'com.creephustlin.creepypastaghicestepersonaj',
#   'com.buzztime.entertainment',
#   'com.animoca.google.starGirlHalloween14',
#   'com.bedrill.quiz.flags.capitals',
#   'borralloespinarrafael.kissmarrycrucio',
#   'com.taplane.foodquizm',
#   'com.hiicerod.neighboor',
#   'com.free.cp.bundle.freecp.cpquizforcod',
#   'com.codecomputerlove.higherlowergame',
#   'com.goodquizzes.guessthecharacterquiz',
#   'com.bestgame.theimpossiblequiznew',
#   'com.saklanistudio.quiz2020forpubgmobile',
#   'block.puzzle.jewel.gem2020',
#   'com.ilab.VforVoodoo',
#   'com.TailOfTales.AnimeIn10Words',
#   'com.taplane.logoquiz2',
#   'air.me.kupina.EnBuscaDeJesus',
#   'com.onemillionairetrivia.weakestlink',
#   'pt.wm.trivialworld',
#   'com.goxal.logos'],
#  ['com.etermax.preguntados.pro',
#   'com.newgeogamerni',
#   'com.sporcle',
#   'com.jackboxgames.TJPP3Loader',
#   'com.jackboxgames.JBPP2Loader',
#   'com.jackboxgames.JackboxPartyLoaderFull',
#   'com.timleg.quizPro',
#   'com.jackboxgames.TJPP5Loader',
#   'com.loadupgames.musictriviachallenge',
#   'coolcherrytrees.games.reactor4',
#   'com.jackboxgames.TJPP4Loader',
#   'com.puzzlenation.JumboCrosswords1',
#   'com.popsmarttriviarnapp'],
#  ['com.platinumplayer.word.addict',
#   'com.braindom',
#   'com.peoplefun.wordcross',
#   'com.dreamstudio.word.connect',
#   'com.pieyel.scrabble',
#   'com.chippymediallc.word.nut.android',
#   'com.mobilegame.wordsearch',
#   'com.scopely.wheeloffortune',
#   'com.fanatee.noodles',
#   'es.socialpoint.wordlife',
#   'com.peoplefun.wordsearch',
#   'com.zynga.words3',
#   'com.wordgame.words.connect',
#   'com.bitmango.go.wordcookies',
#   'in.crossy.daily_crossword',
#   'com.tangramgames.gourddoll.wordcrush',
#   'se.maginteractive.wordzee',
#   'com.wordgame.newcross.android.en',
#   'com.peoplefun.wordstacks',
#   'com.blackout.word',
#   'in.playsimple.wordtrip',
#   'com.apprope.wordmansion',
#   'in.playsimple.tripcross',
#   'com.wb.headsup',
#   'com.word.wordy.wordscape.wordrelax',
#   'com.thrivegames.wordshapes',
#   'com.histudiogames.wordserenityg',
#   'app.kryds.android',
#   'com.bettagames.wordbuddies',
#   'com.gsr.wordcross',
#   'com.fanatee.cody',
#   'com.word.smash.wordstacks.crossword',
#   'word.game.wordscapes.wordconnect',
#   'mobi.redstonegames.crossword.en',
#   'com.crossword.free.relax',
#   'tv.yaqua.WordsOut',
#   'com.fugo.wowsearch',
#   'com.oakgames.wordgame',
#   'com.bruyere.android.wordsearch',
#   'com.townsend.puzzlescapes',
#   'com.zynga.words',
#   'com.word.forest.android',
#   'com.evilapples.app',
#   'com.easybrain.word.search',
#   'com.kooapps.pictowordandroid',
#   'bible.wordgame.words.connect.crossword.cookies',
#   'com.qiiwi.wordington',
#   'com.matchasaucellc.word.search.android',
#   'word.search.wordsearch',
#   'com.great10games.word.link',
#   'com.wb.goog.ellen.psych',
#   'com.fatchicken007.headsupcharades2',
#   'word.games.puzzle.four.pics.one.word.cookies.free',
#   'com.dreamstudio.word.travel.scapes',
#   'com.timeplusq.drawnguess',
#   'com.littleengine.wordpal',
#   'com.wordgame.puzzle.block.crush.pic.en',
#   'com.wizard.word.puzzle.games.scapes.fun',
#   'com.oneup.word.search',
#   'com.TinyBit.GameOfWords',
#   'com.randomlogicgames.wordsearch',
#   'com.iscoolentertainment.snc',
#   'com.word.fire.android',
#   'in.crossword.wordplanet',
#   'com.rolling.crossword.puzzle.game',
#   'com.word.game.fun.puzzle.prison.escape.captain',
#   'in.daily_puzzle.crossword',
#   'com.immortaltaoists.en',
#   'com.fingerlab.block.wordgame',
#   'com.puzzle1studio.go.wordsearchinspiration',
#   'in.WordSearch.WordBliss',
#   'com.thrivegames.mysteryword',
#   'bible.wordgame.words.puzzle.swipeword.collect.verses.an',
#   'com.omgpop.dstfree',
#   'com.lotum.wordblitz',
#   'com.lulo.scrabble.classicwords',
#   'com.relaxingbraintraining.wordcup',
#   'com.zl.wordgame.wordsweeper',
#   'com.iscoolentertainment.wl',
#   'com.wordgame.cross.android.en',
#   'com.crossword.bible.cookies.find.english',
#   'com.kangwang.word',
#   'com.zynga.wwf2.free',
#   'com.cookapps.wordlife',
#   'com.wordfarm.scapes',
#   'com.winrgames.wordswordswords',
#   'com.rlg.guesstheemoji',
#   'com.sleepingbeastgames.spaceteam',
#   'com.happydream.wordsearch',
#   'com.wingjoy.dynastyLife.inter',
#   'com.zytoona.wordscrush',
#   'com.word.picnic.fun.crossword.puzzle',
#   'com.fanatee.stop',
#   'com.lovetoknow.wordfinder',
#   'com.fotoable.WordVillas',
#   'word.game.wordscapes',
#   'com.zimad.magicwordconnect',
#   'com.hiplay.word.games.wordscapes.nature',
#   'best.word.connect.search.free.offline.puzzle.word.games.world',
#   'com.peoplefun.wordflowers',
#   'com.oneup.word.soup.free',
#   'com.best.wordsearch.free',
#   'de.lotum.whatsinthefoto.us',
#   'com.escape.puzzle.prison.bank.steal.money.fun',
#   'com.wordloco.wordchallenge',
#   'com.havos.g.allapps',
#   'com.puzzle.word.wordfreetime.gp',
#   'com.wordgame.puzzle.block.search',
#   'bible.wordgame.verse.wordstacks.puzzle',
#   'com.fugo.wow',
#   'com.jdpapps.wordsearch',
#   'com.blueboat.justriddles',
#   'com.zatg.scaryteacher.wordgame',
#   'com.zynga.boggle',
#   'com.rocygamesa.guessthetiktokstar',
#   'com.braindom2riddle',
#   'com.zytoona.lostword2',
#   'com.eggheadgames.quicklogicproblems',
#   'com.wordgame.puzzle.block.crush',
#   'com.wordscapes.word.cookies.puzzle.wordbrain.collect',
#   'com.twominds.HeadsUpCharadas',
#   'com.uk.best.cross.word.game',
#   'com.vivinte.android.word2',
#   'com.randomlogicgames.crossword',
#   'com.BrainLadder.AmirzaGP',
#   'word.heaps.scroll.connect.swipe.stacks.free.word.games.puzzle',
#   'net.artgamestudio.charadesapp',
#   'com.piggyqojciqudhecuidqhuroblox.piggyroblox.piggyrobloxkjvnuidfnvuidnuvn33',
#   'bible.wordgame.story.verse.words.connect.puzzle',
#   'com.bibleword.crossword.en',
#   'com.puzzle.word.wordcolour.gp',
#   'com.layton.bookworm.pro',
#   'com.wordfinder.unscrabble.connect.addict',
#   'com.sonypicturestelevision.jeopardycross',
#   'in.androidmate.never_have_i_ever',
#   'com.word.connect.master.free.word.game',
#   'com.pixplicity.cryptogram',
#   'com.wordgame.puzzle.board.en',
#   'com.blackout.season',
#   'com.bitmango.go.wordsearchhiddenwords',
#   'air.com.pinturillo2free.pinturillo2free',
#   'com.fun9games.word.cross',
#   'com.appynation.occw',
#   'com.crazy.letter.wordfind',
#   'com.blackout.cube',
#   'com.lydia.wordsgame.word.talent',
#   'com.fgcos.crossword_puzzle',
#   'com.puzzle1studio.go.wordcalmcross',
#   'com.asgeir_albretsen.funlibs',
#   'com.verses.biblepuzzle.an',
#   'com.word.journey.crossword',
#   'com.glorygame.secret.puzzle.plot',
#   'com.theangrykraken.twopictures',
#   'com.wordpuzzle.wordfall',
#   'com.wordgame.words.connect.bibleverse.en',
#   'com.word.connect.theme.travel.puzzle.cross',
#   'com.melimots.WordSearch',
#   'com.androidmate.catchphrase',
#   'com.pizzagames.wordcrossy',
#   'org.duckdodo.baikoh',
#   'com.appspot.orium_blog.crossword.eng',
#   'com.marulgames.wordsurf',
#   'com.fonaps.hangmanmaster',
#   'com.games.makewords2',
#   'texttwist.n2',
#   'com.love.puzzles.word.serene',
#   'com.emrekhan.hangmanmultiplayerandroid',
#   'com.oneup.word.packs',
#   'com.g5e.crosswordspg.android',
#   'com.binggogames.wordblocks',
#   'com.kooapps.wordxbeachandroid',
#   'com.casual.candy.crosswords',
#   'com.blueoxtech.sevenlittlewords',
#   'word.bubble.pop.parts.combine.guess.find.swipe.crush.scrabble.puzzle.game',
#   'com.asgardsoft.words',
#   'com.razzlepuzzles.fillins',
#   'air.au.com.minimega.bonza',
#   'com.peoplefun.wordchums',
#   'com.puzzlenation.dpcrosswords',
#   'com.peoplefun.wordvistas',
#   'com.andron.crosswords2',
#   'com.pollardbanknote.cashword',
#   'com.etermax.guesscrack',
#   'com.razzlepuzzles.cryptograms',
#   'com.plus9.fandogh',
#   'com.adveractive.game.jumblecrossworddroid',
#   'com.escape.room.door.word.prison.puzzle.adventure',
#   'com.baek.Gatalk3',
#   'com.matchasaucellc.word.hound.android',
#   'com.eggheadgames.logicproblems',
#   'com.tgts.portablewordsearch',
#   'wordpuzzle.innovationgames.crossword',
#   'com.bitmango.go.wordtiles',
#   'com.spotlight.languinis',
#   'com.mobiloids.wordmix',
#   'com.bigstarkids.wordtravel',
#   'com.donkeysoft.wordwowfree',
#   'net.lrstudios.word_search',
#   'com.wordsearchpuzzle.game.android',
#   'fred.scrabbledictionary'],
#  ['com.lulo.scrabble.classicwordsplus',
#   'com.hbwares.wordfeud.full',
#   'pt.cosmicode.guessupkids',
#   'agamz.logic',
#   'com.teazel.crossword.full',
#   'com.androidmate.catchphrasepro',
#   'com.fiftyonefortynine.queenbee.app',
#   'jaguargames.wordmasterpro',
#   'com.omgpop.dstpaid',
#   'air.com.littlebigplay.games.wordgamespro',
#   'com.educ8s.stavrolexa_pro',
#   'se.maginteractive.rumble',
#   'com.verywisetech.pictionarypro',
#   'agamz.acrostics',
#   'com.firecrackersw.wordbreakerfull',
#   'air.com.littlebigplay.games.premium.spellingchallenge',
#   'com.sparkgenius.TGGWordGenerator',
#   'com.brainium.jumbline2',
#   'com.etermax.apalabrados.pro',
#   'air.com.littlebigplay.games.wordsearchdailypro',
#   'com.eekgames.dropwords2',
#   'com.planetrational.wordplus']]

# %%
# Turning list of lists into list only and checking number of scraped app ids.

listofappids = [item for sublist in listoflistofappids for item in sublist]
len(listofappids)
# Out:
# 5150

# %%
# Checking if there are any overlaps in app ids.

uniqueappidlist = []
for x in listofappids:
    if x not in uniqueappidlist:
        uniqueappidlist.append(x)
            
uniqueappidlist
# Out:
# ['com.innersloth.spacemafia',
#  'com.tapped.drawrider',
#  'com.activision.callofduty.shooter',
#  'com.playgendary.hitmasters',
#  'com.drawprotector.wavy.ios',
#  'com.fungames.sniper3d',
#  'com.cassette.aquapark',
#  'com.rkgames.basisgame',
#  'air.com.hypah.io.slither',
#  'com.playgendary.kickthebuddy',
#  'com.dts.freefireth',
#  'com.YummyGames.SamuraiFlash',
#  'com.cg.fanofguns',
#  'com.nintendo.zaka',
#  'lol.onevone',
#  'com.jtsniper.game',
#  'com.Neurononfire.SupremeDuelist',
#  'com.rubygames.assassin',
#  'com.ducky.slicethemall',
#  'com.geishatokyo.trafficrun',
#  'com.tencent.ig',
#  'com.outfit7.herodash',
#  'com.supercell.brawlstars',
#  'spider.rope.hero.frogninja.gangstar.crime.herogame',
#  'ru.galya.drawjoust',
#  'com.groogadgets.swipefight',
#  'com.jpgroup.pocketsniper',
#  'com.PoxelStudios.DudeTheftAuto',
#  'com.amelosinteractive.snake',
#  'com.miniclip.bowmasters',
#  'com.playgendary.tom',
#  'games.nerf.epic.pranks.free',
#  'com.outfit7.talkingtomgoldrun',
#  'com.stealthgame.master',
#  'com.time.trigger',
#  'mobi.gameguru.slapkings',
#  'com.ohmgames.crowdshooter',
#  'com.miniclip.agar.io',
#  'com.ohbibi.fps',
#  'com.ohmgames.knockdolls',
#  'com.netboom.cloudgaming.vortex_stadia_shadow_GeForce',
#  'com.wildlife.games.battle.royale.free.zooba',
#  'com.nintendo.zara',
#  'com.seenax.HideAndSeek',
#  'com.fungames.battletanksbeta',
#  'com.gamestart.protectthevip',
#  'com.crazylabs.lady.bug',
#  'com.hgamesart.hurricanehero',
#  'com.habby.archero',
#  'com.Deven.Arrow3D',
#  'vh.one',
#  'com.geishatokyo.snowballio',
#  'com.pixel.gun3d',
#  'com.sandboxol.indiegame.bedwar',
#  'com.kabam.marvelbattle',
#  'com.edkongames.mobs',
#  'zombie.survival.craft.z',
#  'com.studio501.curvypunch3d',
#  'com.imangi.templerun2',
#  'com.mgc.RopeHero.ViceTown',
#  'com.yodo1.crossyroad',
#  'com.playgendary.tombpaint',
#  'com.pixonic.wwr',
#  'com.wildspike.wormszone',
#  'black.mafia.ironboy.stickman.rope.heros',
#  'com.mobile.legends',
#  'com.dangernoodle.killerbee',
#  'com.chaloapps.strikefortressbox',
#  'com.gamehivecorp.beattheboss4',
#  'com.Bingo.Football',
#  'com.Snow.Golf',
#  'com.stickman.warriors.stickwarriors.dragon.shadow.fight',
#  'com.stickman.shadow.battle',
#  'com.tikitaka.folk',
#  'com.funnii.maskofstick',
#  'com.hitrock.hideonline',
#  'com.vng.g6.a.zombie',
#  'com.gamedevltd.wwh',
#  'com.hgamesart.blackholehero',
#  'com.generagames.resistance',
#  'com.geishatokyo.dinosaur',
#  'com.bandainamcoent.dblegends_ww',
#  'com.chillyroom.zhmr.gp',
#  'com.mousemobile.explorationcraft',
#  'air.com.ubisoft.brawl.halla.platform.fighting.action.pvp',
#  'com.gta.truck.driver.city.crush',
#  'com.Eageron.apps.RealTimeShields',
#  'com.fcnaud.robbery',
#  'com.ohmgames.smashthemall',
#  'com.cec.skateuniverse',
#  'me.modernator.stickWarfareBloodStrike',
#  'com.os.falcon.yogame.stickfighter',
#  'com.lalonde.upstream',
#  'com.h8games.helixjump',
#  'com.freegamesstudio.thesurvivalhuntergames2',
#  'com.wb.goog.mkx',
#  'com.gta.real.gangster.crime',
#  'com.bhvr.deadbydaylight',
#  'com.dive.bed.game',
#  'games.noho.gungang',
#  'com.chaloapps.roosterrudy',
#  'com.onetongames.rocketroyale',
#  'com.nekki.shadowfight',
#  'com.gameloft.android.ANMP.GloftGGHM',
#  'com.sega.sonic1px',
#  'com.titan.cd.gb',
#  'jpark.AOS5',
#  'com.zeptolab.bulletecho.google',
#  'com.netease.ddsfna',
#  'com.stick.fight.battle.warrior',
#  'com.rage.road',
#  'com.ZenithGames.CrowdBomber',
#  'com.bandainamcoent.ninjavoltage_app',
#  'com.hgamesart.snowstorm',
#  'com.skygo.stickfight2',
#  'com.mizo.robot.fps.shooting.game',
#  'rs.pwn.zombielike',
#  'com.cheshirex.stickmanthefight',
#  'com.ivy.garfield.run',
#  'com.aryasgames.zombieseverywhere',
#  'com.desert.riders',
#  'com.playstack.svtc',
#  'com.zeptolab.robotics',
#  'com.junesoftware.maskgun',
#  'sniper.gun.zombie.shooting',
#  'io.painkiller.battle.royale',
#  'com.tomo.pushbattle',
#  'com.my.warface.online.fps.pvp.action.shooter',
#  'com.gun.black.ops',
#  'com.yuriychechulin.throwio',
#  'com.matte.rushcrush',
#  'com.rubygames.slingdrift',
#  'com.cg.cowboy',
#  'com.grandgangster.crimecity.prisonescape',
#  'com.glu.zbs',
#  'com.funnii.robotsuper.offlinegames',
#  'sniper.honor.real3d.shooter.assassin.free.android',
#  'com.gsgames.pixel.combat',
#  'com.flaregames.zgs',
#  'com.chaloapps.memeswars',
#  'fi.twomenandadog.zombiecatchers',
#  'com.PuzzleOnly.KnockoutRace',
#  'com.ChillyRoom.DungeonShooter',
#  'com.mtvn.superbrawlapp',
#  'com.criticalforceentertainment.criticalops',
#  'com.joydo.minestrikenew',
#  'com.babil.archers.tale.bow.hunter.battle.action',
#  'com.fun.games.commando.black.shadow',
#  'com.gamedevltd.modernstrike',
#  'com.madfingergames.deadtrigger2',
#  'com.aurecas.stickmanzombieshooter',
#  'com.panzerdog.tacticool',
#  'com.hgamesart.superhero',
#  'com.aldagames.zombieshooter',
#  'com.lf.sniper.gun.shooter.free.apps',
#  'com.bandainamcogames.dbzdokkanww',
#  'com.hgamesart.ropemummy',
#  'com.funnii.galaxyofstick',
#  'com.bloop.food',
#  'com.clement.ballmayhem',
#  'com.pikpok.dr2.play',
#  'com.zg.dinosaur.hunter.wild.jungle.animals.hunting.sniper.safari.free.apps',
#  'com.zeptolab.omnomrun.google',
#  'com.roadglider.game',
#  'com.madfingergames.wargames.shooter',
#  'com.doctor.surgerymaster',
#  'com.Floor18.Zombiner',
#  'com.azurgames.BattleGroundRoyale',
#  'com.kwalee.superherosunset',
#  'com.spider.ropeman.superhero.gangster.vegas.crimecity',
#  'com.hasbro.beybladesenterprise',
#  'com.sega.soniccd.classic',
#  'com.anfagames.sodaguys',
#  'com.DCGEntertainment.EnergyBlast',
#  'com.rkgames.smashywanted',
#  'com.soneraltincit.cityfightvsstreetgang',
#  'com.nway.powerrangerslegacywars',
#  'org.ppsspp.ppsspp',
#  'com.mgs.sniper1',
#  'com.stick.hero.fighter.saiyan.supreme.dragon.warrios',
#  'com.assassingames.ninjafrogrope',
#  'com.alienshooter.galaxy.attack2',
#  'com.kotobagames.namelesscat',
#  'com.turborilla.bmx2',
#  'com.sgs.urb.versuspixels',
#  'com.miniclip.diep.io',
#  'com.sunnybaria.collabgame',
#  'com.axlebolt.standoff2',
#  'com.herogame.gplay.lastdayrulessurvival',
#  'com.crazylabs.mr.bullet.puzzle.game3d',
#  'com.kabam.bigrobot',
#  'com.gamedevltd.destinywarfare',
#  'com.lf.frontline.elite.war.free.apps',
#  'com.ggv.grand.city.thug.crime.gangester',
#  'com.gameloft.android.ANMP.GloftOLHM',
#  'se.itatake.gumslinger',
#  'com.chillingo.robberybobfree.android.row',
#  'com.feelingtouch.zf3d',
#  'com.gameloft.android.ANMP.GloftM5HM',
#  'com.autumn.skullgirls',
#  'com.scottgames.fivenightsatfreddys',
#  'com.clickteam.ultimatecustomnight',
#  'com.rockstargames.gtasa',
#  'com.dsemu.drastic',
#  'com.scottgames.sisterlocation',
#  'com.ubisoft.assassinscreed.identity',
#  'com.scottgames.fnaf4',
#  'com.squareenixmontreal.hitmansniperandroid',
#  'com.scottgames.fnaf3',
#  'com.activision.boz',
#  'jp.konami.epjCastlevania2',
#  'com.rockstargames.bully',
#  'com.rockstar.gta3',
#  'com.bethsoft.DOOM',
#  'com.damonplay.damonps2.pro.ppsspp',
#  'com.wb.lego.marvel',
#  'com.GameCoaster.ProtectDungeon',
#  'org.ppsspp.ppssppgold',
#  'com.playdigious.deadcells.mobile',
#  'com.tipsworks.android.pascalswager.google',
#  'com.turner.ttgfigures2',
#  'com.bethsoft.DOOMII',
#  'com.rockstargames.gtactw',
#  'com.jdroid.gtasacheater',
#  'com.jumpgames.RealSteel',
#  'com.venomizedArt.SlaughterRebels',
#  'com.nekki.shadowfight2.paid',
#  'com.turner.b10runner',
#  'com.EvilTortillaGames.cookiesvclaus',
#  'com.agaming.thesun.origin',
#  'com.coffeestainstudios.goatsimulator.goatz',
#  'com.MikaMobile.Zombieville2',
#  'com.MortalCrusade.SwordOfKnight',
#  'com.khg.actionsquad',
#  'com.oddworld.Stranger',
#  'com.limbic.ac130',
#  'com.altavite.ps2emu',
#  'com.dotemu.titanquest',
#  'com.foursakenmedia.heroesandcastles2',
#  'com.pastagames.ro1mobile',
#  'com.ubisoft.rayman.fiestarun',
#  'com.Zonmob.Stickman.FightingGames.ShadowOfDeath',
#  'com.gameloft.android.ANMP.GloftM4HM',
#  'com.devolver.downwell_rerelease',
#  'air.com.sfbgames.HauntTheHouseTerrortown',
#  'com.mtvn.tmntpp',
#  'com.oddworld.NNT',
#  'com.archi701.elchapo',
#  'com.ThoriumGameLab.BattleOfVicksburg3',
#  'com.tequilabyte.walker.main',
#  'com.gameloft.android.ANMP.GloftG4HM',
#  'com.ThoriumGameLab.EastFront',
#  'com.gameloft.android.ANMP.GloftM3HM',
#  'com.FYQD.BrightMemory',
#  'com.candyrufusgames.survivalcraft',
#  'com.outerminds.pewdiepie',
#  'com.ThoriumGameLab.WinterWar',
#  'com.mtvn.tmntMovieGame',
#  'com.DastroGamesStudio.FateZ',
#  'com.dingogames.tastyplanet2',
#  'com.mygdx.digtochina.android',
#  'com.mtvn.tmntrooftoprun',
#  'jp.co.capcom.rockman1en',
#  'com.dingogames.tastyplanet1',
#  'com.IvanPanasenko.EndurancePremium',
#  'com.ThoriumGameLab.Petrolia',
#  'com.blinigames.lus',
#  'com.vblank.RCRDX',
#  'com.pixelbite.sg',
#  'com.Drool.ThumperPocketEdition',
#  'jp.co.capcom.rockman6en',
#  'air.com.oranginalplan.weaphones2020',
#  'com.opentouchgaming.deltatouch',
#  'com.jdroid.gta3modder',
#  'jp.co.capcom.rockman2en',
#  'com.fansipan.stickman.shadow.knights.fightinggames',
#  'com.starshipstudio.thesurvivorremastered',
#  'com.dotemu.raidenlegacy',
#  'com.opentouchgaming.quadtouch',
#  'com.Dexus.Dinosaur.TRexFights.Dinosaurs.Dominator',
#  'com.kylebarrett.Immortal',
#  'com.doublethink.ofdp2',
#  'com.sigmateam.alienshooter2reloaded',
#  'com.littlegamesstudio.Gauntlet',
#  'com.foursakenmedia.heroesandcastles',
#  'com.square_enix.secret',
#  'com.companyname.LetThemCome',
#  'jp.co.capcom.rockman4en',
#  'jp.co.capcom.rockman3en',
#  'com.stickman.warriors.dragon',
#  'com.zitga.ninja.stickman.legends.shadow.wars',
#  'com.VenomizedArt.Mindcell',
#  'com.unimob.stickman.ghost2.pay',
#  'com.the10tons.teslavslovecraft',
#  'com.the10tons.neonchrome',
#  'com.foursakenmedia.bugheroes2',
#  'com.venomizedart.Slaughter',
#  'de.kamibox.seesaw',
#  'com.nvidia.valvesoftware.halflife2',
#  'com.venomizedArt.Slaughter2',
#  'com.blabberf.gunroundsandroid',
#  'jp.halegg.nazcaf',
#  'com.imcrazy.ds2',
#  'com.sigmateam.alienshootermobile',
#  'com.hgamesart.catsimulatorpro',
#  'com.agaming.reporter',
#  'com.TinyDevbox.DeadRain',
#  'com.Majorariatto.GolfingOverIt',
#  'com.gameloft.android.ANMP.GloftWBHM',
#  'com.Bornthrupieces.Bond007',
#  'com.gsm.overdrivepremium',
#  'com.turner.trutv.wheelofdoom',
#  'com.redantz.game.za3p',
#  'com.AlexeySuslin.RunicCurse',
#  'com.darkarrow.stickfighter.saiyan.vip',
#  'com.Nariworks.VirusZombie',
#  'com.entwell.rk_org',
#  'com.the10tons.jydge',
#  'com.tenbirds.animus',
#  'com.agaming.mentalhospitaliv',
#  'com.agaming.zonaprojectx',
#  'com.tenbirds.animus2c',
#  'com.atypicalgames.chernobyl',
#  'com.dormroom.cyberpunk2069',
#  'com.skyfox.foxoneAdv',
#  'com.pixelstar.PixelFBladeVIP',
#  'com.DefStudio.BattleGunVRGold',
#  'com.mtvn.dafrainforest.google',
#  'com.id.doom3bfg',
#  'com.reeltoreal.survivor_adventure_pro',
#  'com.RideAndCrash.AmonAmarthBerserkerGame',
#  'com.eyesright.amb',
#  'com.atypicalgames.radiationcity',
#  'com.devolverdigital.swredux.play',
#  'com.atypicalgames.radiationisland',
#  'jp.co.capcom.rockman5en',
#  'com.foursakenmedia.nyz2',
#  'com.zitga.cyberfighters.shadow.hunter.legends',
#  'com.impact_studios.superbrawlsmash',
#  'com.the10tons.crimsonland',
#  'co.electrictoy.dig',
#  'com.roblox.client',
#  'com.multicraft.game',
#  'com.BlissGames.Juego23',
#  'com.nianticlabs.pokemongo',
#  'com.oneway.Deathcoming',
#  'com.movile.playkids.pkxd',
#  'com.eers.kraft.eerskraft',
#  'com.jockeygames.rampcar.stuntsfree.impossibletracks.stuntdriving.mega.car',
#  'com.cleverturtle.brickbuilder',
#  'free.os.jump.superbros.adventure.world',
#  'com.sega.sprint',
#  'com.neighbors.darkriddle',
#  'com.tinyco.potter',
#  'com.deuscraft.TurboTeam',
#  'net.wooga.junes_journey_hidden_object_mystery_game',
#  'com.lioncel.NoOneEscape',
#  'com.grand.speed.hero.highway.gangster.chase',
#  'com.grand.police.transport.truck',
#  'com.os.falcon.bob2.adventure.world',
#  'org.nanobit.hollywood',
#  'com.randonautica.app',
#  'com.playrix.manormatters',
#  'com.apps2us.slither.slink.io',
#  'com.gameinsight.gplay.mmanor',
#  'com.sgs.antiterrorism.counterattack.commandomissiongame',
#  'com.naturalmotion.clumsyninja',
#  'com.hitcents.drawastickmanepic2free',
#  'com.superbinogo.jungleboyadventure',
#  'com.gf.extreme.gtracing.car.stunts.impossiblecarstunts.stuntdriving',
#  'com.tinybuildgames.helloneighbor',
#  'com.aidungeon',
#  'com.tellurionmobile.realmcraft',
#  'com.cradley.bee.robot.games',
#  'com.Earthkwak.Platformer',
#  'com.mytona.seekersnotes.android',
#  'com.fa.gym.fighting.game',
#  'com.secg.jurassiccraft',
#  'com.sandboxol.indiegame.eggwars',
#  'air.SuperCity',
#  'com.bl.critical.strike',
#  'com.pocapp.dungeondogsgame',
#  'com.fgz.us.police.flying.helicopter.car.transform.robot.games',
#  'com.doctor.robot.rescue.mission',
#  'com.StickPage.diamant',
#  'com.bigag.bike.stunt.master',
#  'com.craftgames.plntcrft',
#  'com.impp.construction.simulator.forklift',
#  'com.cdt.basic.math.teacher',
#  'air.HardTime',
#  'com.spider.ropehero.superhero.gangstercrime',
#  'com.crazylabs.jumanji',
#  'com.blyts.nobodies',
#  'com.secg.earthcraft',
#  'com.ghs.dino.robot.car.robot.game',
#  'com.mojang.minecraftearth',
#  'com.buildingcraftinggames.fun.kid.games.boys.block.craft.minecraft.story.mode.lego.create.build.marvel.hero.dc.legends.mcpe.mod',
#  'com.hitcents.drawastickmanepic3',
#  'com.jagex.oldscape.android',
#  'com.prettysimple.criminalcaseandroid',
#  'com.buntoo.drone.robot.transformation',
#  'com.tinydragonadventuregames.crafting.building.exploration.blocky.cube.lite.boy.girl.love.date.game.chat.minecraft.boyfriend',
#  'com.craftgames.worldcrft',
#  'com.gun.fun.anti.shoot',
#  'com.gangstar.crime.fps',
#  'com.mustardgames.topspeed.formulacar.racinggames',
#  'com.play.io.monster.truck.demolition.derby.crash.stunts',
#  'games.fatlion.building.mycraft.surfing.craft.free.simulator.jetski.games.surf.league',
#  'com.upjers.zoo2animalpark',
#  'com.us.police.car.transform.robot.war',
#  'com.candyrufusgames.survivalcraft2trial',
#  'com.red.ball.ballgames.bounceball.redball5',
#  'com.RetrostyleGames.LastPirate.deadthieves',
#  'com.animal.attack.simulator2019.wild.hunting.games',
#  'com.tinydragonadventuregames.doll.house.craft.princess.fashion.girls.minecraft.barbie.creative.exploration.lite.build.mine.free',
#  'com.studiowildcard.wardrumstudios.ark',
#  'com.YovoGames.carwash4',
#  'com.rds.bike.racer.highway.rider.traffic.bike.racing.game',
#  'air.com.pixelfederation.diggy',
#  'com.playmini.miniworld',
#  'com.sandboxol.indiegame.skywar',
#  'com.glu.stardomkim',
#  'com.ugen.playquirk',
#  'com.survivalcrafting.scary.theme.park.craft.horror.ghost.zombie.monster',
#  'com.cgs.offroad.farm.animal.transport.trailer.truck.driving.game',
#  'com.happy.family.limousine.robot.game',
#  'com.gs.lightspeed.superhero.rescue.mission.doctor.robot.games',
#  'de.codestream.horus',
#  'com.FoxieGames.DinoProject',
#  'com.impp.city.traindriver.simulator',
#  'com.YovoGames.babyCare2',
#  'com.pm.mega.ramp.impossible.car',
#  'com.nag.pet.dog.virtual.family.adventure',
#  'com.gz.deer.hunting.shooting',
#  'com.wb.goog.legoswtfa',
#  'com.gaminglegends.taxigame.taxisimulator.grand.car.driving2020',
#  'com.sandboxol.indiegame.luckyblock',
#  'freedom.bubble',
#  'com.indigokids.mim',
#  'com.bandagames.miner',
#  'com.fgz.flying.fire.truck.engine.rescue.firefighter.robot.games',
#  'com.mustardgames.muscle.car.stunts.mega.ramp.stunt.car.impossibletracks',
#  'com.frenzygames.fgs.shooting.anti.terrorism.combat.mission',
#  'com.cgs.sea.animal.transport.trailer.truck.driving.game',
#  'com.cradley.jungle.robot.shooting.game',
#  'com.appstrend.police.robot.bus.transform',
#  'com.gamesunion.idleracingtycoon',
#  'com.spider.ropehero.gangster.crimecity',
#  'com.doctor.robot.human.rescue',
#  'com.minecrafting.miniworldcrafting',
#  'com.freerange.goosebumps',
#  'com.eyesthegame.eyes',
#  'com.crazylabs.hotel.transylvania.adventure',
#  'jonessamuelren.far.home.spider.hero.run',
#  'com.EZTECK.brannyTeacherMath',
#  'com.FumbGames.DragonMerge',
#  'com.ludia.jw2',
#  'com.offlinegames.police.racing',
#  'com.rlg.flying.tiger.bike.robot.transform',
#  'com.SGS.DrivingSchoolGames.RealCarParkingSimulator',
#  'com.buildtownn.skimlyblock',
#  'com.appstrend.flying.eagle.robot.car.games',
#  'com.amongus.us',
#  'com.kongregate.mobile.throwdown.google',
#  'com.g5e.homicidesquadpg.android',
#  'com.nag.home.manager.working.virtual.mom',
#  'com.monstergamesproductions.ramp.moto.rider',
#  'com.hanako.mcpe_mods',
#  'com.spinmaster.enterprise.colleggtibles',
#  'com.spider.ropehero.crimecity',
#  'com.gamefeast.bigcity.limousine.car.driver',
#  'air.com.RustyLake.SamsaraRoom',
#  'com.reeltoreal.survivor_adventure',
#  'com.flying.tractor.simulator',
#  'com.igoldtech.streetchaser',
#  'freegames.zombiesniper.deadtrigger',
#  'com.mustardgames.bmx.cycle.stunt.mega.ramp.impossibletracks',
#  'biggiant.prisonescape',
#  'com.HuaYiGame.DeliveryFromThePain',
#  'air.com.moviestarplanet.roboblastplanet',
#  'com.delworkhard1.minecrafting2020',
#  'com.xjoy.mermaid',
#  'com.wooga.pearlsperil',
#  'com.minecraftpe.minicraft.multicraft.blockart',
#  'com.tohsoft.arashi.ninja.shadow',
#  'com.YovoGames.doctorBear',
#  'air.ExtraLives',
#  'com.gametornado.short_life',
#  'com.darksacygames.sirenheadhorrorgame',
#  'com.CoolGames.MazeGame',
#  'com.budgestudios.googleplay.ThomasAndFriendsMagicalTracks',
#  'com.iron.flying.man.rope.hero.vegas.crime.simulator.gta',
#  'com.grand.theft.cheat.codes.five',
#  'com.haiku.adventure.escape.game.mystery.stories',
#  'com.bikesstunt.motomaster.racing.game.trial.trick.bikeRacing',
#  'com.secg.robocraft',
#  'com.wild.animals.transport.simulator',
#  'games.dali.adventure.point.click.lucid.dream.witch.planet.riddle',
#  'com.mastercraft.minecrafting',
#  'com.colto.cknrunner',
#  'com.KidsGames.SuperHippo',
#  'com.fgz.us.police.eagle.robot.transform.flying.bike.game',
#  'games.fatlion.crafting.building.mine.theme.park.games.roller.coaster.tycoon.boys.girls.exploration.lite.roblox.zoo.water',
#  'com.budgestudios.TransformersRescueBotsHeroAdventures',
#  'vegas.craftvegas2.adventuregame2020',
#  'com.superbinogo.jungleboyadventure2',
#  'com.armorgames.sodadungeon2',
#  'com.heliogames.westland',
#  'com.gunshooting.counterstrike.fps',
#  'com.us.army.humvee.jeep.car.transporter.parking.game',
#  'com.survivalcrafting.airport.city.pilot.plane.craft.fly.simulator.flight.air.traffic.control.airline.commander.building.flying',
#  'com.blackpanther.ninjaarashi',
#  'com.RbwInteractive.fortyfourCats',
#  'com.cgs.us.flying.police.robot.speed.hero.crime.city.hero.games',
#  'com.myappz.firegirlWaterboy',
#  'com.runefall.match3.puzzle.adventure.gp',
#  'com.netease.lztgglobal',
#  'com.door.glass.bottle.shooter.expert',
#  'com.nordcurrent.murderinalps',
#  'com.amazing.spider.rope.hero.ninja.gangster.crimecity',
#  'com.aldagames.craftingdead',
#  'com.pacific.wildlands',
#  'com.backstreet.police.panda.robot.transform.robotwar',
#  'com.baldi.horror.escape.basics',
#  'com.happy.family.tiger.robot.games',
#  'com.LiliJoy.DragonLand',
#  'com.PSVStudio.HippoBabyBall',
#  'com.mustardgames.army.prison.transport',
#  'com.pocapp.castlecats',
#  'com.nianticlabs.hpwu.prod',
#  'com.secg.terracraft2',
#  'com.te.virtual.mother.family.simulator',
#  'com.happy.family.deer.robot.game',
#  'es.socialpoint.dragonland',
#  'com.PSVStudio.BirthdayParty',
#  'com.aleson.casefiveanimatronicsfnaf',
#  'com.g5e.hiddencity.android',
#  'com.miniworldblock.krafting202',
#  'com.fivebn.LL1_f2p',
#  'com.scary.siren.head.haunted.town',
#  'com.enteriosoft.extremebalancer3',
#  'com.and.games505.TerrariaPaid',
#  'com.pixelcurves.terlauncher',
#  'com.jds.batim',
#  'com.robotgentleman.game60seconds',
#  'com.wb.goog.legojurassicworld',
#  'com.RobotGentleman.sixtyParsecs.mobile',
#  'com.D3Go.mendel',
#  'com.kleientertainment.doNotStarvePocket',
#  'com.seven2.pawapp2',
#  'com.bscotch.crashlands',
#  'com.rockstargames.gtalcs',
#  'air.com.RustyLake.RustyLakeHotel',
#  'com.gameloft.android.ANMP.GloftICHM',
#  'com.wb.goog.lnjgo',
#  'air.com.RustyLake.RustyLakeParadise',
#  'com.AngryNeighbor',
#  'com.jds.batds',
#  'games.dali.adventure.lucid.dream.part.two',
#  'com.wb.goog.legobdc',
#  'air.com.RustyLake.WhiteDoor',
#  'air.com.RustyLake.RustyLakeRoots',
#  'com.disney.castleofillusion_goo',
#  'com.playdead.limbo.full',
#  'air.com.amanitadesign.chuchel.gp',
#  'com.younghorses.octodad',
#  'jp.co.spike_chunsoft.DR2',
#  'eu.bandainamcoent.verylittlenightmares',
#  'com.wb.goog.lbbg',
#  'com.candyrufusgames.survivalcraft2',
#  'com.wb.goog.legohp1',
#  'com.noodlecake.realmyst',
#  'com.wb.goog.legohp2',
#  'jp.co.spike_chunsoft.DR1',
#  'com.wb.goog.lego.movievideogame',
#  'com.square_enix.FFIXww.android_googleplay',
#  'com.BestFreeGames2k20.PixelcraftPixelmonandpokecraft',
#  'com.blyts.infamousmachine',
#  'edu.terc.zoombinis',
#  'com.leosfortune',
#  'com.devolver.grispaid',
#  'games.dali.adventure.lucid.dream.part.three',
#  'air.net.machinarium.Machinarium.GP',
#  'com.kleientertainment.doNotStarveShipwrecked',
#  'com.Level5.LT1RNA',
#  'com.bonusxp.fate',
#  'com.hitcents.drawastickmanepic2',
#  'com.and.games505.portal_knights',
#  'com.noodlecake.drtc',
#  'com.terribletoybox.thimbleweedparkandroid',
#  'com.creativemobile.beholder',
#  'com.KillmondayGames.LittleMisfortune',
#  'com.peppapig.goldenboots',
#  'jp.co.capcom.gyakusai6en',
#  'com.oddworld.Munch',
#  'com.hitcents.stickmanepic',
#  'com.wb.goog.llotr',
#  'com.pjmasks.superchase',
#  'com.artifexmundi.scarlettmysteries.gp.full',
#  'com.noodlecake.riven',
#  'jp.co.capcom.gyakusai5en',
#  'com.Level5.LT3RNB',
#  'com.feemodev.cat',
#  'com.bigfishgames.pbtmgoogfull',
#  'com.threeminutegames.lifeline.google',
#  'com.lonewolfgames.rescueenchanter',
#  'com.KillmondayGames.FranBowCh3',
#  'com.mojotouch.t7g',
#  'com.NightSchool.Oxenfree',
#  'amanita_design.samorost3.GP',
#  'com.pgstudio.survival.evo.pro',
#  'com.KillmondayGames.FranBowCh1',
#  'com.etterstudio.pnp',
#  'com.KillmondayGames.FranBowCh2',
#  'co.uk.wixgames.ducklifebattle',
#  'com.firemaplegames.returntogrislymanor',
#  'com.Level5.LT2RNA',
#  'jp.co.capcom.kenji1en',
#  'air.com.amanitadesign.botanicula',
#  'com.lonewolfgames.blackthorncastle',
#  'com.and.games505.brothers',
#  'com.happyvolcano.games.thealmostgone',
#  'com.explorationbase.Exploration',
#  'com.dotemu.ys1x',
#  'com.artifexmundi.queensquest2.gp.full',
#  'ru.buka.dville01',
#  'com.sharpen.storm',
#  'com.KillmondayGames.FranBowCh4',
#  'com.Pixelatto.Reventure',
#  'com.foxandsheep.Dinotrux2',
#  'com.noodlecake.suzycube',
#  'com.pgstudio.survivalpro',
#  'com.Tasharen.Windward',
#  'com.antlerinteractive.KrystopiaNovasJourney',
#  'air.com.noodlecake.luminocity',
#  'com.bbg.tiwdroid',
#  'jp.co.capcom.gyakusai4en',
#  'com.econo.gcemulator',
#  'com.specialbit.dreams.android.full',
#  'com.fivebn.daf4.full',
#  'com.psychoseinteractive.forgottenmemories',
#  'com.rawfury.longhathouse.Dandara',
#  'com.dotemu.sanitarium',
#  'com.ProjectTheGalaxy',
#  'com.bigfishgames.mcrugoogfull',
#  'com.eg.antarctica88pro',
#  'com.fgrfg.grgw',
#  'com.glitchgames.theForgottenRoom',
#  'com.lonewolfgames.losttreasure',
#  'com.gtafrogstresstfighter.frogamazinggangster.thefrogsimulator20',
#  'com.pgstudio.siepro',
#  'com.artifexmundi.grimlegends2.gp.full',
#  'com.KillmondayGames.FranBowCh5',
#  'com.KickBack.LostEchoAdventure',
#  'com.MrSamBarlow.HerStoryGame',
#  'com.chorusworldwide.bertramep1',
#  'com.artifexmundi.ghostfiles2.gp.full',
#  'com.threeminutegames.lifeline2.goog',
#  'com.Level5.LaytonMJNA',
#  'net.fmstudio.forgottenhilldisillusion',
#  'com.ludosity.ittledew',
#  'com.studiopango.pangopirate',
#  'com.TenderClaws.VVR',
#  'co.uk.wixgames.ducklifeadventure',
#  'com.glitchgames.allthatremains.part1',
#  'com.artifexmundi.grimlegends.gp.full',
#  'com.cm.whipseey',
#  'com.dynamiczero.survivingtitan',
#  'com.divmob.epicheroeswar.en.freemium',
#  'com.rawfury.woam',
#  'kr.co.sonnori.whiteday.g',
#  'com.threeminutegames.lifelinesilentnight.goog',
#  'com.tribeplay.pandafirestation',
#  'com.mediacitygames.lostfountain',
#  'com.glitchgames.veritas',
#  'com.eline.neveralonemobile',
#  'com.pointclickgames.mysteryofhauntedhollow',
#  'com.makario.vigilos',
#  'com.animationarts.secretfiles2',
#  'com.glitchgames.foreverlostepisode1sd',
#  'com.mediacitygames.alicetrapped2',
#  'de.stollenmayer.philipp.SometimesYouDie',
#  'com.LoopyMood.AntVentor',
#  'com.winterveilstudios.DISTRAINT2',
#  'com.accidentalqueens.anormallostphone',
#  'com.senspark.darkland',
#  'com.pointclickgames.lostadventure',
#  'com.defas.naruto',
#  'com.devolver.hatofulboyfriend',
#  'com.bigfishgames.mwwmgoogfull',
#  'com.bigfishgames.pdogoogfull',
#  'com.devolver.Swordsofditto',
#  'com.artifexmundi.clockwork.gp.full',
#  'com.fivebn.new_york_mysteries_hd_full',
#  'com.buffstudio.sevendays',
#  'com.artifexmundi.thesecretorder7.gp.full',
#  'com.fivebn.ll5.full',
#  'com.artifexmundi.tso8.gp.full',
#  'com.headupgames.anybodyouttheredeadcity',
#  'com.capybaragames.sworcery',
#  'com.deadmage.shadowblade.paid',
#  'com.firemaplegames.games.the_secretofgrislymanor',
#  'com.firemaplegames.Thickety_Creek',
#  'com.accidentalqueens.anotherlostphone',
#  'com.doublefine.thecave',
#  'com.artifexmundi.familymysteries1.gp.full',
#  'com.plug_in_digital.emma',
#  'com.nvidia.valvesoftware.portal',
#  'net.lonewolfgames.games.thelostship',
#  'com.StupaX.Flight',
#  'com.pixbits.junkjack',
#  'com.threeminutegames.lifelinecrisislinegoog',
#  'uk.co.revolution.bs1dc',
#  'com.MarsusProject',
#  'com.artifexmundi.vampirelegends.gp.full',
#  'com.artifexmundi.pathofsin1.gp.full',
#  'com.crescentmoongames.skyfish',
#  'com.kochmedia.secretfiles',
#  'com.threeminutegames.lifelineflatlinegoog',
#  'com.nightlightinteractive.ww',
#  'com.specialbit.angelo.deemon.full',
#  'com.bigfishgames.dmllgoogfull',
#  'com.bigfishgames.dpfsgoogfull',
#  'com.artifexmundi.thesecretorder1.gp.full',
#  'com.fivebn.nym2.full',
#  'com.threeminutegames.lifelinehalftoinfinitygoog',
#  'es.brokenrul.oldmansjourney',
#  'com.dotemu.ihnmaims',
#  'net.playables.kidsgame',
#  'com.arachnowopunk.revolution',
#  'com.fivebn.nym04.full',
#  'air.com.ohnoo.tormentum',
#  'com.mediacitygames.alicetrapped1',
#  'com.theand.OddeyePaid',
#  'com.fivebn.ll6.full',
#  'com.alawar.beholder2',
#  'com.artifexmundi.mybrotherrabbit.gp',
#  'com.artifexmundi.enigmatis3.gp.full',
#  'com.artifexmundi.tso3.gp.full',
#  'com.soladv.game',
#  'jp.co.izanagigames.deathcometrue',
#  'fall.race.io',
#  'com.Atinon.PassOver',
#  'com.kiloo.subwaysurf',
#  'com.fencinggame.master',
#  'com.hanna.bodyguard.expert',
#  'com.games.smashersio',
#  'com.ua.building.Lokicraft',
#  'com.freeplay.runandfight',
#  'com.Tastypill.BallSlide3D',
#  'com.igutso.killphil',
#  'com.Celltop.SpiralRoll',
#  'com.appadvisory.wtfight',
#  'com.mikhailp.logthrower',
#  'com.alien.shooter.galaxy.attack',
#  'com.sega.sonicdash',
#  'com.LightBeam.Demolish',
#  'com.azurgames.stackball',
#  'com.playgendary.creamaster',
#  'com.robtopx.geometryjumplite',
#  'com.fgol.HungrySharkEvolution',
#  'com.iposedon.bricksbreakerballs',
#  'com.dvloper.granny',
#  'com.gamestart.dodgeaction3d',
#  'com.playgendary.tanks',
#  'com.games.bottle',
#  'com.topchopgames.skyroller',
#  'com.dvloper.grannychaptertwo',
#  'com.os.airforce',
#  'io.voodoo.paper2',
#  'com.lightneer.goodslice',
#  'io.voodoo.holeio',
#  'com.timuzgames.savethefish',
#  'io.voodoo.crowdcity',
#  'com.bigdog.games.buddyfitness',
#  'com.pizza.dough',
#  'com.gamepie.airpolice',
#  'com.court.guilty',
#  'com.mindy.grap1',
#  'com.game.space.shooter2',
#  'com.ua.vikos.world',
#  'com.superstar.rollingdice.gp',
#  'com.keplerians.icescream3',
#  'com.mikhailp.perfectsnipe',
#  'com.ubisoft.hungrysharkworld',
#  'com.isl.stairrun',
#  'com.supergame.ohmycar',
#  'com.rmg.idle.tap.strong.granny',
#  'com.keplerians.icescream',
#  'com.halfbrick.fruitninjafree',
#  'com.hyper.plinko.coin',
#  'com.imangi.templerun',
#  'com.appadvisory.drawclimber',
#  'com.miniworld.mastercrafting.survivalboxbuilding20',
#  'com.colorhole.game',
#  'com.natenai.glowhockey',
#  'com.nordcurrent.canteenhd',
#  'com.rioo.runnersubway',
#  'com.riseup.game',
#  'com.namcobandaigames.pacmantournaments',
#  'com.kalipsogames.psychopathhunt',
#  'com.PepUpStudios.FallGuys3D',
#  'com.crazylabs.sausage.run',
#  'com.FDGEntertainment.redball4.gp',
#  'com.boomhits.rampcarjumping',
#  'com.halfbrick.jetpackjoyride',
#  'com.biglime.cookingmadness',
#  'com.ihari.escapetheprison',
#  'net.apex_designs.payback2',
#  'com.YsoCorp.WoodCutter',
#  'bike.hop.fall',
#  'com.sega.sonicboomandroid',
#  'com.team70.gangsterking',
#  'com.keplerians.icescreamtwo',
#  'net.mobigame.zombietsunami',
#  'com.orbitalknight.castlewreck',
#  'com.vincentb.RollyLegs',
#  'com.fungame.casual.fishing.master',
#  'com.colorswitch.switch2',
#  'com.germanicus.cmioo',
#  'io.voodoo.paper3',
#  'com.colorup.game',
#  'com.PlayMax.playergames',
#  'com.playgendary.sportmasters',
#  'com.sega.sonic2.runner',
#  'com.mix.color.paint.game',
#  'com.robtopx.geometrydashsubzero',
#  'com.orbitalknight.ridiculousfreekick',
#  'com.aldagames.zombero.bullet.hell',
#  'com.halfbrick.dantheman',
#  'com.kunpo.virus',
#  'com.feelnside.touchdownmaster',
#  'tdcgame.zombie.idle.defense',
#  'com.robtopx.geometrydashworld',
#  'com.barsstudios.crazyarrow',
#  'bcom.rrdianshiase.table',
#  'com.sandboxol.blockymods',
#  'invaders.os.galaxy.space.shooter.attack.classic',
#  'com.mediocre.smashhit',
#  'com.slash.girl.redfish',
#  'com.agent.action',
#  'com.nekki.vector',
#  'com.YsoCorp.FuryCars',
#  'com.ketchapp.knifehit',
#  'com.crazylabs.light.it.up',
#  'com.kongregate.mobile.run.google',
#  'com.kwalee.gofish1',
#  'com.gigantic.clawee',
#  'com.supersolid.snake',
#  'com.bentostudio.ballsvsblocks',
#  'com.kobgames.skaterrace',
#  'com.triwin.cash.dozer',
#  'com.superwings.jettrun',
#  'com.eg.deathpark',
#  'com.honeyponey.catjump',
#  'com.highcore.hoopstars',
#  'com.kongregate.mobile.burritobison3.google',
#  'com.deerslab.dinoTREX',
#  'com.turner.cnplay',
#  'com.lego.friends.heartlake',
#  'com.os.space.force.galaxy.alien',
#  'com.keplerians.evilnun',
#  'com.robtopx.geometrydashmeltdown',
#  'com.crazylabs.sausage.io',
#  'com.rovio.angrybirdsfriends',
#  'slingshot.building.destroy',
#  'com.JindoBlu.TwoPlayerGamesChallenge',
#  'com.cscmobi.merge.plant',
#  'com.bigframes.color_road',
#  'com.blobbyfishgames.apechase',
#  'com.sdsd.adsh',
#  'net.updategames.granny',
#  'misplayer.games.archery',
#  'com.crazylabs.coin.rush',
#  'comme.dragondrill.minigame',
#  'com.playsidestudios.monkeyropes',
#  'com.acoin.ballz.bricks.breaker',
#  'com.ketchapp.bikerush',
#  'com.mobirix.swipebrick2',
#  'com.bike.jump',
#  'com.bigfishgames.cookingcrazegooglef2p',
#  'com.sega.sonic4episode2',
#  'myandroid.fphoenix.fastspinner',
#  'com.cookingcity.chef.kitchen.craze.fever',
#  'com.custom.goescape',
#  'com.CubeCubeSports.Cubic234PlayerGames',
#  'io.voodoo.dune',
#  'com.eg.antarctica88',
#  'com.rocket.dragon.epic',
#  'com.kwalee.wantedgp',
#  'com.outfit7.talkingtomcandyrun',
#  'games.airion.townfights',
#  'com.mobirix.abmon',
#  'com.attackgalaxyshooter.galaxyspaceshooter2020',
#  'com.linkdesks.jewellegend',
#  'com.devsisters.gb',
#  'com.playgendary.polyspherecoolgame',
#  'com.nomonkeys.ballblast',
#  'com.sonypicturestelevision.qbert',
#  'com.johnemulators.johngbalite',
#  'com.spungegames.failybrakes',
#  'com.mnightt.slices',
#  'com.waterdrop.stickman.global',
#  'com.superluckycasino.hotvegas.slots.vegas.android.free',
#  'com.rocket.dragon',
#  'com.azurinteractive.humanevolution',
#  'com.martinmagni.fancade',
#  'line.color.adventure',
#  'com.jds.binr',
#  'com.dpspace.rocketsky',
#  'com.ubisoft.hungrydragon',
#  'com.coolmath_games.coolmath',
#  'bts.kpop.piano.music.tiles',
#  'com.smartstudygames.babyshark8bit.googlemarket',
#  'com.raongames.growcastle',
#  'io.voodoo.paperio',
#  'com.istomgames.engine',
#  'eu.bandainamcoent.pacman256',
#  'com.redsunpro.fallguyshexagone',
#  'com.match3blaster.DropStackBallFall',
#  'com.my.cooking.chef.kitchen.craze.fever',
#  'mini.zoo.crafting.exploration.creative.survival',
#  'com.wolvesinteractive.motortour',
#  'com.ketchapp.rider',
#  'com.ivy.winwing',
#  'com.vl.rollyhill',
#  'com.ankama.dragnboom',
#  'com.sausageflip.game',
#  'com.bigair.FBENG',
#  'com.mtsfreegames.princessrun3d',
#  'com.InkosGames.HoleIn',
#  'com.abi.move.stop.io',
#  'io.voodoo.stackjump',
#  'at.ner.lepsWorld2',
#  'com.setsnail.daddylonglegs',
#  'com.lawson.tower',
#  'com.baspin.barbershop',
#  'com.game.beerpong',
#  'com.kwalee.drawit',
#  'com.playgendary.coffeeshop3d',
#  'com.XTechStudios.snakeIO',
#  'com.mojang.minecraftpe',
#  'xyz.deeppipes',
#  'com.robtopx.geometryjump',
#  'com.fastemulator.gba',
#  'com.epsxe.ePSXe',
#  'com.rockstargames.gtavc',
#  'com.johnemulators.johngba',
#  'com.fastemulator.gbc',
#  'com.rockstar.maxpayne',
#  'it.dbtecno.pizzaboygbapro',
#  'com.ngmoco.pocketgod',
#  'com.halfbrick.fruitninja',
#  'com.icorewwwi.vDS',
#  'com.sega.sonic4epi',
#  'com.johnemulators.johngbc',
#  'com.retroloungelab.resetcollection',
#  'com.mtvn.SBmoviegame',
#  'com.nekki.vector.paid',
#  'com.worms3.app',
#  'com.explusalpha.NesEmu',
#  'com.NamcoNetworks.MsPacMan',
#  'com.madfingergames.SamuraiIIAll',
#  'com.snkplaymore.kof2012a',
#  'cc.peacedeath.peacedeath',
#  'com.explusalpha.MdEmu',
#  'com.flukedude.impossiblegame',
#  'com.snkplaymore.android007',
#  'com.snkplaymore.android001',
#  'com.jdroid.gtavccheater',
#  'org.mupen64plusae.v3.fzurita.pro',
#  'com.mediocre.grannysmith',
#  'net.kairosoft.android.bouken_en',
#  'com.zenstudios.MarvelPinball',
#  'com.dotemu.neogeo.mslug3',
#  'com.fms.emu',
#  'net.floatingpoint.android.arcturus',
#  'com.sonicjump.sonicjump',
#  'com.stevesnyderart.BalanceTheBeam2',
#  'com.dotemu.ddtrilogy',
#  'com.nostalgiaemulators.nesfull',
#  'com.neutronemulation.retro8',
#  'com.explusalpha.GbaEmu',
#  'com.grapefrukt.games.bore',
#  'com.crescentmoongames.swordshot',
#  'org.lukeallen.bomberfull',
#  'com.square_enix.android_googleplay.finalfantasy2',
#  'com.dotemu.neogeo.mslug',
#  'it.dbtecno.pizzaboypro',
#  'paulscode.android.mupen64plus',
#  'com.square_enix.android_googleplay.subarashikikonosekai_solo',
#  'com.herocraft.game.hyperforma.cyber.hack.arcade.premium',
#  'org.uoyabause.uranus.pro',
#  'jp.co.taito.am.spaceinvaders',
#  'com.dotemu.neogeo.samsho2',
#  'nl.palatamedia.miner',
#  'com.explusalpha.GbcEmu',
#  'com.mightykingdom.shopkinsrun',
#  'jp.co.capcom.mobilemakaiwd',
#  'com.explusalpha.NeoEmu',
#  ...]

# %%
# It appears that there is no overlap in app ids.

len(uniqueappidlist)
# Out:
# 5150

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# # Getting Reviews

# %%
# This will do most of the work for us.

from google_play_scraper import app

# Doing a test run
result = app(
    'com.nianticlabs.pokemongo',
    lang='en',
    country='us'
)

# %%
# Checking what I get in the dictionary.

result
# Out:
# {'title': 'Pokémon GO',
#  'description': 'Join Trainers across the globe who are discovering Pokémon as they explore the world around them. Pokémon GO is the global gaming sensation that has been downloaded over 1 billion times and named “Best Mobile Game” by the Game Developers Choice Awards and “Best App of the Year” by TechCrunch.\r\n_______________\r\n\r\nUNCOVER THE WORLD OF POKÉMON: Explore and discover Pokémon wherever you are!\r\n \r\nCATCH more Pokémon to complete your Pokédex!\r\n \r\nJOURNEY alongside your Buddy Pokémon to help make your Pokémon stronger and earn rewards!\r\n\r\nCOMPETE in epic Gym battles and...\r\n\r\nTEAM UP with other Trainers to catch powerful Pokémon during Raid Battles!\r\n \r\nIt’s time to get moving—your real-life adventures await! Let’s GO!\r\n_______________\r\n\r\nNotes: \r\n\r\n- This app is free-to-play and offers in-game purchases. It is optimized for smartphones, not tablets.\r\n- Compatible with Android devices that have 2GB RAM or more and have Android Version 4.4–7.0+ installed.\r\n- Compatibility is not guaranteed for devices without GPS capabilities or devices that are connected only to Wi-Fi networks.\r\n- Application may not run on certain devices even if they have compatible OS versions installed.\r\n- It is recommended to play while connected to a network in order to obtain accurate location information.\r\n- Compatibility information may be changed at any time.\r\n- Please visit PokemonGO.com for additional compatibility information. \r\n- Information current as of July 11, 2019.',
#  'descriptionHTML': 'Join Trainers across the globe who are discovering Pokémon as they explore the world around them. Pokémon GO is the global gaming sensation that has been downloaded over 1 billion times and named “Best Mobile Game” by the Game Developers Choice Awards and “Best App of the Year” by TechCrunch.<br>_______________<br><br>UNCOVER THE WORLD OF POKÉMON: Explore and discover Pokémon wherever you are!<br> <br>CATCH more Pokémon to complete your Pokédex!<br> <br>JOURNEY alongside your Buddy Pokémon to help make your Pokémon stronger and earn rewards!<br><br>COMPETE in epic Gym battles and...<br><br>TEAM UP with other Trainers to catch powerful Pokémon during Raid Battles!<br> <br>It’s time to get moving—your real-life adventures await! Let’s GO!<br>_______________<br><br>Notes: <br><br>- This app is free-to-play and offers in-game purchases. It is optimized for smartphones, not tablets.<br>- Compatible with Android devices that have 2GB RAM or more and have Android Version 4.4–7.0+ installed.<br>- Compatibility is not guaranteed for devices without GPS capabilities or devices that are connected only to Wi-Fi networks.<br>- Application may not run on certain devices even if they have compatible OS versions installed.<br>- It is recommended to play while connected to a network in order to obtain accurate location information.<br>- Compatibility information may be changed at any time.<br>- Please visit PokemonGO.com for additional compatibility information. <br>- Information current as of July 11, 2019.',
#  'summary': 'Step outside and catch Pokémon in the real world! Collect & battle with others.',
#  'summaryHTML': 'Step outside and catch Pokémon in the real world! Collect &amp; battle with others.',
#  'installs': '100,000,000+',
#  'minInstalls': 100000000,
#  'score': 4.0529737,
#  'ratings': 13713779,
#  'reviews': 5531035,
#  'histogram': [2063257, 456998, 850090, 1663100, 8680334],
#  'price': 0,
#  'free': True,
#  'currency': 'USD',
#  'sale': False,
#  'saleTime': None,
#  'originalPrice': None,
#  'saleText': None,
#  'offersIAP': True,
#  'inAppProductPrice': '$0.99 - $99.99 per item',
#  'size': 'Varies with device',
#  'androidVersion': '5.0',
#  'androidVersionText': '5.0 and up',
#  'developer': 'Niantic, Inc.',
#  'developerId': 'Niantic,+Inc.',
#  'developerEmail': 'pokemon-go-support@nianticlabs.com',
#  'developerWebsite': 'https://niantic.helpshift.com/a/pokemon-go/?p=web',
#  'developerAddress': 'One Ferry Building, Suite 200\nSan Francisco, CA 94111',
#  'privacyPolicy': 'https://nianticlabs.com/privacy/pokemongo/en',
#  'developerInternalID': '7632469272431224129',
#  'genre': 'Adventure',
#  'genreId': 'GAME_ADVENTURE',
#  'icon': 'https://lh3.googleusercontent.com/wPfLmWBJwsPdBhsFXc8X4QZOOvePWjoOBLFXXCwyegjRwYOuabmG5cynthlW0HDgy9s',
#  'headerImage': 'https://lh3.googleusercontent.com/KgDQ-Kjb2B7_jDP-8KmQDNhAmP2lqAV_w3zArOCBL7YZnQ02Qqp4VTlgdocO-4MFk4s',
#  'screenshots': ['https://lh3.googleusercontent.com/PbXsZpBreImadKH9ii50XTti-ykvwKBTZ9kq7CAbJdC7h7ccCbuKoJeHZu8Fc7n3oULh',
#   'https://lh3.googleusercontent.com/vnv6k22XD1tetl6U4I3pTy0iLhsISHeS-u6irGuejgPyo8OBCRUBEiGgdKI2-yS20SsD',
#   'https://lh3.googleusercontent.com/xfyqKVa_XrNI7T2sMXPqUGiiJkXDJlM4YqXQqbYunoL5w1N4qgLZLNULUzNinWEr9PY',
#   'https://lh3.googleusercontent.com/aVzE1thT4zDocUQfPP1EtPq6jS15IIdjB0b7gtLRC9v_irr6gesP5RyiNb70ljh-Max6',
#   'https://lh3.googleusercontent.com/Vek-tDWCQXnLFloZ3KFjHjSYRD5w2EMz3K0sGRhOFCIiJ2sX1prBsFKnbP_TcqGBLg'],
#  'video': 'https://www.youtube.com/embed/v4YZqOfhEc8?ps=play&vq=large&rel=0&autohide=1&showinfo=0',
#  'videoImage': 'https://i.ytimg.com/vi/v4YZqOfhEc8/hqdefault.jpg',
#  'contentRating': 'Everyone',
#  'contentRatingDescription': 'Mild Fantasy Violence',
#  'adSupported': None,
#  'containsAds': False,
#  'released': 'Jul 6, 2016',
#  'updated': 1600306219,
#  'version': '0.187.1',
#  'recentChanges': 'Trainers! There’s always something new in Pokémon GO! You can now enjoy the following:\r\n\r\n- Mega Evolution has made its way to the world of Pokémon GO! Defeat Mega-Evolved Pokémon in raids to earn Mega Energy!\r\n- Reality Blending has rolled out to more devices! With Reality Blending, Pokémon will be able to move behind objects, either partially or completely, while AR features are activated.\r\n- Personalize Gifts you send to friends! Check out the in-game store for new stickers you can send.',
#  'recentChangesHTML': 'Trainers! There’s always something new in Pokémon GO! You can now enjoy the following:<br><br>- Mega Evolution has made its way to the world of Pokémon GO! Defeat Mega-Evolved Pokémon in raids to earn Mega Energy!<br>- Reality Blending has rolled out to more devices! With Reality Blending, Pokémon will be able to move behind objects, either partially or completely, while AR features are activated.<br>- Personalize Gifts you send to friends! Check out the in-game store for new stickers you can send.',
#  'comments': ['Been playing this game since it came out and had many issues at the launch of it. Those same issues of freezing up, heavily lagging, constant errors, to name just a few, are plaguing this game again, making it difficult to play and be competitive. So sad to see how much this game started badly and its now taking its turn back into that hole. I hope the issues are fixed soon else it may become unplayable.',
#   "The game used to be great, but with the new update battling is impossible. Me and a friend could have full bars and be next to each other yet it says weak connection over and over. Raiding now is a problem because you can be kicked out halfway through, try to rejoin but it continues to say that the raid group doesn't exist. You can put in multiple tickets with Niantic but they obviously don't care because they make money either way.",
#   "It's hard to know which Pokémon you need to use in battles since you can't view their move sets when selecting your party. Also, the stats system is ruined. Legendary Pokémon stats get nerfed but yet you can't use them in gyms? Stats need to be as they are in the actual games. Rocket grunts shouldn't be able to take out my Pokémon so easily. Making it a challenge is one thing, but don't use Pokémon if you're not sticking to how Pokémon should be.",
#   "It's a fun game for casual playing if nothing else to do. The problem is the catch rate for raids on anything at all is terrible like they want you to pay more money on passes or something to get what you want. The battle system is a sad joke. Player speed for who taps faster is not smart because of connection and lag. Based off an actual battle from the old games certain pokemon shouldn't stand a chance either but win anyway. Do a Pokemon stadium or nintendo battle system otherwise it's trash.",
#   'I love the game. Althought it can be very repetitive... and its easy to burn out. A huge problem im currently having is the games lack of rewards for potions... even though team rocket is forced right into your face. Potions should be more common for the amount of pokemon that die for raids, gym battles and team rocket battles... its ruining my ability to play the game as i cannot progress...',
#   "I just got today for the community day and I can't even touch the pokemon to catch or even try to access the menu I tried everything! I turned my phone off and on, nothing. I cleared cache and data, nothing. I uninstalled the game and opened again, nothing. I'm mad that there is no real way to call to get answers for this. It needs to be fixed",
#   "Fun. Wish the battle portion wasn't down or unavailable all the time. Whats going on??? Also I paid for a raid pass and got it. Was invited to a raid and we got to the battle my pokemon wouldn't attack. No matter how many times I touched the screen I couldn't attack. Was a waste of my raid pass and the money I spent to get the coins to then trade to get the pass. Was able to change pokemon but none of them would fight. Please fix your issues. I should get a refund for the .99 cent!!",
#   "Im having a problem with the incense in the last events starting in fest and still on going. The incense it works for about 30 minutes or so spawning everything, and then its just starts spawning the animation of a pokemon despaning, making the remaining time of that incense useless and make the event empty for me because I'm expecting the incense to work and in the end it dosen't. And the other thing sometimes when doing that the incense will spawn pokemon just not from the event.",
#   'Game is good, i already battled 3 times in a mega raid, but there is no completion is coming in research. I fought with mega Charizard X and Y and Venasaur. First time, I thought may be some big had come, after 2 more fights, there is still not completion is coming in research for battle in mega raid. Please check this issue. Thanks',
#   "Great game but the street maps dont load for me. For me its the only thing stopping me from giving it 5 stars. Other than the traditional lag at times during raids, great game! Edit: If you have problems loading the street maps(sidewalks, terrain, etc.),go to your device settings, clear data (not cache). You will then have to re-login to POGO. Then your maps should be loaded correctly. The game will take a little longer than normal to load after you delete data. I've done this 4 times and works like a charm. I have given the 5th star for the rating, amazing game!",
#   'Everything is perfect. It is greatly enjoyable and helpful when giving me a care to walk and go outside more. Especially in this extremely hot state. Something I would love to see is a Pokemon candy converter. I have 91 candies for a fully powered up Heracross and am unlikely to use them. Please, possibly install this somehow at some point. Even just rudimentary with two pokemon as one to give and one to receive. It would be greatly interesting and helpful',
#   "Crashes non stop, and a Pokemon just appears and disappears non stop around me and nothing else will spawn while that's happening. It's moving around constantly so I can't catch it or even see what it is.. blocks me from catching anything else and wastes community day time cause it'll be the only thing on my screen. My kids ipads crash every time you go into the shop, friends list or medals",
#   "The Pokeball Plus is not working on a pixel 3 with the android 11 update. It's already a pain to get the pokeball to connect and work properly as it is, and now it's not working at all. Tried with 2 different pokeball plus devices and two pixel 3 phones, tried uninstalling, reinstalling, restarting, etc., and still there is no connection.",
#   "I'm having problems buying event tickets in the shop. I click on the event ticket and it takes me to a blank screen. This has happened multiple times over multiple community days. I've also wasted remote raid passes, I've used 2 and wasted them because my pokémon wouldn't attack no matter what I did. Please fix this...",
#   "June 14, 2020 - 3/5 Great game but it has some issues. Always when I'm logged out, settings are reset to defaults. Without linking account to third party services it can happened several times a day. (Even when linked it happens sometimes, probably after updates) Game is using date format (DD-MM-YYYY) and you can't change it... September 20, 2020 - 1/5 Nothing has been fixed and they introduced super annoying popups to update ARCore every time you try to catch pokemon, if camera access is disabled in system is disabled there will be two popups... - I don't use AR and never will, this popups destroyed game for me...",
#   "I love the game but I've been having issues logging in these last few days. I've had to uninstall it several times and even then its only worked twice. I also feel you should be able to increase your CP by being able to battle wild pokemon and make it easier to get items without having to use pokestops or buying them. Have random items laying around like they do with the actual game.",
#   "This game is absolutely awesome the only way it could be bad as when it says there's no signal even know inside your house and there's one more wise I said that could improve is where you're at your house and says you're going too fast and just kind of glitching all over the place but if they can fix that that's really good",
#   'Update 3: still having issues after 0.187.1 Update 2: even after 0.185.3, still same issue. Update: still not working. Uninstalling. The game freezes after 10 seconds of loading I to the world!!! This has been happening for over a month. Currently using Samsung galaxy note 9 with exynos chipset. Tried reinstalling, rebooting my phone, clearing cache and data.',
#   "Everything you go to catch a pokemon (what the game is based around) you get a pop-up saying you need to update the ar. Always leading you to the ar update page. Even if up to date the message remains. I've cleared cache and app data for both and it did nothing. It seriously hurts gameplay. Please fix this soon",
#   "I have only played this game for about 2 weeks now and I ABSOLUTELY LOVE IT! The detail when looking at your pokemon looks on point and the mechanics in general are just great. Haven't been able to play this game since it was released but I can tell you now, the 4 year wait was worth it! Also Niantic maybe add a gym pass, just like the raid pass. Would love to see that 😄👍",
#   "One more trash update managed to slip pass quality control, all for the sake of getting all the money from stupid consoomers. The game is running slower than a slime mold. Crashes often, and with no apparent reason at all. I won't spare even a single damn penny anymore for this disappointing game.",
#   "I've been seeing some problems with the game, lately. For one thing, when I try to throw a curveball, sometimes when I release my finger to throw, the ball goes right back to its ready position, which is getting annoying. For another, when I scroll through my Pokémon collection, it jumps further up or down than I want to go.",
#   'Unless you give full permission to camera the app limits what you can do. They also seem to be swamped on the support side right now. The game can be fun and it will help you get out of the house. The micro transaction currency can be earned in game but if you want to be the very best you have to pay to have the best odds of getting good raid Pokemon.',
#   "Wish they would add option to 'buy remote raid pass now' if you don't have any when trying to join a raid invite. Takes too long to close that screen, wait for it to zoom back to your avatar, open the store, scroll to the passes, purchase it, then try to get back to the raid invite before the (maybe)25 seconds is up...",
#   "I'm at level 39, nearing the maximum level of 40. I've been playing off and on since 2016. My peak activity has been within the past six months. Negatives: 1) Bugs. From raids to PVP battles, I've lost many, many rewards due to some sort of technical error. 2) Support. I don't always receive thoughtful replies to my concerns. I make a lot of purchases in the app and I feel like the care isn't consistently given to me as a customer. Positives: 1) It's pretty fun. 2) The game keeps evolving! :)",
#   "Super fun game that has improved greatly over the years. I live in the middle of nowhere (literally surrounded by cornfields) and there were NEVER any pokemon that spawned up. Now I'm actually getting some that show up around my house. ----- Recently however, I've been having issues with my character not moving. I will be walking and my character will stay frozen for close to 30 seconds and then run to my current location. I have good signal, so I'm not sure what the problem is.",
#   "I like all the things to Pokemon go expect the fact that when you leave a Pokemon at a gym and it is defeated, you sometime get the coin, and sometimes you don't. The new remote raiding system is also very good, but the cost for the remote passes are just too much, and we should now have remote trading with friends too.",
#   'I\'ve been playing since 2016. Hardcore players constantly whine about it but then keep playing. Other people are like, "Oh I didn\'t know people are still playing that game?" They\'re constantly introducing new elements to make it fun. I love raid battles and the friendships I\'ve made by finding other players through the game on Slack & through FB to help with raid battles, gifts, traiding, trainer battles, etc. I can take a break for a while, and come back to a game that still fun to play!',
#   "I can only give this game 3 stars for now. When I want to catch a pokemon is straight goes to AR and AR does not work for me. Its very annoying and when I want to play with my buddy pokemon I have to go on AR and it only gives me a blank screen. Please fix this issue because it's not comfortable for me to play on.",
#   "I like it. I just hate trainer battles. Why? Because the opponent always charges a move in one hit. Also, the opponents are usually a bot so that is the reason why. Also, gyms and pokestops are far away from where I live. And another thing, one time I couldn't even attack and I had perfect connection. So can you please change everything?",
#   "Lastest update is garbage. Sent invites to friends and request are lagging or not going through. Game restarts when viewing other windows. Pokeball randomly curving or stopping in mid air when thrown. Lastly, when viewing eggs it shows that they are already in an incubator. Current issues; open up trade stays on white screen and can't see Pokemon when trading.",
#   "Pay to win. Pointless to own more than one gym. Max coins earned is 50 a day. Cheapest pokeballs is 100. Mega evolving takes over a week to grind for. It lasts for 4 hours. Very limited item space but you can pay for more. Areas are extremely unbalanced. Why can't we have a normal Pokémon battle? Nobody wants this tap the screen rubbish.",
#   'Its great but when you back out when your about to pick a team,you basicly cannot pick a team anymore;please niantic,i cant choose a team.you cant also play this game naturally if your a kid.also their issue support,micro transaction, and mega raid are so broken.i think they need to fix it.ill gonna reedit this if they fix and balanced this',
#   "I lovethe game dont get me wrong but my character now won't move because for some reason every time I tried to tap on a Pokemon it won't register as a tap and every time I try to see if I can spend my camera view around it doesn't spend I tried everything I tried restarting I tried deleting the game I tried to lead in The Catch the data and then re downloading the game and re-linking my Facebook but nothing so I'm pretty pissed about it and everything I look up it says it's that",
#   "My adventure sync. Doesn't work. Not big issue though. However, I don't have anyone known around me who plays Pokemongo and hence I play alone and I have in game friends from far away. Hence I miss on some of major features such as 3-5 star raids, trading, etc. Therefore please introduce a feature where we can add friends from the game and also chat with the in game friends. Rest, I love the game quite alot.",
#   'Good game. More gyms and stops needed. Pls let others above level 20/25 make pokestops referencing the Google map. Many pokestops created by trainers are located 50-100meteres away from the actual spot so that that particular trainer who nominated it gets the advantage of accessing it from their home. Pls fix that',
#   "Would be a fantsic game were it not for the fact it feeezes itself up so often. I have a decent phone with a decent sercice. However it when I am around an area with many pokestops, its slows down tremendously and i have to restart the game over and over and over. I love playing the game but when i can't battle people becuse the connection is always weak with full LTE connection, it sucks a lot...",
#   "I am still loving this game. But please let me know why all of a sudden when i battle, why the person i am battling gets 3 shields and i only get 2. And after a battle is over i freeze and have to restart? Please see if you can fix this. Thank you. I am in the country and don't have a stop near me but there is a little country store near me. Could you put a stop there please.? It would benifit so many players. Thank you",
#   'This game has extreme amount of bugs. Only this morning, I received 9 error notices while playing PVP. Error with scrolling in the pokemon storage. In 25% of the raids, I cannot attack the boss, but attacks from the boss counts as my own (increasing the charge bar)... In 5-10% of the cases, even if you win the raid, the ball freezes and you have to restart the app.',
#   'I really like this game! I wish that it would go back to the classic turn-based system seen in almost if not all of the Pokemon games. I get that being an entrepreneur requires taking risks, but I enjoy the turn-based system more. And battling the Pokemon and then catching them. But it is easier to do that and then catch another Pokemon in the area. Like I said, I really enjoy the game, and keep up the good work! Also, make the stones and items needed to evolve pokemon more readily available.'],
#  'appId': 'com.nianticlabs.pokemongo',
#  'url': 'https://play.google.com/store/apps/details?id=com.nianticlabs.pokemongo&hl=en&gl=us'}

# %%
# Checking which keys I want to keep to use as features.

result.keys()
# Out:
# dict_keys(['title', 'description', 'descriptionHTML', 'summary', 'summaryHTML', 'installs', 'minInstalls', 'score', 'ratings', 'reviews', 'histogram', 'price', 'free', 'currency', 'sale', 'saleTime', 'originalPrice', 'saleText', 'offersIAP', 'inAppProductPrice', 'size', 'androidVersion', 'androidVersionText', 'developer', 'developerId', 'developerEmail', 'developerWebsite', 'developerAddress', 'privacyPolicy', 'developerInternalID', 'genre', 'genreId', 'icon', 'headerImage', 'screenshots', 'video', 'videoImage', 'contentRating', 'contentRatingDescription', 'adSupported', 'containsAds', 'released', 'updated', 'version', 'recentChanges', 'recentChangesHTML', 'comments', 'appId', 'url'])

# %%
featurekeys = ['title', 'installs', 'minInstalls', 'score', 'ratings', 'reviews', 'histogram', 'price', 'free', 'offersIAP', 'size', 'genre', 'genreId', 'released', 'contentRating']

# %%
# Filtering dictionary so I only get results I want.

filteredresult = dict((k, result[k]) for k in featurekeys if k in result)
filteredresult
# Out:
# {'title': 'Pokémon GO',
#  'installs': '100,000,000+',
#  'minInstalls': 100000000,
#  'score': 4.0529737,
#  'ratings': 13713779,
#  'reviews': 5531035,
#  'histogram': [2063257, 456998, 850090, 1663100, 8680334],
#  'price': 0,
#  'free': True,
#  'offersIAP': True,
#  'size': 'Varies with device',
#  'genre': 'Adventure',
#  'genreId': 'GAME_ADVENTURE',
#  'released': 'Jul 6, 2016',
#  'contentRating': 'Everyone'}

# %%
# Now to make a function that does all of the above

def givemeinfo(appid):
    result = app(
    appid,
    lang='en',
    country='us')
    
    featurekeys = ['title', 'installs', 'minInstalls', 'score', 'ratings', 'reviews', 'histogram', 'price', 'free', 'offersIAP', 'size', 'genre', 'genreId', 'released', 'contentRating']
    
    filteredresult = dict((k, result[k]) for k in featurekeys if k in result)
    
    return filteredresult

# %%
# 100 entries takes about 30 seconds.
# Doing it in pieces in case it messes up
# There was an error that fixed itself around 2500 if done in smaller intervals

listofdictinfo = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[:1000]))
listofdictinfo
# Out:
# [{'title': 'Among Us',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.4352665,
#   'ratings': 2069272,
#   'reviews': 1070149,
#   'histogram': [163295, 43146, 91796, 202372, 1568663],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 15, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Scribble Rider',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.875305,
#   'ratings': 216872,
#   'reviews': 90486,
#   'histogram': [39384, 11069, 15627, 21915, 128877],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '123M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 23, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Call of Duty®: Mobile',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.478295,
#   'ratings': 10747377,
#   'reviews': 4949651,
#   'histogram': [783285, 203338, 400469, 1062865, 8297420],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '94M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 30, 2019',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Hitmasters',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.091615,
#   'ratings': 279506,
#   'reviews': 98735,
#   'histogram': [39089, 10405, 18016, 30292, 181704],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '85M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Draw Defence',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.95,
#   'ratings': 972,
#   'reviews': 389,
#   'histogram': [185, 38, 48, 68, 633],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '76M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Sniper 3D: Fun Free Online FPS Shooting Game',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3793664,
#   'ratings': 13508949,
#   'reviews': 4726429,
#   'histogram': [836058, 308805, 964019, 2185422, 9214645],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 13, 2014',
#   'contentRating': 'Mature 17+'},
#  {'title': 'aquapark.io',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 3.9464014,
#   'ratings': 1047381,
#   'reviews': 491400,
#   'histogram': [172239, 49372, 76316, 113812, 635642],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '79M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 14, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Smashy Road: Wanted 2',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.125356,
#   'ratings': 3612,
#   'reviews': 1624,
#   'histogram': [308, 133, 391, 741, 2039],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '134M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'slither.io',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.0594683,
#   'ratings': 6282186,
#   'reviews': 2609369,
#   'histogram': [842277, 250189, 498610, 791698, 3899412],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 25, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Kick the Buddy',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 3.9639404,
#   'ratings': 2835383,
#   'reviews': 1222495,
#   'histogram': [489890, 120176, 187222, 243090, 1795005],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 22, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Garena Free Fire: 3volution',
#   'installs': '500,000,000+',
#   'minInstalls': 500000000,
#   'score': 4.046586,
#   'ratings': 62977098,
#   'reviews': 38233599,
#   'histogram': [11256979, 1914566, 2710583, 3850455, 43244515],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '46M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 7, 2017',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Samurai Flash',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9850175,
#   'ratings': 31759,
#   'reviews': 11691,
#   'histogram': [4647, 1741, 2460, 3503, 19408],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '59M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 23, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Fan of Guns',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.156909,
#   'ratings': 88982,
#   'reviews': 52747,
#   'histogram': [11091, 2680, 5821, 10971, 58419],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 29, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Mario Kart Tour',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.0392637,
#   'ratings': 1804301,
#   'reviews': 821332,
#   'histogram': [259078, 68822, 120423, 249832, 1106146],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '126M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': '

#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '15M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 1, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Brawlhalla',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.249917,
#   'ratings': 91040,
#   'reviews': 40791,
#   'histogram': [8781, 2675, 6367, 12402, 60815],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 4, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Truck Driver City Crush',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.076905,
#   'ratings': 125920,
#   'reviews': 55073,
#   'histogram': [19408, 5256, 6651, 9532, 85073],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '94M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 17, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Real Time Shields',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.7102177,
#   'ratings': 12117,
#   'reviews': 3045,
#   'histogram': [2253, 801, 1360, 1492, 6211],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '109M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 27, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Robbery.io',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4880953,
#   'ratings': 84,
#   'reviews': 28,
#   'histogram': [5, 1, 6, 8, 64],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': "Push'em all",
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 3.9697797,
#   'ratings': 183934,
#   'reviews': 62815,
#   'histogram': [27371, 9040, 15160, 22565, 109798],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '46M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': "Chuck E.'s Skate Universe",
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.313466,
#   'ratings': 98819,
#   'reviews': 22255,
#   'histogram': [11156, 2512, 4633, 6412, 74106],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '44M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 29, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Stick Warfare: Blood Strike',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.2283206,
#   'ratings': 9323,
#   'reviews': 4456,
#   'histogram': [849, 368, 716, 1259, 6131],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 10, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Stickman 3D - Street Gangster - Street Gangs',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.4504504,
#   'ratings': 2304,
#   'reviews': 707,
#   'histogram': [145, 72, 124, 218, 1745],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Upstream Struggle',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.64,
#   'ratings': 231,
#   'reviews': 143,
#   'histogram': [11, 2, 2, 25, 191],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 5, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Helix Jump',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.060265,
#   'ratings': 4235824,
#   'reviews': 1777987,
#   'histogram': [565544, 174754, 330081, 533948, 2631497],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 12, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'The Survival Hunter Games 2',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9079857,
#   'ratings': 216797,
#   'reviews': 81178,
#   'histogram': [40038, 10341, 13470, 18630, 134318],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '131M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 9, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'MORTAL KOMBAT',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.197278,
#   'ratings': 4019209,
#   'reviews': 1608814,
#   'histogram': [473814, 132379, 244125, 445662, 2723229],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 4, 2015',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Real Gangster Crime',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.0847135,
#   'ratings': 770962,
#   'reviews': 303947,
#   'histogram': [117240, 28389, 44711, 62098, 518524],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '100M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 31, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Dead by Daylight Mobile',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.1434884,
#   'ratings': 158805,
#   'reviews': 77441,
#   'histogram': [16591, 5914, 12992, 25924, 97384],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 15, 2020',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Bed Diving',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.2479339,
#   'ratings': 1258,
#   'reviews': 512,
#   'histogram': [416, 104, 83, 62, 593],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '66M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 3, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Gun Gang',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.3110285,
#   'ratings': 8193,
#   'reviews': 2928,
#   'histogram': [2691, 406, 446, 964, 3686],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '82M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 8, 2020',
#   'contentRating': 'Teen'},
#  {'title': '🐓Chicken Gun🐓',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3645396,
#   'ratings': 73920,
#   'reviews': 39698,
#   'histogram': [7302, 2052, 2836, 5934, 55796],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '73M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Feb 19, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Rocket Royale',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4

#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '95M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 9, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Desert Riders',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.238432,
#   'ratings': 44086,
#   'reviews': 13688,
#   'histogram': [3587, 1829, 4120, 5497, 29053],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 28, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Snipers vs Thieves: Classic!',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.2178574,
#   'ratings': 2924,
#   'reviews': 1546,
#   'histogram': [334, 62, 188, 386, 1954],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 3, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Robotics!',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.7098625,
#   'ratings': 35035,
#   'reviews': 16366,
#   'histogram': [6197, 2511, 3977, 4922, 17428],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '106M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'MaskGun Multiplayer FPS - Free Shooting Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2038465,
#   'ratings': 445388,
#   'reviews': 255569,
#   'histogram': [53645, 13918, 25466, 47328, 305031],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 15, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Sniper Zombies: Offline Game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.4416666,
#   'ratings': 33861,
#   'reviews': 10344,
# ...
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '94M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'SpongeBob: Sponge on the Run',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.228155,
#   'ratings': 2067,
#   'reviews': 650,
#   'histogram': [261, 60, 90, 190, 1466],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '19M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 22, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Vector Full',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.102941,
#   'ratings': 38253,
#   'reviews': 9946,
#   'histogram': [5103, 1537, 2601, 4088, 24924],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '91M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 26, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Worms 3',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.8380191,
#   'ratings': 70348,
#   'reviews': 15118,
#   'histogram': [13383, 2951, 4397, 10562, 39055],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 28, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'NES.emu',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.632768,
#   'ratings': 2378,
#   'reviews': 936,
#   'histogram': [147, 0, 53, 174, 2004],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 9, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Ms. PAC-MAN',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.386117,
#   'ratings': 5650,
#   'reviews': 2298,
#   'histogram': [367, 245, 294, 674, 4070],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 15, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'SAMURAI II: VENGEANCE',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.436451,
#   'ratings': 11946,
#   'reviews': 4569,
#   'histogram': [744, 229, 759, 1547, 8667],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '48M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 24, 2011',
#   'contentRating': 'Teen'},
#  {'title': 'THE KING OF FIGHTERS-A 2012',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.9165154,
#   'ratings': 11047,
#   'reviews': 6687,
#   'histogram': [1694, 541, 982, 1604, 6226],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '24M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 30, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'Peace, Death!',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.6814017,
#   'ratings': 18607,
#   'reviews': 6203,
#   'histogram': [481, 300, 642, 1815, 15369],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '38M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 23, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'MD.emu',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.52459,
#   'ratings': 3001,
#   'reviews': 1429,
#   'histogram': [147, 24, 147, 467, 2216],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 27, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'The Impossible Game',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.939771,
#   'ratings': 20039,
#   'reviews': 3641,
#   'histogram': [3242, 847, 1536, 2663, 11751],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 25, 2010',
#   'contentRating': 'Everyone'},
#  {'title': "THE KING OF FIGHTERS '98",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.4161453,
#   'ratings': 17622,
#   'reviews': 6591,
#   'histogram': [1342, 410, 711, 2264, 12895],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.1M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 23, 2014',
#   'contentRating': 'Teen'},
#  {'title': "THE KING OF FIGHTERS '97",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.388679,
#   'ratings': 15938,
#   'reviews': 5776,
#   'histogram': [1263, 441, 741, 1884, 11609],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 13, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'JCheater: Vice City Edition',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.2322738,
#   'ratings': 4100,
#   'reviews': 1689,
#   'histogram': [1454, 160, 310, 331, 1845],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.7M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 2, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': 'M64Plus FZ Pro Emulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.49,
#   'ratings': 182,
#   'reviews': 99,
#   'histogram': [9, 7, 7, 20, 139],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.4M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 22, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Granny Smith',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.693268,
#   'ratings': 43173,
#   'reviews': 19278,
#   'histogram': [1796, 310, 1094, 2939, 37034],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 29, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Dungeon Village',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.606753,
#   'ratings': 13309,
#   'reviews': 3432,
#   'histogram': [383, 198, 634, 1837, 10257],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 2, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Marvel Pinball',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.7296417,
#   'ratings': 9241,
#   'reviews': 2586,
#   'histogram': [1806, 582, 702, 1364, 4787],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 6, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'METAL SLUG 3',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.967678,
#   'ratings': 15935,
#   'reviews': 6489,
#   'histogram': [2407, 830, 1156, 2018, 9524],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 11, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'VGBAnext - Universal Console Emulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2982454,
#   'ratings': 1142,
#   'reviews': 643,
#   'histogram': [100, 40, 70, 140, 792],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 19, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'ARC Browser',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.26,
#   'ratings': 457,
#   'reviews': 327,
#   'histogram': [45, 9, 36, 55, 312],
#   'price': 8.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '17M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 26, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Sonic Jump Pro',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.830819,
#   'ratings': 9376,
#   'reviews': 4140,
#   'histogram': [2213, 222, 272, 899, 5770],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 21, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Balance The Beam 2.0',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Double Dragon Trilogy',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.163014,
#   'ratings': 7346,
#   'reviews': 2273,
#   'histogram': [684, 392, 604, 1026, 4640],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.6M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 4, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'Nostalgia.NES Pro (NES Emulator)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.6065574,
#   'ratings': 2460,
#   'reviews': 905,
#   'histogram': [121, 40, 60, 242, 1997],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.7M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 26, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Retro8 (NES Emulator)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.7,
#   'ratings': 854,
#   'reviews': 608,
#   'histogram': [188, 17, 128, 51, 470],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 7, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'GBA.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.564815,
#   'ratings': 1454,
#   'reviews': 662,
#   'histogram': [80, 40, 67, 53, 1214],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 21, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'holedown',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.371901,
#   'ratings': 1215,
#   'reviews': 510,
#   'histogram': [10, 60, 150, 241, 754],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 25, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'SWORDSHOT',
#   'installs': '50+',
#   'minInstalls': 50,
#   'score': 4.923077,
#   'ratings': 13,
#   'reviews': 9,
#   'histogram': [0, 0, 0, 1, 12],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 16, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Atomic Bomber Full',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.4928827,
#   'ratings': 9475,
#   'reviews': 2598,
#   'histogram': [556, 168, 455, 1163, 7133],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.6M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 29, 2010',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'FINAL FANTASY II',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.4790998,
#   'ratings': 3124,
#   'reviews': 1228,
#   'histogram': [713, 201, 341, 613, 1256],
#   'price': 7.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 20, 2012',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'METAL SLUG',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8458843,
#   'ratings': 5737,
#   'reviews': 2307,
#   'histogram': [954, 311, 542, 784, 3146],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 19, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'Pizza Boy GBC Pro',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.68,
#   'ratings': 391,
#   'reviews': 269,
#   'histogram': [15, 0, 7, 47, 322],
#   'price': 4.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '11M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 27, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Mupen64Plus AE (N64 Emulator)',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.4527845,
#   'ratings': 4817,
#   'reviews': 1984,
#   'histogram': [1178, 350, 548, 595, 2146],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 18, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'The World Ends With You',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.7336154,
#   'ratings': 4737,
#   'reviews': 1442,
#   'histogram': [110, 60, 130, 380, 4057],
#   'price': 17.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 25, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Hyperforma Premium',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.75,
#   'ratings': 32,
#   'reviews': 27,
#   'histogram': [2, 0, 0, 0, 30],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '33M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 6, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Yaba Sanshiro Pro - Sega Saturn Emulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.19,
#   'ratings': 210,
#   'reviews': 151,
#   'histogram': [12, 10, 25, 38, 125],
#   'price': 5.6,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'SPACE INVADERS',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.59,
#   'ratings': 208,
#   'reviews': 128,
#   'histogram': [6, 8, 4, 27, 163],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 10, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'SAMURAI SHODOWN II',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2686834,
#   'ratings': 5645,
#   'reviews': 2267,
#   'histogram': [512, 221, 311, 793, 3808],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.8M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 28, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Miner Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.0419846,
#   'ratings': 2632,
#   'reviews': 535,
#   'histogram': [311, 110, 251, 442, 1518],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '27M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 3, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'GBC.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.51,
#   'ratings': 1034,
#   'reviews': 435,
#   'histogram': [62, 20, 51, 93, 808],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 23, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Shopkins Run!',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.46,
#   'ratings': 181,
#   'reviews': 117,
#   'histogram': [38, 16, 25, 27, 75],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 21, 2016',
#   'contentRating': 'Everyone'},
#  {'title': "Ghosts'n Goblins MOBILE",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.17,
#   'ratings': 905,
#   'reviews': 537,
#   'histogram': [108, 9, 90, 108, 590],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'NEO.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.43,
#   'ratings': 1156,
#   'reviews': 731,
#   'histogram': [335, 46, 104, 127, 544],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 14, 2012',
#   'contentRating': 'Everyone'}]

# %%
listofdictinfo2 = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[1001:2000]))
listofdictinfo2
# Out:
# [{'title': 'Danmaku Unlimited 3',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.23,
#   'ratings': 249,
#   'reviews': 134,
#   'histogram': [27, 5, 20, 27, 170],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '80M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 9, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'R-TYPE',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.671916,
#   'ratings': 8471,
#   'reviews': 3298,
#   'histogram': [200, 111, 233, 1178, 6749],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 12, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Robo Defense',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.178641,
#   'ratings': 66711,
#   'reviews': 15578,
#   'histogram': [7772, 3238, 3627, 6736, 45338],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': None,
#   'contentRating': 'Everyone 10+'},
#  {'title': '2600.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.24,
#   'ratings': 603,
#   'reviews': 248,
#   'histogram': [78, 12, 24, 60, 429],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 3, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'METAL SLUG 2',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 2.9575071,
#   'ratings': 3541,
#   'reviews': 1596,
#   'histogram': [1264, 421, 321, 271, 1264],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 6, 2013',
#   'contentRating': 'Teen'},
#  {'title': "Ghouls'n Ghosts MOBILE",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.96,
#   'ratings': 327,
#   'reviews': 216,
#   'histogram': [29, 26, 49, 46, 177],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '49M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 17, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Sky Gamblers: Storm Raiders',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.357444,
#   'ratings': 14270,
#   'reviews': 4437,
#   'histogram': [1222, 451, 611, 1703, 10283],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '10M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 22, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Star Wars™ Pinball 7',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.5526483,
#   'ratings': 15735,
#   'reviews': 5913,
#   'histogram': [3866, 873, 1235, 2219, 7542],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 27, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Space Shooter: Alien vs Galaxy Attack (Premium)',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.8935769,
#   'ratings': 15972,
#   'reviews': 6180,
#   'histogram': [2786, 754, 1388, 1488, 9556],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '108M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 17, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'The Impossible Game Level Pack',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.179348,
#   'ratings': 6529,
#   'reviews': 1147,
#   'histogram': [840, 224, 319, 686, 4460],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 15, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'METAL SLUG X',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.3120916,
#   'ratings': 6147,
#   'reviews': 2841,
#   'histogram': [1567, 713, 683, 602, 2582],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 6, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'Danmaku Unlimited 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4594593,
#   'ratings': 1119,
#   'reviews': 337,
#   'histogram': [40, 40, 100, 121, 818],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '4.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 28, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Death Worm™',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.9320755,
#   'ratings': 7981,
#   'reviews': 1803,
#   'histogram': [1235, 331, 632, 1325, 4458],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '17M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 21, 2011',
#   'contentRating': 'Teen'},
#  {'title': 'Vector 2 Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.71,
#   'ratings': 814,
#   'reviews': 378,
#   'histogram': [179, 57, 40, 81, 457],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '96M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 20, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Ordia',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.78,
#   'ratings': 424,
#   'reviews': 183,
#   'histogram': [0, 8, 8, 51, 357],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Delver',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.972167,
#   'ratings': 5691,
#   'reviews': 2101,
#   'histogram': [599, 305, 849, 837, 3101],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 20, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'Nostalgia.GBA Pro (GBA Emulator)',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.66,
#   'ratings': 108,
#   'reviews': 55,
#   'histogram': [4, 0, 5, 8, 91],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.2M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Ninja Village',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.575296,
#   'ratings': 5952,
#   'reviews': 868,
#   'histogram': [282, 100, 221, 654, 4695],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 24, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Chameleon Run',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.450169,
#   'ratings': 11907,
#   'reviews': 4845,
#   'histogram': [643, 251, 774, 1669, 8570],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 7, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'GAROU: MARK OF THE WOLVES',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.647059,
#   'ratings': 3067,
#   'reviews': 1189,
#   'histogram': [60, 30, 130, 491, 2356],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.1M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 19, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Sky Gamblers: Storm Raiders 2',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.36,
#   'ratings': 122,
#   'reviews': 97,
#   'histogram': [27, 13, 18, 16, 48],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '81M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 3, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'N64 Retro+',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 2.5454545,
#   'ratings': 22,
#   'reviews': 12,
#   'histogram': [12, 1, 1, 1, 7],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '18M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 29, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'WorldCraft Premium: Mine & Craft',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.09,
#   'ratings': 126,
#   'reviews': 83,
#   'histogram': [43, 7, 16, 14, 46],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '78M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 24, 2019',
#   'contentRating': 'Everyone'},
#  {'title': "Lep's World Plus 🍀",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.18,
#   'ratings': 567,
#   'reviews': 254,
#   'histogram': [68, 28, 22, 62, 387],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '33M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 15, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Jelly Defense',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.5052085,
#   'ratings': 10385,
#   'reviews': 4704,
#   'histogram': [685, 234, 468, 757, 8241],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '94M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 28, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Ski Safari',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.532231,
#   'ratings': 66406,
#   'reviews': 25526,
#   'histogram': [4097, 1084, 1985, 7449, 51791],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 4, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Galaxy Attack: Alien Shooter (Premium)',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.315427,
#   'ratings': 7308,
#   'reviews': 2350,
#   'histogram': [765, 171, 402, 624, 5346],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '90M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 25, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Defender 1',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 2.935484,
#   'ratings': 31,
#   'reviews': 22,
#   'histogram': [9, 3, 7, 5, 7],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.6M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 5, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'BattleBears Zombies',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.7438598,
#   'ratings': 570,
#   'reviews': 295,
#   'histogram': [108, 31, 53, 85, 293],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 6, 2010',
#   'contentRating': 'Teen'},
#  {'title': "Dragon's Lair",
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 2.8688524,
#   'ratings': 2521,
#   'reviews': 1399,
#   'histogram': [1034, 234, 165, 206, 882],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 2, 2011',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'C64.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.31,
#   'ratings': 535,
#   'reviews': 314,
#   'histogram': [166, 37, 32, 64, 236],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.1M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 1, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Canabalt HD',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.133858,
#   'ratings': 3388,
#   'reviews': 820,
#   'histogram': [400, 133, 200, 533, 2122],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '14M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 15, 2012',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Slendrina: The Cellar',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.38,
#   'ratings': 623,
#   'reviews': 205,
#   'histogram': [56, 6, 50, 43, 468],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '36M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 30, 2014',
#   'contentRating': 'Teen'},
#  {'title': '1942 MOBILE',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.04,
#   'ratings': 253,
#   'reviews': 152,
#   'histogram': [28, 17, 20, 38, 150],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 8, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Cheats Keyboard for San Andreas',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 3.642857,
#   'ratings': 14,
#   'reviews': 7,
#   'histogram': [4, 1, 0, 0, 9],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.1M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 16, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Galax Defender',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 2.4418604,
#   'ratings': 43,
#   'reviews': 33,
#   'histogram': [19, 7, 4, 5, 8],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '4.4M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 21, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Shopkins: Shoppie Dash!',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.23,
#   'ratings': 102,
#   'reviews': 44,
#   'histogram': [14, 2, 4, 7, 75],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '54M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 27, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Party Hard Go',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.064516,
#   'ratings': 1250,
#   'reviews': 636,
#   'histogram': [303, 252, 131, 191, 373],
#   'price': 6.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '36M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 9, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Pocket Stables',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5607142,
#   'ratings': 2835,
#   'reviews': 430,
#   'histogram': [152, 50, 70, 344, 2219],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 21, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Radiant',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.714286,
#   'ratings': 5980,
#   'reviews': 1672,
#   'histogram': [222, 37, 148, 408, 5165],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': None,
#   'contentRating': 'Everyone'},
#  {'title': 'FATAL FURY SPECIAL',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.9,
#   'ratings': 945,
#   'reviews': 342,
#   'histogram': [170, 37, 66, 113, 559],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '33M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 2, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Galaxy Shooter : Falcon Squad Premium',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.146789,
#   'ratings': 1105,
#   'reviews': 436,
#   'histogram': [142, 30, 81, 121, 731],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 26, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Beat Hazard Ultra',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.3742857,
#   'ratings': 3759,
#   'reviews': 1508,
#   'histogram': [268, 96, 268, 451, 2676],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '20M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 16, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'One Punch - LIMITED EDITION',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.6065574,
#   'ratings': 1224,
#   'reviews': 575,
#   'histogram': [30, 40, 50, 140, 964],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '78M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 5, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'IMPOSSIBLE ROAD',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.4259257,
#   'ratings': 4360,
#   'reviews': 663,
#   'histogram': [272, 121, 222, 605, 3140],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '35M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 7, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Boson X',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5961537,
#   'ratings': 2090,
#   'reviews': 310,
#   'histogram': [100, 30, 100, 150, 1710],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '11M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 25, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Ping or Pong',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '17M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 28, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Minos Starfighter VR',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.48,
#   'ratings': 610,
#   'reviews': 378,
#   'histogram': [128, 30, 122, 79, 251],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '55M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 5, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'House of Slendrina',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.556701,
#   'ratings': 97,
#   'reviews': 36,
#   'histogram': [6, 2, 2, 9, 78],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '32M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 22, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Grow',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.6330276,
#   'ratings': 4364,
#   'reviews': 1487,
#   'histogram': [160, 80, 160, 400, 3564],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 30, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'GunCrafter Pro',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.0239043,
#   'ratings': 2527,
#   'reviews': 1122,
#   'histogram': [413, 80, 110, 352, 1572],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '59M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 31, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Super8Pro (NE$/FC Emulator)',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.37,
#   'ratings': 292,
#   'reviews': 135,
#   'histogram': [29, 8, 8, 23, 224],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '4.6M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 6, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Arkanoid vs Space Invaders',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.58,
#   'ratings': 489,
#   'reviews': 267,
#   'histogram': [14, 14, 24, 54, 383],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '45M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 17, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'DARIUSBURST -SP-',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.46,
#   'ratings': 754,
#   'reviews': 385,
#   'histogram': [22, 22, 68, 113, 529],
#   'price': 9.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 22, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Portal ® Pinball',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.137931,
#   'ratings': 1170,
#   'reviews': 371,
#   'histogram': [131, 40, 111, 141, 747],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 28, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Paris Must Be Destroyed',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.3,
#   'ratings': 186,
#   'reviews': 86,
#   'histogram': [18, 3, 11, 22, 132],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 16, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'MasterGear - MasterSystem & GameGear Emulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.31,
#   'ratings': 573,
#   'reviews': 227,
#   'histogram': [51, 5, 34, 103, 380],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.8M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 11, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Karateka Classic',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5039372,
#   'ratings': 1278,
#   'reviews': 366,
#   'histogram': [60, 60, 50, 110, 998],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 16, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'Space Ace',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.04,
#   'ratings': 618,
#   'reviews': 330,
#   'histogram': [99, 24, 18, 86, 391],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 20, 2012',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Atomic Fighter Bomber Pro',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.48,
#   'ratings': 460,
#   'reviews': 241,
#   'histogram': [18, 0, 36, 92, 314],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '35M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 27, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Moorhuhn Deluxe - Crazy Chicken - The Original',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.280587,
#   'ratings': 6167,
#   'reviews': 1368,
#   'histogram': [533, 201, 342, 1016, 4075],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 19, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'NGP.emu',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.45,
#   'ratings': 160,
#   'reviews': 78,
#   'histogram': [8, 3, 14, 17, 118],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 23, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Full Cheats Keyboard for Vice City',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.0,
#   'ratings': 22,
#   'reviews': 6,
#   'histogram': [4, 0, 2, 2, 14],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.1M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 9, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Muffin Knight',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.4666667,
#   'ratings': 5906,
#   'reviews': 2043,
#   'histogram': [337, 182, 309, 633, 4445],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 1, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Super Fancy Pants Adventure',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.2,
#   'ratings': 159,
#   'reviews': 104,
#   'histogram': [19, 8, 9, 8, 115],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '95M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 5, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'PewPew 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.631579,
#   'ratings': 2496,
#   'reviews': 898,
#   'histogram': [131, 18, 112, 112, 2123],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 22, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Unbroken Soul',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.0707965,
#   'ratings': 1141,
#   'reviews': 505,
#   'histogram': [121, 30, 151, 182, 657],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 27, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': '7 Wonders:Magical Mystery Tour',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.88,
#   'ratings': 785,
#   'reviews': 250,
#   'histogram': [165, 31, 23, 78, 488],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.2M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 18, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Rainbow Dash: Color This World',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.8695652,
#   'ratings': 69,
#   'reviews': 34,
#   'histogram': [12, 4, 5, 8, 40],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 23, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Monkey Boxing',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 2.8807948,
#   'ratings': 1519,
#   'reviews': 389,
#   'histogram': [735, 30, 70, 50, 634],
#   'price': 1.0,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 7, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Super Mega Worm',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.23,
#   'ratings': 960,
#   'reviews': 177,
#   'histogram': [67, 57, 67, 163, 606],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '35M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 17, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': 'BLAZING STAR',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.281081,
#   'ratings': 2007,
#   'reviews': 820,
#   'histogram': [162, 54, 152, 325, 1314],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 25, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'AJ Jump: Animal Jam Kangaroos!',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2059803,
#   'ratings': 3026,
#   'reviews': 1423,
#   'histogram': [271, 140, 211, 472, 1932],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '42M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 4, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'The Bug Butcher',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.98,
#   'ratings': 718,
#   'reviews': 404,
#   'histogram': [50, 64, 93, 151, 360],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '22M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 19, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Tilt to Live 2: Redonkulous',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.0825243,
#   'ratings': 2069,
#   'reviews': 352,
#   'histogram': [231, 130, 140, 301, 1267],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '9.1M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 23, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Nostalgia.GG Pro (GG Emulator)',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.51,
#   'ratings': 127,
#   'reviews': 55,
#   'histogram': [6, 0, 11, 14, 96],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 14, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Anodyne',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.16,
#   'ratings': 534,
#   'reviews': 125,
#   'histogram': [32, 37, 37, 134, 294],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '45M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 29, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': '9th Dawn RPG',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.391705,
#   'ratings': 2433,
#   'reviews': 915,
#   'histogram': [134, 67, 213, 314, 1705],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 2, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'PUSS!',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.8,
#   'ratings': 30,
#   'reviews': 23,
#   'histogram': [0, 1, 1, 1, 27],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '140M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Brick Breaker Classic Plus',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '53M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 26, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Kingturn RPG',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.7,
#   'ratings': 1000,
#   'reviews': 273,
#   'histogram': [0, 30, 50, 110, 810],
#   'price': 4.89,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 30, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'Asteroid Storm',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 4.6153846,
#   'ratings': 26,
#   'reviews': 21,
#   'histogram': [0, 1, 2, 3, 20],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '22M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 1, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Wolf of the BF:Commando MOBILE',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.6031747,
#   'ratings': 63,
#   'reviews': 45,
#   'histogram': [8, 10, 9, 8, 28],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 23, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'fumpop',
#   'installs': '5+',
#   'minInstalls': 5,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 2, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Tower Builder',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.03,
#   'ratings': 208,
#   'reviews': 113,
#   'histogram': [69, 23, 25, 16, 75],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '14M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 17, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'North vs South',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 2.409836,
#   'ratings': 1840,
#   'reviews': 729,
#   'histogram': [1037, 90, 110, 130, 473],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '8.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 25, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Beyondium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.68,
#   'ratings': 320,
#   'reviews': 121,
#   'histogram': [41, 35, 45, 61, 138],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '82M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 9, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'R-TYPE II',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.5124793,
#   'ratings': 6046,
#   'reviews': 1306,
#   'histogram': [301, 60, 291, 976, 4418],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 12, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Spitkiss',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.71,
#   'ratings': 127,
#   'reviews': 63,
#   'histogram': [5, 1, 2, 7, 112],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '76M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 6, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Happy Color™ – Color by Number',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.5999613,
#   'ratings': 2124690,
#   'reviews': 831123,
#   'histogram': [66334, 30202, 91197, 311618, 1625339],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '46M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jan 24, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Tile Master - Classic Triple Match & Puzzle Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.427491,
#   'ratings': 53614,
#   'reviews': 11017,
#   'histogram': [4298, 1561, 2645, 3527, 41583],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Feb 22, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Tile Connect - Free Tile Puzzle & Match Brain Game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.5493827,
#   'ratings': 1900,
#   'reviews': 559,
#   'histogram': [82, 23, 35, 387, 1373],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '41M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Aug 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Paint By Number - Coloring Book & Color by Number',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.534307,
#   'ratings': 977244,
#   'reviews': 524141,
#   'histogram': [49812, 18915, 44363, 110372, 753782],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '52M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Aug 10, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Colorscapes - Color by Number & Paint by Number',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.706216,
#   'ratings': 120844,
#   'reviews': 43514,
#   'histogram': [4329, 1651, 3302, 6625, 104937],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '56M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Mar 5, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Onet 3D - Classic Link Puzzle',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.510811,
#   'ratings': 18787,
#   'reviews': 6980,
#   'histogram': [721, 345, 893, 3483, 13345],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '74M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Apr 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Onnect - Pair Matching Puzzle',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4

#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.5153375,
#   'ratings': 1685,
#   'reviews': 572,
#   'histogram': [82, 10, 103, 248, 1242],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jul 9, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Dominoes - Best Classic Dominos Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.4551134,
#   'ratings': 25704,
#   'reviews': 8820,
#   'histogram': [1545, 521, 1234, 3792, 18612],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Aug 10, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Chess Free',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.4748774,
#   'ratings': 1540706,
#   'reviews': 392590,
#   'histogram': [71859, 24707, 78994, 289512, 1075634],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '21M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Aug 26, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Dominoes',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.5457416,
#   'ratings': 6383,
#   'reviews': 1986,
#   'histogram': [282, 130, 211, 956, 4804],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '77M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Dec 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Slots: Epic Jackpot Slots Games Free & Casino Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.8170075,
#   'ratings': 235329,
#   'reviews': 61669,
#   'histogram': [5446, 1645, 3741, 8857, 215640],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '69M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Apr 14, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Color by Number - Happy Paint',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.7253914,
#   'ratings': 19889,
#   'reviews': 6578,
#   'histogram': [702, 261, 381, 1104, 17441],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '141M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jul 1, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Tile Craft - Triple Crush: Puzzle matching game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.491908,
#   'ratings': 162836,
#   'reviews': 43778,
#   'histogram': [4198, 2284, 13487, 32114, 110753],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '79M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Dec 24, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Fun Color by Number Coloring Book Paint Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.858942,
#   'ratings': 4029,
#   'reviews': 1613,
#   'histogram': [741, 223, 335, 294, 2436],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '25M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Feb 13, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Chess - Play and Learn',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.25009,
#   'ratings': 313526,
#   'reviews': 99587,
#   'histogram': [33086, 8561, 17195, 42695, 211989],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Feb 1, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Bingo Treasure - Free Bingo Game',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.715447,
#   'ratings': 1281,
#   'reviews': 482,
#   'histogram': [20, 41, 41, 73, 1106],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '61M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jun 16, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Bingo - Offline Free Bingo Games',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.0142045,
#   'ratings': 3701,
#   'reviews': 1321,
#   'histogram': [452, 210, 389, 431, 2219],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jan 21, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'RISK: Global Domination',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.295175,
#   'ratings': 218868,
#   'reviews': 76630,
#   'histogram': [19062, 6494, 13822, 30887, 148603],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Dec 3, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Dominoes - Classic Domino Tile Based Game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.40458,
#   'ratings': 1359,
#   'reviews': 614,
#   'histogram': [83, 10, 114, 218, 934],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '8.7M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'May 11, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'CROSS-STITCH: COLORING BOOK',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.272388,
#   'ratings': 2718,
#   'reviews': 924,
#   'histogram': [304, 81, 142, 233, 1958],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Apr 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Unoo Classic',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.1666665,
#   'ratings': 2245,
#   'reviews': 873,
#   'histogram': [176, 145, 156, 416, 1352],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '7.8M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jul 3, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Bingo Showdown: Free Bingo Games – Bingo Live Game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.6383734,
#   'ratings': 591736,
#   'reviews': 197525,
#   'histogram': [18151, 9466, 28428, 56126, 479565],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Dec 11, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Parchisi STAR Online',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.3576674,
#   'ratings': 1813111,
#   'reviews': 745454,
# ...
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.9427211,
#   'ratings': 73787,
#   'reviews': 29929,
#   'histogram': [13934, 2931, 4206, 5069, 47647],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': '

#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.599283,
#   'ratings': 1545010,
#   'reviews': 541224,
#   'histogram': [45499, 19773, 72370, 233054, 1174314],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Oct 10, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Dobre Dunk',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.7093244,
#   'ratings': 21079,
#   'reviews': 12212,
#   'histogram': [992, 220, 391, 712, 18764],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 11, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Dice Dreams™️',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.7418528,
#   'ratings': 27568,
#   'reviews': 9017,
#   'histogram': [535, 232, 635, 3008, 23158],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '111M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 27, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Arrows!',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.006579,
#   'ratings': 3102,
#   'reviews': 871,
#   'histogram': [459, 102, 275, 388, 1878],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '32M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 14, 2020',
#   'contentRating': 'Everyone'},
#  {'title': '2048 Balls Winner',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.8,
#   'ratings': 909,
#   'reviews': 257,
#   'histogram': [27, 9, 18, 9, 846],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '56M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'College Girls Team Makeover',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1249905,
#   'ratings': 131586,
#   'reviews': 77328,
#   'histogram': [17345, 5593, 8440, 12095, 88113],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '36M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 2, 2019',
#   'contentRating': 'Everyone'}]

# %%
listofdictinfo3 = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[2001:2500]))
listofdictinfo3
# Out:
# [{'title': 'Paint by Number - Pixel Art, Free Coloring Book',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3070908,
#   'ratings': 117022,
#   'reviews': 63926,
#   'histogram': [10862, 3459, 7442, 12371, 82888],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 18, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Doodle Run',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.1260276,
#   'ratings': 7404,
#   'reviews': 2504,
#   'histogram': [720, 395, 659, 1085, 4545],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '81M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 14, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Pet Puppy Love: Girls Craft',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.080976,
#   'ratings': 49287,
#   'reviews': 24387,
#   'histogram': [7901, 2081, 2000, 3445, 33860],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 1, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Slope Run Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.076682,
#   'ratings': 6445,
#   'reviews': 2676,
#   'histogram': [998, 211, 353, 615, 4268],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '43M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 16, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Bubble Shooter',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3109064,
#   'ratings': 792433,
#   'reviews': 300879,
#   'histogram': [64549, 25394, 53586, 104506, 544398],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '40M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 12, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Police Scanner 5-0 (FREE)',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.1315994,
#   'ratings': 59156,
#   'reviews': 17759,
#   'histogram': [6385, 2348, 4303, 10179, 35941],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '6.1M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 11, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Surprise Eggs Classic',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.7947884,
#   'ratings': 24937,
#   'reviews': 13189,
#   'histogram': [5463, 1259, 1360, 1705, 15150],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '14M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Oct 4, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Dance Clash: Ballet vs Hip Hop',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1815977,
#   'ratings': 385254,
#   'reviews': 198759,
#   'histogram': [43609, 15098, 26372, 42816, 257359],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '48M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 6, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Fishing Food',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.7695293,
#   'ratings': 56819,
#   'reviews': 37364,
#   'histogram': [931, 440, 1462, 5120, 48866],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '29M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Gacha Studio (Anime Dress Up)',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.837302,
#   'ratings': 437705,
#   'reviews': 257347,
#   'histogram': [81065, 22300, 34939, 47880, 251521],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 21, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Best Fiends Stars - Free Puzzle Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.594061,
#   'ratings': 71608,
#   'reviews': 26431,
#   'histogram': [2106, 1033, 3209, 11124, 54136],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Lucky Winner - Today is your lucky day',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.669408,
#   'ratings': 12450,
#   'reviews': 3995,
#   'histogram': [655, 102, 327, 532, 10834],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size':

#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.368889,
#   'ratings': 2296,
#   'reviews': 862,
#   'histogram': [122, 81, 173, 367, 1553],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '53M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 29, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Crayon Epoxy',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 2.5684931,
#   'ratings': 4419,
#   'reviews': 1515,
#   'histogram': [2130, 373, 413, 282, 1221],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '85M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 12, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Stick Heroes: Arrow Master',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.1862745,
#   'ratings': 1048,
#   'reviews': 219,
#   'histogram': [113, 61, 72, 72, 730],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '93M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 19, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Jelly Shift',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.088113,
#   'ratings': 288917,
#   'reviews': 116512,
#   'histogram': [37518, 13717, 22324, 27586, 187772],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '41M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 1, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Harvest Land: Farm & City Building',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.299613,
#   'ratings': 300431,
#   'reviews': 93158,
#   'histogram': [23664, 10107, 22891, 39657, 204112],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '106M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Oct 18, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Lucky Cat - free rewards giveaway',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.452842,
#   'ratings': 62611,
#   'reviews': 15985,
#   'histogram': [6446, 1052, 1463, 2386, 51264],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '39M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 7, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Hidden Through Time',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.49,
#   'ratings': 356,
#   'reviews': 150,
#   'histogram': [14, 7, 32, 39, 264],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '100M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 12, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'My PlayHome : Play Home Doll House',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.3755536,
#   'ratings': 11387,
#   'reviews': 7247,
#   'histogram': [1079, 252, 625, 786, 8645],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '68M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 8, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Melvor Idle: Ad Free',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.63,
#   'ratings': 226,
#   'reviews': 76,
#   'histogram': [2, 9, 13, 20, 182],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.1M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 12, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Hidden Folks',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.7375565,
#   'ratings': 2218,
#   'reviews': 977,
#   'histogram': [50, 30, 50, 190, 1898],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '70M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 14, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'My PlayHome Stores',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.358885,
#   'ratings': 2884,
#   'reviews': 1454,
#   'histogram': [261, 110, 120, 231, 2162],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '42M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 27, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'My PlayHome Hospital',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.3313255,
#   'ratings': 1669,
#   'reviews': 878,
#   'histogram': [171, 40, 100, 110, 1248],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '45M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 13, 2016',
#   'contentRating': 'Everyone'},
#  {'title': "Let's Create! Pottery",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.508627,
#   'ratings': 29795,
#   'reviews': 10658,
#   'histogram': [1617, 567, 1338, 3791, 22482],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '72M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 22, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'FINAL FANTASY',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.538262,
#   'ratings': 8472,
#   'reviews': 3339,
#   'histogram': [1681, 780, 1099, 1121, 3791],
#   'price': 7.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '44M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 26, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'FPse for Android devices',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.612708,
#   'ratings': 62464,
#   'reviews': 32021,
#   'histogram': [2457, 1122, 2232, 6532, 50121],
#   'price': 3.63,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.8M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 12, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'My PlayHome School',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2893615,
#   'ratings': 2365,
#   'reviews': 1197,
#   'histogram': [251, 50, 151, 221, 1692],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '43M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 4, 2015',
#   'contentRating': 'Everyone'},
#  {'title': "SpongeBob's Game Frenzy",
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.0,
#   'ratings': 1986,
#   'reviews': 860,
#   'histogram': [321, 90, 110, 210, 1255],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '24M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 26, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Peppa Pig: Happy Mrs Chicken',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.5337837,
#   'ratings': 1510,
#   'reviews': 615,
#   'histogram': [378, 81, 153, 153, 745],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '48M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 5, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Backflip Madness - Extreme sports flip game',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.4402175,
#   'ratings': 26698,
#   'reviews': 4636,
#   'histogram': [1803, 476, 1388, 3524, 19507],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.7M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 25, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'Muddy Heights® 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.08,
#   'ratings': 273,
#   'reviews': 155,
#   'histogram': [46, 8, 5, 30, 184],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 19, 2016',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Sand! Premium',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.3742857,
#   'ratings': 3512,
#   'reviews': 893,
#   'histogram': [341, 40, 150, 411, 2570],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '128k',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 21, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Fieldrunners HD',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.6225297,
#   'ratings': 8606,
#   'reviews': 4582,
#   'histogram': [2347, 221, 459, 884, 4695],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '72M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 6, 2011',
#   'contentRating': 'Everyone 10+'},
#  {'title': "Jazza's Arty Games",
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.472,
#   'ratings': 3764,
#   'reviews': 1756,
#   'histogram': [241, 80, 150, 482, 2811],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '38M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 7, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'LEGO® Friends',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.4958677,
#   'ratings': 1213,
#   'reviews': 743,
#   'histogram': [341, 40, 90, 160, 582],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.9M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 28, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'The Great Easter Egg Hunt',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.9M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 16, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Little Inferno',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.316245,
#   'ratings': 15106,
#   'reviews': 4108,
#   'histogram': [1609, 452, 593, 1347, 11105],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 25, 2013',
#   'contentRating': 'Everyone'},
#  {'title': "Sally's Spa",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.34,
#   'ratings': 426,
#   'reviews': 204,
#   'histogram': [42, 17, 12, 34, 321],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '71M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 22, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Fish Tycoon',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.7307692,
#   'ratings': 2243,
#   'reviews': 926,
#   'histogram': [414, 120, 293, 241, 1175],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.7M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 24, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Hey Duggee: The Exploring App',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.9230769,
#   'ratings': 13,
#   'reviews': 6,
#   'histogram': [2, 0, 1, 4, 6],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 13, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Virtual Families',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8,
#   'ratings': 5624,
#   'reviews': 2641,
#   'histogram': [712, 543, 712, 844, 2813],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '21M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 26, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Game Dev Story',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.6819243,
#   'ratings': 63035,
#   'reviews': 17428,
#   'histogram': [1781, 691, 2002, 6845, 51716],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 10, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Putt-Putt® Saves the Zoo',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.17,
#   'ratings': 260,
#   'reviews': 109,
#   'histogram': [39, 7, 10, 15, 189],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 9, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Freddi Fish 1: The Case of the Missing Kelp Seeds',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 1.82,
#   'ratings': 176,
#   'reviews': 121,
#   'histogram': [137, 1, 5, 1, 32],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 3, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Chicken The Adult Sex Game 2.0',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.94,
#   'ratings': 295,
#   'reviews': 99,
#   'histogram': [35, 8, 44, 56, 152],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '11M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 2, 2014',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Meme Soundboard PRO 2020',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.3819447,
#   'ratings': 1447,
#   'reviews': 1018,
#   'histogram': [90, 30, 90, 261, 976],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 11, 2018',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Domino Dot Counter',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.64,
#   'ratings': 120,
#   'reviews': 78,
#   'histogram': [3, 3, 4, 8, 102],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.4M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 16, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Burger Shop 2 (No Ads)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.66,
#   'ratings': 748,
#   'reviews': 346,
#   'histogram': [37, 7, 7, 67, 630],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '32M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 23, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Fairy Tale High',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.523256,
#   'ratings': 86,
#   'reviews': 39,
#   'histogram': [2, 3, 7, 10, 64],
#   'price': 1.0,
#   'free': False,
#   'offersIAP': False,
#   'size': '20M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Pajama Sam: No Need to Hide',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.99,
#   'ratings': 306,
#   'reviews': 130,
#   'histogram': [55, 15, 3, 36, 197],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 3, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'i Live - Gold Edition',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.0669527,
#   'ratings': 11737,
#   'reviews': 6392,
#   'histogram': [1541, 493, 927, 1451, 7325],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 16, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'App for GeoGuessr',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.72,
#   'ratings': 143,
#   'reviews': 69,
#   'histogram': [0, 2, 4, 23, 114],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.4M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 29, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Fieldrunners 2',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.999068,
#   'ratings': 10856,
#   'reviews': 3565,
#   'histogram': [1770, 526, 526, 1153, 6881],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 23, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Pajama Sam 3: You Are What You Eat from Your Head',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.46,
#   'ratings': 109,
#   'reviews': 51,
#   'histogram': [6, 2, 11, 4, 86],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'FPse64 for Android',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.5666666,
#   'ratings': 30,
#   'reviews': 20,
#   'histogram': [1, 0, 2, 5, 22],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Pajama Sam 2: Thunder & Lightning',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.13,
#   'ratings': 154,
#   'reviews': 49,
#   'histogram': [23, 3, 10, 10, 108],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 3, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'My Baby Babsy Playground Gold',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '56M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 27, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'The Sushi Spinnery',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5547943,
#   'ratings': 1901,
#   'reviews': 489,
#   'histogram': [91, 65, 78, 130, 1537],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 3, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Air Control 2 - Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.95,
#   'ratings': 945,
#   'reviews': 217,
#   'histogram': [142, 37, 75, 161, 530],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '14M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 17, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Cafeteria Nipponica',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2969923,
#   'ratings': 3599,
#   'reviews': 931,
#   'histogram': [297, 108, 311, 392, 2491],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 4, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'My Little Work – Garage',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2,
#   'ratings': 579,
#   'reviews': 97,
#   'histogram': [69, 17, 29, 75, 389],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '48M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Oct 23, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Cat Playground - Game for cats',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.34,
#   'ratings': 200,
#   'reviews': 124,
#   'histogram': [12, 10, 10, 34, 134],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '22M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 1, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Enigmatis Hidden Object (Full)',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.194175,
#   'ratings': 5782,
#   'reviews': 2671,
#   'histogram': [584, 190, 348, 1055, 3605],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '13M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Oct 5, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'SpongeBob Tickler',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.27,
#   'ratings': 338,
#   'reviews': 125,
#   'histogram': [108, 23, 27, 27, 153],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '8.9M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 23, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Sink It!',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 3.0454545,
#   'ratings': 22,
#   'reviews': 18,
#   'histogram': [10, 0, 1, 1, 10],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '10M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 12, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Freddi Fish 3: The Case of the Stolen Conch Shell',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.85,
#   'ratings': 180,
#   'reviews': 86,
#   'histogram': [40, 1, 14, 14, 111],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 3, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Air Control',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.6116505,
#   'ratings': 16254,
#   'reviews': 6109,
#   'histogram': [315, 276, 591, 3038, 12034],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': None,
#   'contentRating': 'Everyone'},
#  {'title': "Dr. Panda's Swimming Pool",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.0064516,
#   'ratings': 3123,
#   'reviews': 1240,
#   'histogram': [403, 191, 262, 393, 1874],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.3M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 14, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Pirates and Traders: Gold!',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5964913,
#   'ratings': 1767,
#   'reviews': 644,
#   'histogram': [15, 31, 93, 372, 1256],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 7, 2010',
#   'contentRating': 'Teen'},
#  {'title': 'Life Quest 2:Metropoville Full',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4736843,
#   'ratings': 1147,
#   'reviews': 319,
#   'histogram': [110, 10, 10, 110, 907],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 3, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Pocket Academy',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.4530745,
#   'ratings': 3758,
#   'reviews': 866,
#   'histogram': [158, 133, 231, 559, 2677],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 25, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Bigfoot Quest',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.4066668,
#   'ratings': 6211,
#   'reviews': 2318,
#   'histogram': [403, 72, 445, 963, 4328],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '8.7M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 6, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Webkinz™: Cash Cow',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 22, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Putt-Putt® Joins the Parade',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.7222223,
#   'ratings': 18,
#   'reviews': 12,
#   'histogram': [5, 0, 1, 1, 11],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '24M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Putt-Putt® Travels Through Time',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.163265,
#   'ratings': 98,
#   'reviews': 44,
#   'histogram': [14, 4, 4, 6, 70],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 3, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Spy Fox in Dry Cereal',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.82,
#   'ratings': 206,
#   'reviews': 88,
#   'histogram': [37, 14, 16, 18, 121],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 1, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Azada: Ancient Magic (Full) CE',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.45,
#   'ratings': 735,
#   'reviews': 295,
#   'histogram': [29, 29, 44, 110, 523],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 25, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Farm Frenzy: Time management game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8495576,
#   'ratings': 6508,
#   'reviews': 2291,
#   'histogram': [979, 576, 691, 460, 3802],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '12M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': None,
#   'contentRating': 'Everyone'},
#  {'title': 'Dino Dana: Dino Quest',
#   'installs': '50+',
#   'minInstalls': 50,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '66M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 10, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Spy Fox 2 "Some Assembly Required"',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.0,
#   'ratings': 32,
#   'reviews': 14,
#   'histogram': [5, 0, 4, 4, 19],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Dope Wars (Weed Edition)',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.55,
#   'ratings': 224,
#   'reviews': 97,
#   'histogram': [4, 0, 9, 65, 146],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 26, 2017',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Freddi Fish 5: The Creature of Coral Cove',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.5454545,
#   'ratings': 33,
#   'reviews': 19,
#   'histogram': [5, 6, 4, 2, 16],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Spy Fox 3 "Operation Ozone"',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.4166665,
#   'ratings': 48,
#   'reviews': 21,
#   'histogram': [4, 2, 1, 4, 37],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': "Dr. Panda & Toto's Treehouse",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.3741007,
#   'ratings': 5587,
#   'reviews': 1699,
#   'histogram': [502, 100, 271, 643, 4071],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.5M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 13, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Putt-Putt® Goes to the Moon',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.75,
#   'ratings': 16,
#   'reviews': 8,
#   'histogram': [4, 1, 0, 1, 10],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Oh!Edo Towns',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.4322033,
#   'ratings': 2685,
#   'reviews': 429,
#   'histogram': [136, 34, 216, 444, 1855],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 25, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Dragon, Fly! Full',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.581818,
#   'ratings': 10350,
#   'reviews': 5415,
#   'histogram': [225, 150, 752, 1468, 7755],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 22, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Bubble Bliss XL',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 3.8235295,
#   'ratings': 17,
#   'reviews': 14,
#   'histogram': [2, 1, 3, 3, 8],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '40M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 24, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Fix My Car: Classic Muscle Car',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.137931,
#   'ratings': 1167,
#   'reviews': 500,
#   'histogram': [131, 40, 110, 141, 745],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '30M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 26, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'The Jackbox Party Pack 6',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 29.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 6, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'supertype',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.57,
#   'ratings': 229,
#   'reviews': 131,
#   'histogram': [43, 25, 16, 46, 99],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '36M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 1, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Life Quest® [Full]',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.52,
#   'ratings': 886,
#   'reviews': 285,
#   'histogram': [17, 35, 62, 124, 648],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '49M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 7, 2012',
#   'contentRating': 'Everyone'},
#  {'title': "Miner's Idle 3 - Incremental Mining Game",
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.27,
#   'ratings': 871,
#   'reviews': 308,
#   'histogram': [52, 26, 87, 174, 532],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '15M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 6, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Elevator Simulator 3D',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.41,
#   'ratings': 549,
#   'reviews': 307,
# ...
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Jan 4, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'NinGenius Music Ultimate',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.16,
#   'ratings': 50,
#   'reviews': 26,
#   'histogram': [6, 2, 3, 6, 33],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '53M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Aug 23, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'CAMathories Woodland Stories #1',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '24M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Feb 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'My Little Princess : Wizard',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.9813085,
#   'ratings': 3220,
#   'reviews': 1730,
#   'histogram': [391, 220, 331, 391, 1887],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '60M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Mar 15, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Poio by Kahoot! Learn to Read',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.818182,
#   'ratings': 11,
#   'reviews': 7,
#   'histogram': [0, 0, 0, 2, 9],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '153M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Nov 11, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Monster Math: Math Facts Practice Game for kids',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.8461537,
#   'ratings': 26,
#   'reviews': 14,
#   'histogram': [6, 1, 1, 1, 17],
#   'price': 7.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '33M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Jul 13, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'What time is it? Clock 4 kids',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.67,
#   'ratings': 163,
#   'reviews': 61,
#   'histogram': [3, 1, 6, 23, 130],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '14M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Jan 21, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Monkey Preschool Fix-It',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.24,
#   'ratings': 420,
#   'reviews': 81,
#   'histogram': [33, 21, 29, 63, 274],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '71M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Oct 3, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Odd Squad: Blob Chase',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.8888888,
#   'ratings': 18,
#   'reviews': 5,
#   'histogram': [2, 2, 2, 2, 10],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '15M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Jan 14, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Hit the Button Math',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.98,
#   'ratings': 222,
#   'reviews': 106,
#   'histogram': [47, 4, 4, 17, 150],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '14M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Aug 14, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Pango Playground',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4,
#   'ratings': 283,
#   'reviews': 99,
#   'histogram': [17, 8, 22, 31, 205],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Nov 22, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Math for Kids Premium',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.617647,
#   'ratings': 34,
#   'reviews': 22,
#   'histogram': [1, 2, 0, 3, 28],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.2M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Feb 15, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'NinGenius Piano',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '55M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Sep 3, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Shimmer and Shine: Carpet Ride',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.4421053,
#   'ratings': 95,
#   'reviews': 38,
#   'histogram': [31, 0, 9, 6, 49],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '96M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Mar 22, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Zoo-phonics 6. The Refreshment Stand',
#   'installs': '5+',
#   'minInstalls': 5,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'May 10, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'PianoFlash!',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 4.8333335,
#   'ratings': 6,
#   'reviews': 4,
#   'histogram': [0, 0, 0, 1, 5],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.4M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Mar 7, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Pango and friends',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.4927535,
#   'ratings': 69,
#   'reviews': 31,
#   'histogram': [2, 4, 5, 5, 53],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Apr 28, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Pango Halloween Memory',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.8181818,
#   'ratings': 11,
#   'reviews': 5,
#   'histogram': [3, 0, 0, 1, 7],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Oct 9, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Pango Disguises',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.3962264,
#   'ratings': 53,
#   'reviews': 13,
#   'histogram': [5, 1, 2, 5, 40],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Nov 4, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Arithmagic - Math Wizard Game',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.66,
#   'ratings': 171,
#   'reviews': 99,
#   'histogram': [1, 0, 13, 24, 133],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '42M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Dec 8, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Zoo-phonics 3. The Zoo Train Mix-Up',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'May 10, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'leerstof 2de leerjaar/groep 4 (nr2)',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Feb 27, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'iSpellBetter',
#   'installs': '5+',
#   'minInstalls': 5,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.1M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Sep 18, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Riddle Rabbit™ K-1',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 6.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '34M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Nov 2, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'MiniSchool (Math, Rhymes, Tell time, Colors...)',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Jul 2, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Beat Blader 3D: Dash and Slash',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.276961,
#   'ratings': 4537,
#   'reviews': 2107,
#   'histogram': [578, 89, 166, 367, 3337],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '100M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Mar 11, 2020',
#   'contentRating': 'Everyone'},
#  {'title': '6ix9ine Runner',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.5797744,
#   'ratings': 25902,
#   'reviews': 13932,
#   'histogram': [1774, 333, 636, 1513, 21646],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Sep 2, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Tiles Hop: EDM Rush!',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.2989116,
#   'ratings': 1581078,
#   'reviews': 858814,
#   'histogram': [153510, 49923, 92671, 159320, 1125654],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jan 16, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Magic Tiles 3',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.0866556,
#   'ratings': 1823265,
#   'reviews': 839488,
#   'histogram': [250000, 72600, 129102, 189260, 1182303],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Feb 24, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Dancing Road: Color Ball Run!',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.130134,
#   'ratings': 483040,
#   'reviews': 232966,
#   'histogram': [63162, 19780, 31525, 45141, 323432],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '72M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Oct 29, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Beat Blade: Dash Dance',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1705728,
#   'ratings': 237095,
#   'reviews': 84222,
#   'histogram': [22528, 9889, 21033, 34805, 148840],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '97M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Mar 28, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Beat Sword - Rhythm Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.9976172,
#   'ratings': 12777,
#   'reviews': 4740,
#   'histogram': [1948, 558, 974, 1390, 7907],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '84M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jul 2, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Hop Ball 3D',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.988087,
#   'ratings': 129939,
#   'reviews': 60470,
#   'histogram': [19993, 6212, 9700, 13479, 80555],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '57M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'May 8, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Beat Fire - EDM Music & Gun Sounds',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.45935,
#   'ratings': 211170,
#   'reviews': 111571,
#   'histogram': [15390, 5304, 9975, 16746, 163755],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '35M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Nov 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Marshmello Music Dance',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.4755764,
#   'ratings': 36786,
#   'reviews': 17416,
#   'histogram': [2846, 888, 1403, 2433, 29216],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '111M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jul 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Piano Kids - Music & Songs',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.4640107,
#   'ratings': 273077,
#   'reviews': 109143,
#   'histogram': [19977, 6062, 11421, 25426, 210191],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '53M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Feb 2, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Piano Magic Tiles Hot song - Free Piano Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.460765,
#   'ratings': 76263,
#   'reviews': 41419,
#   'histogram': [5520, 1766, 3673, 6398, 58906],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Nov 16, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Water Race 3D: Aqua Music Game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.9072073,
#   'ratings': 11229,
#   'reviews': 4853,
#   'histogram': [2074, 445, 758, 1123, 6829],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Nov 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Magic Piano Pink Tiles - Music Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.391548,
#   'ratings': 86524,
#   'reviews': 44020,
#   'histogram': [7697, 2212, 3535, 8151, 64929],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '66M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jun 24, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Smash Colors 3D - Beat Color Circles Rhythm Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.7012525,
#   'ratings': 5828,
#   'reviews': 2824,
#   'histogram': [260, 73, 104, 271, 5120],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jul 29, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Tap Music 3D',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.87985,
#   'ratings': 16052,
#   'reviews': 6113,
#   'histogram': [2742, 884, 1175, 2009, 9242],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Aug 28, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Color Hop 3D - Music Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0431843,
#   'ratings': 19480,
#   'reviews': 8973,
#   'histogram': [3081, 750, 1206, 1652, 12791],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jul 31, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Just Dance Now',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.8162541,
#   'ratings': 1036264,
#   'reviews': 413445,
#   'histogram': [204151, 51444, 74280, 107175, 599214],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '95M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Sep 24, 2014',
#   'contentRating': 'Everyone'}]

# %%
listofdictinfo4 = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[2501:2511]))
listofdictinfo4
# Out:
# [{'title': 'Real Piano',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 3.798364,
#   'ratings': 87997,
#   'reviews': 32915,
#   'histogram': [17551, 4542, 6742, 8425, 50737],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '17M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jun 2, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Dot n Beat - Test your hand speed',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.963472,
#   'ratings': 115380,
#   'reviews': 55836,
#   'histogram': [16788, 6221, 10205, 13366, 68800],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '63M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Feb 21, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Real Guitar Free - Chords, Tabs & Simulator Games',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 3.7998538,
#   'ratings': 580348,
#   'reviews': 149152,
#   'histogram': [119274, 23937, 44705, 58183, 334249],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'May 17, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'My Singing Monsters',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.616048,
#   'ratings': 1319528,
#   'reviews': 517587,
#   'histogram': [56807, 19696, 46636, 127043, 1069346],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Oct 15, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Beat Shooter',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.472572,
#   'ratings': 20352,
#   'reviews': 10254,
#   'histogram': [1454, 532, 850, 1618, 15898],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jul 15, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Piano Free - Keyboard with Magic Tiles Music Games',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.107496,
#   'ratings': 1221973,
#   'reviews': 414645,
#   'histogram': [185933, 32400, 67091, 115500, 821049],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '73M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jun 5, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Sonic Cat - Slash the Beats',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.6448464,
#   'ratings': 215651,
#   'reviews': 112769,
#   'histogram': [10547, 3218, 6025, 12693, 183168],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '94M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Nov 1, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Tap Tap Music-Pop Songs',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.241686,
#   'ratings': 135328,
#   'reviews': 57501,
#   'histogram': [15476, 4931, 7297, 11326, 96298],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '49M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Dec 3, 2018',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Beat Roller - Music ball race',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9477057,
#   'ratings': 59531,
#   'reviews': 27583,
#   'histogram': [9731, 2852, 4428, 6306, 36214],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Aug 31, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Piano Magic Tiles Pop Music 2',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0767345,
#   'ratings': 74130,
#   'reviews': 37710,
#   'histogram': [10275, 3091, 5375, 7315, 48074],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '25M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Apr 28, 2018',
#   'contentRating': 'Everyone'}]

# %%
listofdictinfo6 = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[2512:3000]))
listofdictinfo6
# Out:
# [{'title': 'Sweet Dance',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.1361504,
#   'ratings': 6425,
#   'reviews': 3302,
#   'histogram': [834, 231, 382, 754, 4224],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Dec 8, 2019',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Beat Jumper: EDM up!',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2379127,
#   'ratings': 39358,
#   'reviews': 17847,
#   'histogram': [4380, 1580, 2285, 3161, 27952],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Oct 30, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Pink Piano',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3

#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.594203,
#   'ratings': 1399,
#   'reviews': 922,
#   'histogram': [345, 60, 152, 101, 741],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Apr 26, 2020',
#   'contentRating': 'Everyone'},
#  {'title': '6ix9ine Game : Music Jump',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.125,
#   'ratings': 56,
#   'reviews': 32,
#   'histogram': [9, 2, 2, 3, 40],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '30M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jun 12, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Beat Slasher',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.65,
#   'ratings': 193,
#   'reviews': 76,
#   'histogram': [45, 9, 17, 19, 103],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '34M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Aug 31, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Piano Beat: Tiles Touch',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.143613,
#   'ratings': 13333,
#   'reviews': 6589,
#   'histogram': [1743, 473, 876, 1270, 8971],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Nov 13, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Rock Hero',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.2445674,
#   'ratings': 638251,
#   'reviews': 166853,
#   'histogram': [55438, 15588, 64617, 84401, 418207],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jul 25, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Magic Piano Beat Tiles',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.17,
#   'ratings': 491,
#   'reviews': 209,
#   'histogram': [59, 9, 54, 34, 335],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Apr 29, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Baby Piano For Toddlers: Kids Music Games',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.58,
#   'ratings': 143,
#   'reviews': 53,
#   'histogram': [43, 4, 5, 7, 84],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Sep 10, 2019',
#   'contentRating': 'Everyone'},
#  {'title': '🎹  Old Town Road Piano tiles game',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.45,
#   'ratings': 116,
#   'reviews': 69,
#   'histogram': [40, 5, 1, 2, 68],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '55M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Sep 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'A.R.M.Y - game for BTS',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.6730275,
#   'ratings': 19602,
#   'reviews': 7126,
#   'histogram': [606, 252, 707, 1809, 16228],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '49M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Dec 30, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Hop Rhythm : Tiles Music',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.125,
#   'ratings': 8,
#   'reviews': 3,
#   'histogram': [0, 2, 0, 1, 5],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '73M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jul 19, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Hop Tiles - jojo games',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.82,
#   'ratings': 111,
#   'reviews': 48,
#   'histogram': [27, 3, 4, 5, 72],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jan 3, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'LIT killah: The Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.399502,
#   'ratings': 48473,
#   'reviews': 24575,
#   'histogram': [4267, 1016, 2073, 4841, 36276],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '125M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Apr 8, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Waterpark: Slide Race',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.81,
#   'ratings': 143,
#   'reviews': 67,
#   'histogram': [27, 10, 8, 14, 84],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '68M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Apr 9, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Arcaea - New Dimension Rhythm Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.6433463,
#   'ratings': 60084,
#   'reviews': 22283,
#   'histogram': [1916, 822, 2297, 6701, 48348],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '500M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Mar 8, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Piano Tiles Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.268151,
#   'ratings': 10456,
#   'reviews': 4705,
#   'histogram': [3138, 870, 1022, 901, 4525],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'May 4, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Piano Games - Free Music Piano Challenge 2020',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.8123002,
#   'ratings': 163397,
#   'reviews': 69344,
#   'histogram': [30629, 8853, 13124, 18741, 92050],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Apr 4, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Dancing HOP: Tiles Ball EDM Rush',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.8967254,
#   'ratings': 4336,
#   'reviews': 2428,
#   'histogram': [819, 174, 295, 393, 2655],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '31M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Sep 18, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Kids Piano Free',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.025828,
#   'ratings': 15341,
#   'reviews': 4127,
#   'histogram': [2215, 701, 1188, 1605, 9632],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Apr 17, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'BanG Dream! Girls Band Party!',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.551947,
#   'ratings': 86740,
#   'reviews': 35648,
#   'histogram': [4470, 1583, 3598, 9032, 68057],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size':

#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.212938,
#   'ratings': 3774,
#   'reviews': 2101,
#   'histogram': [407, 132, 264, 417, 2554],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '30M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Apr 1, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Piano',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.9361541,
#   'ratings': 40670,
#   'reviews': 9022,
#   'histogram': [6741, 1853, 3492, 3757, 24827],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '5.3M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Nov 17, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Marshmello Music Dance : Piano Tiles',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.38,
#   'ratings': 271,
#   'reviews': 176,
#   'histogram': [27, 5, 10, 21, 208],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Oct 10, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Piano Tap - Bendy All song',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.58,
#   'ratings': 349,
#   'reviews': 219,
#   'histogram': [87, 14, 38, 28, 182],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '40M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jan 11, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Piano for babies and kids',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.92,
#   'ratings': 182,
#   'reviews': 76,
#   'histogram': [31, 7, 16, 18, 110],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '26M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Nov 23, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Pro Piano Magic Tiles - Populer Songs',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.37,
#   'ratings': 563,
#   'reviews': 296,
#   'histogram': [158, 39, 67, 33, 266],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Nov 21, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Tiles Hop Ball - Neon EDM Rush',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '65M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Sep 6, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'MIXMSTR - DJ Game',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.1956797,
#   'ratings': 7890,
#   'reviews': 2333,
#   'histogram': [712, 320, 651, 1233, 4974],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '114M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Nov 17, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Chad W.C and Vy Piano SPY Games',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.69,
#   'ratings': 273,
#   'reviews': 149,
#   'histogram': [74, 13, 5, 11, 170],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '22M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Nov 26, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Piano Tiles - Elsa Princess Game',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.13,
#   'ratings': 353,
#   'reviews': 209,
#   'histogram': [46, 24, 17, 14, 252],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '35M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Jan 18, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'The Kreator',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.43,
#   'ratings': 1005,
#   'reviews': 299,
#   'histogram': [30, 50, 100, 100, 725],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '69M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Aug 11, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Sound Sky — Keep Calm, Drum On',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.13,
#   'ratings': 636,
#   'reviews': 328,
#   'histogram': [57, 31, 51, 127, 370],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '75M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Sep 20, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'magic Unicorn Piano Tiles:Vocal & Piano',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.2516556,
#   'ratings': 1581,
#   'reviews': 1114,
#   'histogram': [178, 62, 73, 136, 1132],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '18M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Dec 11, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'BEAT MP3 2.0 - Rhythm Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.112356,
#   'ratings': 207275,
#   'reviews': 56684,
#   'histogram': [21750, 7481, 21810, 30921, 125313],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '38M',
#   'genre': 'Music',
#   'genreId': 'GAME_MUSIC',
#   'released': 'Nov 6, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Piano Tiles 3 - Magic Tiles 2020 Offline',
#   'installs': '100,000+',
#   'minInstalls': 100000,
# ...
#   'reviews': 147,
#   'histogram': [0, 7, 18, 37, 310],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '78M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 16, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Doodle Kingdom',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.230769,
#   'ratings': 1956,
#   'reviews': 171,
#   'histogram': [150, 60, 150, 421, 1175],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 21, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'A Good Snowman',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.77,
#   'ratings': 512,
#   'reviews': 189,
#   'histogram': [15, 0, 0, 56, 441],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '72M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 9, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Dark Echo',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.607067,
#   'ratings': 14197,
#   'reviews': 4026,
#   'histogram': [582, 210, 481, 1655, 11269],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '43M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Feb 17, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Sprinkle Islands',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.5058403,
#   'ratings': 11207,
#   'reviews': 2220,
#   'histogram': [523, 322, 453, 1571, 8338],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 10, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'BUST-A-MOVE JOURNEY',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.4117646,
#   'ratings': 68,
#   'reviews': 47,
#   'histogram': [14, 7, 11, 9, 27],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '32M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 20, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Mind Games Pro',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.263964,
#   'ratings': 22319,
#   'reviews': 7400,
#   'histogram': [1759, 744, 1699, 3760, 14357],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 29, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Legacy 2 - The Ancient Curse',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.364865,
#   'ratings': 3015,
#   'reviews': 1485,
#   'histogram': [142, 122, 163, 652, 1936],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 13, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Sadhana - The way back',
#   'installs': '50+',
#   'minInstalls': 50,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '91M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Sep 16, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Bag It!',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.692946,
#   'ratings': 5251,
#   'reviews': 2519,
#   'histogram': [152, 87, 130, 479, 4403],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '26M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 11, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Tick Tock: A Tale for Two',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.6,
#   'ratings': 353,
#   'reviews': 163,
#   'histogram': [10, 7, 17, 42, 277],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '148M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 7, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'One Circle',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.72,
#   'ratings': 25,
#   'reviews': 20,
#   'histogram': [1, 0, 0, 3, 21],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 28, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'ISOLAND: The Amusement Park',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.5052633,
#   'ratings': 95,
#   'reviews': 35,
#   'histogram': [2, 6, 2, 17, 68],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '30M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 2, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'FRAMED 2',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.9454546,
#   'ratings': 1110,
#   'reviews': 567,
#   'histogram': [141, 80, 80, 202, 607],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '24M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 16, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Cut The Cookie',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 5.0,
#   'ratings': 5,
#   'reviews': 4,
#   'histogram': [0, 0, 0, 0, 5],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 29, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Under Leaves',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.65,
#   'ratings': 135,
#   'reviews': 73,
#   'histogram': [0, 2, 5, 28, 100],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '86M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 23, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Mahjong 3 (Full)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.613924,
#   'ratings': 1591,
#   'reviews': 699,
#   'histogram': [20, 30, 40, 362, 1139],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '42M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 8, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'The Enchanted Worlds',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.4572005,
#   'ratings': 11176,
#   'reviews': 4278,
#   'histogram': [675, 281, 427, 1666, 8127],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '12M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Feb 15, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'The Guides',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.772549,
#   'ratings': 2578,
#   'reviews': 555,
#   'histogram': [50, 20, 50, 222, 2236],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '40M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 16, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Peekaboo Farm & Zoo Ad Free',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 29, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'The Box of Secrets: Extended Escape',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.0,
#   'ratings': 32,
#   'reviews': 20,
#   'histogram': [5, 0, 4, 4, 19],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Bulb Boy',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.6132073,
#   'ratings': 2122,
#   'reviews': 1038,
#   'histogram': [80, 30, 50, 310, 1652],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '29M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Sep 7, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'JezzBall Classic',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.17,
#   'ratings': 129,
#   'reviews': 51,
#   'histogram': [11, 7, 9, 19, 83],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 3, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Isoland',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.351852,
#   'ratings': 1091,
#   'reviews': 402,
#   'histogram': [101, 10, 70, 131, 779],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '33M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 5, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'SpongeBob Marbles & Slides',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.1,
#   'ratings': 182,
#   'reviews': 102,
#   'histogram': [73, 9, 9, 9, 82],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.7M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 4, 2012',
#   'contentRating': 'Everyone'},
#  {'title': "Slayaway Camp: 1980's Horror Puzzle Fun!",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.313308,
#   'ratings': 13183,
#   'reviews': 4930,
#   'histogram': [902, 421, 1102, 1975, 8783],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '71M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 12, 2017',
#   'contentRating': 'Mature 17+'},
#  {'title': 'The Hidden World',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.535326,
#   'ratings': 3709,
#   'reviews': 1016,
#   'histogram': [131, 70, 161, 665, 2682],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Sep 26, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Isoland 2: Ashes of Time',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.61,
#   'ratings': 518,
#   'reviews': 249,
#   'histogram': [10, 0, 36, 88, 384],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '32M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 28, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Tutti Frutti: NEW! Match 3 Game No Ads Free Lives!',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '46M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 14, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Thinkrolls Kings & Queens - Full',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.9,
#   'ratings': 50,
#   'reviews': 23,
#   'histogram': [0, 1, 0, 2, 47],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '59M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 27, 2017',
#   'contentRating': 'Everyone'},
#  {'title': '"OXXO"',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.88,
#   'ratings': 297,
#   'reviews': 130,
#   'histogram': [0, 0, 8, 17, 272],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '46M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 6, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'rymdkapsel',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5525727,
#   'ratings': 4564,
#   'reviews': 945,
#   'histogram': [102, 102, 296, 735, 3329],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '49M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 31, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Where Shadows Slumber',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.7,
#   'ratings': 368,
#   'reviews': 206,
#   'histogram': [11, 3, 7, 40, 307],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 20, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Minesweeper Pro',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.430516,
#   'ratings': 14017,
#   'reviews': 4509,
#   'histogram': [672, 311, 903, 2550, 9581],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.7M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Kenshō',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.09,
#   'ratings': 626,
#   'reviews': 291,
#   'histogram': [50, 25, 87, 119, 345],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '126M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 22, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Hook',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.504556,
#   'ratings': 29954,
#   'reviews': 10629,
#   'histogram': [1526, 616, 1435, 4013, 22364],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 20, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Pango Blocks',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.875,
#   'ratings': 72,
#   'reviews': 37,
#   'histogram': [10, 8, 5, 7, 42],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '34M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 5, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'G30 - A Memory Maze',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.44,
#   'ratings': 410,
#   'reviews': 213,
#   'histogram': [20, 12, 28, 53, 297],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '15M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Feb 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Bleentoro Pro',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.81,
#   'ratings': 306,
#   'reviews': 168,
#   'histogram': [3, 3, 3, 30, 267],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.7M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 19, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Gears logic puzzles premium',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.7586207,
#   'ratings': 29,
#   'reviews': 13,
#   'histogram': [0, 0, 2, 3, 24],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '13M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 11, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Facility 47',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.69,
#   'ratings': 436,
#   'reviews': 195,
#   'histogram': [17, 0, 8, 48, 363],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '21M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 11, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': "Fantasy Mosaics 41: Wizard's Realm",
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.2,
#   'ratings': 5,
#   'reviews': 4,
#   'histogram': [1, 0, 0, 0, 4],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 1, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'ELOH',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.39,
#   'ratings': 320,
#   'reviews': 152,
#   'histogram': [25, 3, 25, 32, 235],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 9, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Million Onion Hotel',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.72,
#   'ratings': 615,
#   'reviews': 287,
#   'histogram': [0, 24, 12, 74, 505],
#   'price': 4.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '72M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 1, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Cut the Rope 2 GOLD',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.39,
#   'ratings': 105,
#   'reviews': 61,
#   'histogram': [31, 5, 11, 8, 50],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 2, 2019',
#   'contentRating': 'Everyone'}]

# %%
listofdictinfo7 = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[3001:4000]))
listofdictinfo7
# Out:
# [{'title': 'Sokodice',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 5.0,
#   'ratings': 6,
#   'reviews': 4,
#   'histogram': [0, 0, 0, 0, 6],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '121M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Sep 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': "Please Don't Touch Anything 3D",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.15,
#   'ratings': 407,
#   'reviews': 207,
#   'histogram': [53, 16, 24, 36, 278],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 7, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Chess',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4952383,
#   'ratings': 1162,
#   'reviews': 530,
#   'histogram': [22, 33, 77, 243, 787],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.9M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Feb 29, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Remember: A Horror Adventure Puzzle Game',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.51,
#   'ratings': 138,
#   'reviews': 88,
#   'histogram': [5, 2, 11, 15, 105],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '95M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 18, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Bring You Home',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.26,
#   'ratings': 163,
#   'reviews': 99,
#   'histogram': [21, 1, 6, 18, 117],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Dream Machine - The Game',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2268906,
#   'ratings': 1201,
#   'reviews': 482,
#   'histogram': [80, 30, 131, 252, 708],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '49M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 22, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Lightbot : Programming Puzzles',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.7539268,
#   'ratings': 1950,
#   'reviews': 468,
#   'histogram': [51, 20, 30, 153, 1696],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '45M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 14, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Hangman Premium',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.202353,
#   'ratings': 4264,
#   'reviews': 1488,
#   'histogram': [341, 150, 361, 863, 2549],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '22M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 13, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Gurk III, the 8-bit RPG',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.716981,
#   'ratings': 1613,
#   'reviews': 598,
#   'histogram': [60, 10, 30, 121, 1392],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 5, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': "ROOMS: The Toymaker's Mansion",
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.49,
#   'ratings': 234,
#   'reviews': 144,
#   'histogram': [11, 9, 4, 35, 175],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '96M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'the Sequence [2]',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.8,
#   'ratings': 185,
#   'reviews': 76,
#   'histogram': [0, 0, 7, 22, 156],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '57M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 28, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Deus Ex GO',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.9414778,
#   'ratings': 13741,
#   'reviews': 4631,
#   'histogram': [1477, 814, 1568, 3056, 6826],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '23M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 17, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Kiwanuka',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2037916,
#   'ratings': 2125,
#   'reviews': 346,
#   'histogram': [100, 80, 292, 463, 1190],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '21M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 6, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'CrossMe Nonograms Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.8453608,
#   'ratings': 2078,
#   'reviews': 615,
#   'histogram': [32, 0, 32, 128, 1886],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 29, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'LYNE',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.766234,
#   'ratings': 3142,
#   'reviews': 472,
#   'histogram': [20, 30, 142, 275, 2675],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '48M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 1, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Motor Town:Soul of the Machine',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.1782947,
#   'ratings': 1295,
#   'reviews': 426,
#   'histogram': [110, 30, 140, 251, 764],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.7M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 14, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Death Squared',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.5,
#   'ratings': 518,
#   'reviews': 291,
#   'histogram': [161, 20, 10, 52, 275],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 28, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Mahjong Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.43,
#   'ratings': 375,
#   'reviews': 138,
#   'histogram': [18, 7, 18, 79, 253],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '8.3M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 13, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Sudoku PRO',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.8,
#   'ratings': 1499,
#   'reviews': 618,
#   'histogram': [10, 10, 10, 207, 1262],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 14, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'reky',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.0,
#   'ratings': 10,
#   'reviews': 7,
#   'histogram': [0, 2, 1, 2, 5],
#   'price': 4.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '54M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'A Foreign Land of Us',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.2105265,
#   'ratings': 19,
#   'reviews': 13,
#   'histogram': [2, 0, 1, 5, 11],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Magnet Balls PRO: Physics Puzzle',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.397112,
#   'ratings': 2832,
#   'reviews': 1023,
#   'histogram': [184, 61, 204, 378, 2005],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 13, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Lyfoes',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.54,
#   'ratings': 321,
#   'reviews': 167,
#   'histogram': [12, 9, 19, 29, 252],
#   'price': 1.0,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 9, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Dissembler',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.707692,
#   'ratings': 65,
#   'reviews': 25,
#   'histogram': [3, 0, 1, 5, 56],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 8, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Mekorama VR',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.3818183,
#   'ratings': 55,
#   'reviews': 35,
#   'histogram': [4, 2, 4, 4, 41],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.6M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 8, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'PathPix Brain',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.9,
#   'ratings': 10,
#   'reviews': 7,
#   'histogram': [0, 0, 0, 1, 9],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '4.7M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 16, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Road Not Taken',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.24,
#   'ratings': 190,
#   'reviews': 110,
#   'histogram': [1, 21, 23, 28, 117],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 14, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Evo Explores',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5449276,
#   'ratings': 3480,
#   'reviews': 1653,
#   'histogram': [90, 80, 191, 595, 2524],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '51M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Feb 11, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search Solver',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 2.409091,
#   'ratings': 22,
#   'reviews': 21,
#   'histogram': [12, 0, 4, 1, 5],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '335k',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 9, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Doodle Kingdom HD',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.09,
#   'ratings': 833,
#   'reviews': 72,
#   'histogram': [58, 75, 58, 183, 459],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '35M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 21, 2014',
#   'contentRating': 'Everyone'},
#  {'title': "Please, Don't Touch Anything VR",
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 3.8181818,
#   'ratings': 11,
#   'reviews': 6,
#   'histogram': [1, 2, 1, 1, 6],
#   'price': 8.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 23, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'CrossMe Color Premium Nonogram',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.870968,
#   'ratings': 1655,
#   'reviews': 475,
#   'histogram': [21, 10, 10, 74, 1540],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 18, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Legacy 3 - The Hidden Relic',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.287582,
#   'ratings': 1545,
#   'reviews': 870,
#   'histogram': [111, 50, 151, 202, 1031],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '99M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 21, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Quell Zen',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.44,
#   'ratings': 420,
#   'reviews': 205,
#   'histogram': [42, 0, 12, 42, 324],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '92M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 13, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Photographs - Puzzle Stories',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.29,
#   'ratings': 216,
#   'reviews': 104,
#   'histogram': [8, 10, 30, 26, 142],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '100M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 11, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'ISOLAND 3: Dust of the Universe',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.2,
#   'ratings': 138,
#   'reviews': 61,
#   'histogram': [9, 5, 15, 25, 84],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '34M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Feb 19, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Feed Me Oil 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2526317,
#   'ratings': 3815,
#   'reviews': 421,
#   'histogram': [341, 140, 261, 542, 2531],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 10, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Fantasy Mosaics 35: Day at the Museum',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Alt-Frequencies',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.41,
#   'ratings': 109,
#   'reviews': 62,
#   'histogram': [2, 7, 4, 24, 72],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '38M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 15, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Tangram Master Premium',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.75,
#   'ratings': 126,
#   'reviews': 56,
#   'histogram': [2, 1, 1, 15, 107],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 2, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Concrete Jungle',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.56,
#   'ratings': 162,
#   'reviews': 66,
#   'histogram': [4, 6, 4, 23, 125],
#   'price': 4.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '95M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Sep 28, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Kids Heads Up Charades!',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.25,
#   'ratings': 24,
#   'reviews': 11,
#   'histogram': [5, 6, 1, 2, 10],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.9M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 12, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Treasures of Montezuma 3. True Match-3 Game.',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.80137,
#   'ratings': 9343,
#   'reviews': 3513,
#   'histogram': [2272, 234, 298, 810, 5729],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Sep 19, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Tic tac toe pro',
#   'installs': '5+',
#   'minInstalls': 5,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.3M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Rhomb',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.5757575,
#   'ratings': 66,
#   'reviews': 32,
#   'histogram': [1, 0, 4, 16, 45],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 2, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Cut the Rope: Experiments GOLD',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.2582645,
#   'ratings': 15147,
#   'reviews': 5316,
#   'histogram': [1189, 532, 1001, 2879, 9546],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '49M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 17, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Mushroom 11',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.62,
#   'ratings': 516,
#   'reviews': 233,
#   'histogram': [20, 0, 36, 41, 419],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '20M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 8, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'ZOOKEEPER DX TouchEdition',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.943038,
#   'ratings': 3281,
#   'reviews': 1291,
#   'histogram': [353, 228, 436, 498, 1766],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '4.6M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 22, 2011',
#   'contentRating': 'Everyone'},
#  {'title': "Rube's Lab PRO Physics Puzzle",
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.14,
#   'ratings': 108,
#   'reviews': 60,
#   'histogram': [11, 1, 18, 9, 69],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '24M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 11, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'No Heroes Allowed:No Puzzles Either!™G',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 2.939759,
#   'ratings': 83,
#   'reviews': 65,
#   'histogram': [26, 11, 13, 8, 25],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '94M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 22, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Speed Anatomy (No ads)',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.626984,
#   'ratings': 126,
#   'reviews': 44,
#   'histogram': [1, 2, 5, 27, 91],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.0M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 4, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Kakuro Puzzles',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.36,
#   'ratings': 283,
#   'reviews': 114,
#   'histogram': [17, 8, 22, 42, 194],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '8.6M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 11, 2012',
#   'contentRating': 'Everyone'},
#  {'title': "Davey's Mystery 2",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5,
#   'ratings': 1312,
#   'reviews': 474,
#   'histogram': [30, 20, 80, 313, 869],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 19, 2015',
#   'contentRating': 'Everyone'},
#  {'title': "Ferris Mueller's Day Off -Wild West Adventure Game",
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.4,
#   'ratings': 131,
#   'reviews': 47,
#   'histogram': [6, 1, 13, 22, 89],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 15, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Lightbot Jr : Coding Puzzles',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.59,
#   'ratings': 283,
#   'reviews': 81,
#   'histogram': [5, 5, 22, 31, 220],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '44M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 8, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Random Mahjong Pro',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.33,
#   'ratings': 1763,
#   'reviews': 696,
#   'histogram': [176, 88, 52, 105, 1342],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 11, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Slingshot Stunt Driver',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.8340914,
#   'ratings': 37768,
#   'reviews': 10269,
#   'histogram': [6357, 2082, 3598, 5164, 20567],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '106M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 10, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Extreme Car Driving Simulator',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.189683,
#   'ratings': 3157701,
#   'reviews': 1193742,
#   'histogram': [387095, 113419, 190048, 290004, 2177135],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '53M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 15, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Fun Race 3D',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.1635222,
#   'ratings': 1702156,
#   'reviews': 784405,
#   'histogram': [195933, 66652, 125096, 189932, 1124543],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'May 28, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Epic Race 3D',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 3.9821618,
#   'ratings': 142320,
#   'reviews': 59042,
#   'histogram': [20924, 7807, 11202, 15333, 87054],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jan 5, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Rebel Racing',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4339924,
#   'ratings': 312850,
#   'reviews': 109905,
#   'histogram': [17898, 7480, 18810, 45422, 223240],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Nov 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Traffic Rider',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.383512,
#   'ratings': 7262001,
#   'reviews': 2492446,
#   'histogram': [556339, 180543, 424188, 861571, 5239360],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '109M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jan 11, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Asphalt 9: Legends - Epic Car Action Racing Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4583907,
#   'ratings': 1717874,
#   'reviews': 701193,
#   'histogram': [120735, 36138, 74120, 190816, 1296065],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '96M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 25, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Street Racing 3D',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.291228,
#   'ratings': 1185090,
#   'reviews': 458999,
#   'histogram': [110023, 32554, 76495, 149214, 816804],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '85M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 10, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Happy Wheels',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.059658,
#   'ratings': 189758,
#   'reviews': 72965,
#   'histogram': [24389, 7955, 15800, 25413, 116201],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '30M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jan 25, 2020',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Earn to Die 2',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3507447,
#   'ratings': 1688416,
#   'reviews': 528399,
#   'histogram': [135965, 44327, 104097, 211176, 1192851],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '75M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'May 4, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Hill Climb Racing',
#   'installs': '500,000,000+',
#   'minInstalls': 500000000,
#   'score': 4.3174925,
#   'ratings': 9848423,
#   'reviews': 2576748,
#   'histogram': [939294, 277277, 577147, 978317, 7076388],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Sep 22, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Moto X3M Bike Race Game',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.316462,
#   'ratings': 282932,
#   'reviews': 123290,
#   'histogram': [27623, 8509, 15780, 25811, 205209],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 18, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Hill Climb Racing 2',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3722796,
#   'ratings': 3890007,
#   'reviews': 1330671,
#   'histogram': [309892, 94553, 207738, 503130, 2774694],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '133M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Nov 27, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'RacerKing',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 2.4,
#   'ratings': 263,
#   'reviews': 154,
#   'histogram': [143, 18, 15, 29, 58],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '57M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Sep 8, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Need for Speed™ No Limits',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4

#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '99M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Dec 18, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Crazy Car Traffic Racing Games 2020: New Car Games',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.094334,
#   'ratings': 67415,
#   'reviews': 30218,
#   'histogram': [10250, 2712, 3647, 4622, 46184],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '57M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'May 10, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'European Luxury Cars',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.0843086,
#   'ratings': 33759,
#   'reviews': 15393,
#   'histogram': [4912, 1428, 1833, 3312, 22274],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '100M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Dec 28, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Top Speed: Drag & Fast Racing',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.5966506,
#   'ratings': 805444,
#   'reviews': 270918,
#   'histogram': [41541, 12136, 27781, 66737, 657249],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 22, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Bikes Hill',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.8530095,
#   'ratings': 56147,
#   'reviews': 17864,
# ...
#   'score': 4.281746,
#   'ratings': 2528,
#   'reviews': 791,
#   'histogram': [160, 100, 170, 532, 1566],
#   'price': 6.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '91M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 11, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Ultimate Dinosaur Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.200855,
#   'ratings': 2351,
#   'reviews': 1544,
#   'histogram': [191, 100, 231, 351, 1478],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jan 14, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'This War of Mine',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8092937,
#   'ratings': 26997,
#   'reviews': 11686,
#   'histogram': [5731, 1104, 1555, 2800, 15807],
#   'price': 13.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '21M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 14, 2015',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Scuba Diving Challenge',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 23, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Train Simulator PRO 2018',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.8267717,
#   'ratings': 1278,
#   'reviews': 774,
#   'histogram': [201, 80, 181, 90, 726],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '36M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 5, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Townsmen 6',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.61,
#   'ratings': 1441,
#   'reviews': 491,
#   'histogram': [288, 115, 144, 216, 678],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '15M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 4, 2011',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Call For Fire',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.4545455,
#   'ratings': 66,
#   'reviews': 45,
#   'histogram': [2, 1, 2, 21, 40],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '62M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 17, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Lawgivers',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.594203,
#   'ratings': 1387,
#   'reviews': 514,
#   'histogram': [10, 10, 110, 271, 986],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '50M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 14, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Pulling USA',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.0215826,
#   'ratings': 1406,
#   'reviews': 429,
#   'histogram': [223, 50, 70, 192, 871],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '60M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 3, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Farming PRO 3',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 2.83,
#   'ratings': 262,
#   'reviews': 159,
#   'histogram': [116, 15, 23, 13, 95],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '54M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 23, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Mega Mall Story2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.627451,
#   'ratings': 1530,
#   'reviews': 825,
#   'histogram': [30, 10, 90, 240, 1160],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '60M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 21, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Fox Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2954545,
#   'ratings': 2656,
#   'reviews': 1673,
#   'histogram': [241, 50, 181, 392, 1792],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 21, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Atlantic Fleet',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5013475,
#   'ratings': 3722,
#   'reviews': 1670,
#   'histogram': [150, 140, 120, 592, 2720],
#   'price': 9.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '80M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 20, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'PicaSim: Flight simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.7234044,
#   'ratings': 1475,
#   'reviews': 740,
#   'histogram': [31, 20, 41, 136, 1247],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '56M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 12, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Construction Simulator PRO',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.9166667,
#   'ratings': 1322,
#   'reviews': 566,
#   'histogram': [230, 80, 50, 170, 792],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 2, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Wolf Simulator',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.203846,
#   'ratings': 7816,
#   'reviews': 4245,
#   'histogram': [912, 230, 430, 1022, 5222],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 7, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Dealer’s Life - Pawn Shop Tycoon',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.538983,
#   'ratings': 2953,
#   'reviews': 1297,
#   'histogram': [110, 80, 140, 400, 2223],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '52M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 10, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Train Sim Pro',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2421055,
#   'ratings': 1913,
#   'reviews': 836,
#   'histogram': [181, 40, 221, 161, 1310],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '116M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 1, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'PC Creator PRO - PC Building Simulator',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 4.25,
#   'ratings': 175,
#   'reviews': 107,
#   'histogram': [8, 19, 10, 17, 121],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '103M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Cult Manager Tycoon',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.869565,
#   'ratings': 23,
#   'reviews': 15,
#   'histogram': [0, 0, 1, 1, 21],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '32M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 18, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Solar 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.3667545,
#   'ratings': 3815,
#   'reviews': 593,
#   'histogram': [251, 90, 302, 533, 2639],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '45M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 5, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Lion Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2491693,
#   'ratings': 3016,
#   'reviews': 1689,
#   'histogram': [280, 90, 230, 411, 2005],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 14, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Passpartout: The Starving Artist',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.320463,
#   'ratings': 2598,
#   'reviews': 1641,
#   'histogram': [200, 60, 190, 401, 1747],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '127M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 30, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'PC Architect Advanced (PC building simulator)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.48,
#   'ratings': 493,
#   'reviews': 305,
#   'histogram': [14, 19, 19, 99, 342],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '27M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 5, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Top Sailor sailing simulator',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.41,
#   'ratings': 306,
#   'reviews': 144,
#   'histogram': [15, 9, 18, 55, 209],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '51M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 22, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Traffix',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.2773585,
#   'ratings': 5322,
#   'reviews': 1786,
#   'histogram': [311, 180, 472, 1115, 3244],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '62M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 12, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Space Agency 2138',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.13,
#   'ratings': 157,
#   'reviews': 122,
#   'histogram': [12, 11, 12, 28, 94],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '38M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 15, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Planet zoo new world',
#   'installs': '50+',
#   'minInstalls': 50,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '70M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Its TITANIC premium',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.36,
#   'ratings': 134,
#   'reviews': 91,
#   'histogram': [9, 8, 4, 16, 97],
#   'price': 2.19,
#   'free': False,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 8, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Esports Life Tycoon | Manage your esports team',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.21,
#   'ratings': 168,
#   'reviews': 87,
#   'histogram': [42, 17, 30, 22, 57],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '39M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 13, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Pacific Fleet',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.3757725,
#   'ratings': 8134,
#   'reviews': 1554,
#   'histogram': [502, 291, 563, 1066, 5712],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '30M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 13, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Motor Depot',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2732096,
#   'ratings': 7574,
#   'reviews': 4669,
#   'histogram': [703, 251, 532, 874, 5214],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 20, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Shark Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.9,
#   'ratings': 791,
#   'reviews': 442,
#   'histogram': [118, 47, 71, 111, 444],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 15, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Endless ATC',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.9,
#   'ratings': 670,
#   'reviews': 291,
#   'histogram': [0, 0, 0, 67, 603],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.5M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 12, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Ant Simulation 3D Full',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.8913043,
#   'ratings': 92,
#   'reviews': 55,
#   'histogram': [14, 4, 9, 16, 49],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '120M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 1, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Minecraft: Skin Studio',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8080645,
#   'ratings': 6223,
#   'reviews': 1765,
#   'histogram': [1024, 451, 642, 682, 3424],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.9M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 16, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Levelhead',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.53,
#   'ratings': 730,
#   'reviews': 370,
#   'histogram': [36, 21, 29, 73, 571],
#   'price': 6.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '266M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 30, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'F-Sim Space Shuttle',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.380165,
#   'ratings': 5657,
#   'reviews': 2351,
#   'histogram': [502, 175, 198, 573, 4209],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 13, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'SuperMD Pro (MD/GEN Emulator)',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.23,
#   'ratings': 286,
#   'reviews': 131,
#   'histogram': [23, 17, 23, 31, 192],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.4M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 28, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Farming PRO 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.73,
#   'ratings': 567,
#   'reviews': 318,
#   'histogram': [108, 34, 62, 62, 301],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '27M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 3, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Gunship III',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.1862745,
#   'ratings': 3077,
#   'reviews': 1651,
#   'histogram': [281, 130, 201, 583, 1882],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '24M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 27, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Station Manager',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4481707,
#   'ratings': 3300,
#   'reviews': 1604,
#   'histogram': [211, 90, 120, 463, 2416],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '43M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 8, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Kirikiroid2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.3,
#   'ratings': 460,
#   'reviews': 219,
#   'histogram': [46, 18, 13, 55, 328],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 13, 2014',
#   'contentRating': 'Everyone'}]

# %%
listofdictinfo8 = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[4001:5149]))
listofdictinfo8
# Out:
# [{'title': 'Silver Screen Story',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.3152175,
#   'ratings': 1848,
#   'reviews': 936,
#   'histogram': [60, 30, 211, 512, 1035],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '61M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Dragon Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2922373,
#   'ratings': 2202,
#   'reviews': 1305,
#   'histogram': [140, 50, 221, 402, 1389],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 26, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Weaphones™ WW2: Firearms Sim',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.65,
#   'ratings': 195,
#   'reviews': 76,
#   'histogram': [5, 1, 9, 19, 161],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 8, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Oh...Sir! The Insult Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.17,
#   'ratings': 744,
#   'reviews': 389,
#   'histogram': [67, 37, 74, 89, 477],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '93M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 21, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'The Manga Works',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.3,
#   'ratings': 700,
#   'reviews': 249,
#   'histogram': [42, 28, 56, 126, 448],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '32M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 4, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'FPV Freerider Recharged',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.35,
#   'ratings': 166,
#   'reviews': 124,
#   'histogram': [11, 5, 13, 20, 117],
#   'price': 6.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 22, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Space Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.84,
#   'ratings': 904,
#   'reviews': 547,
#   'histogram': [163, 36, 81, 126, 498],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '24M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 26, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'FsRadioPanel Pro',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.57,
#   'ratings': 278,
#   'reviews': 204,
#   'histogram': [8, 5, 2, 64, 199],
#   'price': 11.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '13M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 14, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Bus Simulator PRO 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.426087,
#   'ratings': 2305,
#   'reviews': 1110,
#   'histogram': [632, 130, 270, 170, 1103],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '27M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 5, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'This Is the Police',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.255682,
#   'ratings': 1774,
#   'reviews': 584,
#   'histogram': [141, 90, 131, 222, 1190],
#   'price': 7.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '29M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 12, 2018',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Weaphones™ Antiques Gun Sim',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.0609756,
#   'ratings': 82,
#   'reviews': 27,
#   'histogram': [9, 1, 12, 14, 46],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 30, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Kids Trains Pro',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 4.6666665,
#   'ratings': 9,
#   'reviews': 3,
#   'histogram': [0, 1, 0, 0, 8],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '45M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 30, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Sifting Thyme: Otome Visual Novel',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.6,
#   'ratings': 30,
#   'reviews': 21,
#   'histogram': [1, 1, 0, 5, 23],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 14, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'RESCUE: Heroes in Action',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.7244093,
#   'ratings': 1272,
#   'reviews': 309,
#   'histogram': [240, 60, 180, 120, 672],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '22M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Dr. Panda in Space',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.7,
#   'ratings': 601,
#   'reviews': 172,
#   'histogram': [84, 66, 90, 66, 295],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'simLeaf',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.52,
#   'ratings': 100,
#   'reviews': 69,
#   'histogram': [22, 6, 15, 12, 45],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '49M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 19, 2018',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Hmmsim 2 - Train Simulator',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.210412,
#   'ratings': 4620,
#   'reviews': 2563,
#   'histogram': [601, 110, 200, 511, 3198],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '93M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 19, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Truck Simulator PRO 2016',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.9659443,
#   'ratings': 3238,
#   'reviews': 1263,
#   'histogram': [521, 160, 190, 401, 1966],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '25M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 25, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'HARVEST MOON:Seeds Of Memories',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.7194245,
#   'ratings': 1402,
#   'reviews': 777,
#   'histogram': [343, 40, 90, 121, 808],
#   'price': 9.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 18, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'GeoFS - Flight Simulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.53,
#   'ratings': 123,
#   'reviews': 108,
#   'histogram': [18, 16, 21, 17, 51],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '93M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 27, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Gunship III Vietnam People AF',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.31,
#   'ratings': 849,
#   'reviews': 364,
#   'histogram': [76, 25, 51, 102, 595],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 7, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Stray Cat Simulator',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.3378015,
#   'ratings': 3749,
#   'reviews': 2173,
#   'histogram': [281, 110, 211, 603, 2544],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 28, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'F18 Carrier Landing',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.483766,
#   'ratings': 8230,
#   'reviews': 3490,
#   'histogram': [347, 147, 481, 1456, 5799],
#   'price': 12.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 26, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Farm Simulator',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.36,
#   'ratings': 359,
#   'reviews': 272,
#   'histogram': [83, 36, 50, 50, 140],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '79M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 17, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Weapon stripping NoAds',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.81,
#   'ratings': 524,
#   'reviews': 225,
#   'histogram': [10, 5, 5, 31, 473],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 1, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Zoolax Nights:Evil Clowns Full, Escape Challenge',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.86,
#   'ratings': 239,
#   'reviews': 135,
#   'histogram': [4, 0, 2, 9, 224],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '79M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 3, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Anime Studio Story',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4574466,
#   'ratings': 3773,
#   'reviews': 420,
#   'histogram': [150, 70, 301, 632, 2620],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 2, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Star Command',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.4987094,
#   'ratings': 19522,
#   'reviews': 4160,
#   'histogram': [3709, 2056, 2489, 3326, 7942],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.8M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 6, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'SimpleRockets',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.3003755,
#   'ratings': 8061,
#   'reviews': 1763,
#   'histogram': [555, 312, 625, 1231, 5338],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '24M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 3, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'TruckSimulation 16',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.5101798,
#   'ratings': 8357,
#   'reviews': 4359,
#   'histogram': [2272, 360, 690, 901, 4134],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '19M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 25, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'SovietCar: Premium',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.49,
#   'ratings': 175,
#   'reviews': 130,
#   'histogram': [10, 3, 3, 30, 129],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '42M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Fractal Combat X (Premium)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4488187,
#   'ratings': 1281,
#   'reviews': 375,
#   'histogram': [60, 50, 80, 151, 940],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '64M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 23, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Democratic Socialism Simulator',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 4.2352943,
#   'ratings': 51,
#   'reviews': 32,
#   'histogram': [3, 2, 5, 11, 30],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '40M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 21, 2020',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Shiny Ski Resort',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.45,
#   'ratings': 537,
#   'reviews': 234,
#   'histogram': [32, 5, 37, 75, 388],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '49M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 7, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Emergency Call – The Fire Fighting Simulation',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.9679487,
#   'ratings': 1563,
#   'reviews': 949,
#   'histogram': [150, 170, 150, 200, 893],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '36M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 22, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Zombie Simulator Z - Premium',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.3939395,
#   'ratings': 99,
#   'reviews': 72,
#   'histogram': [8, 5, 5, 3, 78],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '75M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 18, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Fix My Car: Classic Muscle 2 - Junkyard Blitz!',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.46,
#   'ratings': 668,
#   'reviews': 246,
#   'histogram': [67, 6, 20, 33, 542],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 3, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Fiz : Brewery Management Game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.223077,
#   'ratings': 7885,
#   'reviews': 847,
#   'histogram': [485, 515, 748, 1142, 4995],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 12, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'Little Crane 2: Mud Play',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.625,
#   'ratings': 16,
#   'reviews': 10,
#   'histogram': [3, 3, 0, 1, 9],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '8.3M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 27, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Pool Slide Story',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.7439446,
#   'ratings': 8677,
#   'reviews': 4685,
#   'histogram': [70, 70, 400, 930, 7207],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '34M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 18, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'The Westport Independent',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.04,
#   'ratings': 285,
#   'reviews': 139,
#   'histogram': [25, 14, 31, 66, 149],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '43M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jan 20, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Big Politics Inc. USA Edition',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 3.5333333,
#   'ratings': 30,
#   'reviews': 13,
#   'histogram': [5, 1, 8, 5, 11],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 24, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'My so-called future girlfriend [Visual Novel]',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.72,
#   'ratings': 154,
#   'reviews': 90,
#   'histogram': [1, 1, 7, 17, 128],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 29, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'U-Boat Simulator',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.54,
#   'ratings': 516,
#   'reviews': 217,
#   'histogram': [36, 0, 5, 82, 393],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.5M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 20, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'GS-III Heroes of the MIG Alley',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.92,
#   'ratings': 412,
#   'reviews': 227,
#   'histogram': [49, 20, 62, 62, 219],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 19, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Snake Simulator',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2782607,
#   'ratings': 2310,
#   'reviews': 680,
#   'histogram': [221, 70, 150, 271, 1598],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 22, 2014',
#   'contentRating': 'Teen'},
#  {'title': "Kitty Powers' Love Life",
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.21,
#   'ratings': 200,
#   'reviews': 114,
#   'histogram': [18, 10, 18, 20, 134],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '55M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 5, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Cheetah Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4270835,
#   'ratings': 1925,
#   'reviews': 690,
#   'histogram': [120, 40, 160, 180, 1425],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 29, 2014',
#   'contentRating': 'Teen'},
#  {'title': "There's a Butcher Around Pro",
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 2.7692308,
#   'ratings': 13,
#   'reviews': 7,
#   'histogram': [6, 0, 2, 1, 4],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '35M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 12, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'This Is the Police 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.55,
#   'ratings': 558,
#   'reviews': 289,
#   'histogram': [123, 44, 61, 61, 269],
#   'price': 7.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '35M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 12, 2019',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Citizen of Rome - Dynasty Ascendant',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.06,
#   'ratings': 270,
#   'reviews': 153,
#   'histogram': [19, 16, 32, 65, 138],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '39M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 28, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Flight 787 - Advanced',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.833935,
#   'ratings': 2775,
#   'reviews': 1694,
#   'histogram': [581, 80, 170, 330, 1614],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '40M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jan 15, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Gunship III - STRIKE PACKAGE',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.14,
#   'ratings': 908,
#   'reviews': 428,
#   'histogram': [118, 9, 63, 154, 564],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 5, 2014',
#   'contentRating': 'Everyone'},
#  {'title': '論如何建立一個修仙門派',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.87,
#   'ratings': 328,
#   'reviews': 181,
#   'histogram': [42, 26, 33, 56, 171],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '31M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 5, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Football Manager 2020 Touch',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.4552846,
#   'ratings': 1237,
#   'reviews': 826,
#   'histogram': [352, 30, 120, 171, 564],
#   'price': 19.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 18, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Hiveswap Friendsim',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.54,
#   'ratings': 291,
#   'reviews': 140,
#   'histogram': [11, 8, 14, 32, 226],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 11, 2018',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Freeways',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.88,
#   'ratings': 406,
#   'reviews': 256,
#   'histogram': [44, 28, 65, 61, 208],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Kamikaze Simulator - Funfair Amusement Parks',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.23,
#   'ratings': 118,
#   'reviews': 67,
#   'histogram': [14, 2, 7, 13, 82],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '61M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 12, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Falcon Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.203252,
#   'ratings': 1236,
#   'reviews': 604,
#   'histogram': [60, 70, 161, 211, 734],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 10, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Green Project',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.41,
#   'ratings': 300,
#   'reviews': 207,
#   'histogram': [12, 12, 21, 51, 204],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '63M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jan 28, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Weaphones™ Firearms Sim Vol 2',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.4179106,
#   'ratings': 67,
#   'reviews': 18,
#   'histogram': [3, 4, 4, 7, 49],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '22M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 9, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'SuperGBC Pro (GBC Emulator)',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.5454545,
#   'ratings': 99,
#   'reviews': 41,
#   'histogram': [5, 0, 5, 15, 74],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.9M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Lucy -The Eternity She Wished For-',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.9,
#   'ratings': 276,
#   'reviews': 151,
#   'histogram': [0, 0, 8, 11, 257],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 8, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Viking Ship - Best Ride Simulators',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.329412,
#   'ratings': 85,
#   'reviews': 45,
#   'histogram': [6, 4, 5, 11, 59],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '62M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 22, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Harvest Master: Farm Sim',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.09,
#   'ratings': 831,
#   'reviews': 509,
#   'histogram': [91, 41, 100, 66, 533],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 1, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Election 2020 - The Game',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.4M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jan 2, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Autobahn Police Simulator',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.01,
#   'ratings': 386,
#   'reviews': 252,
#   'histogram': [108, 58, 58, 46, 116],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 9, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Stray Dog Simulator',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.420749,
#   'ratings': 3475,
#   'reviews': 1725,
#   'histogram': [190, 160, 140, 490, 2495],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 1, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Dolphin Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.76,
#   'ratings': 975,
#   'reviews': 463,
#   'histogram': [195, 29, 107, 127, 517],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 23, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Griffin Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2786884,
#   'ratings': 1223,
#   'reviews': 533,
#   'histogram': [110, 30, 110, 130, 843],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 5, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Air Navy Fighters Xperia TM',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.38,
#   'ratings': 159,
#   'reviews': 38,
#   'histogram': [4, 8, 8, 40, 99],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 20, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'Funfair Ride Simulator 4',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.88,
#   'ratings': 572,
#   'reviews': 388,
#   'histogram': [80, 28, 74, 86, 304],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 2, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Infinite Flight Checklist',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.7555556,
#   'ratings': 45,
#   'reviews': 24,
#   'histogram': [10, 1, 4, 5, 25],
#   'price': 2.29,
#   'free': False,
#   'offersIAP': False,
#   'size': '10M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 8, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'DRS Pro',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.23,
#   'ratings': 116,
#   'reviews': 67,
#   'histogram': [8, 5, 5, 28, 70],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '54M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 12, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Cook, Serve, Delicious!',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.57,
#   'ratings': 344,
#   'reviews': 131,
#   'histogram': [13, 10, 6, 48, 267],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '53M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 12, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Wolf Craft',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.62,
#   'ratings': 567,
#   'reviews': 285,
#   'histogram': [17, 17, 22, 51, 460],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '33M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 26, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Block Tech : Epic Sandbox Car Craft Simulator GOLD',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 2.9615386,
#   'ratings': 26,
#   'reviews': 22,
#   'histogram': [9, 2, 2, 7, 6],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '54M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 30, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'VR Flight Simulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 2.83,
#   'ratings': 134,
#   'reviews': 106,
#   'histogram': [54, 14, 8, 16, 42],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 10, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Take Off The Flight Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.4299066,
#   'ratings': 1072,
#   'reviews': 590,
#   'histogram': [301, 90, 60, 90, 531],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '29M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 9, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Planet Genesis - solar system sandbox',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.94,
#   'ratings': 129,
#   'reviews': 64,
#   'histogram': [19, 7, 14, 7, 82],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '51M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 9, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Inverter : Theme Park Simulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.07,
#   'ratings': 105,
#   'reviews': 69,
#   'histogram': [16, 3, 7, 10, 69],
#   'price': 3.89,
#   'free': False,
#   'offersIAP': False,
#   'size': '109M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 1, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Wildlife Simulator: Crocodile',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.33,
#   'ratings': 629,
#   'reviews': 208,
#   'histogram': [44, 18, 31, 126, 410],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 16, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Bridge Constructor Medieval',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8708487,
#   'ratings': 8166,
#   'reviews': 1685,
#   'histogram': [1296, 452, 763, 1155, 4500],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 30, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Bridge Constructor Playground',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.2620192,
#   'ratings': 8377,
#   'reviews': 2159,
#   'histogram': [2598, 473, 896, 956, 3454],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '30M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 7, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Beam Drive NG Death Stair Car Crash Accidents Pro',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '54M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 12, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'The Lonely Hacker',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.948815,
#   'ratings': 10723,
#   'reviews': 5753,
#   'histogram': [1413, 630, 1097, 1535, 6048],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '107M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 15, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'MusicLabeLManagerExtra',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.92,
#   'ratings': 133,
#   'reviews': 98,
#   'histogram': [17, 9, 14, 17, 76],
#   'price': 4.29,
#   'free': False,
#   'offersIAP': False,
#   'size': '99M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 8, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'NG Flight Simulator',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '110M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 9, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Wild Park Manager',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.54,
#   'ratings': 335,
#   'reviews': 184,
#   'histogram': [64, 30, 50, 43, 148],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 12, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Snow Leopard Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.6282053,
#   'ratings': 1570,
#   'reviews': 679,
#   'histogram': [70, 0, 40, 221, 1239],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 1, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Gunship III - U.S. NAVY',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.216783,
#   'ratings': 1439,
#   'reviews': 684,
#   'histogram': [141, 50, 100, 211, 937],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 12, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Carrier Landings Pro',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.6221867,
#   'ratings': 6249,
#   'reviews': 2164,
#   'histogram': [190, 90, 211, 904, 4854],
#   'price': 12.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 11, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Apocalypse Inc.',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.898734,
#   'ratings': 79,
#   'reviews': 41,
#   'histogram': [10, 5, 5, 22, 37],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '80M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 12, 2020',
#   'contentRating': 'Teen'},
#  {'title': "This War of Mine: Stories - Father's Promise",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.43,
#   'ratings': 774,
#   'reviews': 364,
#   'histogram': [46, 7, 77, 77, 567],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '20M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 27, 2019',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Game Studio Tycoon 3',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.881356,
#   'ratings': 2368,
#   'reviews': 1069,
#   'histogram': [301, 60, 321, 622, 1064],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 26, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Train Simulator 2015 USA HD',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 2.4,
#   'ratings': 25,
#   'reviews': 15,
#   'histogram': [13, 1, 4, 2, 5],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Flight Simulator Paris 2015 HD',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.3,
#   'ratings': 172,
#   'reviews': 56,
#   'histogram': [52, 15, 12, 15, 78],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 26, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Proposed by a Demon Lord',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.8735633,
#   'ratings': 87,
#   'reviews': 62,
#   'histogram': [11, 7, 11, 11, 47],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '93M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 23, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Madden NFL 21 Mobile Football',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.0439925,
#   'ratings': 36806,
#   'reviews': 16125,
#   'histogram': [5009, 1659, 2418, 5333, 22387],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '80M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': '

#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.08882,
#   'ratings': 249729,
#   'reviews': 107997,
#   'histogram': [31196, 11055, 20201, 29196, 158081],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '76M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Aug 29, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Parkour Race - Freerun Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.950673,
#   'ratings': 124677,
#   'reviews': 49584,
#   'histogram': [19073, 6371, 10782, 13857, 74594],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Mar 6, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'PBA® Bowling Challenge',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4960794,
#   'ratings': 269195,
#   'reviews': 73506,
#   'histogram': [12997, 4857, 12715, 43659, 194967],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '77M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jan 15, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Boxing Star',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.400474,
#   'ratings': 679729,
#   'reviews': 240702,
#   'histogram': [45944, 13843, 39338, 103530, 477074],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '84M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jul 11, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Dream League Soccer 2020',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.132278,
#   'ratings': 1235465,
#   'reviews': 655179,
#   'histogram': [156853, 43562, 82791, 148356, 803903],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '349M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jan 14, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Flip Dunk',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0240145,
#   'ratings': 138518,
#   'reviews': 56509,
#   'histogram': [18486, 6452, 12053, 17784, 83743],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '73M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jul 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Pooking - Billiards City',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.4027934,
#   'ratings': 2219335,
#   'reviews': 925225,
#   'histogram': [133552, 56274, 152210, 317946, 1559353],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '41M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'May 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Retro Bowl',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.6983395,
#   'ratings': 178668,
#   'reviews': 67030,
#   'histogram': [1372, 1092, 6063, 33002, 137139],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jan 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Flip Skater',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.225596,
#   'ratings': 112331,
#   'reviews': 50321,
#   'histogram': [11065, 3842, 8367, 14466, 74591],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '77M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Nov 28, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Shooting Battle',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.587988,
#   'ratings': 90671,
#   'reviews': 33773,
#   'histogram': [3470, 1273, 3951, 11754, 70223],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '48M',
# ...
#   'size': '90M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 5, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Smash - crossword & word stack',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.359921,
#   'ratings': 30441,
#   'reviews': 9411,
#   'histogram': [3552, 782, 802, 1324, 23981],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '49M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 16, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Connect - Free offline Word Game 2020',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.79235,
#   'ratings': 5543,
#   'reviews': 2676,
#   'histogram': [80, 20, 90, 585, 4768],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '23M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 18, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Crossword Puzzle Free',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.6795955,
#   'ratings': 85514,
#   'reviews': 29047,
#   'histogram': [1095, 723, 1879, 17087, 64730],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '24M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 16, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Crossword Relax Free',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.74,
#   'ratings': 746,
#   'reviews': 169,
#   'histogram': [29, 7, 0, 52, 658],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '42M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 13, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Words Out',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 2.82,
#   'ratings': 118,
#   'reviews': 86,
#   'histogram': [49, 10, 8, 15, 36],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '37M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Words of Wonders: Search',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.5741916,
#   'ratings': 61833,
#   'reviews': 18889,
#   'histogram': [1748, 934, 3276, 9979, 45896],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '122M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 17, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Pearls: Free Word Games & Puzzles',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.585542,
#   'ratings': 8360,
#   'reviews': 3194,
#   'histogram': [282, 151, 312, 1259, 6356],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '44M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 28, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search - Free Word Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.7987447,
#   'ratings': 268194,
#   'reviews': 110696,
#   'histogram': [6602, 1953, 4428, 12845, 242366],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '3.7M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 25, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Puzzlescapes: Relaxing Word Puzzle Brain Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.7459645,
#   'ratings': 11817,
#   'reviews': 4284,
#   'histogram': [281, 190, 281, 743, 10322],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 25, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Words with Friends Classic: Word Puzzle Challenge',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.1811233,
#   'ratings': 1719373,
#   'reviews': 639444,
#   'histogram': [150622, 66854, 126070, 352762, 1023065],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '82M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 14, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Forest - Free Word Games Puzzle',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.8621793,
#   'ratings': 3166,
#   'reviews': 1085,
#   'histogram': [50, 30, 20, 101, 2965],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 26, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Evil Apples: You Against Humanity!',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.1583004,
#   'ratings': 147362,
#   'reviews': 46355,
#   'histogram': [14774, 5829, 11699, 24051, 91009],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 23, 2014',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Word Search - Free Crossword and Puzzle Game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.5431895,
#   'ratings': 6042,
#   'reviews': 2089,
#   'histogram': [150, 90, 411, 1064, 4327],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 26, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Pictoword: Fun Word Games & Offline Brain Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2178884,
#   'ratings': 404487,
#   'reviews': 156355,
#   'histogram': [37666, 14087, 31412, 60602, 260720],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '84M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 25, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Bible Word Puzzle - Free Bible Word Games',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.660084,
#   'ratings': 104939,
#   'reviews': 44603,
#   'histogram': [2062, 1621, 4074, 14406, 82776],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 1, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Wordington: Words & Design',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.2840095,
#   'ratings': 145249,
#   'reviews': 43875,
#   'histogram': [11172, 5110, 10180, 23617, 95170],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 25, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search Addict - Word Search Puzzle Free',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.791961,
#   'ratings': 49606,
#   'reviews': 23005,
#   'histogram': [1072, 531, 931, 2575, 44497],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '36M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 12, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Puzzle - Word Search Quest',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.9,
#   'ratings': 175,
#   'reviews': 72,
#   'histogram': [0, 1, 1, 8, 165],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '22M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 3, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Link - Free Word Games',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.71,
#   'ratings': 530,
#   'reviews': 203,
#   'histogram': [5, 5, 15, 85, 420],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '61M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 4, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Psych! The best party game to play with friends',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.029069,
#   'ratings': 56001,
#   'reviews': 14147,
#   'histogram': [7174, 2090, 4341, 10722, 31674],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '84M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 8, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Charades!',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.352045,
#   'ratings': 128181,
#   'reviews': 26068,
#   'histogram': [10255, 2717, 7396, 19091, 88722],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '16M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 1, 2013',
#   'contentRating': 'Everyone'},
#  {'title': '4 Pics 1 Word Cookie',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.7314286,
#   'ratings': 1768,
#   'reviews': 508,
#   'histogram': [30, 0, 50, 252, 1436],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 19, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Relax - Free Word Games & Puzzles',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.0307355,
#   'ratings': 68763,
#   'reviews': 25897,
#   'histogram': [10287, 2864, 4417, 8073, 43122],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '69M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 16, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Draw N Guess Multiplayer',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.4864278,
#   'ratings': 37331,
#   'reviews': 17332,
#   'histogram': [9343, 2492, 3475, 4702, 17319],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '30M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 6, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Wars - Word Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.3202443,
#   'ratings': 22960,
#   'reviews': 9733,
#   'histogram': [1823, 761, 1192, 3646, 15538],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 29, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Swipe Pic',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.565508,
#   'ratings': 52457,
#   'reviews': 18844,
#   'histogram': [2915, 1152, 1883, 3907, 42600],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '57M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Wizard of Word',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.6553626,
#   'ratings': 87213,
#   'reviews': 32502,
#   'histogram': [4341, 902, 2386, 5213, 74371],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 11, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search 2020',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.716714,
#   'ratings': 10647,
#   'reviews': 4476,
#   'histogram': [311, 90, 422, 653, 9171],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '21M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 11, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Game of Words: Free Word Games & Puzzles',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.6940546,
#   'ratings': 39269,
#   'reviews': 16563,
#   'histogram': [701, 470, 1332, 5130, 31636],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '60M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 3, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Infinite Word Search Puzzles',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3227234,
#   'ratings': 56839,
#   'reviews': 18264,
#   'histogram': [3286, 2100, 5186, 8674, 37593],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '41M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 6, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Garden of Words - Word game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.214824,
#   'ratings': 281621,
#   'reviews': 79675,
#   'histogram': [18741, 9210, 26250, 66025, 161395],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '98M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 14, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'WORD FIRE: FREE WORD GAMES WITHOUT WIFI!',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.6850543,
#   'ratings': 15629,
#   'reviews': 6818,
#   'histogram': [711, 160, 481, 631, 13646],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '54M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 20, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Planet',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.7450643,
#   'ratings': 11720,
#   'reviews': 4317,
#   'histogram': [181, 130, 402, 1066, 9941],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '73M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 24, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Scrolling Words-Moving Word Game & Find Words',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.772174,
#   'ratings': 23052,
#   'reviews': 7437,
#   'histogram': [370, 200, 451, 2265, 19766],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '32M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 16, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Words Story - Addictive Word Game',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 3.7312088,
#   'ratings': 490783,
#   'reviews': 207636,
#   'histogram': [103045, 29455, 38324, 45507, 274452],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '72M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 10, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Crossword Explorer',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4,
#   'ratings': 386,
#   'reviews': 129,
#   'histogram': [19, 3, 23, 97, 244],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '57M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 10, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Immortal Taoists-Idle Game of Immortal Cultivation',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.4646406,
#   'ratings': 157250,
#   'reviews': 51844,
#   'histogram': [7674, 2715, 9587, 26168, 111106],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 7, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Aplasta Palabras：Juego de Palabras Gratis sin wifi',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.514881,
#   'ratings': 20355,
#   'reviews': 11607,
#   'histogram': [636, 272, 1221, 4069, 14157],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search Inspiration',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.177201,
#   'ratings': 8879,
#   'reviews': 3994,
#   'histogram': [882, 350, 621, 1483, 5543],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 17, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Bliss',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.672414,
#   'ratings': 21500,
#   'reviews': 8583,
#   'histogram': [380, 280, 981, 2715, 17144],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '75M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 1, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Mystery Word Puzzle',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.79,
#   'ratings': 684,
#   'reviews': 228,
#   'histogram': [27, 0, 6, 20, 631],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '104M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 13, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Bible Word Story',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.57,
#   'ratings': 139,
#   'reviews': 57,
#   'histogram': [4, 4, 4, 22, 105],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 24, 2020',
#   'contentRating': 'Everyone'},
#  ...]

# %%
dictinfofinallist = listofdictinfo + listofdictinfo2 + listofdictinfo3 + listofdictinfo4 + listofdictinfo6 + listofdictinfo7 + listofdictinfo8
dictinfofinallist
# Out:
# [{'title': 'Among Us',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.4352665,
#   'ratings': 2069272,
#   'reviews': 1070149,
#   'histogram': [163295, 43146, 91796, 202372, 1568663],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 15, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Scribble Rider',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3
',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 10, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Modern Ops - Online FPS (Gun Games Shooter)',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4291377,
#   'ratings': 543789,
#   'reviews': 260372,
#   'histogram': [41025, 11459, 26167, 59613, 405525],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '54M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Last Day on Earth: Survival',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.3251057,
#   'ratings': 3888081,
#   'reviews': 1962701,
#   'histogram': [340891, 110297, 214543, 500501, 2721849],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 24, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Curvy Punch 3D',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.4949048,
#   'ratings': 22824,
#   'reviews': 9631,
#   'histogram': [5592, 1780, 2265, 2113, 11074],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '78M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 25, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Temple Run 2',
#   'installs': '500,000,000+',
#   'minInstalls': 500000000,
#   'score': 4.22611,
#   'ratings': 9333147,
#   'reviews': 2607097,
#   'histogram': [1024619, 316573, 595485, 983658, 6412812],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 23, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Rope Hero: Vice Town',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.1320653,
#   'ratings': 821654,
#   'reviews': 330324,
#   'histogram': [116106, 30789, 45395, 65557, 563807],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '90M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 14, 2016',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Crossy Road',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.5555296,
#   'ratings': 4428457,
#   'reviews': 1418029,
#   'histogram': [193832, 60608, 222348, 566466, 3385203],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '77M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 7, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Tomb of the Mask: Color',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.227905,
#   'ratings': 119233,
#   'reviews': 44019,
#   'histogram': [13059, 4179, 7444, 12396, 82155],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Oct 14, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'War Robots Multiplayer Battles',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.1665583,
#   'ratings': 4092305,
#   'reviews': 1778205,
#   'histogram': [531774, 129499, 224435, 446233, 2760364],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '78M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 26, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Worms Zone .io - Voracious Snake',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.305752,
#   'ratings': 1609151,
#   'reviews': 774136,
#   'histogram': [151296, 49843, 98705, 165023, 1144284],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '29M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 2, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Neon Iron Stickman Rope Hero City Gangstar Mafia',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.070202,
#   'ratings': 27151,
#   'reviews': 16090,
#   'histogram': [4177, 1024, 1409, 2646, 17895],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 26, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Mobile Legends: Bang Bang',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.1420083,
#   'ratings': 22221147,
#   'reviews': 11122186,
#   'histogram': [3198316, 648820, 1117563, 2090709, 15165739],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '99M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Oct 31, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Murder Hornet',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.855872,
#   'ratings': 22620,
#   'reviews': 9077,
#   'histogram': [4347, 1227, 1459, 1891, 13696],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '124M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 24, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'StrikeFortressBox',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.319669,
#   'ratings': 46309,
#   'reviews': 22344,
#   'histogram': [5039, 1312, 1969, 3473, 34516],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '67M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 22, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Beat the Boss 4: Stress-Relief Game. Hit the buddy',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0669203,
#   'ratings': 335410,
#   'reviews': 121963,
#   'histogram': [45524, 13865, 27077, 35115, 213829],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '160M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 23, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Football Field Kick',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.3435693,
#   'ratings': 22568,
#   'reviews': 7963,
#   'histogram': [1406, 773, 1828, 3214, 15347],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Feb 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Golf Hit',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.0634356,
#   'ratings': 28173,
#   'reviews': 9611,
#   'histogram': [2359, 1305, 3725, 5582, 15202],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 29, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Stickman Warriors - Super Dragon Shadow Fight',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.5830264,
#   'ratings': 150344,
#   'reviews': 72578,
#   'histogram': [8278, 2336, 5700, 11168, 122862],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '87M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 8, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Stickman Battle',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1168127,
#   'ratings': 42559,
#   'reviews': 18259,
#   'histogram': [5535, 2143, 2777, 3462, 28642],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 6, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Run Royale 3D',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.28,
#   'ratings': 891,
#   'reviews': 416,
#   'histogram': [80, 8, 62, 169, 572],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '65M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Mask of Stick: Superhero',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.568027,
#   'ratings': 3037,
#   'reviews': 1359,
#   'histogram': [144, 31, 206, 227, 2429],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 2, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Hide Online - Hunters vs Props',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.09411,
#   'ratings': 997875,
#   'reviews': 470110,
#   'histogram': [123553, 38472, 78767, 136801, 620282],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Offline Shooting: DEAD TARGET- Free Zombie Games',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.4671683,
#   'ratings': 1874519,
#   'reviews': 702149,
#   'histogram': [118456, 43044, 99991, 195863, 1417165],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 16, 2014',
#   'contentRating': 'Mature 17+'},
#  {'title': 'World War Heroes: WW2 FPS',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.4289064,
#   'ratings': 1962136,
#   'reviews': 838682,
#   'histogram': [158147, 46114, 88500, 172630, 1496745],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 22, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Black Hole Hero : Vice Vegas Rope Mafia',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0260954,
#   'ratings': 73548,
#   'reviews': 31350,
#   'histogram': [11829, 3343, 4485, 5313, 48578],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '130M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 29, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Cover Fire: Offline Shooting Games',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.4710875,
#   'ratings': 1786040,
#   'reviews': 698514,
#   'histogram': [116427, 36470, 84456, 200624, 1348063],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 30, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Dinosaur Rampage',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3764186,
#   'ratings': 47900,
#   'reviews': 20710,
#   'histogram': [4238, 1530, 2275, 3775, 36082],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'DRAGON BALL LEGENDS',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.469549,
#   'ratings': 991764,
#   'reviews': 490390,
#   'histogram': [64046, 20604, 46376, 115331, 745407],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '96M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 17, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Otherworld Legends',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.308609,
#   'ratings': 34346,
#   'reviews': 18956,
#   'histogram': [2046, 1217, 2987, 5934, 22162],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '62M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 19, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Exploration Lite Craft',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.8387163,
#   'ratings': 301494,
#   'reviews': 130113,
#   'histogram': [59250, 14127, 21362, 28014, 178741],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '15M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 1, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Brawlhalla',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.249917,
#   'ratings': 91040,
#   'reviews': 40791,
#   'histogram': [8781, 2675, 6367, 12402, 60815],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 4, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Truck Driver City Crush',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.076905,
#   'ratings': 125920,
#   'reviews': 55073,
#   'histogram': [19408, 5256, 6651, 9532, 85073],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '94M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 17, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Real Time Shields',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.7102177,
#   'ratings': 12117,
#   'reviews': 3045,
#   'histogram': [2253, 801, 1360, 1492, 6211],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '109M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 27, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Robbery.io',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4880953,
#   'ratings': 84,
#   'reviews': 28,
#   'histogram': [5, 1, 6, 8, 64],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': "Push'em all",
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 3.9697797,
#   'ratings': 183934,
#   'reviews': 62815,
#   'histogram': [27371, 9040, 15160, 22565, 109798],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '46M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': "Chuck E.'s Skate Universe",
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.313466,
#   'ratings': 98819,
#   'reviews': 22255,
#   'histogram': [11156, 2512, 4633, 6412, 74106],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '44M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 29, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Stick Warfare: Blood Strike',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.2283206,
#   'ratings': 9323,
#   'reviews': 4456,
#   'histogram': [849, 368, 716, 1259, 6131],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 10, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Stickman 3D - Street Gangster - Street Gangs',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.4504504,
#   'ratings': 2304,
#   'reviews': 707,
#   'histogram': [145, 72, 124, 218, 1745],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Upstream Struggle',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.64,
#   'ratings': 231,
#   'reviews': 143,
#   'histogram': [11, 2, 2, 25, 191],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 5, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Helix Jump',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.060265,
#   'ratings': 4235824,
#   'reviews': 1777987,
#   'histogram': [565544, 174754, 330081, 533948, 2631497],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 12, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'The Survival Hunter Games 2',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9079857,
#   'ratings': 216797,
#   'reviews': 81178,
#   'histogram': [40038, 10341, 13470, 18630, 134318],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '131M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 9, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'MORTAL KOMBAT',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.197278,
#   'ratings': 4019209,
#   'reviews': 1608814,
#   'histogram': [473814, 132379, 244125, 445662, 2723229],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 4, 2015',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Real Gangster Crime',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.0847135,
#   'ratings': 770962,
#   'reviews': 303947,
#   'histogram': [117240, 28389, 44711, 62098, 518524],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '100M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 31, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Dead by Daylight Mobile',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.1434884,
#   'ratings': 158805,
#   'reviews': 77441,
#   'histogram': [16591, 5914, 12992, 25924, 97384],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 15, 2020',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Bed Diving',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.2479339,
#   'ratings': 1258,
#   'reviews': 512,
#   'histogram': [416, 104, 83, 62, 593],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '66M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 3, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Gun Gang',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.3110285,
#   'ratings': 8193,
#   'reviews': 2928,
#   'histogram': [2691, 406, 446, 964, 3686],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '82M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 8, 2020',
#   'contentRating': 'Teen'},
#  {'title': '🐓Chicken Gun🐓',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3645396,
#   'ratings': 73920,
#   'reviews': 39698,
#   'histogram': [7302, 2052, 2836, 5934, 55796],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '73M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Feb 19, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Rocket Royale',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.081656,
#   'ratings': 283562,
#   'reviews': 168516,
#   'histogram': [43199, 9370, 16292, 26916, 187785],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 10, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Shadow Fight 2',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.5734944,
#   'ratings': 13330398,
#   'reviews': 4807507,
#   'histogram': [826159, 199056, 422378, 938924, 10943881],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '145M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 22, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Gangstar Vegas: World of Crime',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.2892175,
#   'ratings': 5971240,
#   'reviews': 2613172,
#   'histogram': [653797, 153625, 297795, 572597, 4293426],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 19, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Sonic the Hedgehog™ Classic',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1328845,
#   'ratings': 222287,
#   'reviews': 107034,
#   'histogram': [30623, 7593, 12936, 21604, 149531],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '63M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 21, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Creative Destruction',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1502066,
#   'ratings': 1166812,
#   'reviews': 673373,
#   'histogram': [163788, 34262, 63164, 107278, 798320],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '74M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 19, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Anger of stick 5 : zombie',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.303291,
#   'ratings': 1065410,
#   'reviews': 450197,
#   'histogram': [105991, 32712, 62465, 95248, 768994],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '33M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 8, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Bullet Echo',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.1989098,
#   'ratings': 75596,
#   'reviews': 30994,
#   'histogram': [7337, 2814, 5267, 12232, 47946],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '98M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 21, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Stick Fight: The Game Mobile',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9676058,
#   'ratings': 123692,
#   'reviews': 58191,
#   'histogram': [18890, 5473, 10263, 15194, 73872],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 16, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Stick Fight Battle 2020',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.36,
#   'ratings': 502,
#   'reviews': 195,
#   'histogram': [35, 10, 45, 60, 352],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '44M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 20, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Rage Road',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0131917,
#   'ratings': 58576,
#   'reviews': 20571,
#   'histogram': [7466, 3121, 5720, 7135, 35134],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '76M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 26, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Crowd Bomber',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 2.9085367,
#   'ratings': 1652,
#   'reviews': 658,
#   'histogram': [575, 191, 211, 161, 514],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 24, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'NARUTO X BORUTO NINJA VOLTAGE',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9463892,
#   'ratings': 644605,
#   'reviews': 337804,
#   'histogram': [112980, 26595, 42771, 61915, 400344],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '78M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 21, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Snow Storm Superhero',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.060577,
#   'ratings': 10597,
#   'reviews': 4583,
#   'histogram': [1732, 387, 580, 703, 7195],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '156M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 14, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Stickfight Infinity',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.042698,
#   'ratings': 93006,
#   'reviews': 39210,
#   'histogram': [13331, 4001, 6886, 9933, 58855],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 13, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Fps Robot Shooting Games – Counter Terrorist Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.455696,
#   'ratings': 21752,
#   'reviews': 13702,
#   'histogram': [1876, 683, 693, 897, 17603],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 1, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Diableros: Zombie RPG Shooter',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.8350515,
#   'ratings': 97,
#   'reviews': 46,
#   'histogram': [24, 1, 2, 10, 60],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '85M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 31, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Stick Fight Online: Multiplayer Stickman Battle',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4614143,
#   'ratings': 118400,
#   'reviews': 60473,
#   'histogram': [8583, 2143, 5695, 11612, 90367],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '37M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 8, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Garfield™ Rush',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.263311,
#   'ratings': 31462,
#   'reviews': 12635,
#   'histogram': [3401, 1258, 1533, 2731, 22539],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '77M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 22, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'LegendArya',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.04,
#   'ratings': 106,
#   'reviews': 73,
#   'histogram': [9, 10, 9, 13, 65],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '95M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 9, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Desert Riders',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.238432,
#   'ratings': 44086,
#   'reviews': 13688,
#   'histogram': [3587, 1829, 4120, 5497, 29053],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 28, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Snipers vs Thieves: Classic!',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.2178574,
#   'ratings': 2924,
#   'reviews': 1546,
#   'histogram': [334, 62, 188, 386, 1954],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 3, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Robotics!',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.7098625,
#   'ratings': 35035,
#   'reviews': 16366,
#   'histogram': [6197, 2511, 3977, 4922, 17428],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '106M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'MaskGun Multiplayer FPS - Free Shooting Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2038465,
#   'ratings': 445388,
#   'reviews': 255569,
#   'histogram': [53645, 13918, 25466, 47328, 305031],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 15, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Sniper Zombies: Offline Game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.4416666,
#   'ratings': 33861,
#   'reviews': 10344,
# ...
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '94M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'SpongeBob: Sponge on the Run',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.228155,
#   'ratings': 2067,
#   'reviews': 650,
#   'histogram': [261, 60, 90, 190, 1466],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '19M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 22, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Vector Full',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.102941,
#   'ratings': 38253,
#   'reviews': 9946,
#   'histogram': [5103, 1537, 2601, 4088, 24924],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '91M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 26, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Worms 3',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.8380191,
#   'ratings': 70348,
#   'reviews': 15118,
#   'histogram': [13383, 2951, 4397, 10562, 39055],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 28, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'NES.emu',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.632768,
#   'ratings': 2378,
#   'reviews': 936,
#   'histogram': [147, 0, 53, 174, 2004],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 9, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Ms. PAC-MAN',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.386117,
#   'ratings': 5650,
#   'reviews': 2298,
#   'histogram': [367, 245, 294, 674, 4070],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 15, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'SAMURAI II: VENGEANCE',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.436451,
#   'ratings': 11946,
#   'reviews': 4569,
#   'histogram': [744, 229, 759, 1547, 8667],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '48M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 24, 2011',
#   'contentRating': 'Teen'},
#  {'title': 'THE KING OF FIGHTERS-A 2012',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.9165154,
#   'ratings': 11047,
#   'reviews': 6687,
#   'histogram': [1694, 541, 982, 1604, 6226],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '24M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 30, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'Peace, Death!',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.6814017,
#   'ratings': 18607,
#   'reviews': 6203,
#   'histogram': [481, 300, 642, 1815, 15369],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '38M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 23, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'MD.emu',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.52459,
#   'ratings': 3001,
#   'reviews': 1429,
#   'histogram': [147, 24, 147, 467, 2216],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 27, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'The Impossible Game',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.939771,
#   'ratings': 20039,
#   'reviews': 3641,
#   'histogram': [3242, 847, 1536, 2663, 11751],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 25, 2010',
#   'contentRating': 'Everyone'},
#  {'title': "THE KING OF FIGHTERS '98",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.4161453,
#   'ratings': 17622,
#   'reviews': 6591,
#   'histogram': [1342, 410, 711, 2264, 12895],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.1M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 23, 2014',
#   'contentRating': 'Teen'},
#  {'title': "THE KING OF FIGHTERS '97",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.388679,
#   'ratings': 15938,
#   'reviews': 5776,
#   'histogram': [1263, 441, 741, 1884, 11609],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 13, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'JCheater: Vice City Edition',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.2322738,
#   'ratings': 4100,
#   'reviews': 1689,
#   'histogram': [1454, 160, 310, 331, 1845],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.7M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 2, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': 'M64Plus FZ Pro Emulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.49,
#   'ratings': 182,
#   'reviews': 99,
#   'histogram': [9, 7, 7, 20, 139],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.4M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 22, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Granny Smith',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.693268,
#   'ratings': 43173,
#   'reviews': 19278,
#   'histogram': [1796, 310, 1094, 2939, 37034],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 29, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Dungeon Village',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.606753,
#   'ratings': 13309,
#   'reviews': 3432,
#   'histogram': [383, 198, 634, 1837, 10257],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 2, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Marvel Pinball',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.7296417,
#   'ratings': 9241,
#   'reviews': 2586,
#   'histogram': [1806, 582, 702, 1364, 4787],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 6, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'METAL SLUG 3',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.967678,
#   'ratings': 15935,
#   'reviews': 6489,
#   'histogram': [2407, 830, 1156, 2018, 9524],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 11, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'VGBAnext - Universal Console Emulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2982454,
#   'ratings': 1142,
#   'reviews': 643,
#   'histogram': [100, 40, 70, 140, 792],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 19, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'ARC Browser',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.26,
#   'ratings': 457,
#   'reviews': 327,
#   'histogram': [45, 9, 36, 55, 312],
#   'price': 8.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '17M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 26, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Sonic Jump Pro',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.830819,
#   'ratings': 9376,
#   'reviews': 4140,
#   'histogram': [2213, 222, 272, 899, 5770],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 21, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Balance The Beam 2.0',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Double Dragon Trilogy',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.163014,
#   'ratings': 7346,
#   'reviews': 2273,
#   'histogram': [684, 392, 604, 1026, 4640],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.6M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 4, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'Nostalgia.NES Pro (NES Emulator)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.6065574,
#   'ratings': 2460,
#   'reviews': 905,
#   'histogram': [121, 40, 60, 242, 1997],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.7M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 26, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Retro8 (NES Emulator)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.7,
#   'ratings': 854,
#   'reviews': 608,
#   'histogram': [188, 17, 128, 51, 470],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 7, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'GBA.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.564815,
#   'ratings': 1454,
#   'reviews': 662,
#   'histogram': [80, 40, 67, 53, 1214],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 21, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'holedown',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.371901,
#   'ratings': 1215,
#   'reviews': 510,
#   'histogram': [10, 60, 150, 241, 754],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 25, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'SWORDSHOT',
#   'installs': '50+',
#   'minInstalls': 50,
#   'score': 4.923077,
#   'ratings': 13,
#   'reviews': 9,
#   'histogram': [0, 0, 0, 1, 12],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 16, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Atomic Bomber Full',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.4928827,
#   'ratings': 9475,
#   'reviews': 2598,
#   'histogram': [556, 168, 455, 1163, 7133],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.6M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 29, 2010',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'FINAL FANTASY II',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.4790998,
#   'ratings': 3124,
#   'reviews': 1228,
#   'histogram': [713, 201, 341, 613, 1256],
#   'price': 7.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 20, 2012',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'METAL SLUG',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8458843,
#   'ratings': 5737,
#   'reviews': 2307,
#   'histogram': [954, 311, 542, 784, 3146],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 19, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'Pizza Boy GBC Pro',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.68,
#   'ratings': 391,
#   'reviews': 269,
#   'histogram': [15, 0, 7, 47, 322],
#   'price': 4.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '11M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 27, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Mupen64Plus AE (N64 Emulator)',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.4527845,
#   'ratings': 4817,
#   'reviews': 1984,
#   'histogram': [1178, 350, 548, 595, 2146],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 18, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'The World Ends With You',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.7336154,
#   'ratings': 4737,
#   'reviews': 1442,
#   'histogram': [110, 60, 130, 380, 4057],
#   'price': 17.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 25, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Hyperforma Premium',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.75,
#   'ratings': 32,
#   'reviews': 27,
#   'histogram': [2, 0, 0, 0, 30],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '33M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 6, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Yaba Sanshiro Pro - Sega Saturn Emulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.19,
#   'ratings': 210,
#   'reviews': 151,
#   'histogram': [12, 10, 25, 38, 125],
#   'price': 5.6,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'SPACE INVADERS',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.59,
#   'ratings': 208,
#   'reviews': 128,
#   'histogram': [6, 8, 4, 27, 163],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 10, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'SAMURAI SHODOWN II',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2686834,
#   'ratings': 5645,
#   'reviews': 2267,
#   'histogram': [512, 221, 311, 793, 3808],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.8M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 28, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Miner Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.0419846,
#   'ratings': 2632,
#   'reviews': 535,
#   'histogram': [311, 110, 251, 442, 1518],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '27M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 3, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'GBC.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.51,
#   'ratings': 1034,
#   'reviews': 435,
#   'histogram': [62, 20, 51, 93, 808],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 23, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Shopkins Run!',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.46,
#   'ratings': 181,
#   'reviews': 117,
#   'histogram': [38, 16, 25, 27, 75],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 21, 2016',
#   'contentRating': 'Everyone'},
#  {'title': "Ghosts'n Goblins MOBILE",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.17,
#   'ratings': 905,
#   'reviews': 537,
#   'histogram': [108, 9, 90, 108, 590],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'NEO.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.43,
#   'ratings': 1156,
#   'reviews': 731,
#   'histogram': [335, 46, 104, 127, 544],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 14, 2012',
#   'contentRating': 'Everyone'},
#  ...]

# %%
# It appears 7 entries were lost somehow

len(dictinfofinallist)
# Out:
# 5143

# %%
df = pd.DataFrame(dictinfofinallist)
df
# Out:
#                                     title      installs  minInstalls  \
# 0                                Among Us  100,000,000+    100000000
# 1                          Scribble Rider   10,000,000+     10000000
# 2                   Call of Duty®: Mobile  100,000,000+    100000000
# 3                              Hitmasters   50,000,000+     50000000
# 4                            Draw Defence      100,000+       100000
# ...                                   ...           ...          ...
# 5138        The Game Gal's Word Generator        1,000+         1000
# 5139                           Jumbline 2       10,000+        10000
# 5140                 Word Crack (Ad free)       50,000+        50000
# 5141  Word Search Daily PRO (900+ Levels)        1,000+         1000
# 5142                          Dropwords 2        1,000+         1000
#
#          score     ratings    reviews  \
# 0     4.435267   2069272.0  1070149.0
# 1     3.875305    216872.0    90486.0
# 2     4.478295  10747377.0  4949651.0
# 3     4.091615    279506.0    98735.0
# 4     3.950000       972.0      389.0
# ...        ...         ...        ...
# 5138  4.666666        12.0        6.0
# 5139  4.579439      1286.0      627.0
# 5140  4.225993     16368.0     7664.0
# 5141  4.425532        47.0       19.0
# 5142  4.452381        42.0       17.0
#
#                                        histogram  price   free  offersIAP  \
# 0        [163295, 43146, 91796, 202372, 1568663]   0.00   True       True
# 1           [39384, 11069, 15627, 21915, 128877]   0.00   True       True
# 2     [783285, 203338, 400469, 1062865, 8297420]   0.00   True       True
# 3           [39089, 10405, 18016, 30292, 181704]   0.00   True       True
# 4                         [185, 38, 48, 68, 633]   0.00   True      False
# ...                                          ...    ...    ...        ...
# 5138                            [0, 1, 0, 1, 10]   1.99  False      False
# 5139                       [36, 0, 84, 228, 938]   2.99  False      False
# 5140               [1335, 472, 1040, 3829, 9692]   2.99  False       True
# 5141                           [2, 0, 4, 11, 30]   1.99  False      False
# 5142                            [1, 2, 2, 9, 28]   0.99  False      False
#
#       size   genre      genreId      released contentRating
# 0      70M  Action  GAME_ACTION  Jun 15, 2018  Everyone 10+
# 1     123M  Action  GAME_ACTION  Jul 23, 2020      Everyone
# 2      94M  Action  GAME_ACTION  Sep 30, 2019    Mature 17+
# 3      85M  Action  GAME_ACTION  Mar 19, 2020          Teen
# 4      76M  Action  GAME_ACTION  Aug 27, 2020      Everyone
# ...    ...     ...          ...           ...           ...
# 5138  9.4M    Word    GAME_WORD  Dec 25, 2017      Everyone
# 5139   35M    Word    GAME_WORD   Nov 1, 2011      Everyone
# 5140   56M    Word    GAME_WORD  Oct 19, 2011      Everyone
# 5141  9.9M    Word    GAME_WORD  Aug 13, 2018      Everyone
# 5142   16M    Word    GAME_WORD  Jul 22, 2014      Everyone
#
# [5143 rows x 15 columns]

# %%
df.to_pickle('reviewfeatures.pkl')
