# %% [markdown]
# # Importing and Installing Necessary Things

# %%
# Will be using this to get information on each app based on appid
# Information can be found here https://github.com/JoMingyu/google-play-scraper

#pip install google_play_scraper

# %%
# Will help me scroll down a page to get all the possible html

#pip install selenium

# %%
import requests
import datetime
from datetime import datetime
import time
import pandas as pd

from bs4 import BeautifulSoup
from selenium import webdriver

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# # Getting List of App IDs per category

# %%
#Categories, focusing on top free and top paid apps of each.

#Action
ActionFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfZnJlZV9HQU1FX0FDVElPThAHGAM%3D:S:ANO1ljKHNjI&gsr=CibSDiMKIQobdG9wc2VsbGluZ19mcmVlX0dBTUVfQUNUSU9OEAcYAw%3D%3D:S:ANO1ljLUxfQ&hl=en_US'
ActionPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfcGFpZF9HQU1FX0FDVElPThAHGAM%3D:S:ANO1ljLH0kM&gsr=CibSDiMKIQobdG9wc2VsbGluZ19wYWlkX0dBTUVfQUNUSU9OEAcYAw%3D%3D:S:ANO1ljIdBNk&hl=en_US'

#Adventure
AdventureFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4mCiQKHnRvcHNlbGxpbmdfZnJlZV9HQU1FX0FEVkVOVFVSRRAHGAM%3D:S:ANO1ljJV7FQ&gsr=CinSDiYKJAoedG9wc2VsbGluZ19mcmVlX0dBTUVfQURWRU5UVVJFEAcYAw%3D%3D:S:ANO1ljIcQUo&hl=en_US'
AdventurePaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4mCiQKHnRvcHNlbGxpbmdfcGFpZF9HQU1FX0FEVkVOVFVSRRAHGAM%3D:S:ANO1ljKjB_A&gsr=CinSDiYKJAoedG9wc2VsbGluZ19wYWlkX0dBTUVfQURWRU5UVVJFEAcYAw%3D%3D:S:ANO1ljJuB_8&hl=en_US'

#Arcade
ArcadeFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfZnJlZV9HQU1FX0FSQ0FERRAHGAM%3D:S:ANO1ljIshgI&gsr=CibSDiMKIQobdG9wc2VsbGluZ19mcmVlX0dBTUVfQVJDQURFEAcYAw%3D%3D:S:ANO1ljJq_Gc&hl=en_US'
ArcadePaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfcGFpZF9HQU1FX0FSQ0FERRAHGAM%3D:S:ANO1ljIhZHI&gsr=CibSDiMKIQobdG9wc2VsbGluZ19wYWlkX0dBTUVfQVJDQURFEAcYAw%3D%3D:S:ANO1ljKAU-U&hl=en_US'

#Board
BoardFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4iCiAKGnRvcHNlbGxpbmdfZnJlZV9HQU1FX0JPQVJEEAcYAw%3D%3D:S:ANO1ljL4-C4&gsr=CiXSDiIKIAoadG9wc2VsbGluZ19mcmVlX0dBTUVfQk9BUkQQBxgD:S:ANO1ljKCMxA&hl=en_US'
BoardPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4iCiAKGnRvcHNlbGxpbmdfcGFpZF9HQU1FX0JPQVJEEAcYAw%3D%3D:S:ANO1ljJzXAU&gsr=CiXSDiIKIAoadG9wc2VsbGluZ19wYWlkX0dBTUVfQk9BUkQQBxgD:S:ANO1ljKlrPM&hl=en_US'

#Card
CardFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4hCh8KGXRvcHNlbGxpbmdfZnJlZV9HQU1FX0NBUkQQBxgD:S:ANO1ljLIZ98&gsr=CiTSDiEKHwoZdG9wc2VsbGluZ19mcmVlX0dBTUVfQ0FSRBAHGAM%3D:S:ANO1ljJ_lBQ&hl=en_US'
CardPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4hCh8KGXRvcHNlbGxpbmdfcGFpZF9HQU1FX0NBUkQQBxgD:S:ANO1ljJscys&gsr=CiTSDiEKHwoZdG9wc2VsbGluZ19wYWlkX0dBTUVfQ0FSRBAHGAM%3D:S:ANO1ljJdjQU&hl=en_US'

#Casino
CasinoFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfZnJlZV9HQU1FX0NBU0lOTxAHGAM%3D:S:ANO1ljLgBLI&gsr=CibSDiMKIQobdG9wc2VsbGluZ19mcmVlX0dBTUVfQ0FTSU5PEAcYAw%3D%3D:S:ANO1ljKRt4Q&hl=en_US'
CasinoPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfcGFpZF9HQU1FX0NBU0lOTxAHGAM%3D:S:ANO1ljKKXS8&gsr=CibSDiMKIQobdG9wc2VsbGluZ19wYWlkX0dBTUVfQ0FTSU5PEAcYAw%3D%3D:S:ANO1ljKKlDQ&hl=en_US'

#Casual
CasualFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfZnJlZV9HQU1FX0NBU1VBTBAHGAM%3D:S:ANO1ljLV380&gsr=CibSDiMKIQobdG9wc2VsbGluZ19mcmVlX0dBTUVfQ0FTVUFMEAcYAw%3D%3D:S:ANO1ljIYYsk&hl=en_US'
CasualPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfcGFpZF9HQU1FX0NBU1VBTBAHGAM%3D:S:ANO1ljKu4yM&gsr=CibSDiMKIQobdG9wc2VsbGluZ19wYWlkX0dBTUVfQ0FTVUFMEAcYAw%3D%3D:S:ANO1ljK2Y3o&hl=en_US'

#Educational
EducationalFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4oCiYKIHRvcHNlbGxpbmdfZnJlZV9HQU1FX0VEVUNBVElPTkFMEAcYAw%3D%3D:S:ANO1ljIXePQ&gsr=CivSDigKJgogdG9wc2VsbGluZ19mcmVlX0dBTUVfRURVQ0FUSU9OQUwQBxgD:S:ANO1ljJyrL8&hl=en_US'
EducationalPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4oCiYKIHRvcHNlbGxpbmdfcGFpZF9HQU1FX0VEVUNBVElPTkFMEAcYAw%3D%3D:S:ANO1ljKfMYQ&gsr=CivSDigKJgogdG9wc2VsbGluZ19wYWlkX0dBTUVfRURVQ0FUSU9OQUwQBxgD:S:ANO1ljKesRA&hl=en_US'

#Music
MusicFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4iCiAKGnRvcHNlbGxpbmdfZnJlZV9HQU1FX01VU0lDEAcYAw%3D%3D:S:ANO1ljLRvvI&gsr=CiXSDiIKIAoadG9wc2VsbGluZ19mcmVlX0dBTUVfTVVTSUMQBxgD:S:ANO1ljJI1UU&hl=en_US'
MusicPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4iCiAKGnRvcHNlbGxpbmdfcGFpZF9HQU1FX01VU0lDEAcYAw%3D%3D:S:ANO1ljLaZUI&gsr=CiXSDiIKIAoadG9wc2VsbGluZ19wYWlkX0dBTUVfTVVTSUMQBxgD:S:ANO1ljK7800&hl=en_US'

#Puzzle
PuzzleFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfZnJlZV9HQU1FX1BVWlpMRRAHGAM%3D:S:ANO1ljLYuNA&gsr=CibSDiMKIQobdG9wc2VsbGluZ19mcmVlX0dBTUVfUFVaWkxFEAcYAw%3D%3D:S:ANO1ljIyFv8&hl=en_US'
PuzzlePaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfcGFpZF9HQU1FX1BVWlpMRRAHGAM%3D:S:ANO1ljIFZPM&gsr=CibSDiMKIQobdG9wc2VsbGluZ19wYWlkX0dBTUVfUFVaWkxFEAcYAw%3D%3D:S:ANO1ljIYoBk&hl=en_US'

#Racing
RacingFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfZnJlZV9HQU1FX1JBQ0lORxAHGAM%3D:S:ANO1ljKlRGU&gsr=CibSDiMKIQobdG9wc2VsbGluZ19mcmVlX0dBTUVfUkFDSU5HEAcYAw%3D%3D:S:ANO1ljIWYJI&hl=en_US'
RacingPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfcGFpZF9HQU1FX1JBQ0lORxAHGAM%3D:S:ANO1ljLklZk&gsr=CibSDiMKIQobdG9wc2VsbGluZ19wYWlkX0dBTUVfUkFDSU5HEAcYAw%3D%3D:S:ANO1ljJvXBg&hl=en_US'

#RolePlaying
RolePlayingFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4pCicKIXRvcHNlbGxpbmdfZnJlZV9HQU1FX1JPTEVfUExBWUlORxAHGAM%3D:S:ANO1ljJawN8&gsr=CizSDikKJwohdG9wc2VsbGluZ19mcmVlX0dBTUVfUk9MRV9QTEFZSU5HEAcYAw%3D%3D:S:ANO1ljISF1w&hl=en_US'
RolePlayingPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4pCicKIXRvcHNlbGxpbmdfcGFpZF9HQU1FX1JPTEVfUExBWUlORxAHGAM%3D:S:ANO1ljLiiew&gsr=CizSDikKJwohdG9wc2VsbGluZ19wYWlkX0dBTUVfUk9MRV9QTEFZSU5HEAcYAw%3D%3D:S:ANO1ljJ0Gwk&hl=en_US'

#Simulation
SimulationFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4nCiUKH3RvcHNlbGxpbmdfZnJlZV9HQU1FX1NJTVVMQVRJT04QBxgD:S:ANO1ljKreHA&gsr=CirSDicKJQofdG9wc2VsbGluZ19mcmVlX0dBTUVfU0lNVUxBVElPThAHGAM%3D:S:ANO1ljI7FRI&hl=en_US'
SimulationPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4nCiUKH3RvcHNlbGxpbmdfcGFpZF9HQU1FX1NJTVVMQVRJT04QBxgD:S:ANO1ljIt5SI&gsr=CirSDicKJQofdG9wc2VsbGluZ19wYWlkX0dBTUVfU0lNVUxBVElPThAHGAM%3D:S:ANO1ljKeTxs&hl=en_US'

#Sports
SportsFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfZnJlZV9HQU1FX1NQT1JUUxAHGAM%3D:S:ANO1ljK19eE&gsr=CibSDiMKIQobdG9wc2VsbGluZ19mcmVlX0dBTUVfU1BPUlRTEAcYAw%3D%3D:S:ANO1ljJKUZM&hl=en_US'
SportsPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfcGFpZF9HQU1FX1NQT1JUUxAHGAM%3D:S:ANO1ljIGfKM&gsr=CibSDiMKIQobdG9wc2VsbGluZ19wYWlkX0dBTUVfU1BPUlRTEAcYAw%3D%3D:S:ANO1ljLc9sU&hl=en_US'

#Strategy
StrategyFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4lCiMKHXRvcHNlbGxpbmdfZnJlZV9HQU1FX1NUUkFURUdZEAcYAw%3D%3D:S:ANO1ljIuwtQ&gsr=CijSDiUKIwoddG9wc2VsbGluZ19mcmVlX0dBTUVfU1RSQVRFR1kQBxgD:S:ANO1ljLpyj4&hl=en_US'
StrategyPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4lCiMKHXRvcHNlbGxpbmdfcGFpZF9HQU1FX1NUUkFURUdZEAcYAw%3D%3D:S:ANO1ljI3COs&gsr=CijSDiUKIwoddG9wc2VsbGluZ19wYWlkX0dBTUVfU1RSQVRFR1kQBxgD:S:ANO1ljIhVjE&hl=en_US'

#Trivia
TriviaFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfZnJlZV9HQU1FX1RSSVZJQRAHGAM%3D:S:ANO1ljLw164&gsr=CibSDiMKIQobdG9wc2VsbGluZ19mcmVlX0dBTUVfVFJJVklBEAcYAw%3D%3D:S:ANO1ljIUmRc&hl=en_US'
TriviaPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4jCiEKG3RvcHNlbGxpbmdfcGFpZF9HQU1FX1RSSVZJQRAHGAM%3D:S:ANO1ljJeZh8&gsr=CibSDiMKIQobdG9wc2VsbGluZ19wYWlkX0dBTUVfVFJJVklBEAcYAw%3D%3D:S:ANO1ljKHdVE&hl=en_US'

#Word
WordFree = 'https://play.google.com/store/apps/collection/cluster?clp=0g4hCh8KGXRvcHNlbGxpbmdfZnJlZV9HQU1FX1dPUkQQBxgD:S:ANO1ljLuO2k&gsr=CiTSDiEKHwoZdG9wc2VsbGluZ19mcmVlX0dBTUVfV09SRBAHGAM%3D:S:ANO1ljIqSWE&hl=en_US'
WordPaid = 'https://play.google.com/store/apps/collection/cluster?clp=0g4hCh8KGXRvcHNlbGxpbmdfcGFpZF9HQU1FX1dPUkQQBxgD:S:ANO1ljJM7Hg&gsr=CiTSDiEKHwoZdG9wc2VsbGluZ19wYWlkX0dBTUVfV09SRBAHGAM%3D:S:ANO1ljJLmvc&hl=en_US'

# %%
#List of Categories to run function through later.

listofcateg = [ActionFree, ActionPaid, AdventureFree, AdventurePaid, ArcadeFree, ArcadePaid, BoardFree, BoardPaid, CardFree, CardPaid, CasinoFree, CasinoPaid, CasualFree, CasualPaid, EducationalFree, EducationalPaid, MusicFree, MusicPaid, PuzzleFree, PuzzlePaid, RacingFree, RacingPaid, RolePlayingFree, RolePlayingPaid, SimulationFree, SimulationPaid, SportsFree, SportsPaid, StrategyFree, StrategyPaid, TriviaFree, TriviaPaid, WordFree, WordPaid]

# %% [markdown]
# ### Creating Function to return list of appids

# %%
# Testing a link in this bottom example to see if I can get the link I need.

#driver = webdriver.Safari()
#driver.get('https://play.google.com/store/apps/collection/cluster?clp=0g4fCh0KF3RvcGdyb3NzaW5nX0dBTUVfQUNUSU9OEAcYAw%3D%3D:S:ANO1ljIOh7o&gsr=CiLSDh8KHQoXdG9wZ3Jvc3NpbmdfR0FNRV9BQ1RJT04QBxgD:S:ANO1ljLWGVQ&hl=en_US')

def scroll_to_bottom(driver):

    old_position = 0
    new_position = None

    while new_position != old_position:
        # Get old scroll position
        old_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                 " window.pageYOffset : (document.documentElement ||"
                 " document.body.parentNode || document.body);"))
        
        # Sleep and Scroll
        time.sleep(1)
        driver.execute_script((
                "var scrollingElement = (document.scrollingElement ||"
                " document.body);scrollingElement.scrollTop ="
                " scrollingElement.scrollHeight;"))
        
        # Get new position
        new_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                 " window.pageYOffset : (document.documentElement ||"
                 " document.body.parentNode || document.body);"))

#scroll_to_bottom(driver)

#html = driver.page_source

#soup = BeautifulSoup(html, 'lxml')

#driver.quit()

# %%
def cleaner(stuff):
    # Only looking for href links as this is where our appid is.
    links = [a['href'] for a in stuff.find_all('a', href=True)]
    
    # Only looking for unique links as game links show up several times.
    uniquelinks = []
    for x in links:
        if x not in uniquelinks:
            uniquelinks.append(x)
            
    # Only want links with that specific prefix as there are a lot of useless href links.            
    uniqueappidlinks = list(filter(lambda k: '/store/apps/details?id=' in k, uniquelinks))
    
    # Removing the front part now that we have the link we need.
    uniqueappid = [s.replace('/store/apps/details?id=', '') for s in uniqueappidlinks]
    
    return uniqueappid

# %%
# Putting everything together.

def giveappid(link):
    driver = webdriver.Safari()
    driver.get(link)
    
    scroll_to_bottom(driver)
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    
    driver.quit()
    
    return cleaner(soup)

# %%
# Applying function to the list of categories we made earlier.

listoflistofappids = list(map(lambda link: giveappid(link), listofcateg))
listoflistofappids
# Out:
# [['com.innersloth.spacemafia',
#   'com.tapped.drawrider',
#   'com.activision.callofduty.shooter',
#   'com.playgendary.hitmasters',
#   'com.drawprotector.wavy.ios',
#   'com.fungames.sniper3d',
#   'com.rkgames.basisgame',
#   'com.cassette.aquapark',
#   'air.com.hypah.io.slither',
#   'com.dts.freefireth',
#   'com.playgendary.kickthebuddy',
#   'com.YummyGames.SamuraiFlash',
#   'com.jtsniper.game',
#   'com.groogadgets.swipefight',
#   'com.nintendo.zaka',
#   'lol.onevone',
#   'com.ducky.slicethemall',
#   'com.cg.fanofguns',
#   'com.rubygames.assassin',
#   'spider.rope.hero.frogninja.gangstar.crime.herogame',
#   'com.Neurononfire.SupremeDuelist',
#   'com.tencent.ig',
#   'ru.galya.drawjoust',
#   'com.geishatokyo.trafficrun',
#   'com.supercell.brawlstars',
#   'com.outfit7.herodash',
#   'com.jpgroup.pocketsniper',
#   'com.PoxelStudios.DudeTheftAuto',
#   'com.miniclip.bowmasters',
#   'games.nerf.epic.pranks.free',
#   'com.time.trigger',
#   'com.outfit7.talkingtomgoldrun',
#   'com.amelosinteractive.snake',
#   'com.stealthgame.master',
#   'com.ohmgames.crowdshooter',
#   'mobi.gameguru.slapkings',
#   'com.playgendary.tom',
#   'com.ohbibi.fps',
#   'com.ohmgames.knockdolls',
#   'com.seenax.HideAndSeek',
#   'com.fungames.battletanksbeta',
#   'com.nintendo.zara',
#   'com.miniclip.agar.io',
#   'com.wildlife.games.battle.royale.free.zooba',
#   'com.netboom.cloudgaming.vortex_stadia_shadow_GeForce',
#   'com.crazylabs.lady.bug',
#   'vh.one',
#   'com.habby.archero',
#   'com.gamestart.protectthevip',
#   'com.pixel.gun3d',
#   'com.Deven.Arrow3D',
#   'com.sandboxol.indiegame.bedwar',
#   'com.studio501.curvypunch3d',
#   'com.geishatokyo.snowballio',
#   'com.hgamesart.hurricanehero',
#   'com.edkongames.mobs',
#   'com.yodo1.crossyroad',
#   'zombie.survival.craft.z',
#   'com.imangi.templerun2',
#   'com.kabam.marvelbattle',
#   'com.playgendary.tombpaint',
#   'com.dangernoodle.killerbee',
#   'com.pixonic.wwr',
#   'com.tikitaka.folk',
#   'com.Bingo.Football',
#   'com.mgc.RopeHero.ViceTown',
#   'com.gamehivecorp.beattheboss4',
#   'com.wildspike.wormszone',
#   'com.mobile.legends',
#   'com.Snow.Golf',
#   'black.mafia.ironboy.stickman.rope.heros',
#   'com.stickman.warriors.stickwarriors.dragon.shadow.fight',
#   'com.chaloapps.strikefortressbox',
#   'com.hitrock.hideonline',
#   'com.geishatokyo.dinosaur',
#   'com.vng.g6.a.zombie',
#   'com.gamedevltd.wwh',
#   'com.generagames.resistance',
#   'com.bandainamcoent.dblegends_ww',
#   'air.com.ubisoft.brawl.halla.platform.fighting.action.pvp',
#   'com.bhvr.deadbydaylight',
#   'com.chillyroom.zhmr.gp',
#   'com.funnii.maskofstick',
#   'com.ohmgames.smashthemall',
#   'sniper.gun.zombie.shooting',
#   'com.cec.skateuniverse',
#   'com.stickman.shadow.battle',
#   'com.hgamesart.blackholehero',
#   'me.modernator.stickWarfareBloodStrike',
#   'games.noho.gungang',
#   'com.gta.truck.driver.city.crush',
#   'com.mousemobile.explorationcraft',
#   'com.wb.goog.mkx',
#   'com.h8games.helixjump',
#   'com.Eageron.apps.RealTimeShields',
#   'com.freegamesstudio.thesurvivalhuntergames2',
#   'com.gta.real.gangster.crime',
#   'com.lalonde.upstream',
#   'com.gameloft.android.ANMP.GloftGGHM',
#   'rs.pwn.zombielike',
#   'com.fcnaud.robbery',
#   'com.dive.bed.game',
#   'com.chaloapps.roosterrudy',
#   'com.nekki.shadowfight',
#   'com.zeptolab.bulletecho.google',
#   'com.os.falcon.yogame.stickfighter',
#   'com.netease.ddsfna',
#   'com.sega.sonic1px',
#   'com.titan.cd.gb',
#   'com.rage.road',
#   'jpark.AOS5',
#   'com.aryasgames.zombieseverywhere',
#   'com.babil.archers.tale.bow.hunter.battle.action',
#   'com.ZenithGames.CrowdBomber',
#   'com.desert.riders',
#   'com.bandainamcoent.ninjavoltage_app',
#   'com.mizo.robot.fps.shooting.game',
#   'com.junesoftware.maskgun',
#   'io.painkiller.battle.royale',
#   'com.cheshirex.stickmanthefight',
#   'com.ivy.garfield.run',
#   'com.bloop.food',
#   'com.zeptolab.robotics',
#   'com.hgamesart.snowstorm',
#   'com.matte.rushcrush',
#   'com.playstack.svtc',
#   'com.glu.zbs',
#   'com.cg.cowboy',
#   'com.skygo.stickfight2',
#   'com.rubygames.slingdrift',
#   'com.yuriychechulin.throwio',
#   'com.grandgangster.crimecity.prisonescape',
#   'com.my.warface.online.fps.pvp.action.shooter',
#   'com.gun.black.ops',
#   'com.tomo.pushbattle',
#   'com.gsgames.pixel.combat',
#   'sniper.honor.real3d.shooter.assassin.free.android',
#   'com.PuzzleOnly.KnockoutRace',
#   'com.stick.fight.battle.warrior',
#   'com.flaregames.zgs',
#   'com.pikpok.dr2.play',
#   'fi.twomenandadog.zombiecatchers',
#   'com.hgamesart.ropemummy',
#   'com.chaloapps.memeswars',
#   'com.funnii.robotsuper.offlinegames',
#   'com.ChillyRoom.DungeonShooter',
#   'com.panzerdog.tacticool',
#   'com.joydo.minestrikenew',
#   'com.clement.ballmayhem',
#   'com.mtvn.superbrawlapp',
#   'com.zg.dinosaur.hunter.wild.jungle.animals.hunting.sniper.safari.free.apps',
#   'com.criticalforceentertainment.criticalops',
#   'com.funnii.galaxyofstick',
#   'com.aldagames.zombieshooter',
#   'com.fun.games.commando.black.shadow',
#   'com.zeptolab.omnomrun.google',
#   'com.bandainamcogames.dbzdokkanww',
#   'com.lf.sniper.gun.shooter.free.apps',
#   'com.aurecas.stickmanzombieshooter',
#   'com.hgamesart.superhero',
#   'com.madfingergames.wargames.shooter',
#   'com.roadglider.game',
#   'com.anfagames.sodaguys',
#   'com.doctor.surgerymaster',
#   'com.Floor18.Zombiner',
#   'com.hasbro.beybladesenterprise',
#   'com.sega.soniccd.classic',
#   'com.azurgames.BattleGroundRoyale',
#   'com.rkgames.smashywanted',
#   'com.kwalee.superherosunset',
#   'com.mgs.sniper1',
#   'com.spider.ropeman.superhero.gangster.vegas.crimecity',
#   'com.soneraltincit.cityfightvsstreetgang',
#   'com.autumn.skullgirls',
#   'com.nway.powerrangerslegacywars',
#   'com.DCGEntertainment.EnergyBlast',
#   'com.crazylabs.mr.bullet.puzzle.game3d',
#   'com.alienshooter.galaxy.attack2',
#   'com.assassingames.ninjafrogrope',
#   'com.gameloft.android.ANMP.GloftOLHM',
#   'com.gamedevltd.destinywarfare',
#   'com.miniclip.diep.io',
#   'com.lf.frontline.elite.war.free.apps',
#   'org.ppsspp.ppsspp',
#   'com.herogame.gplay.lastdayrulessurvival',
#   'com.gameloft.android.ANMP.GloftM5HM',
#   'com.sunnybaria.collabgame',
#   'com.sgs.urb.versuspixels',
#   'com.kabam.bigrobot',
#   'supreme.dragon.battle.shadow.fight.warriors',
#   'com.axlebolt.standoff2',
#   'com.mad.gunz',
#   'com.ggv.grand.city.thug.crime.gangester',
#   'com.edkongames.aurora',
#   'se.itatake.gumslinger',
#   'com.stick.hero.fighter.saiyan.supreme.dragon.warrios',
#   'com.kotobagames.namelesscat'],
#  ['com.scottgames.fivenightsatfreddys',
#   'com.rockstargames.gtasa',
#   'com.clickteam.ultimatecustomnight',
#   'com.dsemu.drastic',
#   'com.scottgames.sisterlocation',
#   'com.scottgames.fnaf4',
#   'com.ubisoft.assassinscreed.identity',
#   'com.squareenixmontreal.hitmansniperandroid',
#   'com.scottgames.fnaf3',
#   'com.activision.boz',
#   'jp.konami.epjCastlevania2',
#   'com.rockstargames.bully',
#   'com.rockstar.gta3',
#   'com.damonplay.damonps2.pro.ppsspp',
#   'com.bethsoft.DOOM',
#   'com.wb.lego.marvel',
#   'com.GameCoaster.ProtectDungeon',
#   'org.ppsspp.ppssppgold',
#   'com.playdigious.deadcells.mobile',
#   'com.turner.ttgfigures2',
#   'com.tipsworks.android.pascalswager.google',
#   'com.bethsoft.DOOMII',
#   'com.rockstargames.gtactw',
#   'com.jdroid.gtasacheater',
#   'com.jumpgames.RealSteel',
#   'com.venomizedArt.SlaughterRebels',
#   'com.nekki.shadowfight2.paid',
#   'com.turner.b10runner',
#   'com.MikaMobile.Zombieville2',
#   'com.EvilTortillaGames.cookiesvclaus',
#   'com.MortalCrusade.SwordOfKnight',
#   'com.agaming.thesun.origin',
#   'com.coffeestainstudios.goatsimulator.goatz',
#   'com.altavite.ps2emu',
#   'com.limbic.ac130',
#   'com.khg.actionsquad',
#   'com.Zonmob.Stickman.FightingGames.ShadowOfDeath',
#   'com.oddworld.Stranger',
#   'com.dotemu.titanquest',
#   'com.devolver.downwell_rerelease',
#   'com.foursakenmedia.heroesandcastles2',
#   'com.pastagames.ro1mobile',
#   'air.com.sfbgames.HauntTheHouseTerrortown',
#   'com.ubisoft.rayman.fiestarun',
#   'com.gameloft.android.ANMP.GloftM4HM',
#   'com.mtvn.tmntpp',
#   'com.archi701.elchapo',
#   'com.ThoriumGameLab.BattleOfVicksburg3',
#   'com.gameloft.android.ANMP.GloftM3HM',
#   'com.ThoriumGameLab.EastFront',
#   'com.DastroGamesStudio.FateZ',
#   'jp.co.capcom.rockman1en',
#   'com.FYQD.BrightMemory',
#   'com.gameloft.android.ANMP.GloftG4HM',
#   'com.oddworld.NNT',
#   'com.opentouchgaming.deltatouch',
#   'com.candyrufusgames.survivalcraft',
#   'com.mtvn.tmntrooftoprun',
#   'com.mygdx.digtochina.android',
#   'com.ThoriumGameLab.WinterWar',
#   'com.dingogames.tastyplanet1',
#   'com.mtvn.tmntMovieGame',
#   'air.com.oranginalplan.weaphones2020',
#   'com.outerminds.pewdiepie',
#   'com.dingogames.tastyplanet2',
#   'com.tequilabyte.walker.main',
#   'jp.co.capcom.rockman6en',
#   'com.IvanPanasenko.EndurancePremium',
#   'jp.co.capcom.rockman2en',
#   'com.vblank.RCRDX',
#   'com.ThoriumGameLab.Petrolia',
#   'com.Drool.ThumperPocketEdition',
#   'com.starshipstudio.thesurvivorremastered',
#   'com.pixelbite.sg',
#   'com.the10tons.teslavslovecraft',
#   'com.companyname.LetThemCome',
#   'com.jdroid.gta3modder',
#   'com.fansipan.stickman.shadow.knights.fightinggames',
#   'com.Dexus.Dinosaur.TRexFights.Dinosaurs.Dominator',
#   'com.littlegamesstudio.Gauntlet',
#   'com.foursakenmedia.heroesandcastles',
#   'com.the10tons.neonchrome',
#   'com.blinigames.lus',
#   'com.sigmateam.alienshooter2reloaded',
#   'com.stickman.warriors.dragon',
#   'jp.co.capcom.rockman4en',
#   'com.kylebarrett.Immortal',
#   'com.doublethink.ofdp2',
#   'com.dotemu.raidenlegacy',
#   'com.opentouchgaming.quadtouch',
#   'com.venomizedArt.Slaughter2',
#   'jp.halegg.nazcaf',
#   'com.square_enix.secret',
#   'com.agaming.zonaprojectx',
#   'com.unimob.stickman.ghost2.pay',
#   'com.TinyDevbox.DeadRain',
#   'com.gameloft.android.ANMP.GloftWBHM',
#   'com.darkarrow.stickfighter.saiyan.vip',
#   'com.imcrazy.ds2',
#   'jp.co.capcom.rockman3en',
#   'com.skyfox.foxoneAdv',
#   'com.AlexeySuslin.RunicCurse',
#   'com.zitga.ninja.stickman.legends.shadow.wars',
#   'com.foursakenmedia.bugheroes2',
#   'com.jurassicapps.jurassidinokidsunlocked',
#   'com.touchdimensions.zombie',
#   'com.venomizedart.Slaughter',
#   'com.Majorariatto.GolfingOverIt',
#   'com.nvidia.valvesoftware.halflife2',
#   'com.blabberf.gunroundsandroid',
#   'com.id.doom3bfg',
#   'com.sigmateam.alienshootermobile',
#   'com.VenomizedArt.Mindcell',
#   'com.tenbirds.animus',
#   'com.hgamesart.catsimulatorpro',
#   'com.devolverdigital.swredux.play',
#   'jp.co.capcom.rockman5en',
#   'com.Bornthrupieces.Bond007',
#   'de.kamibox.seesaw',
#   'com.Nariworks.VirusZombie',
#   'com.redantz.game.za3p',
#   'jp.konami.mgs2hd.shield',
#   'com.agaming.reporter',
#   'com.gsm.overdrivepremium',
#   'com.RideAndCrash.AmonAmarthBerserkerGame',
#   'com.reeltoreal.survivor_adventure_pro',
#   'com.entwell.rk_org',
#   'com.turner.trutv.wheelofdoom',
#   'com.the10tons.jydge',
#   'com.atypicalgames.chernobyl',
#   'com.addictinggames.manatarms',
#   'com.pixelstar.PixelFBladeVIP',
#   'com.PoshToffeeGames.MedalOfValor4PRO',
#   'com.agaming.mentalhospitaliv',
#   'com.atypicalgames.radiationcity',
#   'com.DefStudio.BattleGunVRGold',
#   'com.mtvn.dafrainforest.google',
#   'com.eyesright.amb',
#   'com.zitga.cyberfighters.shadow.hunter.legends',
#   'co.electrictoy.dig'],
#  ['com.roblox.client',
#   'com.multicraft.game',
#   'com.nianticlabs.pokemongo',
#   'com.BlissGames.Juego23',
#   'com.oneway.Deathcoming',
#   'com.movile.playkids.pkxd',
#   'com.cleverturtle.brickbuilder',
#   'com.eers.kraft.eerskraft',
#   'com.jockeygames.rampcar.stuntsfree.impossibletracks.stuntdriving.mega.car',
#   'free.os.jump.superbros.adventure.world',
#   'com.sega.sprint',
#   'com.tinyco.potter',
#   'com.neighbors.darkriddle',
#   'com.deuscraft.TurboTeam',
#   'net.wooga.junes_journey_hidden_object_mystery_game',
#   'com.lioncel.NoOneEscape',
#   'com.randonautica.app',
#   'com.os.falcon.bob2.adventure.world',
#   'com.grand.speed.hero.highway.gangster.chase',
#   'org.nanobit.hollywood',
#   'com.grand.police.transport.truck',
#   'com.playrix.manormatters',
#   'com.gameinsight.gplay.mmanor',
#   'com.apps2us.slither.slink.io',
#   'com.naturalmotion.clumsyninja',
#   'com.sgs.antiterrorism.counterattack.commandomissiongame',
#   'com.superbinogo.jungleboyadventure',
#   'com.hitcents.drawastickmanepic2free',
#   'com.gf.extreme.gtracing.car.stunts.impossiblecarstunts.stuntdriving',
#   'com.tinybuildgames.helloneighbor',
#   'com.tellurionmobile.realmcraft',
#   'com.secg.jurassiccraft',
#   'com.Earthkwak.Platformer',
#   'com.mytona.seekersnotes.android',
#   'com.aidungeon',
#   'com.cradley.bee.robot.games',
#   'com.sandboxol.indiegame.eggwars',
#   'air.SuperCity',
#   'com.bl.critical.strike',
#   'com.pocapp.dungeondogsgame',
#   'com.StickPage.diamant',
#   'com.fgz.us.police.flying.helicopter.car.transform.robot.games',
#   'com.doctor.robot.rescue.mission',
#   'games.fatlion.building.mycraft.surfing.craft.free.simulator.jetski.games.surf.league',
#   'com.fa.gym.fighting.game',
#   'com.spider.ropehero.superhero.gangstercrime',
#   'com.craftgames.plntcrft',
#   'com.crazylabs.jumanji',
#   'com.blyts.nobodies',
#   'com.impp.construction.simulator.forklift',
#   'com.bigag.bike.stunt.master',
#   'com.mojang.minecraftearth',
#   'com.cdt.basic.math.teacher',
#   'com.prettysimple.criminalcaseandroid',
#   'air.HardTime',
#   'com.jagex.oldscape.android',
#   'com.buildingcraftinggames.fun.kid.games.boys.block.craft.minecraft.story.mode.lego.create.build.marvel.hero.dc.legends.mcpe.mod',
#   'com.hitcents.drawastickmanepic3',
#   'com.buntoo.drone.robot.transformation',
#   'com.secg.earthcraft',
#   'com.tinydragonadventuregames.crafting.building.exploration.blocky.cube.lite.boy.girl.love.date.game.chat.minecraft.boyfriend',
#   'com.craftgames.worldcrft',
#   'com.mustardgames.topspeed.formulacar.racinggames',
#   'com.gun.fun.anti.shoot',
#   'com.gangstar.crime.fps',
#   'com.candyrufusgames.survivalcraft2trial',
#   'com.upjers.zoo2animalpark',
#   'com.ghs.dino.robot.car.robot.game',
#   'com.ugen.playquirk',
#   'com.studiowildcard.wardrumstudios.ark',
#   'com.RetrostyleGames.LastPirate.deadthieves',
#   'com.play.io.monster.truck.demolition.derby.crash.stunts',
#   'com.us.police.car.transform.robot.war',
#   'air.com.pixelfederation.diggy',
#   'com.tinydragonadventuregames.doll.house.craft.princess.fashion.girls.minecraft.barbie.creative.exploration.lite.build.mine.free',
#   'com.YovoGames.carwash4',
#   'com.playmini.miniworld',
#   'com.glu.stardomkim',
#   'com.rds.bike.racer.highway.rider.traffic.bike.racing.game',
#   'com.survivalcrafting.scary.theme.park.craft.horror.ghost.zombie.monster',
#   'com.cgs.offroad.farm.animal.transport.trailer.truck.driving.game',
#   'com.animal.attack.simulator2019.wild.hunting.games',
#   'de.codestream.horus',
#   'com.sandboxol.indiegame.skywar',
#   'com.YovoGames.babyCare2',
#   'com.appstrend.police.robot.bus.transform',
#   'com.pm.mega.ramp.impossible.car',
#   'com.FoxieGames.DinoProject',
#   'com.FumbGames.DragonMerge',
#   'com.wb.goog.legoswtfa',
#   'com.nag.pet.dog.virtual.family.adventure',
#   'com.happy.family.limousine.robot.game',
#   'com.appstrend.flying.eagle.robot.car.games',
#   'com.gz.deer.hunting.shooting',
#   'com.gaminglegends.taxigame.taxisimulator.grand.car.driving2020',
#   'freedom.bubble',
#   'com.red.ball.ballgames.bounceball.redball5',
#   'com.bandagames.miner',
#   'com.impp.city.traindriver.simulator',
#   'com.sandboxol.indiegame.luckyblock',
#   'com.indigokids.mim',
#   'com.cradley.jungle.robot.shooting.game',
#   'com.fgz.flying.fire.truck.engine.rescue.firefighter.robot.games',
#   'com.frenzygames.fgs.shooting.anti.terrorism.combat.mission',
#   'com.mustardgames.muscle.car.stunts.mega.ramp.stunt.car.impossibletracks',
#   'com.gs.lightspeed.superhero.rescue.mission.doctor.robot.games',
#   'com.cgs.sea.animal.transport.trailer.truck.driving.game',
#   'com.gamesunion.idleracingtycoon',
#   'com.spider.ropehero.gangster.crimecity',
#   'com.ludia.jw2',
#   'com.minecrafting.miniworldcrafting',
#   'com.eyesthegame.eyes',
#   'com.freerange.goosebumps',
#   'com.doctor.robot.human.rescue',
#   'com.EZTECK.brannyTeacherMath',
#   'jonessamuelren.far.home.spider.hero.run',
#   'com.SGS.DrivingSchoolGames.RealCarParkingSimulator',
#   'com.rlg.flying.tiger.bike.robot.transform',
#   'com.crazylabs.hotel.transylvania.adventure',
#   'com.monstergamesproductions.ramp.moto.rider',
#   'com.nag.home.manager.working.virtual.mom',
#   'com.buildtownn.skimlyblock',
#   'com.amongus.us',
#   'air.com.RustyLake.SamsaraRoom',
#   'com.offlinegames.police.racing',
#   'com.kongregate.mobile.throwdown.google',
#   'biggiant.prisonescape',
#   'com.g5e.homicidesquadpg.android',
#   'com.spider.ropehero.crimecity',
#   'com.hanako.mcpe_mods',
#   'com.CoolGames.MazeGame',
#   'com.minecraftpe.minicraft.multicraft.blockart',
#   'freegames.zombiesniper.deadtrigger',
#   'com.wooga.pearlsperil',
#   'com.igoldtech.streetchaser',
#   'com.reeltoreal.survivor_adventure',
#   'com.delworkhard1.minecrafting2020',
#   'com.darksacygames.sirenheadhorrorgame',
#   'air.com.moviestarplanet.roboblastplanet',
#   'com.gametornado.short_life',
#   'com.YovoGames.doctorBear',
#   'com.mustardgames.bmx.cycle.stunt.mega.ramp.impossibletracks',
#   'com.grand.theft.cheat.codes.five',
#   'com.gamefeast.bigcity.limousine.car.driver',
#   'com.spinmaster.enterprise.colleggtibles',
#   'com.tohsoft.arashi.ninja.shadow',
#   'com.budgestudios.googleplay.ThomasAndFriendsMagicalTracks',
#   'com.haiku.adventure.escape.game.mystery.stories',
#   'com.flying.tractor.simulator',
#   'com.xjoy.mermaid',
#   'air.ExtraLives',
#   'com.iron.flying.man.rope.hero.vegas.crime.simulator.gta',
#   'com.secg.robocraft',
#   'com.HuaYiGame.DeliveryFromThePain',
#   'com.wild.animals.transport.simulator',
#   'games.dali.adventure.point.click.lucid.dream.witch.planet.riddle',
#   'com.colto.cknrunner',
#   'com.KidsGames.SuperHippo',
#   'com.mastercraft.minecrafting',
#   'com.bikesstunt.motomaster.racing.game.trial.trick.bikeRacing',
#   'com.budgestudios.TransformersRescueBotsHeroAdventures',
#   'vegas.craftvegas2.adventuregame2020',
#   'com.armorgames.sodadungeon2',
#   'com.heliogames.westland',
#   'com.gunshooting.counterstrike.fps',
#   'games.fatlion.crafting.building.mine.theme.park.games.roller.coaster.tycoon.boys.girls.exploration.lite.roblox.zoo.water',
#   'com.superbinogo.jungleboyadventure2',
#   'com.survivalcrafting.airport.city.pilot.plane.craft.fly.simulator.flight.air.traffic.control.airline.commander.building.flying',
#   'com.RbwInteractive.fortyfourCats',
#   'com.us.army.humvee.jeep.car.transporter.parking.game',
#   'com.backstreet.police.panda.robot.transform.robotwar',
#   'com.netease.lztgglobal',
#   'com.fgz.us.police.eagle.robot.transform.flying.bike.game',
#   'com.myappz.firegirlWaterboy',
#   'com.runefall.match3.puzzle.adventure.gp',
#   'com.amazing.spider.rope.hero.ninja.gangster.crimecity',
#   'com.aldagames.craftingdead',
#   'com.blackpanther.ninjaarashi',
#   'com.baldi.horror.escape.basics',
#   'com.nianticlabs.hpwu.prod',
#   'com.secg.terracraft2',
#   'com.cgs.us.flying.police.robot.speed.hero.crime.city.hero.games',
#   'com.happy.family.tiger.robot.games',
#   'com.door.glass.bottle.shooter.expert',
#   'com.pacific.wildlands',
#   'com.LiliJoy.DragonLand',
#   'com.nordcurrent.murderinalps',
#   'com.PSVStudio.HippoBabyBall',
#   'com.pocapp.castlecats',
#   'com.miniworldblock.krafting202',
#   'com.fivebn.LL1_f2p',
#   'es.socialpoint.dragonland',
#   'com.mustardgames.army.prison.transport',
#   'com.PSVStudio.BirthdayParty',
#   'com.glaznev.innocent',
#   'air.com.RustyLake.CubeEscapeParadox',
#   'com.formula.car.racing',
#   'com.g5e.hiddencity.android',
#   'com.aleson.casefiveanimatronicsfnaf',
#   'studio.genius.nurse'],
#  ['com.and.games505.TerrariaPaid',
#   'com.pixelcurves.terlauncher',
#   'com.robotgentleman.game60seconds',
#   'com.jds.batim',
#   'com.wb.goog.legojurassicworld',
#   'com.RobotGentleman.sixtyParsecs.mobile',
#   'com.D3Go.mendel',
#   'com.kleientertainment.doNotStarvePocket',
#   'com.bscotch.crashlands',
#   'com.rockstargames.gtalcs',
#   'air.com.RustyLake.RustyLakeHotel',
#   'com.seven2.pawapp2',
#   'com.gameloft.android.ANMP.GloftICHM',
#   'com.AngryNeighbor',
#   'com.wb.goog.lnjgo',
#   'air.com.RustyLake.RustyLakeParadise',
#   'games.dali.adventure.lucid.dream.part.two',
#   'com.jds.batds',
#   'air.com.RustyLake.WhiteDoor',
#   'com.disney.castleofillusion_goo',
#   'com.wb.goog.legobdc',
#   'com.playdead.limbo.full',
#   'air.com.RustyLake.RustyLakeRoots',
#   'com.younghorses.octodad',
#   'eu.bandainamcoent.verylittlenightmares',
#   'com.wb.goog.lbbg',
#   'jp.co.spike_chunsoft.DR2',
#   'air.com.amanitadesign.chuchel.gp',
#   'com.wb.goog.legohp1',
#   'com.candyrufusgames.survivalcraft2',
#   'jp.co.spike_chunsoft.DR1',
#   'com.noodlecake.realmyst',
#   'com.wb.goog.legohp2',
#   'com.wb.goog.lego.movievideogame',
#   'games.dali.adventure.lucid.dream.part.three',
#   'com.blyts.infamousmachine',
#   'edu.terc.zoombinis',
#   'com.square_enix.FFIXww.android_googleplay',
#   'air.net.machinarium.Machinarium.GP',
#   'com.kleientertainment.doNotStarveShipwrecked',
#   'com.leosfortune',
#   'com.BestFreeGames2k20.PixelcraftPixelmonandpokecraft',
#   'com.Level5.LT1RNA',
#   'com.hitcents.drawastickmanepic2',
#   'com.devolver.grispaid',
#   'com.bonusxp.fate',
#   'com.peppapig.goldenboots',
#   'com.terribletoybox.thimbleweedparkandroid',
#   'com.wb.goog.llotr',
#   'com.hitcents.stickmanepic',
#   'com.creativemobile.beholder',
#   'com.noodlecake.drtc',
#   'jp.co.capcom.gyakusai5en',
#   'com.pgstudio.survival.evo.pro',
#   'com.pjmasks.superchase',
#   'com.KillmondayGames.LittleMisfortune',
#   'com.and.games505.portal_knights',
#   'com.NightSchool.Oxenfree',
#   'com.lonewolfgames.rescueenchanter',
#   'com.oddworld.Munch',
#   'com.threeminutegames.lifeline.google',
#   'jp.co.capcom.gyakusai6en',
#   'com.noodlecake.riven',
#   'com.feemodev.cat',
#   'com.Level5.LT3RNB',
#   'com.mojotouch.t7g',
#   'com.KillmondayGames.FranBowCh1',
#   'com.antlerinteractive.KrystopiaNovasJourney',
#   'amanita_design.samorost3.GP',
#   'com.artifexmundi.scarlettmysteries.gp.full',
#   'com.KillmondayGames.FranBowCh3',
#   'co.uk.wixgames.ducklifeadventure',
#   'com.Level5.LT2RNA',
#   'com.lonewolfgames.blackthorncastle',
#   'jp.co.capcom.kenji1en',
#   'com.bigfishgames.pbtmgoogfull',
#   'com.KillmondayGames.FranBowCh2',
#   'com.fivebn.daf4.full',
#   'com.and.games505.brothers',
#   'co.uk.wixgames.ducklifebattle',
#   'ru.buka.dville01',
#   'com.accidentalqueens.anormallostphone',
#   'com.dotemu.sanitarium',
#   'jp.co.capcom.gyakusai4en',
#   'com.devolver.Swordsofditto',
#   'com.happyvolcano.games.thealmostgone',
#   'com.firemaplegames.returntogrislymanor',
#   'com.Tasharen.Windward',
#   'com.dotemu.ys1x',
#   'com.sharpen.storm',
#   'com.KickBack.LostEchoAdventure',
#   'com.eg.antarctica88pro',
#   'com.etterstudio.pnp',
#   'com.specialbit.dreams.android.full',
#   'air.com.amanitadesign.botanicula',
#   'com.dynamiczero.survivingtitan',
#   'com.chorusworldwide.bertramep1',
#   'com.noodlecake.suzycube',
#   'com.artifexmundi.queensquest2.gp.full',
#   'air.com.noodlecake.luminocity',
#   'com.bbg.tiwdroid',
#   'com.Pixelatto.Reventure',
#   'com.fgrfg.grgw',
#   'com.pgstudio.survivalpro',
#   'com.psychoseinteractive.forgottenmemories',
#   'com.foxandsheep.Dinotrux2',
#   'com.eline.neveralonemobile',
#   'com.LoopyMood.AntVentor',
#   'com.studiopango.pangopirate',
#   'com.glitchgames.theForgottenRoom',
#   'com.rawfury.longhathouse.Dandara',
#   'com.bigfishgames.mcrugoogfull',
#   'com.tribeplay.pandafirestation',
#   'com.explorationbase.Exploration',
#   'uk.co.revolution.bs1dc',
#   'com.pgstudio.siepro',
#   'com.cm.whipseey',
#   'com.arachnowopunk.revolution',
#   'com.alawar.beholder2',
#   'net.fmstudio.forgottenhilldisillusion',
#   'com.animationarts.secretfiles2',
#   'com.TenderClaws.VVR',
#   'com.lonewolfgames.losttreasure',
#   'com.glitchgames.allthatremains.part1',
#   'com.KillmondayGames.FranBowCh4',
#   'com.artifexmundi.grimlegends2.gp.full',
#   'com.bigfishgames.mwwmgoogfull',
#   'com.rawfury.woam',
#   'com.ProjectTheGalaxy',
#   'kr.co.sonnori.whiteday.g',
#   'com.ludosity.ittledew',
#   'com.econo.gcemulator',
#   'com.gtafrogstresstfighter.frogamazinggangster.thefrogsimulator20',
#   'com.devolver.hatofulboyfriend',
#   'com.KillmondayGames.FranBowCh5',
#   'com.theand.OddeyePaid',
#   'com.bigfishgames.pdogoogfull',
#   'com.Level5.LaytonMJNA',
#   'com.pointclickgames.mysteryofhauntedhollow',
#   'com.fivebn.ll5.full',
#   'com.accidentalqueens.anotherlostphone',
#   'com.fivebn.lost_lands_the_four_horsemen_full',
#   'com.noodlecake.waywardsouls',
#   'net.lonewolfgames.games.thelostship',
#   'com.glitchgames.foreverlostepisode1sd',
#   'com.mediacitygames.alicetrapped2',
#   'com.doublefine.thecave',
#   'com.artifexmundi.thesecretorder1.gp.full',
#   'com.divmob.epicheroeswar.en.freemium',
#   'com.senspark.darkland',
#   'net.playables.kidsgame',
#   'com.fivebn.new_york_mysteries_hd_full',
#   'com.artifexmundi.clockwork.gp.full',
#   'com.buffstudio.sevendays',
#   'com.threeminutegames.lifelinesilentnight.goog',
#   'com.threeminutegames.lifeline2.goog',
#   'com.artifexmundi.enigmatis3.gp.full',
#   'com.capybaragames.sworcery',
#   'com.firemaplegames.games.the_secretofgrislymanor',
#   'com.firemaplegames.Thickety_Creek',
#   'de.stollenmayer.philipp.SometimesYouDie',
#   'com.kochmedia.secretfiles',
#   'com.specialbit.angelo.deemon.full',
#   'com.Rain.Teslagrad',
#   'com.artifexmundi.ghostfiles2.gp.full',
#   'com.mediacitygames.lostfountain',
#   'com.fivebn.ll6.full',
#   'air.com.ohnoo.tormentum',
#   'com.soladv.game',
#   'com.glitchgames.veritas',
#   'com.headupgames.anybodyouttheredeadcity',
#   'com.artifexmundi.familymysteries1.gp.full',
#   'com.threeminutegames.lifelinecrisislinegoog',
#   'uk.co.revolution.bs5.ep2',
#   'com.winterveilstudios.DISTRAINT2',
#   'com.artifexmundi.pathofsin1.gp.full',
#   'com.defas.naruto',
#   'com.dotemu.ihnmaims',
#   'es.brokenrul.oldmansjourney',
#   'com.artifexmundi.thesecretorder7.gp.full',
#   'com.artifexmundi.tso8.gp.full',
#   'com.fivebn.lostlandsdo_full',
#   'com.fivebn.tl1.full',
#   'com.nvidia.valvesoftware.portal',
#   'com.pixbits.junkjack',
#   'com.bigfishgames.fbecgoogfull',
#   'com.bigfishgames.bawogoogfull',
#   'dk.lovable.lapetite',
#   'com.crescentmoongames.skyfish',
#   'com.pointclickgames.lostadventure',
#   'com.artifexmundi.demonhunter3.gp.full',
#   'com.fivebn.nym2.full',
#   'com.threeminutegames.lifelinehalftoinfinitygoog',
#   'com.hazegames.fractalspacetv',
#   'com.artifexmundi.grimlegends.gp.full',
#   'com.tommo.ff2g',
#   'com.herocraft.game.tinybangstory',
#   'com.fivebn.nym04.full'],
#  ['fall.race.io',
#   'com.Atinon.PassOver',
#   'com.kiloo.subwaysurf',
#   'com.fencinggame.master',
#   'com.games.smashersio',
#   'com.hanna.bodyguard.expert',
#   'com.freeplay.runandfight',
#   'com.ua.building.Lokicraft',
#   'com.Tastypill.BallSlide3D',
#   'com.LightBeam.Demolish',
#   'com.Celltop.SpiralRoll',
#   'com.mikhailp.logthrower',
#   'com.appadvisory.wtfight',
#   'com.playgendary.creamaster',
#   'com.alien.shooter.galaxy.attack',
#   'com.igutso.killphil',
#   'com.azurgames.stackball',
#   'com.sega.sonicdash',
#   'com.iposedon.bricksbreakerballs',
#   'com.robtopx.geometryjumplite',
#   'com.fgol.HungrySharkEvolution',
#   'com.topchopgames.skyroller',
#   'com.games.bottle',
#   'com.gamestart.dodgeaction3d',
#   'com.playgendary.tanks',
#   'com.dvloper.granny',
#   'com.ua.vikos.world',
#   'com.lightneer.goodslice',
#   'com.os.airforce',
#   'com.dvloper.grannychaptertwo',
#   'com.bigdog.games.buddyfitness',
#   'io.voodoo.paper2',
#   'io.voodoo.holeio',
#   'io.voodoo.crowdcity',
#   'com.timuzgames.savethefish',
#   'com.game.space.shooter2',
#   'com.gamepie.airpolice',
#   'com.pizza.dough',
#   'com.mindy.grap1',
#   'com.court.guilty',
#   'com.mikhailp.perfectsnipe',
#   'com.supergame.ohmycar',
#   'com.isl.stairrun',
#   'com.rmg.idle.tap.strong.granny',
#   'com.keplerians.icescream3',
#   'com.ubisoft.hungrysharkworld',
#   'com.superstar.rollingdice.gp',
#   'com.hyper.plinko.coin',
#   'com.keplerians.icescream',
#   'com.halfbrick.fruitninjafree',
#   'com.miniworld.mastercrafting.survivalboxbuilding20',
#   'com.imangi.templerun',
#   'com.nordcurrent.canteenhd',
#   'com.rioo.runnersubway',
#   'com.riseup.game',
#   'com.colorhole.game',
#   'com.kalipsogames.psychopathhunt',
#   'com.namcobandaigames.pacmantournaments',
#   'com.FDGEntertainment.redball4.gp',
#   'com.crazylabs.sausage.run',
#   'com.appadvisory.drawclimber',
#   'com.halfbrick.jetpackjoyride',
#   'com.boomhits.rampcarjumping',
#   'com.PepUpStudios.FallGuys3D',
#   'com.YsoCorp.WoodCutter',
#   'com.biglime.cookingmadness',
#   'net.apex_designs.payback2',
#   'com.fungame.casual.fishing.master',
#   'bike.hop.fall',
#   'com.ihari.escapetheprison',
#   'com.sega.sonicboomandroid',
#   'com.keplerians.icescreamtwo',
#   'com.orbitalknight.castlewreck',
#   'net.mobigame.zombietsunami',
#   'com.vincentb.RollyLegs',
#   'io.voodoo.paper3',
#   'com.orbitalknight.ridiculousfreekick',
#   'com.playgendary.sportmasters',
#   'com.halfbrick.dantheman',
#   'com.colorup.game',
#   'com.barsstudios.crazyarrow',
#   'com.sega.sonic2.runner',
#   'com.PlayMax.playergames',
#   'com.colorswitch.switch2',
#   'com.aldagames.zombero.bullet.hell',
#   'com.germanicus.cmioo',
#   'com.feelnside.touchdownmaster',
#   'com.mix.color.paint.game',
#   'com.team70.gangsterking',
#   'invaders.os.galaxy.space.shooter.attack.classic',
#   'com.robtopx.geometrydashworld',
#   'com.robtopx.geometrydashsubzero',
#   'bcom.rrdianshiase.table',
#   'tdcgame.zombie.idle.defense',
#   'com.honeyponey.catjump',
#   'com.nekki.vector',
#   'com.kunpo.virus',
#   'com.crazylabs.light.it.up',
#   'com.mediocre.smashhit',
#   'com.agent.action',
#   'com.kongregate.mobile.run.google',
#   'com.bentostudio.ballsvsblocks',
#   'com.triwin.cash.dozer',
#   'com.gigantic.clawee',
#   'com.slash.girl.redfish',
#   'com.kobgames.skaterrace',
#   'com.deerslab.dinoTREX',
#   'com.supersolid.snake',
#   'com.bike.jump',
#   'com.sandboxol.blockymods',
#   'com.superwings.jettrun',
#   'com.eg.deathpark',
#   'com.YsoCorp.FuryCars',
#   'com.cscmobi.merge.plant',
#   'com.turner.cnplay',
#   'com.rovio.angrybirdsfriends',
#   'com.os.space.force.galaxy.alien',
#   'com.lego.friends.heartlake',
#   'com.robtopx.geometrydashmeltdown',
#   'com.kongregate.mobile.burritobison3.google',
#   'com.JindoBlu.TwoPlayerGamesChallenge',
#   'slingshot.building.destroy',
#   'com.bigframes.color_road',
#   'com.crazylabs.sausage.io',
#   'com.highcore.hoopstars',
#   'comme.dragondrill.minigame',
#   'com.keplerians.evilnun',
#   'com.crazylabs.coin.rush',
#   'com.acoin.ballz.bricks.breaker',
#   'com.sdsd.adsh',
#   'com.blobbyfishgames.apechase',
#   'com.mobirix.swipebrick2',
#   'net.updategames.granny',
#   'com.sega.sonic4episode2',
#   'com.kwalee.wantedgp',
#   'misplayer.games.archery',
#   'com.bigfishgames.cookingcrazegooglef2p',
#   'com.playsidestudios.monkeyropes',
#   'com.cookingcity.chef.kitchen.craze.fever',
#   'com.ketchapp.bikerush',
#   'com.eg.antarctica88',
#   'io.voodoo.dune',
#   'com.CubeCubeSports.Cubic234PlayerGames',
#   'com.game.beerpong',
#   'myandroid.fphoenix.fastspinner',
#   'com.attackgalaxyshooter.galaxyspaceshooter2020',
#   'games.airion.townfights',
#   'com.playgendary.polyspherecoolgame',
#   'com.rocket.dragon.epic',
#   'com.mobirix.abmon',
#   'com.sonypicturestelevision.qbert',
#   'com.martinmagni.fancade',
#   'com.dpspace.rocketsky',
#   'com.custom.goescape',
#   'com.johnemulators.johngbalite',
#   'com.devsisters.gb',
#   'com.cooking.yummy.kitchen.fever.madness.gp',
#   'com.raongames.growcastle',
#   'com.rocket.dragon',
#   'com.linkdesks.jewellegend',
#   'com.jds.binr',
#   'com.istomgames.engine',
#   'com.ubisoft.hungrydragon',
#   'com.nomonkeys.ballblast',
#   'com.azurinteractive.humanevolution',
#   'bts.kpop.piano.music.tiles',
#   'eu.bandainamcoent.pacman256',
#   'com.smartstudygames.babyshark8bit.googlemarket',
#   'io.voodoo.paperio',
#   'com.superluckycasino.hotvegas.slots.vegas.android.free',
#   'line.color.adventure',
#   'com.spungegames.failybrakes',
#   'com.ankama.dragnboom',
#   'com.mnightt.slices',
#   'com.redsunpro.fallguyshexagone',
#   'com.my.cooking.chef.kitchen.craze.fever',
#   'com.waterdrop.stickman.global',
#   'com.ivy.winwing',
#   'com.lawson.tower',
#   'mini.zoo.crafting.exploration.creative.survival',
#   'com.kwalee.drawit',
#   'com.vl.rollyhill',
#   'com.setsnail.daddylonglegs',
#   'com.playgendary.coffeeshop3d',
#   'com.ketchapp.rider',
#   'com.abi.move.stop.io',
#   'com.custom.pickmeup',
#   'com.sausageflip.game',
#   'com.match3blaster.DropStackBallFall',
#   'com.baspin.barbershop',
#   'com.supernds.free',
#   'com.InkosGames.HoleIn',
#   'com.coolmath_games.coolmath',
#   'at.ner.lepsWorld2',
#   'com.survivalcrafting.crafting.fashion.car.salon.makeover.spa.girls.craft.fun.free.driving.games.girls.racing.simulator',
#   'com.ShivanshTiwari.FlappyBird'],
#  ['com.mojang.minecraftpe',
#   'xyz.deeppipes',
#   'com.robtopx.geometryjump',
#   'com.fastemulator.gba',
#   'com.epsxe.ePSXe',
#   'com.rockstargames.gtavc',
#   'com.johnemulators.johngba',
#   'com.fastemulator.gbc',
#   'com.rockstar.maxpayne',
#   'it.dbtecno.pizzaboygbapro',
#   'com.halfbrick.fruitninja',
#   'com.ngmoco.pocketgod',
#   'com.icorewwwi.vDS',
#   'com.sega.sonic4epi',
#   'com.retroloungelab.resetcollection',
#   'com.snkplaymore.kof2012a',
#   'com.nekki.vector.paid',
#   'com.madfingergames.SamuraiIIAll',
#   'com.snkplaymore.android007',
#   'com.worms3.app',
#   'com.explusalpha.NesEmu',
#   'com.explusalpha.MdEmu',
#   'com.johnemulators.johngbc',
#   'com.mtvn.SBmoviegame',
#   'com.NamcoNetworks.MsPacMan',
#   'cc.peacedeath.peacedeath',
#   'com.flukedude.impossiblegame',
#   'net.kairosoft.android.bouken_en',
#   'com.dotemu.neogeo.mslug3',
#   'com.snkplaymore.android001',
#   'org.mupen64plusae.v3.fzurita.pro',
#   'com.mediocre.grannysmith',
#   'com.fms.emu',
#   'com.jdroid.gtavccheater',
#   'com.zenstudios.MarvelPinball',
#   'com.sonicjump.sonicjump',
#   'com.square_enix.android_googleplay.finalfantasy2',
#   'com.nostalgiaemulators.nesfull',
#   'com.stevesnyderart.BalanceTheBeam2',
#   'com.explusalpha.GbaEmu',
#   'com.grapefrukt.games.bore',
#   'com.dotemu.ddtrilogy',
#   'com.dotemu.neogeo.mslug',
#   'net.floatingpoint.android.arcturus',
#   'com.crescentmoongames.swordshot',
#   'com.mightykingdom.shopkinsrun',
#   'com.herocraft.game.hyperforma.cyber.hack.arcade.premium',
#   'com.neutronemulation.retro8',
#   'org.lukeallen.bomberfull',
#   'it.dbtecno.pizzaboypro',
#   'com.dotemu.neogeo.samsho2',
#   'paulscode.android.mupen64plus',
#   'org.uoyabause.uranus.pro',
#   'com.explusalpha.GbcEmu',
#   'com.square_enix.android_googleplay.subarashikikonosekai_solo',
#   'jp.co.taito.am.spaceinvaders',
#   'com.magicwach.rdefense',
#   'com.doragongames.danmakuunlimited3',
#   'com.dotemu.rtype',
#   'jp.co.capcom.mobilemakaiwd',
#   'com.dotemu.neogeo.mslug2',
#   'jp.co.capcom.mobiledaimakaiwd',
#   'com.dotemu.neogeo.mslugx',
#   'com.PceEmu',
#   'com.explusalpha.A2600Emu',
#   'com.explusalpha.NeoEmu',
#   'nl.palatamedia.miner',
#   'com.playcreek.DeathWorm',
#   'com.atypicalgames.sgsr',
#   'com.doragongames.danmakuunlimited2',
#   'com.craftgames.worldcrft.premium',
#   'com.atypicalgames.sgsr2',
#   'com.nostalgiaemulators.gbafull',
#   'com.space.shooter.alien.galaxyattack',
#   'com.lojugames.android.Ordia',
#   'com.zenstudios.StarWarsPinball',
#   'es.jdbc.n64retroplus',
#   'com.flukedude.impossiblegamelevelpack',
#   'com.apdconsultinginc.defender1',
#   'net.kairosoft.android.ninja_en',
#   'com.snkplaymore.android013',
#   'com.interrupt.dungeoneer',
#   'com.alien.shooter.galaxy.attack.premium',
#   'com.digitalleisure.dragonslair',
#   'jp.co.capcom.mobile1942wd',
#   'com.skyvu.battlebearszombies',
#   'at.nerbrothers.SuperJumpPlus',
#   'com.dvloper.slendrinacellar',
#   'com.noodlecake.chameleonrun',
#   'pl.idreams.jellydefense',
#   'com.nekki.vector2.paid',
#   'com.endspacevr',
#   'com.os.falcon.galaxy.space.shooter.attack.vip',
#   'com.fluffycat.sanandreaskeyboard.full',
#   'com.muandheyo.bosonx',
#   'com.DefiantDev.SkiSafari',
#   'net.kairosoft.android.horse_en',
#   'com.explusalpha.C64Emu',
#   'com.dotemu.neogeo.blazstar',
#   'fishnoodle.canabalt',
#   'com.Chorrus.UnbrokenSoul',
#   'com.snkplaymore.android012',
#   'com.SmartBomb.AJJump',
#   'ru.whitebunny.usagifeed',
#   'com.turbomonad.galaxdefender',
#   'com.DVloper.HouseOfSlendrina',
#   'com.tinybuild.PartyHardGO',
#   'com.digitalleisure.spaceace',
#   'com.moose.shoppiedash',
#   'com.coldbeamgames.beathazardultragooglefull',
#   'com.naquatic.guncrafterpro',
#   'com.epicpixel.Grow',
#   'com.super8bit.pro',
#   'com.crescentmoongames.monkeyboxing',
#   'com.sig.PingOrPong',
#   'com.squareenixmontreal.avssi',
#   'net.hexage.radiant',
#   'com.freetoolsassociation.karateka',
#   'com.pixelsontoast.impossibleroad',
#   'com.mumbojumbo.wonders4',
#   'com.zenstudios.PortalPinball',
#   'jp.co.taito.am.dariusBurstSP',
#   'com.deckeleven.pmbdmarket',
#   'com.fms.mg',
#   'com.topsecretdevelopments.games.bomberFighterPro',
#   'com.isolgames.dauntless',
#   'com.onemanleft.tilttolive2',
#   'com.TeamCoil.PUSS',
#   'com.nostalgiaemulators.gbcfull',
#   'net.hexage.radiant.hd',
#   'air.com.kongregate.mobile.fancypants.google',
#   'jp.co.capcom.mobileikusawd',
#   'com.romansixvigaming.rainbowdash',
#   'com.angrymobgames.muffinknight',
#   'com.jyaif.pewpew2',
#   'com.noodlecake.bugbutcher',
#   'abyxentertainment.brick_breaker_classic_plus',
#   'com.ZephirothGames.AsteroidStorm',
#   'com.qeorge.fumpop',
#   'com.Patitoyazilim.TowerBuild',
#   'com.microids.google.bcnorthvssouth'],
#  ['com.pixel.art.coloring.color.number',
#   'com.tilemaster.puzzle.block.match',
#   'link.merge.puzzle.onnect.number',
#   'paint.by.number.pixel.art.coloring.drawing.puzzle',
#   'com.artlife.coloringbook',
#   'com.gamebility.onet',
#   'bp.free.puzzle.game.mahjong.onet',
#   'com.scopely.yux',
#   'air.com.buffalo_studios.newflashbingo',
#   'com.huuuge.domino',
#   'com.clipwiregames.bingostory',
#   'com.llx.chess',
#   'com.appcraft.number.puzzle',
#   'com.jetstartgames.chess',
#   'onext.boombox',
#   'com.free.drawing.coloring.book.paint.by.number',
#   'solitaire.card.games.klondike.solitaire.classic.free',
#   'paintist.pixel.art.color.paint.by.number.coloring.paint.drawing.book',
#   'com.two31play.mahjongcity',
#   'com.yalla.yallagames',
#   'com.LoopGames.Domino',
#   'com.fiogonia.yatzy',
#   'loppipoppi.dominoes',
#   'com.pixel.art.coloring.by.number',
#   'com.dimcoms.checkers',
#   'com.kiaora.dominoes',
#   'com.ludo.king',
#   'com.coloring.lwapps',
#   'uk.co.aifactory.chessfree',
#   'com.qybteck.color.by.number.paint',
#   'com.crossfield.bingotreasure',
#   'com.starsprite.tilecraft',
#   'com.sngict.bingo',
#   'com.mobilegame.dominoes',
#   'com.pixel.art.happy.color.by.number.paint.coloring.free',
#   'com.chess',
#   'com.superluckycasino.epicjackpot.slots.vegas.android.free',
#   'air.com.spicerackmedia.bingoshowdown',
#   'com.hasbro.riskbigscreen',
#   'com.mochess.online',
#   'air.com.bitrhymes.bingo',
#   'onnect.connect.pair.matching.line.puzzle.match3d.tilemaster',
#   'com.superking.parchisi.star',
#   'com.playcus.crossstitchcoloringbook',
#   'com.gdv.uno',
#   'pl.lukok.draughts',
#   'com.kristanix.android.mahjongsolitairetitan',
#   'com.abradoodle.bingo',
#   'lu.zvasoft.lotto.free',
#   'com.superluckycasino.viponly.slots.vegas.android.free',
#   'com.sng.yatzy',
#   'athena.studio.woody.sudoku.block.puzzle.brain.training.mind.games.free.happy.offline',
#   'thinkcube.project312',
#   'com.twelvegigs.heaven.bingo',
#   'com.fungamesforfree.colorfy',
#   'de.smuttlewerk.fleetbattle',
#   'com.moonfrog.ludo.club',
#   'com.pcoloring.art.puzzle.color.by.number',
#   'com.withbuddies.dice.free',
#   'com.TikGames.DominoMaster',
#   'com.blackout.match3d',
#   'com.dg.puzzlebrothers.mahjong.mysterymansion',
#   'com.fiogonia.dominoes',
#   'com.dg.puzzlebrothers.mahjong.solitaire.holiday.fun',
#   'com.flyclops.domino.android',
#   'loppipoppi.yatzy',
#   'com.mintgames.pocket.color.world.paintnumber.games3d',
#   'com.xten.starfall',
#   'air.com.beachbumgammon',
#   'com.agedstudio.board.game.dominoes',
#   'com.europosit.polygon2d.coloringpuzzle',
#   'ru.skillcap.dominoes',
#   'com.LoopGames.Yatzy',
#   'paint.by.number.relax.pixel.art.drawing.book.free',
#   'mahjong.solitaire.games.puzzle.mahjong.classic.free',
#   'com.rummikubfree',
#   'com.chess.chesscoach',
#   'com.gameberry.ludo.star2',
#   'com.lemongame.matchtwo.mahjong',
#   'net.skillcap.farkle',
#   'uk.co.aifactory.backgammonfree',
#   'com.tictactoe.wintrino',
#   'com.noodlecake.reallybadchess',
#   'dev.marosi.gregbox',
#   'com.chef.ollect',
#   'org.lichess.mobileapp',
#   'com.ahoygames.backgammon',
#   'com.dg.puzzlebrothers.mahjong.holiday.magic.christmas',
#   'com.usm.catanuniverse',
#   'com.koga.domino',
#   'com.quge.bingopowerball',
#   'com.playcus.bingostar',
#   'com.hagstrom.henrik.chess',
#   'com.dg.turbonuke.my.bingo.life',
#   'fr.apprize.actionouverite.enfants',
#   'com.alignit.fourinarow',
#   'io.yarsa.games.ludo',
#   'com.blackcircleapps.tropicalbingo',
#   'air.bg.lan.Monopoli',
#   'com.pixel.coloring.color.by.number',
#   'com.blackcircleapps.halloweenbingo',
#   'com.blacklightsw.ludo',
#   'com.wixot.bingo',
#   'com.games.lucky.dice.win.bonus.big.master.prize.rewards.free',
#   'pl.lukok.chess',
#   'com.idz.snakes.and.ladders.dice.board.games',
#   'com.one1line.onetouch.onestroke.dotgame',
#   'org.softmotion.fpack.lite',
#   'air.com.jogatina.domino.android',
#   'air.br.com.domino.mobile',
#   'com.qhost.aceanddice_domino',
#   'com.Offs.Games.The.Clue.Do.Crime.Detective.Investigation.Solve.and.Discover.Mystery.Criminal.Cases',
#   'com.dg.turbonuke.tradbingo.elvenwoods',
#   'com.hama.universe',
#   'com.zynga.chess.googleplay',
#   'com.sngict.dominoes',
#   'com.gbgames.mahjongunlimited',
#   'com.magic.paint.pixel.art.color.by.number',
#   'com.renatus.hittheboard',
#   'com.playcus.findthedifferences2',
#   'com.dg.turbonuke.rainbowbingoadventure',
#   'com.rottzgames.logic',
#   'com.dunjegame.andrecastany.fourinarow',
#   'com.kristanix.android.mahjongsolitaireepic',
#   'com.UmiringoStudio.FunColor',
#   'uk.co.aifactory.gofree',
#   'com.humblelogicgames.tilematch',
#   'solitaire.arcadegames.freecard.solitaireplus.epic.klodike',
#   'au.com.imagination.familyfeudbuzzerus.full',
#   'com.blackcircleapps.wonderlandbingo',
#   'com.mobirix.SnakeGame',
#   'com.superluckycasino.fortunespin.slots.vegas.android.free',
#   'com.rottzgames.findobject',
#   'com.Alienforcegames.ChessFusionFree',
#   'com.quarzo.fourinarow',
#   'com.turbolabz.instantchess.android.googleplay',
#   'com.emflag.mahjongmaster',
#   'company.greenergrass.goldenroll',
#   'com.mobirix.connectfour',
#   'com.yoozoogames.ludogameallstar',
#   'air.com.playcus.bingocountryboys',
#   'com.platsera.freebingoworld',
#   'com.Offs.WhoIAm',
#   'com.dg.puzzlebrothers.mahjong.solitaire.grand.autumn.harvest',
#   'com.oneup.treasure.map.mahjongg',
#   'com.northstargames.evolutiongame',
#   'com.blackout.connect',
#   'com.bestlis.farkle',
#   'com.dg.puzzlebrothers.mahjong.halloween',
#   'com.maysalward.Dominoes',
#   'com.IguazuGames.Mahjong',
#   'air.com.come2play.backgammon',
#   'com.sngict.backgammon',
#   'com.foxelpix.crossstitchclub',
#   'air.com.playcus.free.bingo.games.casino.slots.country.days.game',
#   'com.bigwinlab.bingolegends',
#   'com.kingsofgames.chessuniverse',
#   'com.ruby.coloring.pages.art.games.anime.manga',
#   'lu.zvasoft.lotto.free.bbc',
#   'glowingeye.mexican_train_dominoes_gold',
#   'com.daygames.five.seconds',
#   'lu.zvasoft.lotto.free.emo',
#   'sg.bigo.ludolegend',
#   'com.bss.game.DicastRoc',
#   'com.ludo.master.hippo',
#   'com.dg.puzzlebrothers.mahjong.king',
#   'com.ignacemaes.fourinarow',
#   'com.blackzen.BingoMania',
#   'com.PPGame.Onnect',
#   'com.njbee.candy.sort.m',
#   'com.alpg.yatzy',
#   'com.crossfield.shogi',
#   'com.seavus.yatzyultimate.droid',
#   'com.alignit.sixteenbead',
#   'com.dg.turbonuke.bingo.quest.crazy.candy.kingdom',
#   'com.joycity.god',
#   'com.game.roleplaying18',
#   'air.com.playcus.bingocountryways',
#   'com.tellmewow.senior.dominoes',
#   'com.dg.turbonuke.bingo.quest.summer.garden',
#   'com.ludo.multiplayer',
#   'com.alpg.bingo',
#   'com.blacklight.carrom.multiplayer',
#   'com.litegames.farkle',
#   'board.tictactoe.glow.puzzle.lite',
#   'com.optimesoftware.checkers.free',
#   'air.com.playcus.bingokingdom',
#   'com.tellmewow.senior.battleship',
#   'com.landlordgame.tycoon',
#   'us.digitalsmoke.yatzymaster',
#   'com.bumblebox.coloring.animeboys',
#   'com.kemigogames.chesscoach',
#   'com.chess.strategy.classic.friends.free',
#   'com.esotericsoftware.gloomhavenhelper',
#   'com.haptic.chesstime',
#   'com.tig.oil.painting',
#   'com.winrgames.doubledouble',
#   'com.intentsoftware.android.yatzylite',
#   'com.bingo.games.online.offline.free.slots.lotto.keno.casino.adventure'],
#  ['com.marmalade.monopoly',
#   'com.marmalade.gol2',
#   'com.marmalade.cluedogame',
#   'com.marmalade.golmobile',
#   'number.link',
#   'com.marmalade.golv',
#   'com.daysofwonder.tt.android',
#   'uk.co.aifactory.chess',
#   'com.playdekgames.waterdeep',
#   'com.asmodeedigital.carcassonne',
#   'com.exozet.android.catan',
#   'com.handelabra.OneDeckDungeon',
#   'com.marmalade.battleship',
#   'com.asmodeedigital.terraformingmars',
#   'com.daysofwonder.Splendor.gp',
#   'com.StudioGoya.MiracleSudokuCTC',
#   'com.templegatesgames.RollAndroid',
#   'com.nomadgames.talisman',
#   'uk.co.aifactory.backgammon',
#   'com.StudioGoya.ChessSudoku',
#   'com.StudioGoya.ClassicSudoku',
#   'com.handelabra.AeonsEnd',
#   'de.brettspielwelt.cartographers',
#   'uk.co.aifactory.go',
#   'com.asmodeedigital.mysterium',
#   'com.daysofwonder.smallworld2',
#   'com.f2zentertainment.pandemic',
#   'com.funforgedigital.tokaido',
#   'com.StudioGoya.ThermoSudoku',
#   'com.fantasyflightgames.ESAndroid',
#   'com.direwolfdigital.sagrada',
#   'com.steelcrategames.keeptalkingandnobodyexplodes',
#   'net.gowrite',
#   'techmasterplus.sudokupuzzlepro',
#   'com.youdagames.stratego',
#   'com.czechgames.galaxytrucker',
#   'com.StudioGoya.SandwichSudoku',
#   'com.beadapps.chessrepertoiretrainer.paid',
#   'com.templegatesgames.RaceAndroid',
#   'com.asmodeedigital.millebornes',
#   'com.digidiced.vxcrelease',
#   'com.czechgames.tta',
#   'com.horriblegames.similo',
#   'com.asmodeedigital.potionexplosion',
#   'com.playdekgames.twilightstruggle',
#   'com.digidiced.txmrelease',
#   'com.kemigogames.chesscoachpro',
#   'de.brettspielwelt.ganzschoenclever',
#   'com.acram.Charterstone',
#   'com.nextchessmove',
#   'com.asmodeedigital.takenoko',
#   'com.nomadgames.loveletterdev',
#   'com.direwolfdigital.raiders',
#   'com.ayelmarc.chessormpro',
#   'pl.portalgames.isrw',
#   'com.handelabra.Sentinels',
#   'com.hiddenachievement.dfco',
#   'uk.co.aifactory.checkers',
#   'com.meepletouch.jaipur',
#   'com.Roxley.SantoriniGame',
#   'com.digidiced.ixsrelease',
#   'com.direwolfdigital.lanterns',
#   'com.SandersApps.Moanopoly',
#   'se.sweetstone.yatzy',
#   'com.Thunderbox.Tsuro',
#   'com.gmail.codesbyjandt.Bingo75App',
#   'com.digidiced.sxprelease',
#   'de.brettspielwelt.freitag',
#   'uk.co.aifactory.rr',
#   'jp.co.unbalance.IgoKouza01',
#   'de.brettspielwelt.coffee_roaster',
#   'com.chessgenius.android.chess',
#   'com.amuseware.mexicantrain',
#   'uk.co.aifactory.sudoku',
#   'com.nomadgames.talismanchronicles',
#   'com.PeterKossits.FootballHighlights',
#   'com.asmodeedigital.coltexpress',
#   'com.randomsaladgames.simpledominoes',
#   'chessbase.android.chessdb',
#   'com.suburbiagame.suburbia',
#   'com.pereira.analysis.paid',
#   'com.blacklistgamesllc.StreetMasters.pro',
#   'jp.co.unbalance.android.gocsdl',
#   'com.boardgametables.ontour',
#   'pl.portalgames.convoy',
#   'de.brettspielwelt.doppeltsoclever',
#   'com.digidiced.bvbrelease',
#   'com.komodochess.komodo13',
#   'com.mobilecastles.castles',
#   'com.PeterKossits.BBall2045',
#   'mallusofts.blockpuzzleclassic',
#   'com.cublo.brass',
#   'com.youdagames.strategomp.premium',
#   'com.digidiced.insrelease'],
#  ['net.solitaireff.tripeaks',
#   'net.supertreat.solitaire',
#   'com.smilerlee.klondike',
#   'com.gsn.android.tripeaks',
#   'com.cardgame.solitaire.fishdom',
#   'com.fiogonia.spades',
#   'com.playtika.wsop.gp',
#   'com.mattel163.phase10',
#   'com.solitaire.klondike.patience.ocean.aquarium',
#   'beetles.puzzle.solitaire',
#   'com.solitaire.card',
#   'com.bbumgames.spadesroyale',
#   'com.matteljv.uno',
#   'com.tripledot.blackjack',
#   'net.peakgames.mobile.spades.android',
#   'com.me2zen.tripeaks.v4.and',
#   'com.mobilityware.solitaire',
#   'com.mobilityware.spider',
#   'com.agedstudio.card.solitaire.klondike',
#   'com.forevernine.texaspoker.android',
#   'com.bigc.solitaire.spider',
#   'com.tripledot.solitaire',
#   'com.betterforsol.solitaire.card.games.free',
#   'com.freegame.solitaire.basic2',
#   'com.solitaire.daily.challenge.card.game',
#   'com.reachjunction.card.game.solitaire',
#   'jp.konami.duellinks',
#   'net.solitairecs.tripeaks',
#   'com.absolute.bingo',
#   'com.mobilityware.Spades',
#   'com.bbumgames.rummystars',
#   'com.me2zen.tripeaks',
#   'com.solitaire.real',
#   'com.plarium.solitaire',
#   'com.boke_miniplay.beauty_chef',
#   'net.peakgames.ginrummyplus',
#   'com.blizzard.wtcg.hearthstone',
#   'com.mobilityware.freecell',
#   'com.superprism.allstar',
#   'solitaire.card.games.free.klondike.solitaire.classic.fun',
#   'com.bigcake.android.solitairedaily',
#   'com.winrgames.solitaire',
#   'com.dna.solitaireapp',
#   'com.two31play.solitaire',
# ...
#   'air.com.flipline.papasburgeria',
#   'age.of.civilizations.europe.jakowski',
#   'com.bistudio.at',
#   'ru.gamedevteam.mechcom2',
#   'com.tortugateam.bravelandwizard',
#   'com.Faerytalepainting.TheDefendersOath',
#   'com.rubicon.dev.glwg2',
#   'com.rubicon.dev.gbwg',
#   'com.rubicon.dev.glwg',
#   'com.easytech.ew3',
#   'com.eightfloor.gnomesgardenchristmasstory.premium.googleplay',
#   'com.jollypixel.saratoga.android',
#   'com.homemadegames.frontwars',
#   'com.eightfloor.roadsoftime.premium.googleplay',
#   'com.MASTGames.StarChindy01',
#   'smpxg.mythdefdf_pt',
#   'com.ariton.spacewardho',
#   'com.clarus.egyptfull',
#   'com.asmodeedigital.zombicidev2',
#   'com.gyorgyszucs.colonizerul',
#   'com.tresebrothers.games.factionwarselite',
#   'ru.gamedevteam.wz',
#   'com.BaronnerieGames.ElectromazeDefense',
#   'com.divmob.eternitylegends.leagueofgods.premium',
#   'com.jusckeux.frontarmies',
#   'com.herocraft.game.full.st_ussr_usa',
#   'com.hexwar.twilightslastgleaming',
#   'com.windowsgames.slay',
#   'com.sgg.archipelago_kr',
#   'com.gameops.cta',
#   'com.tsomogyi.gc',
#   'smpxg.mythdefense',
#   'com.pageboy.oraiah',
#   'com.cloudworth.patwar',
#   'air.com.flipline.papaswingeriahd',
#   'com.birdshel.Uciana',
#   'com.hg.rebelcops',
#   'com.blueplop.StarColoniesFull',
#   'age.of.civilizations.africa.lukasz.jakowski',
#   'com.pokulan.aliveinshelteradult',
#   'air.com.mediadivision.sparkchessphone',
#   'com.aevumobscurum.androidworld',
#   'air.com.clarusvictoria.preciv.ba',
#   'com.easytech.wc1',
#   'net.kairosoft.android.noujou_en',
#   'com.amtgames.ewtd2',
#   'com.hexwar.acwgettysburg',
#   'com.tropicalstormfront.android.full'],
#  ['com.unicostudio.whois',
#   'com.trivia.star.android',
#   'com.unicostudio.braintest',
#   'com.unicostudio.braintest2new',
#   'tr.com.apps.trivia.race',
#   'com.wangcheng.logo',
#   'com.etermax.preguntados.trivia.cars',
#   'com.etermax.trivia.preguntados2',
#   'com.sonypicturestelevision.millionaire',
#   'app.free.lucky.quiz.us',
#   'com.submarineapps.mill',
#   'com.umi.feudlive',
#   'com.etermax.preguntados.lite',
#   'com.red.answer.hw',
#   'com.xmonetize.quizzland',
#   'com.eightsec.TriviaIO',
#   'start.boss',
#   'com.magmic.android.ScattergoriesBlitz',
#   'com.nixgames.truthordare',
#   'com.aquaman.braincrack',
#   'com.hiride.social',
#   'com.crestvisuals.gp.dirtyriddles',
#   'com.tozzmedia.trickme',
#   'com.msi.logogame',
#   'com.sonypicturestelevision.jeopardy2',
#   'com.angry.granny.simulator.fight',
#   'com.relaxingbraintraining.triviamillion',
#   'com.YsoCorp.ThisOrThat',
#   'battle.royalechapter2quiz',
#   'word.riddles.guess.brain.test.tricky.puzzle.quiz.game.free',
#   'com.cookie.swirl.tikentdev',
#   'lemmingsatwork.quiz',
#   'quess.song.music.pop.quiz',
#   'com.oyeapps.logotestworld2',
#   'com.theangrykraken.trivial',
#   'com.onehundredpics.onehundredpicsquiz',
#   'com.grandmas.cookie.swirl.love.erikadev',
#   'com.timleg.quiz',
#   'com.niceteen.games.dtbam',
#   'com.dreamlabentertainment.wouldyourather',
#   'com.taplane.logoquizm',
#   'com.magmic.android.squash',
#   'com.taplane.triviaquizm',
#   'aasuited.net.word',
#   'com.wb.goog.ellen.gameofgames',
#   'com.reddream.game.trickybrain',
#   'fr.two4tea.fightlist',
#   'com.age.usa.appspot',
#   'com.imagzle',
#   'com.intermedia.hq',
#   'dh3games.wouldyourather',
#   'com.HeyNau.MegaQuizGaming',
#   'com.escapefun.the100roomiv',
#   'com.quizup.core',
#   'minicraft.eers.kraft.eerskraft.crafting.building.games',
#   'logo.quiz.guess.movie',
#   'dh3games.doeshelikeme',
#   'com.feelinggame.pluckit',
#   'com.danpanichev.kissmarrykillnext',
#   'com.us.wouldyourather.game',
#   'macrostudios.howwelldoyouknowme',
#   'com.internetdesignzone.triviaquizzes',
#   'com.maxcraft.big.max.craft.city.prime.builder.aadia',
#   'co.palang.QuizOfKingss',
#   'games.teatime.trivia',
#   'com.gmail.troylyndon.PlayTrivia',
#   'com.age.wgg.appspot',
#   'marcostudios.yesorno',
#   'com.daygames.kob.would.you.rather',
#   'macrostudios.guessmynickname',
#   'io.gartic.Gartic',
#   'com.diacoipj.picopool',
#   'com.works.timeglass.logoquiz',
#   'smartowlapps.com.quiz360',
#   'com.happeningnow.blebrity',
#   'com.creactive.quemquersermilionario.millonario.lite',
#   'com.playstation.knowledge',
#   'com.cookie.swirl.candy.land.obby',
#   'us.christiangames.bibletrivia',
#   'com.lotum.quizplanet',
#   'com.volley.voicecompanion.songquiz',
#   'com.us.wouldyourather.trivia.quiz',
#   'bubbleshooter.classic',
#   'app.game.flashcraft.exploration',
#   'com.maestro.craftingbuilding',
#   'jail.escape.robux.jailbreak.studio',
#   'us.christiangames.trueorfalse',
#   'com.gmail.ramosmarbella.squizme',
#   'com.tellmewow.senior.wheel.fortune',
#   'logos.quiz.companies.game',
#   'com.freevbx.quiztruefalse',
#   'com.asmolgam.states',
#   'com.orangenose.trick',
#   'nuea.apps.hexws',
#   'com.edujoy.skills',
#   'com.niceteen.games.milliondeal',
#   'com.danpanichev.topanimecharacters',
#   'com.cadev.presstheluck',
#   'com.yunbu.brain.boom',
#   'com.qbis.guessthecountry',
#   'com.blockpuzzle.brick2020',
#   'com.vns.three.quiz.logo.quiz.flag.quiz.capital.quiz',
#   'com.knowledgequizgames.justriddles',
#   'eerskraft.crafting.pro.building.games.exploration.lite.rojo',
#   'com.goxal.eighties',
#   'com.trivia.quizfordescendants.trixtengames',
#   'com.halloween.h23',
#   'com.taplane.emojisquiz',
#   'com.champapps.gtp',
#   'com.asmolgam.flags',
#   'com.cashquizz.cashquizz',
#   'com.junkers.hellopiggyscarychapter',
#   'io.edia.quizfortnite',
#   'com.ninetyfour.degrees.app',
#   'free.robux.master.freerobuxmaster',
#   'pl.swiatquizu.disneyquiz.android',
#   'com.educ8s.triviaquiz2015',
#   'com.cadev.primaria',
#   'com.openmygame.games.android.pics',
#   'com.taplane.fourpics',
#   'com.ncm.noovietrivia',
#   'boyansoft.bogmix.millionaire',
#   'nineties.quiz.pub.trivia.questions.games',
#   'com.PlayShow.tv',
#   'foodquiz.guessthefood',
#   'com.bogaziciapps.mapgameus',
#   'com.gsn.chasefree',
#   'com.finjanapps.syla',
#   'com.scimob.ninetyfour.percent',
#   'com.taplane.iconquizm',
#   'braintest.iq.quiz.brain.out.mind.challenge.pass.tricky.puzzles',
#   'borralloespinarrafael.wouldyouratherharrypotter',
#   'com.nixgames.neverdid',
#   'com.peoresnada.mental',
#   'com.SKORBcorporation.JournalsGFAndroid',
#   'com.topquizgames.triviaquiz',
#   'macrostudios.whichanimalareyou',
#   'com.free.craft.craftlegend.legend.crafting.android.building.games',
#   'com.taplane.twopics',
#   'com.taplane.logoquiz',
#   'com.app3arabi.trueorfalsev1',
#   'app.playandwinapp.com',
#   'live.brainbattle',
#   'dh3games.stupidtest',
#   'com.biblia.aprende.ingles',
#   'com.mtapps.quiz.flags_off_the_world_quiz',
#   'net.wouldyouratherapp.wouldyourather',
#   'com.asmolgam.dogs',
#   'com.msi.icongame',
#   'com.yourmillionaire.befristmillionaire',
#   'com.TailOfTales.AnimeIn10Words',
#   'com.animoca.google.starGirlHalloween14',
#   'battle.royalechapter2qseason13',
#   'skribbl.io.drawing.game',
#   'com.playstation.kipdecades',
#   'com.knowledgequizgames.guessthesong',
#   'com.guess.games.bts.song.quiz',
#   'com.goxal.restaurant',
#   'com.pch.ilab.wincredible',
#   'air.com.superbook.bible.trivia.quiz.game.android.app',
#   'com.appigeon.guessairbenderelement',
#   'com.etermax.kingdoms',
#   'borralloespinarrafael.kissmarrycrucio',
#   'com.goldrushgames.triviatiles',
#   'com.creephustlin.creepypastaghicestepersonaj',
#   'com.aelahhd.guessmyheroacademia',
#   'com.snakezone.wormbatle.cusdux',
#   'com.qbisstudio.usaquiz',
#   'uk.co.huntthegoose.app',
#   'com.xmonetize.quizzclub',
#   'com.sopelus.elements',
#   'com.smart.brain.riddles',
#   'com.free.cp.bundle.freecp.cpquizforcod',
#   'com.luckytrivialive',
#   'com.dmvcompany.guessthefortniteskin',
#   'block.puzzle.jewel.gem2020',
#   'com.buzztime.entertainment',
#   'wouldyouratherkids.com.would_you_rather_kids',
#   'com.sporcle.party',
#   'com.onemillionairetrivia.weakestlink',
#   'com.amientertainment.TapTVController',
#   'zebi24.guess_5',
#   'com.goodquizzes.guessthecharacterquiz',
#   'pt.wm.trivialworld',
#   'com.hiicerod.neighboor',
#   'com.taplane.foodquizm',
#   'com.techxstar.friendsquiz',
#   'com.marveldeviser.wwewrestler',
#   'com.boldcat.turbo2',
#   'com.ultim8quiz.HarryPotter',
#   'com.bedrill.quiz.flags.capitals',
#   'com.awesomeapps.doesmycrushlikeme',
#   'air.me.kupina.EnBuscaDeJesus',
#   'com.fenghenda.Trivia',
#   'com.saklanistudio.quiz2020forpubgmobile'],
#  ['com.etermax.preguntados.pro',
#   'com.newgeogamerni',
#   'com.sporcle',
#   'com.jackboxgames.TJPP3Loader',
#   'com.jackboxgames.JBPP2Loader',
#   'com.jackboxgames.JackboxPartyLoaderFull',
#   'com.timleg.quizPro',
#   'com.jackboxgames.TJPP5Loader',
#   'coolcherrytrees.games.reactor4',
#   'com.jackboxgames.TJPP4Loader',
#   'com.puzzlenation.JumboCrosswords1',
#   'com.loadupgames.musictriviachallenge'],
#  ['com.platinumplayer.word.addict',
#   'com.pieyel.scrabble',
#   'com.peoplefun.wordcross',
#   'com.dreamstudio.word.connect',
#   'com.braindom',
#   'com.chippymediallc.word.nut.android',
#   'com.mobilegame.wordsearch',
#   'com.scopely.wheeloffortune',
#   'com.fanatee.noodles',
#   'com.peoplefun.wordsearch',
#   'es.socialpoint.wordlife',
#   'com.wordgame.words.connect',
#   'com.zynga.words3',
#   'com.bitmango.go.wordcookies',
#   'in.crossy.daily_crossword',
#   'com.tangramgames.gourddoll.wordcrush',
#   'se.maginteractive.wordzee',
#   'com.wordgame.newcross.android.en',
#   'in.playsimple.wordtrip',
#   'com.peoplefun.wordstacks',
#   'com.apprope.wordmansion',
#   'in.playsimple.tripcross',
#   'com.blackout.word',
#   'com.wb.headsup',
#   'com.word.wordy.wordscape.wordrelax',
#   'com.thrivegames.wordshapes',
#   'com.great10games.word.link',
#   'com.histudiogames.wordserenityg',
#   'com.fanatee.cody',
#   'app.kryds.android',
#   'com.gsr.wordcross',
#   'com.bettagames.wordbuddies',
#   'com.fugo.wowsearch',
#   'com.word.smash.wordstacks.crossword',
#   'word.game.wordscapes.wordconnect',
#   'tv.yaqua.WordsOut',
#   'com.townsend.puzzlescapes',
#   'mobi.redstonegames.crossword.en',
#   'com.oakgames.wordgame',
#   'com.word.forest.android',
#   'com.kooapps.pictowordandroid',
#   'com.zynga.words',
#   'com.easybrain.word.search',
#   'com.bruyere.android.wordsearch',
#   'word.search.wordsearch',
#   'bible.wordgame.words.connect.crossword.cookies',
#   'com.qiiwi.wordington',
#   'com.crossword.free.relax',
#   'com.matchasaucellc.word.search.android',
#   'com.evilapples.app',
#   'com.littleengine.wordpal',
#   'com.fatchicken007.headsupcharades2',
#   'word.games.puzzle.four.pics.one.word.cookies.free',
#   'com.wb.goog.ellen.psych',
#   'com.timeplusq.drawnguess',
#   'com.dreamstudio.word.travel.scapes',
#   'com.randomlogicgames.wordsearch',
#   'com.oneup.word.search',
#   'com.iscoolentertainment.snc',
#   'com.TinyBit.GameOfWords',
#   'in.crossword.wordplanet',
#   'in.WordSearch.WordBliss',
#   'com.wizard.word.puzzle.games.scapes.fun',
#   'com.rolling.crossword.puzzle.game',
#   'com.word.fire.android',
#   'com.wordgame.puzzle.block.crush.pic.en',
#   'com.word.game.fun.puzzle.prison.escape.captain',
#   'in.daily_puzzle.crossword',
#   'com.fingerlab.block.wordgame',
#   'com.puzzle1studio.go.wordsearchinspiration',
#   'bible.wordgame.words.puzzle.swipeword.collect.verses.an',
#   'com.word.picnic.fun.crossword.puzzle',
#   'com.thrivegames.mysteryword',
#   'com.omgpop.dstfree',
#   'com.immortaltaoists.en',
#   'com.lotum.wordblitz',
#   'com.lulo.scrabble.classicwords',
#   'com.iscoolentertainment.wl',
#   'com.relaxingbraintraining.wordcup',
#   'com.crossword.bible.cookies.find.english',
#   'com.wordgame.cross.android.en',
#   'com.zl.wordgame.wordsweeper',
#   'com.kangwang.word',
#   'com.wingjoy.dynastyLife.inter',
#   'com.zynga.wwf2.free',
#   'com.wordfarm.scapes',
#   'com.cookapps.wordlife',
#   'com.winrgames.wordswordswords',
#   'com.zytoona.wordscrush',
#   'com.fotoable.WordVillas',
#   'com.rlg.guesstheemoji',
#   'com.sleepingbeastgames.spaceteam',
#   'com.lovetoknow.wordfinder',
#   'com.happydream.wordsearch',
#   'bible.wordgame.verse.wordstacks.puzzle',
#   'com.fanatee.stop',
#   'best.word.connect.search.free.offline.puzzle.word.games.world',
#   'com.escape.puzzle.prison.bank.steal.money.fun',
#   'com.wordgame.puzzle.block.search',
#   'word.game.wordscapes',
#   'com.havos.g.allapps',
#   'com.peoplefun.wordflowers',
#   'com.hiplay.word.games.wordscapes.nature',
#   'de.lotum.whatsinthefoto.us',
#   'com.zimad.magicwordconnect',
#   'com.oneup.word.soup.free',
#   'com.fugo.wow',
#   'com.best.wordsearch.free',
#   'com.wordloco.wordchallenge',
#   'com.jdpapps.wordsearch',
#   'com.eggheadgames.quicklogicproblems',
#   'com.zytoona.lostword2',
#   'com.puzzle.word.wordfreetime.gp',
#   'com.zatg.scaryteacher.wordgame',
#   'com.vivinte.android.word2',
#   'com.wordgame.puzzle.block.crush',
#   'com.rocygamesa.guessthetiktokstar',
#   'com.zynga.boggle',
#   'com.blueboat.justriddles',
#   'net.artgamestudio.charadesapp',
#   'com.braindom2riddle',
#   'com.uk.best.cross.word.game',
#   'com.randomlogicgames.crossword',
#   'com.BrainLadder.AmirzaGP',
#   'com.twominds.HeadsUpCharadas',
#   'com.sonypicturestelevision.jeopardycross',
#   'word.heaps.scroll.connect.swipe.stacks.free.word.games.puzzle',
#   'com.piggyqojciqudhecuidqhuroblox.piggyroblox.piggyrobloxkjvnuidfnvuidnuvn33',
#   'com.puzzle.word.wordcolour.gp',
#   'com.wordscapes.word.cookies.puzzle.wordbrain.collect',
#   'com.layton.bookworm.pro',
#   'bible.wordgame.story.verse.words.connect.puzzle',
#   'com.fgcos.crossword_puzzle',
#   'com.verses.biblepuzzle.an',
#   'in.androidmate.never_have_i_ever',
#   'com.wordfinder.unscrabble.connect.addict',
#   'com.wordgame.puzzle.board.en',
#   'com.crazy.letter.wordfind',
#   'com.wordgame.words.connect.bibleverse.en',
#   'com.pixplicity.cryptogram',
#   'com.bitmango.go.wordsearchhiddenwords',
#   'com.blackout.season',
#   'com.games.makewords2',
#   'com.bibleword.crossword.en',
#   'com.lydia.wordsgame.word.talent',
#   'com.asgeir_albretsen.funlibs',
#   'org.duckdodo.baikoh',
#   'com.puzzle1studio.go.wordcalmcross',
#   'com.blackout.cube',
#   'air.com.pinturillo2free.pinturillo2free',
#   'com.theangrykraken.twopictures',
#   'com.wordpuzzle.wordfall',
#   'com.fonaps.hangmanmaster',
#   'com.melimots.WordSearch',
#   'com.appynation.occw',
#   'com.fun9games.word.cross',
#   'com.word.connect.theme.travel.puzzle.cross',
#   'com.word.journey.crossword',
#   'com.appspot.orium_blog.crossword.eng',
#   'com.blueoxtech.sevenlittlewords',
#   'com.binggogames.wordblocks',
#   'air.au.com.minimega.bonza',
#   'texttwist.n2',
#   'com.androidmate.catchphrase',
#   'com.emrekhan.hangmanmultiplayerandroid',
#   'com.glorygame.secret.puzzle.plot',
#   'com.marulgames.wordsurf',
#   'com.oneup.word.packs',
#   'com.g5e.crosswordspg.android',
#   'com.casual.candy.crosswords',
#   'com.asgardsoft.words',
#   'word.bubble.pop.parts.combine.guess.find.swipe.crush.scrabble.puzzle.game',
#   'com.peoplefun.wordchums',
#   'com.kooapps.wordxbeachandroid',
#   'com.pizzagames.wordcrossy',
#   'com.puzzlenation.dpcrosswords',
#   'com.andron.crosswords2',
#   'com.razzlepuzzles.fillins',
#   'com.pollardbanknote.cashword',
#   'com.baek.Gatalk3',
#   'com.razzlepuzzles.cryptograms',
#   'com.plus9.fandogh',
#   'com.matchasaucellc.word.hound.android',
#   'com.love.puzzles.word.serene',
#   'wordpuzzle.innovationgames.crossword',
#   'com.word.clash.puzzle.searchjourney',
#   'com.peoplefun.wordvistas',
#   'com.bigstarkids.wordtravel',
#   'com.escape.room.door.word.prison.puzzle.adventure',
#   'net.lrstudios.word_search',
#   'com.tgts.portablewordsearch',
#   'com.mobiloids.wordmix',
#   'com.eggheadgames.logicproblems',
#   'com.adveractive.game.jumblecrossworddroid',
#   'com.bitmango.go.wordtiles',
#   'com.donkeysoft.wordwowfree',
#   'word.blocks.jigsaw.puzzle.boggle.find.hidden.scapes.shapes.fit.search.scrabble.free',
#   'com.etermax.guesscrack',
#   'com.spotlight.languinis'],
#  ['com.lulo.scrabble.classicwordsplus',
#   'com.hbwares.wordfeud.full',
#   'pt.cosmicode.guessupkids',
#   'com.teazel.crossword.full',
#   'com.androidmate.catchphrasepro',
#   'agamz.logic',
#   'jaguargames.wordmasterpro',
#   'com.fiftyonefortynine.queenbee.app',
#   'com.omgpop.dstpaid',
#   'air.com.littlebigplay.games.wordgamespro',
#   'com.educ8s.stavrolexa_pro',
#   'se.maginteractive.rumble',
#   'agamz.acrostics',
#   'com.verywisetech.pictionarypro',
#   'com.etermax.apalabrados.pro',
#   'com.sparkgenius.TGGWordGenerator',
#   'com.eekgames.dropwords2',
#   'com.ortsoftware.crosscrazePro',
#   'com.firecrackersw.wordbreakerfull',
#   'air.com.littlebigplay.games.premium.spellingchallenge',
#   'com.planetrational.wordplus']]

# %%
# Turning list of lists into list only and checking number of scraped app ids.

listofappids = [item for sublist in listoflistofappids for item in sublist]
len(listofappids)
# Out:
# 5136

# %%
# Checking if there are any overlaps in app ids.

uniqueappidlist = []
for x in listofappids:
    if x not in uniqueappidlist:
        uniqueappidlist.append(x)
            
uniqueappidlist
# Out:
# ['com.innersloth.spacemafia',
#  'com.tapped.drawrider',
#  'com.activision.callofduty.shooter',
#  'com.playgendary.hitmasters',
#  'com.drawprotector.wavy.ios',
#  'com.fungames.sniper3d',
#  'com.rkgames.basisgame',
#  'com.cassette.aquapark',
#  'air.com.hypah.io.slither',
#  'com.dts.freefireth',
#  'com.playgendary.kickthebuddy',
#  'com.YummyGames.SamuraiFlash',
#  'com.jtsniper.game',
#  'com.groogadgets.swipefight',
#  'com.nintendo.zaka',
#  'lol.onevone',
#  'com.ducky.slicethemall',
#  'com.cg.fanofguns',
#  'com.rubygames.assassin',
#  'spider.rope.hero.frogninja.gangstar.crime.herogame',
#  'com.Neurononfire.SupremeDuelist',
#  'com.tencent.ig',
#  'ru.galya.drawjoust',
#  'com.geishatokyo.trafficrun',
#  'com.supercell.brawlstars',
#  'com.outfit7.herodash',
#  'com.jpgroup.pocketsniper',
#  'com.PoxelStudios.DudeTheftAuto',
#  'com.miniclip.bowmasters',
#  'games.nerf.epic.pranks.free',
#  'com.time.trigger',
#  'com.outfit7.talkingtomgoldrun',
#  'com.amelosinteractive.snake',
#  'com.stealthgame.master',
#  'com.ohmgames.crowdshooter',
#  'mobi.gameguru.slapkings',
#  'com.playgendary.tom',
#  'com.ohbibi.fps',
#  'com.ohmgames.knockdolls',
#  'com.seenax.HideAndSeek',
#  'com.fungames.battletanksbeta',
#  'com.nintendo.zara',
#  'com.miniclip.agar.io',
#  'com.wildlife.games.battle.royale.free.zooba',
#  'com.netboom.cloudgaming.vortex_stadia_shadow_GeForce',
#  'com.crazylabs.lady.bug',
#  'vh.one',
#  'com.habby.archero',
#  'com.gamestart.protectthevip',
#  'com.pixel.gun3d',
#  'com.Deven.Arrow3D',
#  'com.sandboxol.indiegame.bedwar',
#  'com.studio501.curvypunch3d',
#  'com.geishatokyo.snowballio',
#  'com.hgamesart.hurricanehero',
#  'com.edkongames.mobs',
#  'com.yodo1.crossyroad',
#  'zombie.survival.craft.z',
#  'com.imangi.templerun2',
#  'com.kabam.marvelbattle',
#  'com.playgendary.tombpaint',
#  'com.dangernoodle.killerbee',
#  'com.pixonic.wwr',
#  'com.tikitaka.folk',
#  'com.Bingo.Football',
#  'com.mgc.RopeHero.ViceTown',
#  'com.gamehivecorp.beattheboss4',
#  'com.wildspike.wormszone',
#  'com.mobile.legends',
#  'com.Snow.Golf',
#  'black.mafia.ironboy.stickman.rope.heros',
#  'com.stickman.warriors.stickwarriors.dragon.shadow.fight',
#  'com.chaloapps.strikefortressbox',
#  'com.hitrock.hideonline',
#  'com.geishatokyo.dinosaur',
#  'com.vng.g6.a.zombie',
#  'com.gamedevltd.wwh',
#  'com.generagames.resistance',
#  'com.bandainamcoent.dblegends_ww',
#  'air.com.ubisoft.brawl.halla.platform.fighting.action.pvp',
#  'com.bhvr.deadbydaylight',
#  'com.chillyroom.zhmr.gp',
#  'com.funnii.maskofstick',
#  'com.ohmgames.smashthemall',
#  'sniper.gun.zombie.shooting',
#  'com.cec.skateuniverse',
#  'com.stickman.shadow.battle',
#  'com.hgamesart.blackholehero',
#  'me.modernator.stickWarfareBloodStrike',
#  'games.noho.gungang',
#  'com.gta.truck.driver.city.crush',
#  'com.mousemobile.explorationcraft',
#  'com.wb.goog.mkx',
#  'com.h8games.helixjump',
#  'com.Eageron.apps.RealTimeShields',
#  'com.freegamesstudio.thesurvivalhuntergames2',
#  'com.gta.real.gangster.crime',
#  'com.lalonde.upstream',
#  'com.gameloft.android.ANMP.GloftGGHM',
#  'rs.pwn.zombielike',
#  'com.fcnaud.robbery',
#  'com.dive.bed.game',
#  'com.chaloapps.roosterrudy',
#  'com.nekki.shadowfight',
#  'com.zeptolab.bulletecho.google',
#  'com.os.falcon.yogame.stickfighter',
#  'com.netease.ddsfna',
#  'com.sega.sonic1px',
#  'com.titan.cd.gb',
#  'com.rage.road',
#  'jpark.AOS5',
#  'com.aryasgames.zombieseverywhere',
#  'com.babil.archers.tale.bow.hunter.battle.action',
#  'com.ZenithGames.CrowdBomber',
#  'com.desert.riders',
#  'com.bandainamcoent.ninjavoltage_app',
#  'com.mizo.robot.fps.shooting.game',
#  'com.junesoftware.maskgun',
#  'io.painkiller.battle.royale',
#  'com.cheshirex.stickmanthefight',
#  'com.ivy.garfield.run',
#  'com.bloop.food',
#  'com.zeptolab.robotics',
#  'com.hgamesart.snowstorm',
#  'com.matte.rushcrush',
#  'com.playstack.svtc',
#  'com.glu.zbs',
#  'com.cg.cowboy',
#  'com.skygo.stickfight2',
#  'com.rubygames.slingdrift',
#  'com.yuriychechulin.throwio',
#  'com.grandgangster.crimecity.prisonescape',
#  'com.my.warface.online.fps.pvp.action.shooter',
#  'com.gun.black.ops',
#  'com.tomo.pushbattle',
#  'com.gsgames.pixel.combat',
#  'sniper.honor.real3d.shooter.assassin.free.android',
#  'com.PuzzleOnly.KnockoutRace',
#  'com.stick.fight.battle.warrior',
#  'com.flaregames.zgs',
#  'com.pikpok.dr2.play',
#  'fi.twomenandadog.zombiecatchers',
#  'com.hgamesart.ropemummy',
#  'com.chaloapps.memeswars',
#  'com.funnii.robotsuper.offlinegames',
#  'com.ChillyRoom.DungeonShooter',
#  'com.panzerdog.tacticool',
#  'com.joydo.minestrikenew',
#  'com.clement.ballmayhem',
#  'com.mtvn.superbrawlapp',
#  'com.zg.dinosaur.hunter.wild.jungle.animals.hunting.sniper.safari.free.apps',
#  'com.criticalforceentertainment.criticalops',
#  'com.funnii.galaxyofstick',
#  'com.aldagames.zombieshooter',
#  'com.fun.games.commando.black.shadow',
#  'com.zeptolab.omnomrun.google',
#  'com.bandainamcogames.dbzdokkanww',
#  'com.lf.sniper.gun.shooter.free.apps',
#  'com.aurecas.stickmanzombieshooter',
#  'com.hgamesart.superhero',
#  'com.madfingergames.wargames.shooter',
#  'com.roadglider.game',
#  'com.anfagames.sodaguys',
#  'com.doctor.surgerymaster',
#  'com.Floor18.Zombiner',
#  'com.hasbro.beybladesenterprise',
#  'com.sega.soniccd.classic',
#  'com.azurgames.BattleGroundRoyale',
#  'com.rkgames.smashywanted',
#  'com.kwalee.superherosunset',
#  'com.mgs.sniper1',
#  'com.spider.ropeman.superhero.gangster.vegas.crimecity',
#  'com.soneraltincit.cityfightvsstreetgang',
#  'com.autumn.skullgirls',
#  'com.nway.powerrangerslegacywars',
#  'com.DCGEntertainment.EnergyBlast',
#  'com.crazylabs.mr.bullet.puzzle.game3d',
#  'com.alienshooter.galaxy.attack2',
#  'com.assassingames.ninjafrogrope',
#  'com.gameloft.android.ANMP.GloftOLHM',
#  'com.gamedevltd.destinywarfare',
#  'com.miniclip.diep.io',
#  'com.lf.frontline.elite.war.free.apps',
#  'org.ppsspp.ppsspp',
#  'com.herogame.gplay.lastdayrulessurvival',
#  'com.gameloft.android.ANMP.GloftM5HM',
#  'com.sunnybaria.collabgame',
#  'com.sgs.urb.versuspixels',
#  'com.kabam.bigrobot',
#  'supreme.dragon.battle.shadow.fight.warriors',
#  'com.axlebolt.standoff2',
#  'com.mad.gunz',
#  'com.ggv.grand.city.thug.crime.gangester',
#  'com.edkongames.aurora',
#  'se.itatake.gumslinger',
#  'com.stick.hero.fighter.saiyan.supreme.dragon.warrios',
#  'com.kotobagames.namelesscat',
#  'com.scottgames.fivenightsatfreddys',
#  'com.rockstargames.gtasa',
#  'com.clickteam.ultimatecustomnight',
#  'com.dsemu.drastic',
#  'com.scottgames.sisterlocation',
#  'com.scottgames.fnaf4',
#  'com.ubisoft.assassinscreed.identity',
#  'com.squareenixmontreal.hitmansniperandroid',
#  'com.scottgames.fnaf3',
#  'com.activision.boz',
#  'jp.konami.epjCastlevania2',
#  'com.rockstargames.bully',
#  'com.rockstar.gta3',
#  'com.damonplay.damonps2.pro.ppsspp',
#  'com.bethsoft.DOOM',
#  'com.wb.lego.marvel',
#  'com.GameCoaster.ProtectDungeon',
#  'org.ppsspp.ppssppgold',
#  'com.playdigious.deadcells.mobile',
#  'com.turner.ttgfigures2',
#  'com.tipsworks.android.pascalswager.google',
#  'com.bethsoft.DOOMII',
#  'com.rockstargames.gtactw',
#  'com.jdroid.gtasacheater',
#  'com.jumpgames.RealSteel',
#  'com.venomizedArt.SlaughterRebels',
#  'com.nekki.shadowfight2.paid',
#  'com.turner.b10runner',
#  'com.MikaMobile.Zombieville2',
#  'com.EvilTortillaGames.cookiesvclaus',
#  'com.MortalCrusade.SwordOfKnight',
#  'com.agaming.thesun.origin',
#  'com.coffeestainstudios.goatsimulator.goatz',
#  'com.altavite.ps2emu',
#  'com.limbic.ac130',
#  'com.khg.actionsquad',
#  'com.Zonmob.Stickman.FightingGames.ShadowOfDeath',
#  'com.oddworld.Stranger',
#  'com.dotemu.titanquest',
#  'com.devolver.downwell_rerelease',
#  'com.foursakenmedia.heroesandcastles2',
#  'com.pastagames.ro1mobile',
#  'air.com.sfbgames.HauntTheHouseTerrortown',
#  'com.ubisoft.rayman.fiestarun',
#  'com.gameloft.android.ANMP.GloftM4HM',
#  'com.mtvn.tmntpp',
#  'com.archi701.elchapo',
#  'com.ThoriumGameLab.BattleOfVicksburg3',
#  'com.gameloft.android.ANMP.GloftM3HM',
#  'com.ThoriumGameLab.EastFront',
#  'com.DastroGamesStudio.FateZ',
#  'jp.co.capcom.rockman1en',
#  'com.FYQD.BrightMemory',
#  'com.gameloft.android.ANMP.GloftG4HM',
#  'com.oddworld.NNT',
#  'com.opentouchgaming.deltatouch',
#  'com.candyrufusgames.survivalcraft',
#  'com.mtvn.tmntrooftoprun',
#  'com.mygdx.digtochina.android',
#  'com.ThoriumGameLab.WinterWar',
#  'com.dingogames.tastyplanet1',
#  'com.mtvn.tmntMovieGame',
#  'air.com.oranginalplan.weaphones2020',
#  'com.outerminds.pewdiepie',
#  'com.dingogames.tastyplanet2',
#  'com.tequilabyte.walker.main',
#  'jp.co.capcom.rockman6en',
#  'com.IvanPanasenko.EndurancePremium',
#  'jp.co.capcom.rockman2en',
#  'com.vblank.RCRDX',
#  'com.ThoriumGameLab.Petrolia',
#  'com.Drool.ThumperPocketEdition',
#  'com.starshipstudio.thesurvivorremastered',
#  'com.pixelbite.sg',
#  'com.the10tons.teslavslovecraft',
#  'com.companyname.LetThemCome',
#  'com.jdroid.gta3modder',
#  'com.fansipan.stickman.shadow.knights.fightinggames',
#  'com.Dexus.Dinosaur.TRexFights.Dinosaurs.Dominator',
#  'com.littlegamesstudio.Gauntlet',
#  'com.foursakenmedia.heroesandcastles',
#  'com.the10tons.neonchrome',
#  'com.blinigames.lus',
#  'com.sigmateam.alienshooter2reloaded',
#  'com.stickman.warriors.dragon',
#  'jp.co.capcom.rockman4en',
#  'com.kylebarrett.Immortal',
#  'com.doublethink.ofdp2',
#  'com.dotemu.raidenlegacy',
#  'com.opentouchgaming.quadtouch',
#  'com.venomizedArt.Slaughter2',
#  'jp.halegg.nazcaf',
#  'com.square_enix.secret',
#  'com.agaming.zonaprojectx',
#  'com.unimob.stickman.ghost2.pay',
#  'com.TinyDevbox.DeadRain',
#  'com.gameloft.android.ANMP.GloftWBHM',
#  'com.darkarrow.stickfighter.saiyan.vip',
#  'com.imcrazy.ds2',
#  'jp.co.capcom.rockman3en',
#  'com.skyfox.foxoneAdv',
#  'com.AlexeySuslin.RunicCurse',
#  'com.zitga.ninja.stickman.legends.shadow.wars',
#  'com.foursakenmedia.bugheroes2',
#  'com.jurassicapps.jurassidinokidsunlocked',
#  'com.touchdimensions.zombie',
#  'com.venomizedart.Slaughter',
#  'com.Majorariatto.GolfingOverIt',
#  'com.nvidia.valvesoftware.halflife2',
#  'com.blabberf.gunroundsandroid',
#  'com.id.doom3bfg',
#  'com.sigmateam.alienshootermobile',
#  'com.VenomizedArt.Mindcell',
#  'com.tenbirds.animus',
#  'com.hgamesart.catsimulatorpro',
#  'com.devolverdigital.swredux.play',
#  'jp.co.capcom.rockman5en',
#  'com.Bornthrupieces.Bond007',
#  'de.kamibox.seesaw',
#  'com.Nariworks.VirusZombie',
#  'com.redantz.game.za3p',
#  'jp.konami.mgs2hd.shield',
#  'com.agaming.reporter',
#  'com.gsm.overdrivepremium',
#  'com.RideAndCrash.AmonAmarthBerserkerGame',
#  'com.reeltoreal.survivor_adventure_pro',
#  'com.entwell.rk_org',
#  'com.turner.trutv.wheelofdoom',
#  'com.the10tons.jydge',
#  'com.atypicalgames.chernobyl',
#  'com.addictinggames.manatarms',
#  'com.pixelstar.PixelFBladeVIP',
#  'com.PoshToffeeGames.MedalOfValor4PRO',
#  'com.agaming.mentalhospitaliv',
#  'com.atypicalgames.radiationcity',
#  'com.DefStudio.BattleGunVRGold',
#  'com.mtvn.dafrainforest.google',
#  'com.eyesright.amb',
#  'com.zitga.cyberfighters.shadow.hunter.legends',
#  'co.electrictoy.dig',
#  'com.roblox.client',
#  'com.multicraft.game',
#  'com.nianticlabs.pokemongo',
#  'com.BlissGames.Juego23',
#  'com.oneway.Deathcoming',
#  'com.movile.playkids.pkxd',
#  'com.cleverturtle.brickbuilder',
#  'com.eers.kraft.eerskraft',
#  'com.jockeygames.rampcar.stuntsfree.impossibletracks.stuntdriving.mega.car',
#  'free.os.jump.superbros.adventure.world',
#  'com.sega.sprint',
#  'com.tinyco.potter',
#  'com.neighbors.darkriddle',
#  'com.deuscraft.TurboTeam',
#  'net.wooga.junes_journey_hidden_object_mystery_game',
#  'com.lioncel.NoOneEscape',
#  'com.randonautica.app',
#  'com.os.falcon.bob2.adventure.world',
#  'com.grand.speed.hero.highway.gangster.chase',
#  'org.nanobit.hollywood',
#  'com.grand.police.transport.truck',
#  'com.playrix.manormatters',
#  'com.gameinsight.gplay.mmanor',
#  'com.apps2us.slither.slink.io',
#  'com.naturalmotion.clumsyninja',
#  'com.sgs.antiterrorism.counterattack.commandomissiongame',
#  'com.superbinogo.jungleboyadventure',
#  'com.hitcents.drawastickmanepic2free',
#  'com.gf.extreme.gtracing.car.stunts.impossiblecarstunts.stuntdriving',
#  'com.tinybuildgames.helloneighbor',
#  'com.tellurionmobile.realmcraft',
#  'com.secg.jurassiccraft',
#  'com.Earthkwak.Platformer',
#  'com.mytona.seekersnotes.android',
#  'com.aidungeon',
#  'com.cradley.bee.robot.games',
#  'com.sandboxol.indiegame.eggwars',
#  'air.SuperCity',
#  'com.bl.critical.strike',
#  'com.pocapp.dungeondogsgame',
#  'com.StickPage.diamant',
#  'com.fgz.us.police.flying.helicopter.car.transform.robot.games',
#  'com.doctor.robot.rescue.mission',
#  'games.fatlion.building.mycraft.surfing.craft.free.simulator.jetski.games.surf.league',
#  'com.fa.gym.fighting.game',
#  'com.spider.ropehero.superhero.gangstercrime',
#  'com.craftgames.plntcrft',
#  'com.crazylabs.jumanji',
#  'com.blyts.nobodies',
#  'com.impp.construction.simulator.forklift',
#  'com.bigag.bike.stunt.master',
#  'com.mojang.minecraftearth',
#  'com.cdt.basic.math.teacher',
#  'com.prettysimple.criminalcaseandroid',
#  'air.HardTime',
#  'com.jagex.oldscape.android',
#  'com.buildingcraftinggames.fun.kid.games.boys.block.craft.minecraft.story.mode.lego.create.build.marvel.hero.dc.legends.mcpe.mod',
#  'com.hitcents.drawastickmanepic3',
#  'com.buntoo.drone.robot.transformation',
#  'com.secg.earthcraft',
#  'com.tinydragonadventuregames.crafting.building.exploration.blocky.cube.lite.boy.girl.love.date.game.chat.minecraft.boyfriend',
#  'com.craftgames.worldcrft',
#  'com.mustardgames.topspeed.formulacar.racinggames',
#  'com.gun.fun.anti.shoot',
#  'com.gangstar.crime.fps',
#  'com.candyrufusgames.survivalcraft2trial',
#  'com.upjers.zoo2animalpark',
#  'com.ghs.dino.robot.car.robot.game',
#  'com.ugen.playquirk',
#  'com.studiowildcard.wardrumstudios.ark',
#  'com.RetrostyleGames.LastPirate.deadthieves',
#  'com.play.io.monster.truck.demolition.derby.crash.stunts',
#  'com.us.police.car.transform.robot.war',
#  'air.com.pixelfederation.diggy',
#  'com.tinydragonadventuregames.doll.house.craft.princess.fashion.girls.minecraft.barbie.creative.exploration.lite.build.mine.free',
#  'com.YovoGames.carwash4',
#  'com.playmini.miniworld',
#  'com.glu.stardomkim',
#  'com.rds.bike.racer.highway.rider.traffic.bike.racing.game',
#  'com.survivalcrafting.scary.theme.park.craft.horror.ghost.zombie.monster',
#  'com.cgs.offroad.farm.animal.transport.trailer.truck.driving.game',
#  'com.animal.attack.simulator2019.wild.hunting.games',
#  'de.codestream.horus',
#  'com.sandboxol.indiegame.skywar',
#  'com.YovoGames.babyCare2',
#  'com.appstrend.police.robot.bus.transform',
#  'com.pm.mega.ramp.impossible.car',
#  'com.FoxieGames.DinoProject',
#  'com.FumbGames.DragonMerge',
#  'com.wb.goog.legoswtfa',
#  'com.nag.pet.dog.virtual.family.adventure',
#  'com.happy.family.limousine.robot.game',
#  'com.appstrend.flying.eagle.robot.car.games',
#  'com.gz.deer.hunting.shooting',
#  'com.gaminglegends.taxigame.taxisimulator.grand.car.driving2020',
#  'freedom.bubble',
#  'com.red.ball.ballgames.bounceball.redball5',
#  'com.bandagames.miner',
#  'com.impp.city.traindriver.simulator',
#  'com.sandboxol.indiegame.luckyblock',
#  'com.indigokids.mim',
#  'com.cradley.jungle.robot.shooting.game',
#  'com.fgz.flying.fire.truck.engine.rescue.firefighter.robot.games',
#  'com.frenzygames.fgs.shooting.anti.terrorism.combat.mission',
#  'com.mustardgames.muscle.car.stunts.mega.ramp.stunt.car.impossibletracks',
#  'com.gs.lightspeed.superhero.rescue.mission.doctor.robot.games',
#  'com.cgs.sea.animal.transport.trailer.truck.driving.game',
#  'com.gamesunion.idleracingtycoon',
#  'com.spider.ropehero.gangster.crimecity',
#  'com.ludia.jw2',
#  'com.minecrafting.miniworldcrafting',
#  'com.eyesthegame.eyes',
#  'com.freerange.goosebumps',
#  'com.doctor.robot.human.rescue',
#  'com.EZTECK.brannyTeacherMath',
#  'jonessamuelren.far.home.spider.hero.run',
#  'com.SGS.DrivingSchoolGames.RealCarParkingSimulator',
#  'com.rlg.flying.tiger.bike.robot.transform',
#  'com.crazylabs.hotel.transylvania.adventure',
#  'com.monstergamesproductions.ramp.moto.rider',
#  'com.nag.home.manager.working.virtual.mom',
#  'com.buildtownn.skimlyblock',
#  'com.amongus.us',
#  'air.com.RustyLake.SamsaraRoom',
#  'com.offlinegames.police.racing',
#  'com.kongregate.mobile.throwdown.google',
#  'biggiant.prisonescape',
#  'com.g5e.homicidesquadpg.android',
#  'com.spider.ropehero.crimecity',
#  'com.hanako.mcpe_mods',
#  'com.CoolGames.MazeGame',
#  'com.minecraftpe.minicraft.multicraft.blockart',
#  'freegames.zombiesniper.deadtrigger',
#  'com.wooga.pearlsperil',
#  'com.igoldtech.streetchaser',
#  'com.reeltoreal.survivor_adventure',
#  'com.delworkhard1.minecrafting2020',
#  'com.darksacygames.sirenheadhorrorgame',
#  'air.com.moviestarplanet.roboblastplanet',
#  'com.gametornado.short_life',
#  'com.YovoGames.doctorBear',
#  'com.mustardgames.bmx.cycle.stunt.mega.ramp.impossibletracks',
#  'com.grand.theft.cheat.codes.five',
#  'com.gamefeast.bigcity.limousine.car.driver',
#  'com.spinmaster.enterprise.colleggtibles',
#  'com.tohsoft.arashi.ninja.shadow',
#  'com.budgestudios.googleplay.ThomasAndFriendsMagicalTracks',
#  'com.haiku.adventure.escape.game.mystery.stories',
#  'com.flying.tractor.simulator',
#  'com.xjoy.mermaid',
#  'air.ExtraLives',
#  'com.iron.flying.man.rope.hero.vegas.crime.simulator.gta',
#  'com.secg.robocraft',
#  'com.HuaYiGame.DeliveryFromThePain',
#  'com.wild.animals.transport.simulator',
#  'games.dali.adventure.point.click.lucid.dream.witch.planet.riddle',
#  'com.colto.cknrunner',
#  'com.KidsGames.SuperHippo',
#  'com.mastercraft.minecrafting',
#  'com.bikesstunt.motomaster.racing.game.trial.trick.bikeRacing',
#  'com.budgestudios.TransformersRescueBotsHeroAdventures',
#  'vegas.craftvegas2.adventuregame2020',
#  'com.armorgames.sodadungeon2',
#  'com.heliogames.westland',
#  'com.gunshooting.counterstrike.fps',
#  'games.fatlion.crafting.building.mine.theme.park.games.roller.coaster.tycoon.boys.girls.exploration.lite.roblox.zoo.water',
#  'com.superbinogo.jungleboyadventure2',
#  'com.survivalcrafting.airport.city.pilot.plane.craft.fly.simulator.flight.air.traffic.control.airline.commander.building.flying',
#  'com.RbwInteractive.fortyfourCats',
#  'com.us.army.humvee.jeep.car.transporter.parking.game',
#  'com.backstreet.police.panda.robot.transform.robotwar',
#  'com.netease.lztgglobal',
#  'com.fgz.us.police.eagle.robot.transform.flying.bike.game',
#  'com.myappz.firegirlWaterboy',
#  'com.runefall.match3.puzzle.adventure.gp',
#  'com.amazing.spider.rope.hero.ninja.gangster.crimecity',
#  'com.aldagames.craftingdead',
#  'com.blackpanther.ninjaarashi',
#  'com.baldi.horror.escape.basics',
#  'com.nianticlabs.hpwu.prod',
#  'com.secg.terracraft2',
#  'com.cgs.us.flying.police.robot.speed.hero.crime.city.hero.games',
#  'com.happy.family.tiger.robot.games',
#  'com.door.glass.bottle.shooter.expert',
#  'com.pacific.wildlands',
#  'com.LiliJoy.DragonLand',
#  'com.nordcurrent.murderinalps',
#  'com.PSVStudio.HippoBabyBall',
#  'com.pocapp.castlecats',
#  'com.miniworldblock.krafting202',
#  'com.fivebn.LL1_f2p',
#  'es.socialpoint.dragonland',
#  'com.mustardgames.army.prison.transport',
#  'com.PSVStudio.BirthdayParty',
#  'com.glaznev.innocent',
#  'air.com.RustyLake.CubeEscapeParadox',
#  'com.formula.car.racing',
#  'com.g5e.hiddencity.android',
#  'com.aleson.casefiveanimatronicsfnaf',
#  'studio.genius.nurse',
#  'com.and.games505.TerrariaPaid',
#  'com.pixelcurves.terlauncher',
#  'com.robotgentleman.game60seconds',
#  'com.jds.batim',
#  'com.wb.goog.legojurassicworld',
#  'com.RobotGentleman.sixtyParsecs.mobile',
#  'com.D3Go.mendel',
#  'com.kleientertainment.doNotStarvePocket',
#  'com.bscotch.crashlands',
#  'com.rockstargames.gtalcs',
#  'air.com.RustyLake.RustyLakeHotel',
#  'com.seven2.pawapp2',
#  'com.gameloft.android.ANMP.GloftICHM',
#  'com.AngryNeighbor',
#  'com.wb.goog.lnjgo',
#  'air.com.RustyLake.RustyLakeParadise',
#  'games.dali.adventure.lucid.dream.part.two',
#  'com.jds.batds',
#  'air.com.RustyLake.WhiteDoor',
#  'com.disney.castleofillusion_goo',
#  'com.wb.goog.legobdc',
#  'com.playdead.limbo.full',
#  'air.com.RustyLake.RustyLakeRoots',
#  'com.younghorses.octodad',
#  'eu.bandainamcoent.verylittlenightmares',
#  'com.wb.goog.lbbg',
#  'jp.co.spike_chunsoft.DR2',
#  'air.com.amanitadesign.chuchel.gp',
#  'com.wb.goog.legohp1',
#  'com.candyrufusgames.survivalcraft2',
#  'jp.co.spike_chunsoft.DR1',
#  'com.noodlecake.realmyst',
#  'com.wb.goog.legohp2',
#  'com.wb.goog.lego.movievideogame',
#  'games.dali.adventure.lucid.dream.part.three',
#  'com.blyts.infamousmachine',
#  'edu.terc.zoombinis',
#  'com.square_enix.FFIXww.android_googleplay',
#  'air.net.machinarium.Machinarium.GP',
#  'com.kleientertainment.doNotStarveShipwrecked',
#  'com.leosfortune',
#  'com.BestFreeGames2k20.PixelcraftPixelmonandpokecraft',
#  'com.Level5.LT1RNA',
#  'com.hitcents.drawastickmanepic2',
#  'com.devolver.grispaid',
#  'com.bonusxp.fate',
#  'com.peppapig.goldenboots',
#  'com.terribletoybox.thimbleweedparkandroid',
#  'com.wb.goog.llotr',
#  'com.hitcents.stickmanepic',
#  'com.creativemobile.beholder',
#  'com.noodlecake.drtc',
#  'jp.co.capcom.gyakusai5en',
#  'com.pgstudio.survival.evo.pro',
#  'com.pjmasks.superchase',
#  'com.KillmondayGames.LittleMisfortune',
#  'com.and.games505.portal_knights',
#  'com.NightSchool.Oxenfree',
#  'com.lonewolfgames.rescueenchanter',
#  'com.oddworld.Munch',
#  'com.threeminutegames.lifeline.google',
#  'jp.co.capcom.gyakusai6en',
#  'com.noodlecake.riven',
#  'com.feemodev.cat',
#  'com.Level5.LT3RNB',
#  'com.mojotouch.t7g',
#  'com.KillmondayGames.FranBowCh1',
#  'com.antlerinteractive.KrystopiaNovasJourney',
#  'amanita_design.samorost3.GP',
#  'com.artifexmundi.scarlettmysteries.gp.full',
#  'com.KillmondayGames.FranBowCh3',
#  'co.uk.wixgames.ducklifeadventure',
#  'com.Level5.LT2RNA',
#  'com.lonewolfgames.blackthorncastle',
#  'jp.co.capcom.kenji1en',
#  'com.bigfishgames.pbtmgoogfull',
#  'com.KillmondayGames.FranBowCh2',
#  'com.fivebn.daf4.full',
#  'com.and.games505.brothers',
#  'co.uk.wixgames.ducklifebattle',
#  'ru.buka.dville01',
#  'com.accidentalqueens.anormallostphone',
#  'com.dotemu.sanitarium',
#  'jp.co.capcom.gyakusai4en',
#  'com.devolver.Swordsofditto',
#  'com.happyvolcano.games.thealmostgone',
#  'com.firemaplegames.returntogrislymanor',
#  'com.Tasharen.Windward',
#  'com.dotemu.ys1x',
#  'com.sharpen.storm',
#  'com.KickBack.LostEchoAdventure',
#  'com.eg.antarctica88pro',
#  'com.etterstudio.pnp',
#  'com.specialbit.dreams.android.full',
#  'air.com.amanitadesign.botanicula',
#  'com.dynamiczero.survivingtitan',
#  'com.chorusworldwide.bertramep1',
#  'com.noodlecake.suzycube',
#  'com.artifexmundi.queensquest2.gp.full',
#  'air.com.noodlecake.luminocity',
#  'com.bbg.tiwdroid',
#  'com.Pixelatto.Reventure',
#  'com.fgrfg.grgw',
#  'com.pgstudio.survivalpro',
#  'com.psychoseinteractive.forgottenmemories',
#  'com.foxandsheep.Dinotrux2',
#  'com.eline.neveralonemobile',
#  'com.LoopyMood.AntVentor',
#  'com.studiopango.pangopirate',
#  'com.glitchgames.theForgottenRoom',
#  'com.rawfury.longhathouse.Dandara',
#  'com.bigfishgames.mcrugoogfull',
#  'com.tribeplay.pandafirestation',
#  'com.explorationbase.Exploration',
#  'uk.co.revolution.bs1dc',
#  'com.pgstudio.siepro',
#  'com.cm.whipseey',
#  'com.arachnowopunk.revolution',
#  'com.alawar.beholder2',
#  'net.fmstudio.forgottenhilldisillusion',
#  'com.animationarts.secretfiles2',
#  'com.TenderClaws.VVR',
#  'com.lonewolfgames.losttreasure',
#  'com.glitchgames.allthatremains.part1',
#  'com.KillmondayGames.FranBowCh4',
#  'com.artifexmundi.grimlegends2.gp.full',
#  'com.bigfishgames.mwwmgoogfull',
#  'com.rawfury.woam',
#  'com.ProjectTheGalaxy',
#  'kr.co.sonnori.whiteday.g',
#  'com.ludosity.ittledew',
#  'com.econo.gcemulator',
#  'com.gtafrogstresstfighter.frogamazinggangster.thefrogsimulator20',
#  'com.devolver.hatofulboyfriend',
#  'com.KillmondayGames.FranBowCh5',
#  'com.theand.OddeyePaid',
#  'com.bigfishgames.pdogoogfull',
#  'com.Level5.LaytonMJNA',
#  'com.pointclickgames.mysteryofhauntedhollow',
#  'com.fivebn.ll5.full',
#  'com.accidentalqueens.anotherlostphone',
#  'com.fivebn.lost_lands_the_four_horsemen_full',
#  'com.noodlecake.waywardsouls',
#  'net.lonewolfgames.games.thelostship',
#  'com.glitchgames.foreverlostepisode1sd',
#  'com.mediacitygames.alicetrapped2',
#  'com.doublefine.thecave',
#  'com.artifexmundi.thesecretorder1.gp.full',
#  'com.divmob.epicheroeswar.en.freemium',
#  'com.senspark.darkland',
#  'net.playables.kidsgame',
#  'com.fivebn.new_york_mysteries_hd_full',
#  'com.artifexmundi.clockwork.gp.full',
#  'com.buffstudio.sevendays',
#  'com.threeminutegames.lifelinesilentnight.goog',
#  'com.threeminutegames.lifeline2.goog',
#  'com.artifexmundi.enigmatis3.gp.full',
#  'com.capybaragames.sworcery',
#  'com.firemaplegames.games.the_secretofgrislymanor',
#  'com.firemaplegames.Thickety_Creek',
#  'de.stollenmayer.philipp.SometimesYouDie',
#  'com.kochmedia.secretfiles',
#  'com.specialbit.angelo.deemon.full',
#  'com.Rain.Teslagrad',
#  'com.artifexmundi.ghostfiles2.gp.full',
#  'com.mediacitygames.lostfountain',
#  'com.fivebn.ll6.full',
#  'air.com.ohnoo.tormentum',
#  'com.soladv.game',
#  'com.glitchgames.veritas',
#  'com.headupgames.anybodyouttheredeadcity',
#  'com.artifexmundi.familymysteries1.gp.full',
#  'com.threeminutegames.lifelinecrisislinegoog',
#  'uk.co.revolution.bs5.ep2',
#  'com.winterveilstudios.DISTRAINT2',
#  'com.artifexmundi.pathofsin1.gp.full',
#  'com.defas.naruto',
#  'com.dotemu.ihnmaims',
#  'es.brokenrul.oldmansjourney',
#  'com.artifexmundi.thesecretorder7.gp.full',
#  'com.artifexmundi.tso8.gp.full',
#  'com.fivebn.lostlandsdo_full',
#  'com.fivebn.tl1.full',
#  'com.nvidia.valvesoftware.portal',
#  'com.pixbits.junkjack',
#  'com.bigfishgames.fbecgoogfull',
#  'com.bigfishgames.bawogoogfull',
#  'dk.lovable.lapetite',
#  'com.crescentmoongames.skyfish',
#  'com.pointclickgames.lostadventure',
#  'com.artifexmundi.demonhunter3.gp.full',
#  'com.fivebn.nym2.full',
#  'com.threeminutegames.lifelinehalftoinfinitygoog',
#  'com.hazegames.fractalspacetv',
#  'com.artifexmundi.grimlegends.gp.full',
#  'com.tommo.ff2g',
#  'com.herocraft.game.tinybangstory',
#  'com.fivebn.nym04.full',
#  'fall.race.io',
#  'com.Atinon.PassOver',
#  'com.kiloo.subwaysurf',
#  'com.fencinggame.master',
#  'com.games.smashersio',
#  'com.hanna.bodyguard.expert',
#  'com.freeplay.runandfight',
#  'com.ua.building.Lokicraft',
#  'com.Tastypill.BallSlide3D',
#  'com.LightBeam.Demolish',
#  'com.Celltop.SpiralRoll',
#  'com.mikhailp.logthrower',
#  'com.appadvisory.wtfight',
#  'com.playgendary.creamaster',
#  'com.alien.shooter.galaxy.attack',
#  'com.igutso.killphil',
#  'com.azurgames.stackball',
#  'com.sega.sonicdash',
#  'com.iposedon.bricksbreakerballs',
#  'com.robtopx.geometryjumplite',
#  'com.fgol.HungrySharkEvolution',
#  'com.topchopgames.skyroller',
#  'com.games.bottle',
#  'com.gamestart.dodgeaction3d',
#  'com.playgendary.tanks',
#  'com.dvloper.granny',
#  'com.ua.vikos.world',
#  'com.lightneer.goodslice',
#  'com.os.airforce',
#  'com.dvloper.grannychaptertwo',
#  'com.bigdog.games.buddyfitness',
#  'io.voodoo.paper2',
#  'io.voodoo.holeio',
#  'io.voodoo.crowdcity',
#  'com.timuzgames.savethefish',
#  'com.game.space.shooter2',
#  'com.gamepie.airpolice',
#  'com.pizza.dough',
#  'com.mindy.grap1',
#  'com.court.guilty',
#  'com.mikhailp.perfectsnipe',
#  'com.supergame.ohmycar',
#  'com.isl.stairrun',
#  'com.rmg.idle.tap.strong.granny',
#  'com.keplerians.icescream3',
#  'com.ubisoft.hungrysharkworld',
#  'com.superstar.rollingdice.gp',
#  'com.hyper.plinko.coin',
#  'com.keplerians.icescream',
#  'com.halfbrick.fruitninjafree',
#  'com.miniworld.mastercrafting.survivalboxbuilding20',
#  'com.imangi.templerun',
#  'com.nordcurrent.canteenhd',
#  'com.rioo.runnersubway',
#  'com.riseup.game',
#  'com.colorhole.game',
#  'com.kalipsogames.psychopathhunt',
#  'com.namcobandaigames.pacmantournaments',
#  'com.FDGEntertainment.redball4.gp',
#  'com.crazylabs.sausage.run',
#  'com.appadvisory.drawclimber',
#  'com.halfbrick.jetpackjoyride',
#  'com.boomhits.rampcarjumping',
#  'com.PepUpStudios.FallGuys3D',
#  'com.YsoCorp.WoodCutter',
#  'com.biglime.cookingmadness',
#  'net.apex_designs.payback2',
#  'com.fungame.casual.fishing.master',
#  'bike.hop.fall',
#  'com.ihari.escapetheprison',
#  'com.sega.sonicboomandroid',
#  'com.keplerians.icescreamtwo',
#  'com.orbitalknight.castlewreck',
#  'net.mobigame.zombietsunami',
#  'com.vincentb.RollyLegs',
#  'io.voodoo.paper3',
#  'com.orbitalknight.ridiculousfreekick',
#  'com.playgendary.sportmasters',
#  'com.halfbrick.dantheman',
#  'com.colorup.game',
#  'com.barsstudios.crazyarrow',
#  'com.sega.sonic2.runner',
#  'com.PlayMax.playergames',
#  'com.colorswitch.switch2',
#  'com.aldagames.zombero.bullet.hell',
#  'com.germanicus.cmioo',
#  'com.feelnside.touchdownmaster',
#  'com.mix.color.paint.game',
#  'com.team70.gangsterking',
#  'invaders.os.galaxy.space.shooter.attack.classic',
#  'com.robtopx.geometrydashworld',
#  'com.robtopx.geometrydashsubzero',
#  'bcom.rrdianshiase.table',
#  'tdcgame.zombie.idle.defense',
#  'com.honeyponey.catjump',
#  'com.nekki.vector',
#  'com.kunpo.virus',
#  'com.crazylabs.light.it.up',
#  'com.mediocre.smashhit',
#  'com.agent.action',
#  'com.kongregate.mobile.run.google',
#  'com.bentostudio.ballsvsblocks',
#  'com.triwin.cash.dozer',
#  'com.gigantic.clawee',
#  'com.slash.girl.redfish',
#  'com.kobgames.skaterrace',
#  'com.deerslab.dinoTREX',
#  'com.supersolid.snake',
#  'com.bike.jump',
#  'com.sandboxol.blockymods',
#  'com.superwings.jettrun',
#  'com.eg.deathpark',
#  'com.YsoCorp.FuryCars',
#  'com.cscmobi.merge.plant',
#  'com.turner.cnplay',
#  'com.rovio.angrybirdsfriends',
#  'com.os.space.force.galaxy.alien',
#  'com.lego.friends.heartlake',
#  'com.robtopx.geometrydashmeltdown',
#  'com.kongregate.mobile.burritobison3.google',
#  'com.JindoBlu.TwoPlayerGamesChallenge',
#  'slingshot.building.destroy',
#  'com.bigframes.color_road',
#  'com.crazylabs.sausage.io',
#  'com.highcore.hoopstars',
#  'comme.dragondrill.minigame',
#  'com.keplerians.evilnun',
#  'com.crazylabs.coin.rush',
#  'com.acoin.ballz.bricks.breaker',
#  'com.sdsd.adsh',
#  'com.blobbyfishgames.apechase',
#  'com.mobirix.swipebrick2',
#  'net.updategames.granny',
#  'com.sega.sonic4episode2',
#  'com.kwalee.wantedgp',
#  'misplayer.games.archery',
#  'com.bigfishgames.cookingcrazegooglef2p',
#  'com.playsidestudios.monkeyropes',
#  'com.cookingcity.chef.kitchen.craze.fever',
#  'com.ketchapp.bikerush',
#  'com.eg.antarctica88',
#  'io.voodoo.dune',
#  'com.CubeCubeSports.Cubic234PlayerGames',
#  'com.game.beerpong',
#  'myandroid.fphoenix.fastspinner',
#  'com.attackgalaxyshooter.galaxyspaceshooter2020',
#  'games.airion.townfights',
#  'com.playgendary.polyspherecoolgame',
#  'com.rocket.dragon.epic',
#  'com.mobirix.abmon',
#  'com.sonypicturestelevision.qbert',
#  'com.martinmagni.fancade',
#  'com.dpspace.rocketsky',
#  'com.custom.goescape',
#  'com.johnemulators.johngbalite',
#  'com.devsisters.gb',
#  'com.cooking.yummy.kitchen.fever.madness.gp',
#  'com.raongames.growcastle',
#  'com.rocket.dragon',
#  'com.linkdesks.jewellegend',
#  'com.jds.binr',
#  'com.istomgames.engine',
#  'com.ubisoft.hungrydragon',
#  'com.nomonkeys.ballblast',
#  'com.azurinteractive.humanevolution',
#  'bts.kpop.piano.music.tiles',
#  'eu.bandainamcoent.pacman256',
#  'com.smartstudygames.babyshark8bit.googlemarket',
#  'io.voodoo.paperio',
#  'com.superluckycasino.hotvegas.slots.vegas.android.free',
#  'line.color.adventure',
#  'com.spungegames.failybrakes',
#  'com.ankama.dragnboom',
#  'com.mnightt.slices',
#  'com.redsunpro.fallguyshexagone',
#  'com.my.cooking.chef.kitchen.craze.fever',
#  'com.waterdrop.stickman.global',
#  'com.ivy.winwing',
#  'com.lawson.tower',
#  'mini.zoo.crafting.exploration.creative.survival',
#  'com.kwalee.drawit',
#  'com.vl.rollyhill',
#  'com.setsnail.daddylonglegs',
#  'com.playgendary.coffeeshop3d',
#  'com.ketchapp.rider',
#  'com.abi.move.stop.io',
#  'com.custom.pickmeup',
#  'com.sausageflip.game',
#  'com.match3blaster.DropStackBallFall',
#  'com.baspin.barbershop',
#  'com.supernds.free',
#  'com.InkosGames.HoleIn',
#  'com.coolmath_games.coolmath',
#  'at.ner.lepsWorld2',
#  'com.survivalcrafting.crafting.fashion.car.salon.makeover.spa.girls.craft.fun.free.driving.games.girls.racing.simulator',
#  'com.ShivanshTiwari.FlappyBird',
#  'com.mojang.minecraftpe',
#  'xyz.deeppipes',
#  'com.robtopx.geometryjump',
#  'com.fastemulator.gba',
#  'com.epsxe.ePSXe',
#  'com.rockstargames.gtavc',
#  'com.johnemulators.johngba',
#  'com.fastemulator.gbc',
#  'com.rockstar.maxpayne',
#  'it.dbtecno.pizzaboygbapro',
#  'com.halfbrick.fruitninja',
#  'com.ngmoco.pocketgod',
#  'com.icorewwwi.vDS',
#  'com.sega.sonic4epi',
#  'com.retroloungelab.resetcollection',
#  'com.snkplaymore.kof2012a',
#  'com.nekki.vector.paid',
#  'com.madfingergames.SamuraiIIAll',
#  'com.snkplaymore.android007',
#  'com.worms3.app',
#  'com.explusalpha.NesEmu',
#  'com.explusalpha.MdEmu',
#  'com.johnemulators.johngbc',
#  'com.mtvn.SBmoviegame',
#  'com.NamcoNetworks.MsPacMan',
#  'cc.peacedeath.peacedeath',
#  'com.flukedude.impossiblegame',
#  'net.kairosoft.android.bouken_en',
#  'com.dotemu.neogeo.mslug3',
#  'com.snkplaymore.android001',
#  'org.mupen64plusae.v3.fzurita.pro',
#  'com.mediocre.grannysmith',
#  'com.fms.emu',
#  'com.jdroid.gtavccheater',
#  'com.zenstudios.MarvelPinball',
#  'com.sonicjump.sonicjump',
#  'com.square_enix.android_googleplay.finalfantasy2',
#  'com.nostalgiaemulators.nesfull',
#  'com.stevesnyderart.BalanceTheBeam2',
#  'com.explusalpha.GbaEmu',
#  'com.grapefrukt.games.bore',
#  'com.dotemu.ddtrilogy',
#  'com.dotemu.neogeo.mslug',
#  'net.floatingpoint.android.arcturus',
#  'com.crescentmoongames.swordshot',
#  'com.mightykingdom.shopkinsrun',
#  'com.herocraft.game.hyperforma.cyber.hack.arcade.premium',
#  'com.neutronemulation.retro8',
#  'org.lukeallen.bomberfull',
#  'it.dbtecno.pizzaboypro',
#  'com.dotemu.neogeo.samsho2',
#  'paulscode.android.mupen64plus',
#  'org.uoyabause.uranus.pro',
#  'com.explusalpha.GbcEmu',
#  'com.square_enix.android_googleplay.subarashikikonosekai_solo',
#  'jp.co.taito.am.spaceinvaders',
#  'com.magicwach.rdefense',
#  'com.doragongames.danmakuunlimited3',
#  'com.dotemu.rtype',
#  'jp.co.capcom.mobilemakaiwd',
#  'com.dotemu.neogeo.mslug2',
#  'jp.co.capcom.mobiledaimakaiwd',
#  'com.dotemu.neogeo.mslugx',
#  'com.PceEmu',
#  'com.explusalpha.A2600Emu',
#  'com.explusalpha.NeoEmu',
#  'nl.palatamedia.miner',
#  'com.playcreek.DeathWorm',
#  'com.atypicalgames.sgsr',
#  ...]

# %%
# It appears that there is no overlap in app ids.
# For reference, this list of app information was collected on 9/22/2020 at 11:30AM EST.

len(uniqueappidlist)
# Out:
# 5136

# %%
import pickle

# %%
# Saving list because list will differ when scraped at different times.

with open('uniqueappidlist.pkl', 'wb') as f:
    pickle.dump(uniqueappidlist, f)

# %%
with open('uniqueappidlist.pkl', 'rb') as f:
    
    uniqueappidlist = pickle.load(f)

# %%
len(uniqueappidlist)
# Out:
# 5136

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# # Getting feature information for all of our apps

# %%
# This will do most of the work for us.

from google_play_scraper import app

# Doing a test run with a well-known app.
result = app(
    'com.nianticlabs.pokemongo',
    lang='en',
    country='us'
)

# %%
# Checking what I get in the dictionary.

result
# Out:
# {'title': 'Pokémon GO',
#  'description': 'Join Trainers across the globe who are discovering Pokémon as they explore the world around them. Pokémon GO is the global gaming sensation that has been downloaded over 1 billion times and named “Best Mobile Game” by the Game Developers Choice Awards and “Best App of the Year” by TechCrunch.\r\n_______________\r\n\r\nUNCOVER THE WORLD OF POKÉMON: Explore and discover Pokémon wherever you are!\r\n \r\nCATCH more Pokémon to complete your Pokédex!\r\n \r\nJOURNEY alongside your Buddy Pokémon to help make your Pokémon stronger and earn rewards!\r\n\r\nCOMPETE in epic Gym battles and...\r\n\r\nTEAM UP with other Trainers to catch powerful Pokémon during Raid Battles!\r\n \r\nIt’s time to get moving—your real-life adventures await! Let’s GO!\r\n_______________\r\n\r\nNotes: \r\n\r\n- This app is free-to-play and offers in-game purchases. It is optimized for smartphones, not tablets.\r\n- Compatible with Android devices that have 2GB RAM or more and have Android Version 4.4–7.0+ installed.\r\n- Compatibility is not guaranteed for devices without GPS capabilities or devices that are connected only to Wi-Fi networks.\r\n- Application may not run on certain devices even if they have compatible OS versions installed.\r\n- It is recommended to play while connected to a network in order to obtain accurate location information.\r\n- Compatibility information may be changed at any time.\r\n- Please visit PokemonGO.com for additional compatibility information. \r\n- Information current as of July 11, 2019.',
#  'descriptionHTML': 'Join Trainers across the globe who are discovering Pokémon as they explore the world around them. Pokémon GO is the global gaming sensation that has been downloaded over 1 billion times and named “Best Mobile Game” by the Game Developers Choice Awards and “Best App of the Year” by TechCrunch.<br>_______________<br><br>UNCOVER THE WORLD OF POKÉMON: Explore and discover Pokémon wherever you are!<br> <br>CATCH more Pokémon to complete your Pokédex!<br> <br>JOURNEY alongside your Buddy Pokémon to help make your Pokémon stronger and earn rewards!<br><br>COMPETE in epic Gym battles and...<br><br>TEAM UP with other Trainers to catch powerful Pokémon during Raid Battles!<br> <br>It’s time to get moving—your real-life adventures await! Let’s GO!<br>_______________<br><br>Notes: <br><br>- This app is free-to-play and offers in-game purchases. It is optimized for smartphones, not tablets.<br>- Compatible with Android devices that have 2GB RAM or more and have Android Version 4.4–7.0+ installed.<br>- Compatibility is not guaranteed for devices without GPS capabilities or devices that are connected only to Wi-Fi networks.<br>- Application may not run on certain devices even if they have compatible OS versions installed.<br>- It is recommended to play while connected to a network in order to obtain accurate location information.<br>- Compatibility information may be changed at any time.<br>- Please visit PokemonGO.com for additional compatibility information. <br>- Information current as of July 11, 2019.',
#  'summary': 'Step outside and catch Pokémon in the real world! Collect & battle with others.',
#  'summaryHTML': 'Step outside and catch Pokémon in the real world! Collect &amp; battle with others.',
#  'installs': '100,000,000+',
#  'minInstalls': 100000000,
#  'score': 4.05224,
#  'ratings': 13716120,
#  'reviews': 5532222,
#  'histogram': [2065980, 457472, 850260, 1662734, 8679674],
#  'price': 0,
#  'free': True,
#  'currency': 'USD',
#  'sale': False,
#  'saleTime': None,
#  'originalPrice': None,
#  'saleText': None,
#  'offersIAP': True,
#  'inAppProductPrice': '$0.99 - $99.99 per item',
#  'size': 'Varies with device',
#  'androidVersion': '5.0',
#  'androidVersionText': '5.0 and up',
#  'developer': 'Niantic, Inc.',
#  'developerId': 'Niantic,+Inc.',
#  'developerEmail': 'pokemon-go-support@nianticlabs.com',
#  'developerWebsite': 'https://niantic.helpshift.com/a/pokemon-go/?p=web',
#  'developerAddress': 'One Ferry Building, Suite 200\nSan Francisco, CA 94111',
#  'privacyPolicy': 'https://nianticlabs.com/privacy/pokemongo/en',
#  'developerInternalID': '7632469272431224129',
#  'genre': 'Adventure',
#  'genreId': 'GAME_ADVENTURE',
#  'icon': 'https://lh3.googleusercontent.com/wPfLmWBJwsPdBhsFXc8X4QZOOvePWjoOBLFXXCwyegjRwYOuabmG5cynthlW0HDgy9s',
#  'headerImage': 'https://lh3.googleusercontent.com/KgDQ-Kjb2B7_jDP-8KmQDNhAmP2lqAV_w3zArOCBL7YZnQ02Qqp4VTlgdocO-4MFk4s',
#  'screenshots': ['https://lh3.googleusercontent.com/PbXsZpBreImadKH9ii50XTti-ykvwKBTZ9kq7CAbJdC7h7ccCbuKoJeHZu8Fc7n3oULh',
#   'https://lh3.googleusercontent.com/vnv6k22XD1tetl6U4I3pTy0iLhsISHeS-u6irGuejgPyo8OBCRUBEiGgdKI2-yS20SsD',
#   'https://lh3.googleusercontent.com/xfyqKVa_XrNI7T2sMXPqUGiiJkXDJlM4YqXQqbYunoL5w1N4qgLZLNULUzNinWEr9PY',
#   'https://lh3.googleusercontent.com/aVzE1thT4zDocUQfPP1EtPq6jS15IIdjB0b7gtLRC9v_irr6gesP5RyiNb70ljh-Max6',
#   'https://lh3.googleusercontent.com/Vek-tDWCQXnLFloZ3KFjHjSYRD5w2EMz3K0sGRhOFCIiJ2sX1prBsFKnbP_TcqGBLg'],
#  'video': 'https://www.youtube.com/embed/v4YZqOfhEc8?ps=play&vq=large&rel=0&autohide=1&showinfo=0',
#  'videoImage': 'https://i.ytimg.com/vi/v4YZqOfhEc8/hqdefault.jpg',
#  'contentRating': 'Everyone',
#  'contentRatingDescription': 'Mild Fantasy Violence',
#  'adSupported': None,
#  'containsAds': False,
#  'released': 'Jul 6, 2016',
#  'updated': 1600306219,
#  'version': '0.187.1',
#  'recentChanges': 'Trainers! There’s always something new in Pokémon GO! You can now enjoy the following:\r\n\r\n- Mega Evolution has made its way to the world of Pokémon GO! Defeat Mega-Evolved Pokémon in raids to earn Mega Energy!\r\n- Reality Blending has rolled out to more devices! With Reality Blending, Pokémon will be able to move behind objects, either partially or completely, while AR features are activated.\r\n- Personalize Gifts you send to friends! Check out the in-game store for new stickers you can send.',
#  'recentChangesHTML': 'Trainers! There’s always something new in Pokémon GO! You can now enjoy the following:<br><br>- Mega Evolution has made its way to the world of Pokémon GO! Defeat Mega-Evolved Pokémon in raids to earn Mega Energy!<br>- Reality Blending has rolled out to more devices! With Reality Blending, Pokémon will be able to move behind objects, either partially or completely, while AR features are activated.<br>- Personalize Gifts you send to friends! Check out the in-game store for new stickers you can send.',
#  'comments': ["This is a really fun game. I play it with my family whenever we would go on walks. The only problem is that the game would freeze at times, and it'd always take me a while to get back in. Another thing is that you should either let everyone have unlimited poke balls, or the pokemon never breaks free. Either one is fine, because it's so aggravating to go outside and go a far distance just to see that I have no more poke balls. You can make either thing happen, it shouldn't be that hard.",
#   "I think there should be up to 3 free passes in the span of two days. For example, you could get up to 3 free raid passes a day, but then, on the second day, you wouldn't get any. This would really improve my expierience as a f2p player, and I know I'm not alone. It is very hard for me and other f2p players to grind legendarys or even mega Pokemon, as I live in a rural area, where gyms are few and far apart. Also what I would like to see is when there is a raid hour, you get more free passes.",
#   'Been playing this game since it came out and had many issues at the launch of it. Those same issues of freezing up, heavily lagging, constant errors, to name just a few, are plaguing this game again, making it difficult to play and be competitive. So sad to see how much this game started badly and its now taking its turn back into that hole. I hope the issues are fixed soon else it may become unplayable.',
#   "The game seems fun and good, but I give it one star for all the times I have transferred a pokemon to get candy and was given nothing at all. It take long enough to try and evolve a pokemon you like without the game literally ripping you off! It's bull$*@#! I thought I was tripping but I talked to two coworkers and asked my girlfriend and they say it happens all the time. Come on!",
#   "Yall messed up the update. GO battle league is beyond broken. I thought it might be network issues but no. It doesn't matter how fast the wifi connection I use is, it always claims its weak and I have to sit and watch my pokemon get pelted, and lose over and over again. I loved this game, but I don't see the point of any of the other functions if I just can't compete in the League. 👎",
#   'I\'ve noticed the app glitches sometimes. In most cases, I can bear with the lag, but not when I can\'t get from lobby because the others players beat it before my app loads it. This results in a missed raid and I dont get the chance to catch it. In the past few weeks, the battles have been so laggy. My first pokemon is half gone before "GO" is gone and I can start attacking sometimes. Also, i dont think my attacks are all going through. Theres a steady decrease in hp of the opponent and then',
#   "Bugged. PvP is supposed to be their main core feature. But since the latest update, it is broken. You can't switch your pokemon half the time. It works fine if you roll back one version. How can you NOT qa your core feature??? Unfortunately, it is the same for most features. There are countless bugs, that makes life miserable.",
#   'As of last week I started getting a "weak connection" message in the battle league. I have confirmed that my internet connection is not the problem, and in the past I\'ve noticed this same problem with the other player, which ultimately makes you win or lose unfairly. Will reconsider rating with a better score once this issue is fixed.',
#   "Look at Edit in the end: It's a good game. I travel a lot and walk a good enough distance to work. The only thing that is so horrible is the online battles. It's impossible to have a good connection. I also think they should nerf the team rocket power. Mean now it's impossible to beat them unless you're a die heart old timer playing the game.... Edit: I tried coming back after a month break and now the game is unplayable. It lags so much. Does anyone else have this problem?",
#   'I hadn\'t played the game in years and wanted to delete my account for a fresh start. Cue me getting an email that they "cannot delete my account for legal reasons that require it to retain player activity in the U.S." I haven\'t played the game since like 2017 at the latest! What "data" are you so desperate to retain from an account that\'s been inactive for 3 years?!',
#   "It's hard to know which Pokémon you need to use in battles since you can't view their move sets when selecting your party. Also, the stats system is ruined. Legendary Pokémon stats get nerfed but yet you can't use them in gyms? Stats need to be as they are in the actual games. Rocket grunts shouldn't be able to take out my Pokémon so easily. Making it a challenge is one thing, but don't use Pokémon if you're not sticking to how Pokémon should be.",
#   "It's going so far good but when I'm doing trainer battle game sucks, no matter how many times i tap on screen my Pokemon don't do anything except for getting beaten,,,, if we are not supposed to play that features why adding that in first place. Please improve that features so that we can play overall game and if you can't then just remove that feature.",
#   'I love the game. Althought it can be very repetitive... and its easy to burn out. A huge problem im currently having is the games lack of rewards for potions... even though team rocket is forced right into your face. Potions should be more common for the amount of pokemon that die for raids, gym battles and team rocket battles... its ruining my ability to play the game as i cannot progress...',
#   "I just got today for the community day and I can't even touch the pokemon to catch or even try to access the menu I tried everything! I turned my phone off and on, nothing. I cleared cache and data, nothing. I uninstalled the game and opened again, nothing. I'm mad that there is no real way to call to get answers for this. It needs to be fixed",
#   "Fun. Wish the battle portion wasn't down or unavailable all the time. Whats going on??? Also I paid for a raid pass and got it. Was invited to a raid and we got to the battle my pokemon wouldn't attack. No matter how many times I touched the screen I couldn't attack. Was a waste of my raid pass and the money I spent to get the coins to then trade to get the pass. Was able to change pokemon but none of them would fight. Please fix your issues. I should get a refund for the .99 cent!!",
#   "Im having a problem with the incense in the last events starting in fest and still on going. The incense it works for about 30 minutes or so spawning everything, and then its just starts spawning the animation of a pokemon despaning, making the remaining time of that incense useless and make the event empty for me because I'm expecting the incense to work and in the end it dosen't. And the other thing sometimes when doing that the incense will spawn pokemon just not from the event.",
#   "While I'm still having fun with the game, stability has fallen off a cliff over the past few months. The game often freezes on a white screen when attempting an encounter, sending and receiving gifts takes forever and there are graphical glitches everywhere. Please focus on game client stability, it's beginning to become too much of a nuisance to have to deal with this all the time.",
#   "Great game but the street maps dont load for me. For me its the only thing stopping me from giving it 5 stars. Other than the traditional lag at times during raids, great game! Edit: If you have problems loading the street maps(sidewalks, terrain, etc.),go to your device settings, clear data (not cache). You will then have to re-login to POGO. Then your maps should be loaded correctly. The game will take a little longer than normal to load after you delete data. I've done this 4 times and works like a charm. I have given the 5th star for the rating, amazing game!",
#   "The game used to be great, but with the new update battling is impossible. Me and a friend could have full bars and be next to each other yet it says weak connection over and over. Raiding now is a problem because you can be kicked out halfway through, try to rejoin but it continues to say that the raid group doesn't exist. You can put in multiple tickets with Niantic but they obviously don't care because they make money either way.",
#   "Have just lost 8 battles in a row because the app keeps freezing, crashing and preventing me from attacking, blocking or switching my pokemon in the pokemon go battles. Fix this and restore my botched battle stats or I'll complain through every corner of the internet. Very angry!!! I have complained Twice today to the support centre, without answer or result.",
#   "Crashes non stop, and a Pokemon just appears and disappears non stop around me and nothing else will spawn while that's happening. It's moving around constantly so I can't catch it or even see what it is.. blocks me from catching anything else and wastes community day time cause it'll be the only thing on my screen. My kids ipads crash every time you go into the shop, friends list or medals",
#   "The Pokeball Plus is not working on a pixel 3 with the android 11 update. It's already a pain to get the pokeball to connect and work properly as it is, and now it's not working at all. Tried with 2 different pokeball plus devices and two pixel 3 phones, tried uninstalling, reinstalling, restarting, etc., and still there is no connection.",
#   "I'm having problems buying event tickets in the shop. I click on the event ticket and it takes me to a blank screen. This has happened multiple times over multiple community days. I've also wasted remote raid passes, I've used 2 and wasted them because my pokémon wouldn't attack no matter what I did. Please fix this...",
#   "June 14, 2020 - 3/5 Great game but it has some issues. Always when I'm logged out, settings are reset to defaults. Without linking account to third party services it can happened several times a day. (Even when linked it happens sometimes, probably after updates) Game is using date format (DD-MM-YYYY) and you can't change it... September 20, 2020 - 1/5 Nothing has been fixed and they introduced super annoying popups to update ARCore every time you try to catch pokemon, if camera access is disabled in system is disabled there will be two popups... - I don't use AR and never will, this popups destroyed game for me...",
#   "I love the game but I've been having issues logging in these last few days. I've had to uninstall it several times and even then its only worked twice. I also feel you should be able to increase your CP by being able to battle wild pokemon and make it easier to get items without having to use pokestops or buying them. Have random items laying around like they do with the actual game.",
#   "This game is absolutely awesome the only way it could be bad as when it says there's no signal even know inside your house and there's one more wise I said that could improve is where you're at your house and says you're going too fast and just kind of glitching all over the place but if they can fix that that's really good",
#   'Was a five star game.. And honestly if the battles didnt say week connection(with my gaming router at full bars and with my 4g data) everytime i would have kept it at five stars but ive spent hundreds on this game becaise i love playing and my money on battle passes was just a waste now. Not to mention the ar update issue.. I hope these can be corrected soon.',
#   'Update 3: still having issues after 0.187.1 Update 2: even after 0.185.3, still same issue. Update: still not working. Uninstalling. The game freezes after 10 seconds of loading I to the world!!! This has been happening for over a month. Currently using Samsung galaxy note 9 with exynos chipset. Tried reinstalling, rebooting my phone, clearing cache and data.',
#   "Trade problem My friend and I were trading gravelers ,and they were both perfect ,but I had the higher cp I got really lucky with that ,and I was happy to know he had one too but when we traded our pokemon they were demoted from 3 star to 0 star im big sad because most of my mons aren't that good anyway but the gravler was beautiful and if this is a feature just why why would you do that to me? Please fix that im really sad about it but you win some you lose some i guess :,(",
#   "Everything you go to catch a pokemon (what the game is based around) you get a pop-up saying you need to update the ar. Always leading you to the ar update page. Even if up to date the message remains. I've cleared cache and app data for both and it did nothing. It seriously hurts gameplay. Please fix this soon",
#   "I have only played this game for about 2 weeks now and I ABSOLUTELY LOVE IT! The detail when looking at your pokemon looks on point and the mechanics in general are just great. Haven't been able to play this game since it was released but I can tell you now, the 4 year wait was worth it! Also Niantic maybe add a gym pass, just like the raid pass. Would love to see that 😄👍",
#   "I love the game but when I win a raid, sometimes the game freezes not allowing me to throw the pokeballs. I would have to clear the game off with hopes of being able to get back into the raid to do the bonus stage and catch the pokemon. I've uninstalled and reinstalled the game and I still have the same problems. I would like for us to be able to do something with the shiny pokemons as well besides evolving them. I can't trade them or send them to the professor. Please update this bugs.",
#   "I've been seeing some problems with the game, lately. For one thing, when I try to throw a curveball, sometimes when I release my finger to throw, the ball goes right back to its ready position, which is getting annoying. For another, when I scroll through my Pokémon collection, it jumps further up or down than I want to go.",
#   "Still having trouble when giving berries to other pokemon in Gyms. I still don't know how to successfully give berries to all pokemon in the gym; swiping doesn't work and only after at least 10 times trying to press a pokemon and getting instead the neighbouring pokemon am i able to give the pokemon i want to give a berry. Ridiculous.",
#   'Unless you give full permission to camera the app limits what you can do. They also seem to be swamped on the support side right now. The game can be fun and it will help you get out of the house. The micro transaction currency can be earned in game but if you want to be the very best you have to pay to have the best odds of getting good raid Pokemon.',
#   "Wish they would add option to 'buy remote raid pass now' if you don't have any when trying to join a raid invite. Takes too long to close that screen, wait for it to zoom back to your avatar, open the store, scroll to the passes, purchase it, then try to get back to the raid invite before the (maybe)25 seconds is up...",
#   "Game sucks and wasted of 4 years of time, money and energy. I couldn't even catch Pokemon from the raid after won the battle. What's the purpose of having player go to raid for? Chellenge is fun but this happened too many times already! And you know what's funny? I'm at level 40 and my buddy is 28, he caught it and I didn't? And you expect 5 stars from me? That's pretty dumb and very disappointing! And your server has weak connection when I do GO battle! WEAK SIGNAL? C'MON! Have a heart!!",
#   'Ok the game is awesome i love it i play it everyday walking to parks and other places i have been going outside more and here is my problem in gyms your pokemon can earn 50 coins a day maximum and i sometime my pokemon stays in a hour after 1 day it doesnt give me my coins at all. But if its one day without one hour its good i just think its weird.',
#   "I love the game and all but since I can't progress in the game its loosing its fun, because I can't heal any of my Pokémon's without potions and its all because there isn't enough storage and I don't want to waste money on a game I like but I have no need to waste money on so what do I do ?????",
#   "I'm at level 39, nearing the maximum level of 40. I've been playing off and on since 2016. My peak activity has been within the past six months. Negatives: 1) Bugs. From raids to PVP battles, I've lost many, many rewards due to some sort of technical error. 2) Support. I don't always receive thoughtful replies to my concerns. I make a lot of purchases in the app and I feel like the care isn't consistently given to me as a customer. Positives: 1) It's pretty fun. 2) The game keeps evolving! :)"],
#  'appId': 'com.nianticlabs.pokemongo',
#  'url': 'https://play.google.com/store/apps/details?id=com.nianticlabs.pokemongo&hl=en&gl=us'}

# %%
# Checking which keys I want to keep to use as features.

result.keys()
# Out:
# dict_keys(['title', 'description', 'descriptionHTML', 'summary', 'summaryHTML', 'installs', 'minInstalls', 'score', 'ratings', 'reviews', 'histogram', 'price', 'free', 'currency', 'sale', 'saleTime', 'originalPrice', 'saleText', 'offersIAP', 'inAppProductPrice', 'size', 'androidVersion', 'androidVersionText', 'developer', 'developerId', 'developerEmail', 'developerWebsite', 'developerAddress', 'privacyPolicy', 'developerInternalID', 'genre', 'genreId', 'icon', 'headerImage', 'screenshots', 'video', 'videoImage', 'contentRating', 'contentRatingDescription', 'adSupported', 'containsAds', 'released', 'updated', 'version', 'recentChanges', 'recentChangesHTML', 'comments', 'appId', 'url'])

# %%
featurekeys = ['title', 'installs', 'minInstalls', 'score', 'ratings', 'reviews', 'histogram', 'price', 'free', 'offersIAP', 'size', 'genre', 'genreId', 'released', 'contentRating']

# %%
# Filtering dictionary so I only get results I want.

filteredresult = dict((k, result[k]) for k in featurekeys if k in result)
filteredresult
# Out:
# {'title': 'Pokémon GO',
#  'installs': '100,000,000+',
#  'minInstalls': 100000000,
#  'score': 4.05224,
#  'ratings': 13716120,
#  'reviews': 5532222,
#  'histogram': [2065980, 457472, 850260, 1662734, 8679674],
#  'price': 0,
#  'free': True,
#  'offersIAP': True,
#  'size': 'Varies with device',
#  'genre': 'Adventure',
#  'genreId': 'GAME_ADVENTURE',
#  'released': 'Jul 6, 2016',
#  'contentRating': 'Everyone'}

# %%
# Now to make a function that does all of the above

def givemeinfo(appid):
    result = app(
    appid,
    lang='en',
    country='us')
    
    featurekeys = ['title', 'installs', 'minInstalls', 'score', 'ratings', 'reviews', 'histogram', 'price', 'free', 'offersIAP', 'size', 'genre', 'genreId', 'released', 'contentRating']
    
    filteredresult = dict((k, result[k]) for k in featurekeys if k in result)
    
    return filteredresult

# %%
# 1000 entries takes about 5 minutes.
# Doing it in pieces in case there is an error somewhere.

listofdictinfo = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[:1000]))
listofdictinfo
# Out:
# [{'title': 'Among Us',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.474048,
#   'ratings': 2132693,
#   'reviews': 1101564,
#   'histogram': [154333, 39857, 89011, 206765, 1642727],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 15, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Scribble Rider',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.8843145,
#   'ratings': 219513,
#   'reviews': 91620,
#   'histogram': [39359, 11409, 15784, 21673, 131288],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '123M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 23, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Call of Duty®: Mobile',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.4783134,
#   'ratings': 10757089,
#   'reviews': 4953322,
#   'histogram': [783831, 203300, 401111, 1064381, 8304466],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '94M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 30, 2019',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Hitmasters',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.090488,
#   'ratings': 280248,
#   'reviews': 98967,
#   'histogram': [39272, 10530, 17919, 30372, 182155],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '85M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Draw Defence',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.91,
#   'ratings': 1080,
#   'reviews': 425,
#   'histogram': [227, 21, 54, 97, 681],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '76M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Sniper 3D: Fun Free Online FPS Shooting Game',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.379428,
#   'ratings': 13511800,
#   'reviews': 4727488,
#   'histogram': [836062, 308989, 964042, 2185740, 9216967],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 13, 2014',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Smashy Road: Wanted 2',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.1657305,
#   'ratings': 3679,
#   'reviews': 1643,
#   'histogram': [299, 124, 372, 754, 2130],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '119M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'aquapark.io',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 3.946079,
#   'ratings': 1048102,
#   'reviews': 491659,
#   'histogram': [172476, 49435, 76327, 113752, 636112],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '79M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 14, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'slither.io',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.059621,
#   'ratings': 6283044,
#   'reviews': 2609762,
#   'histogram': [842235, 250206, 498604, 791673, 3900326],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 25, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Garena Free Fire: 3volution',
#   'installs': '500,000,000+',
#   'minInstalls': 500000000,
#   'score': 4.0465617,
#   'ratings': 63024309,
#   'reviews': 38262571,
#   'histogram': [11273044, 1912209, 2706676, 3847612, 43284768],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '46M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 7, 2017',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Kick the Buddy',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 3.9639745,
#   'ratings': 2836222,
#   'reviews': 1222887,
#   'histogram': [489959, 120253, 187258, 243285, 1795467],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 22, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Samurai Flash',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9987307,
#   'ratings': 32047,
#   'reviews': 11810,
#   'histogram': [4617, 1749, 2471, 3427, 19783],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '59M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 23, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Johnny Trigger - Sniper Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2502513,
#   'ratings': 70353,
#   'reviews': 24487,
#   'histogram': [5808, 2171, 6050, 10899, 45425],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '74M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 29, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Swipe Fight!',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.86,
#   'ratings': 305,
#   'reviews': 128,
#   'histogram': [55, 15, 30, 21, 184],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '87M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 11, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Mario Kart Tour',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.0398498,
#   'ratings': 1804785,
#   'reviews': 821500,
#   'histogram': [258801, 68898, 120434, 250095, 1106557],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '126M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 24, 2019',
#   'contentRating': 'Everyone'},
#  {'title': '1v1.LOL - Online Building & Shooting Simulator',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.139084,
#   'ratings': 124909,
#   'reviews': 67574,
#   'histogram': [15274, 4338, 9645, 14134, 81518],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 1, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Slice them All! 3D',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.8817022,
#   'ratings': 12400,
#   'reviews': 2156,
#   'histogram': [2089, 580, 1256, 1256, 7219],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '78M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 19, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Fan of Guns',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.1575565,
#   'ratings': 89167,
#   'reviews': 52844,
#   'histogram': [11074, 2723, 5828, 10994, 58548],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 29, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Hunter Assassin',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.1811147,
#   'ratings': 1259612,
#   'reviews': 514968,
#   'histogram': [140928, 47468, 89615, 146129, 835472],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Oct 9, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Spider Rope Hero - Vegas Crime city',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.6957405,
#   'ratings': 5137,
#   'reviews': 2190,
#   'histogram': [1365, 177, 229, 250, 3116],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '80M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 9, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Supreme Duelist Stickman',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.3562512,
#   'ratings': 455371,
#   'reviews': 225973,
#   'histogram': [39105, 12032, 26288, 48049, 329897],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '32M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 16, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'PUBG MOBILE - NEW ERA',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.181501,
#   'ratings': 32705756,
#   'reviews': 15727032,
#   'histogram': [4957891, 795922, 1241010, 2068273, 23642660],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Draw Joust!',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.001171,
#   'ratings': 146261,
#   'reviews': 52811,
#   'histogram': [21299, 7203, 12120, 15042, 90597],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 7, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Traffic Run!',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.066528,
#   'ratings': 207430,
#   'reviews': 83013,
#   'histogram': [25417, 10893, 16867, 25548, 128705],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Brawl Stars',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.2763553,
#   'ratings': 13796763,
#   'reviews': 7795996,
#   'histogram': [1683057, 299680, 585851, 1180986, 10047189],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '149M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 12, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Talking Tom Hero Dash - Run Game',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.2567043,
#   'ratings': 629261,
#   'reviews': 301615,
#   'histogram': [72536, 20441, 31633, 52991, 451660],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '91M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Pocket Sniper!',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.474037,
#   'ratings': 6072,
#   'reviews': 1926,
#   'histogram': [1302, 600, 803, 651, 2716],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '68M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 8, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Dude Theft Wars: Open World Sandbox Simulator BETA',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.210153,
#   'ratings': 322248,
#   'reviews': 173544,
#   'histogram': [39775, 9926, 17557, 30533, 224457],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '97M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 8, 2018',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Bowmasters',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.5153155,
#   'ratings': 4594790,
#   'reviews': 2147708,
#   'histogram': [276757, 83973, 213208, 441656, 3579196],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 10, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'NERF Epic Pranks!',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.086793,
#   'ratings': 106949,
#   'reviews': 45964,
#   'histogram': [14767, 4802, 7002, 10186, 70192],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '135M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 9, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Johnny Trigger - Action Shooting Game',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3011575,
#   'ratings': 1267190,
#   'reviews': 486768,
#   'histogram': [111323, 37651, 85707, 155904, 876605],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '100M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 13, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Talking Tom Gold Run',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3697796,
#   'ratings': 4214464,
#   'reviews': 1799820,
#   'histogram': [384138, 108663, 200652, 392190, 3128821],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '90M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 13, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Snake.io - Fun Addicting Arcade Battle .io Games',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.145872,
#   'ratings': 290121,
#   'reviews': 137615,
#   'histogram': [38389, 10245, 17294, 28917, 195276],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '33M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 14, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Stealth Master - Assassin Ninja Game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.0701013,
#   'ratings': 31096,
#   'reviews': 9923,
#   'histogram': [3589, 1429, 2991, 4289, 18798],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '71M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 22, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Bullet Rush!',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.842427,
#   'ratings': 21520,
#   'reviews': 6078,
#   'histogram': [3563, 1235, 2115, 2723, 11884],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '43M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 2, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Slap Kings',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.1962314,
#   'ratings': 647139,
#   'reviews': 232309,
#   'histogram': [67733, 23185, 46611, 86439, 423171],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '92M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Feb 25, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Tomb of the Mask',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3231797,
#   'ratings': 1261721,
#   'reviews': 606091,
#   'histogram': [109977, 36067, 74401, 157044, 884232],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '62M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 19, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'FRAG Pro Shooter',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3650136,
#   'ratings': 701374,
#   'reviews': 379962,
#   'histogram': [62959, 18379, 36356, 65674, 518006],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '100M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 5, 2019',
#   'contentRating': 'Teen'},
#  {'title': "Knock'em All",
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2955184,
#   'ratings': 164092,
#   'reviews': 58641,
#   'histogram': [14376, 4842, 9945, 23678, 111251],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': "Hide 'N Seek!",
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0238075,
#   'ratings': 113612,
#   'reviews': 45355,
#   'histogram': [15058, 5884, 9668, 13685, 69317],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '72M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 23, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'War Machines: Tank Battle - Army & Military Games',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.0888257,
#   'ratings': 1025975,
#   'reviews': 352964,
#   'histogram': [119047, 39628, 86960, 165847, 614493],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '84M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 16, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Super Mario Run',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 3.6733491,
#   'ratings': 1514594,
#   'reviews': 645319,
#   'histogram': [334900, 84937, 128907, 157112, 808738],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 22, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Agar.io',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 3.9792123,
#   'ratings': 4029094,
#   'reviews': 1345611,
#   'histogram': [677803, 135812, 281520, 431161, 2502798],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '37M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 8, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Zooba: Free-for-all Zoo Combat Battle Royale Games',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2260933,
#   'ratings': 555378,
#   'reviews': 277550,
#   'histogram': [62292, 17572, 34954, 58016, 382544],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '157M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Oct 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Netboom -Play Cloud Gaming',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.8663492,
#   'ratings': 35964,
#   'reviews': 27239,
#   'histogram': [9251, 614, 715, 493, 24891],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '18M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 6, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Miraculous Ladybug & Cat Noir',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.277721,
#   'ratings': 690001,
#   'reviews': 357470,
#   'histogram': [78782, 21328, 31551, 56156, 502184],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '49M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 24, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'I, The One - Action Fighting Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1894817,
#   'ratings': 77217,
#   'reviews': 31849,
#   'histogram': [9774, 2640, 4393, 6781, 53629],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '44M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 10, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Archero',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.457535,
#   'ratings': 1336392,
#   'reviews': 515701,
#   'histogram': [77606, 26329, 73049, 189434, 969974],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '104M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 18, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Protect the VIP',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.8372881,
#   'ratings': 6141,
#   'reviews': 1921,
#   'histogram': [1124, 333, 510, 624, 3550],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '77M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 22, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Pixel Gun 3D: FPS Shooter & Battle Royale',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.150195,
#   'ratings': 5519273,
#   'reviews': 2806722,
#   'histogram': [762473, 177049, 303983, 501296, 3774472],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '91M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Feb 21, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Archer Hero 3D',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.008346,
#   'ratings': 13576,
#   'reviews': 5266,
#   'histogram': [1792, 721, 1102, 1926, 8035],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '60M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 12, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Bed Wars',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.264458,
#   'ratings': 540258,
#   'reviews': 303379,
#   'histogram': [64016, 14030, 25630, 47966, 388616],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '127M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 6, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Curvy Punch 3D',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.4858532,
#   'ratings': 22931,
#   'reviews': 9669,
#   'histogram': [5657, 1784, 2321, 2098, 11071],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '78M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 25, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Snowball.io',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0957813,
#   'ratings': 252346,
#   'reviews': 121523,
#   'histogram': [30170, 10735, 21942, 31404, 158095],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 29, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Hurricane Superhero : Wind Tornado Vegas Mafia',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.995041,
#   'ratings': 34752,
#   'reviews': 14691,
#   'histogram': [6011, 1490, 1987, 2433, 22831],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '139M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 3, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Modern Ops - Online FPS (Gun Games Shooter)',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4289846,
#   'ratings': 544210,
#   'reviews': 260549,
#   'histogram': [41009, 11493, 26286, 59663, 405759],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '54M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Crossy Road',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.555462,
#   'ratings': 4428545,
#   'reviews': 1418053,
#   'histogram': [193863, 60618, 222439, 566468, 3385157],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '77M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 7, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Last Day on Earth: Survival',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.3252273,
#   'ratings': 3888679,
#   'reviews': 1962946,
#   'histogram': [340864, 110224, 214598, 500646, 2722347],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 24, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Temple Run 2',
#   'installs': '500,000,000+',
#   'minInstalls': 500000000,
#   'score': 4.2260504,
#   'ratings': 9334443,
#   'reviews': 2607602,
#   'histogram': [1024774, 316759, 595568, 983880, 6413462],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 23, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Marvel Contest of Champions',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.2595973,
#   'ratings': 3030323,
#   'reviews': 1028591,
#   'histogram': [320312, 81063, 167112, 384996, 2076840],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '97M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 10, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Tomb of the Mask: Color',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.230219,
#   'ratings': 119412,
#   'reviews': 44081,
#   'histogram': [12996, 4221, 7428, 12413, 82354],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Oct 14, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Murder Hornet',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.8471112,
#   'ratings': 22674,
#   'reviews': 9094,
#   'histogram': [4394, 1249, 1461, 1894, 13676],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '124M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 24, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'War Robots Multiplayer Battles',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.166083,
#   'ratings': 4092634,
#   'reviews': 1778396,
#   'histogram': [532193, 129603, 224523, 446288, 2760027],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '78M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 26, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Run Royale 3D',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.17,
#   'ratings': 925,
#   'reviews': 440,
#   'histogram': [111, 27, 55, 129, 603],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '65M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Football Field Kick',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.344598,
#   'ratings': 22588,
#   'reviews': 7966,
#   'histogram': [1396, 773, 1838, 3224, 15357],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Feb 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Rope Hero: Vice Town',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.131836,
#   'ratings': 822330,
#   'reviews': 330623,
#   'histogram': [116261, 30761, 45483, 65622, 564203],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '90M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 14, 2016',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Beat the Boss 4: Stress-Relief Game. Hit the buddy',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.065804,
#   'ratings': 335449,
#   'reviews': 121973,
#   'histogram': [45615, 13865, 27077, 35165, 213727],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '160M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 23, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Worms Zone .io - Voracious Snake',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.30585,
#   'ratings': 1610602,
#   'reviews': 774803,
#   'histogram': [151501, 49865, 98707, 164983, 1145546],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '29M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 2, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Mobile Legends: Bang Bang',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.1405125,
#   'ratings': 22256120,
#   'reviews': 11149929,
#   'histogram': [3212395, 650893, 1118330, 2089932, 15184570],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '99M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Oct 31, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Golf Hit',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.059096,
#   'ratings': 28222,
#   'reviews': 9626,
#   'histogram': [2381, 1306, 3757, 5596, 15182],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 29, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Neon Iron Stickman Rope Hero City Gangstar Mafia',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0690556,
#   'ratings': 27174,
#   'reviews': 16095,
#   'histogram': [4179, 1034, 1420, 2637, 17904],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 26, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Stickman Warriors - Super Dragon Shadow Fight',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.583233,
#   'ratings': 150804,
#   'reviews': 72811,
#   'histogram': [8327, 2318, 5696, 11191, 123272],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '87M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 8, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'StrikeFortressBox',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3138194,
#   'ratings': 46472,
#   'reviews': 22437,
#   'histogram': [5138, 1324, 1921, 3519, 34570],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '67M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 22, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Hide Online - Hunters vs Props',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.093869,
#   'ratings': 998283,
#   'reviews': 470316,
#   'histogram': [123728, 38409, 78813, 136808, 620525],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Dinosaur Rampage',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.372508,
#   'ratings': 48033,
#   'reviews': 20767,
#   'histogram': [4294, 1532, 2288, 3790, 36129],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Offline Shooting: DEAD TARGET- Free Zombie Games',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.4670696,
#   'ratings': 1874914,
#   'reviews': 702323,
#   'histogram': [118511, 43039, 100024, 195988, 1417352],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 16, 2014',
#   'contentRating': 'Mature 17+'},
#  {'title': 'World War Heroes: WW2 FPS',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.429087,
#   'ratings': 1963254,
#   'reviews': 839146,
#   'histogram': [158213, 46097, 88465, 172770, 1497709],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 22, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Cover Fire: Offline Shooting Games',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.4708223,
#   'ratings': 1786994,
#   'reviews': 698960,
#   'histogram': [116580, 36491, 84590, 200660, 1348673],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 30, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'DRAGON BALL LEGENDS',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4695873,
#   'ratings': 992167,
#   'reviews': 490551,
#   'histogram': [64085, 20587, 46393, 115368, 745734],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '96M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 17, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Brawlhalla',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.2490907,
#   'ratings': 91428,
#   'reviews': 40928,
#   'histogram': [8797, 2710, 6409, 12515, 60997],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 4, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Dead by Daylight Mobile',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.1431003,
#   'ratings': 159082,
#   'reviews': 77544,
#   'histogram': [16624, 5959, 13022, 25895, 97582],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 15, 2020',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Otherworld Legends',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.339133,
#   'ratings': 34943,
#   'reviews': 19195,
#   'histogram': [1927, 1205, 2906, 5956, 22949],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '62M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 19, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Mask of Stick: Superhero',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.5082507,
#   'ratings': 3082,
#   'reviews': 1373,
#   'histogram': [234, 30, 152, 183, 2483],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 2, 2020',
#   'contentRating': 'Teen'},
#  {'title': "Push'em all",
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 3.9696789,
#   'ratings': 184008,
#   'reviews': 62837,
#   'histogram': [27385, 9041, 15162, 22598, 109822],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '46M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Sniper Zombies: Offline Game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.439596,
#   'ratings': 34008,
#   'reviews': 10393,
#   'histogram': [2533, 858, 1453, 3442, 25722],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '169M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 16, 2020',
#   'contentRating': 'Mature 17+'},
#  {'title': "Chuck E.'s Skate Universe",
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.313466,
#   'ratings': 98820,
#   'reviews': 22258,
#   'histogram': [11156, 2512, 4633, 6412, 74107],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '44M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 29, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Stickman Battle',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.110586,
#   'ratings': 42610,
#   'reviews': 18278,
#   'histogram': [5598, 2154, 2789, 3463, 28606],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 6, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Black Hole Hero : Vice Vegas Rope Mafia',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.023313,
#   'ratings': 73795,
#   'reviews': 31443,
#   'histogram': [11891, 3359, 4513, 5404, 48628],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '130M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 29, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Stick Warfare: Blood Strike',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.2641306,
#   'ratings': 9471,
#   'reviews': 4510,
#   'histogram': [813, 360, 648, 1338, 6312],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 10, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Gun Gang',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.3107276,
#   'ratings': 8287,
#   'reviews': 2959,
#   'histogram': [2688, 459, 449, 971, 3720],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '82M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 8, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Truck Driver City Crush',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.074579,
#   'ratings': 126159,
#   'reviews': 55173,
#   'histogram': [19536, 5260, 6636, 9550, 85177],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '94M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 17, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Exploration Lite Craft',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.8389516,
#   'ratings': 301584,
#   'reviews': 130157,
#   'histogram': [59226, 14149, 21386, 28028, 178795],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '15M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 1, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'MORTAL KOMBAT',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.1973867,
#   'ratings': 4019713,
#   'reviews': 1609045,
#   'histogram': [473850, 132286, 244119, 445777, 2723681],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 4, 2015',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Helix Jump',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.0603323,
#   'ratings': 4235981,
#   'reviews': 1778039,
#   'histogram': [565492, 174727, 330135, 533995, 2631632],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 12, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Real Time Shields',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.7147622,
#   'ratings': 12270,
#   'reviews': 3086,
#   'histogram': [2241, 818, 1412, 1525, 6274],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '109M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 27, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'The Survival Hunter Games 2',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9077623,
#   'ratings': 216849,
#   'reviews': 81207,
#   'histogram': [40033, 10363, 13482, 18663, 134308],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '131M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 9, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Real Gangster Crime',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.085054,
#   'ratings': 771410,
#   'reviews': 304147,
#   'histogram': [117265, 28367, 44725, 62187, 518866],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '100M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 31, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Upstream Struggle',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.65,
#   'ratings': 258,
#   'reviews': 157,
#   'histogram': [13, 2, 2, 26, 215],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 5, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Gangstar Vegas: World of Crime',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.289243,
#   'ratings': 5972163,
#   'reviews': 2613626,
#   'histogram': [653855, 153626, 297937, 572580, 4294165],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 19, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Diableros: Zombie RPG Shooter',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.8058252,
#   'ratings': 103,
#   'reviews': 50,
#   'histogram': [25, 2, 2, 13, 61],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '85M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 31, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Robbery.io',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5057473,
#   'ratings': 87,
#   'reviews': 29,
#   'histogram': [5, 1, 6, 8, 67],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Bed Diving',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.172131,
#   'ratings': 1269,
#   'reviews': 514,
#   'histogram': [437, 114, 83, 62, 573],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '66M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 3, 2020',
#   'contentRating': 'Everyone'},
#  {'title': '🐓Chicken Gun🐓',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.365416,
#   'ratings': 74089,
#   'reviews': 39770,
#   'histogram': [7322, 2044, 2820, 5952, 55951],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '73M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Feb 19, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Shadow Fight 2',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.5733514,
#   'ratings': 13332533,
#   'reviews': 4808509,
#   'histogram': [826643, 199104, 422586, 939248, 10944952],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '145M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 22, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Bullet Echo',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.1954875,
#   'ratings': 76043,
#   'reviews': 31146,
#   'histogram': [7377, 2896, 5379, 12221, 48170],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '98M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 21, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Stickman 3D - Street Gangster - Street Gangs',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.450893,
#   'ratings': 2384,
#   'reviews': 742,
#   'histogram': [170, 53, 127, 213, 1821],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Stick Fight: The Game Mobile',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.966894,
#   'ratings': 123829,
#   'reviews': 58252,
#   'histogram': [18880, 5486, 10369, 15212, 73882],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 16, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Sonic the Hedgehog™ Classic',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.132171,
#   'ratings': 222351,
#   'reviews': 107067,
#   'histogram': [30654, 7623, 12946, 21584, 149544],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '63M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 21, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Creative Destruction',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1500473,
#   'ratings': 1167115,
#   'reviews': 673536,
#   'histogram': [163887, 34276, 63191, 107230, 798531],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '74M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 19, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Rage Road',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.01216,
#   'ratings': 58607,
#   'reviews': 20585,
#   'histogram': [7468, 3131, 5741, 7146, 35121],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '76M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 26, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Anger of stick 5 : zombie',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3032002,
#   'ratings': 1065784,
#   'reviews': 450402,
#   'histogram': [106054, 32766, 62462, 95198, 769304],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '33M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 8, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'LegendArya',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.01,
#   'ratings': 113,
#   'reviews': 76,
#   'histogram': [10, 12, 10, 13, 68],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '95M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 9, 2020',
#   'contentRating': 'Teen'},
#  {'title': "Archer's Tale - Adventures of Rogue Archer",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.39172,
#   'ratings': 3302,
#   'reviews': 782,
#   'histogram': [231, 84, 147, 536, 2304],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '93M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 26, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Crowd Bomber',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 2.9268293,
#   'ratings': 1656,
#   'reviews': 660,
#   'histogram': [566, 192, 212, 171, 515],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 24, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Desert Riders',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.234745,
#   'ratings': 44144,
#   'reviews': 13706,
#   'histogram': [3628, 1839, 4131, 5488, 29058],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 28, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'NARUTO X BORUTO NINJA VOLTAGE',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9474807,
#   'ratings': 644976,
#   'reviews': 338018,
#   'histogram': [112926, 26571, 42771, 61889, 400819],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '78M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 21, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Fps Robot Shooting Games – Counter Terrorist Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4539075,
#   'ratings': 21850,
#   'reviews': 13776,
#   'histogram': [1850, 726, 715, 920, 17639],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 1, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'MaskGun Multiplayer FPS - Free Shooting Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.203501,
#   'ratings': 445862,
#   'reviews': 255819,
#   'histogram': [53715, 13953, 25476, 47456, 305262],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 15, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Spider Hero: Superhero Fighting',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.880015,
#   'ratings': 27272,
#   'reviews': 11628,
#   'histogram': [5339, 1084, 1843, 2249, 16757],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '146M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 21, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Stick Fight Online: Multiplayer Stickman Battle',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4569297,
#   'ratings': 118736,
#   'reviews': 60671,
#   'histogram': [8696, 2186, 5733, 11669, 90452],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '37M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 8, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Garfield™ Rush',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2649903,
#   'ratings': 31542,
#   'reviews': 12664,
#   'histogram': [3386, 1250, 1555, 2776, 22575],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '77M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 22, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Food Gang',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.9281712,
#   'ratings': 19837,
#   'reviews': 10398,
#   'histogram': [2961, 1010, 1900, 2587, 11379],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '30M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 29, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Robotics!',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.707331,
#   'ratings': 35113,
#   'reviews': 16394,
#   'histogram': [6224, 2524, 3992, 4937, 17436],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '106M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Snow Storm Superhero',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.042105,
#   'ratings': 10705,
#   'reviews': 4626,
#   'histogram': [1813, 368, 584, 727, 7213],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '156M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 14, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Crowd Master 3D',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.9815125,
#   'ratings': 12075,
# ...
#   'ratings': 18621,
#   'reviews': 6211,
#   'histogram': [471, 300, 631, 1835, 15384],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '38M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 23, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'The Impossible Game',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.9473996,
#   'ratings': 20039,
#   'reviews': 3641,
#   'histogram': [3269, 793, 1610, 2416, 11951],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 25, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Dungeon Village',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.606753,
#   'ratings': 13309,
#   'reviews': 3432,
#   'histogram': [383, 198, 634, 1837, 10257],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 2, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'METAL SLUG 3',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.967678,
#   'ratings': 15937,
#   'reviews': 6489,
#   'histogram': [2407, 830, 1156, 2018, 9526],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 11, 2012',
#   'contentRating': 'Teen'},
#  {'title': "THE KING OF FIGHTERS '97",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.3865495,
#   'ratings': 15940,
#   'reviews': 5778,
#   'histogram': [1272, 440, 741, 1883, 11604],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 13, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'M64Plus FZ Pro Emulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.49,
#   'ratings': 183,
#   'reviews': 99,
#   'histogram': [9, 7, 7, 20, 140],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.4M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 22, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Granny Smith',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.693646,
#   'ratings': 43175,
#   'reviews': 19279,
#   'histogram': [1796, 310, 1094, 2923, 37052],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 29, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'VGBAnext - Universal Console Emulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2982454,
#   'ratings': 1143,
#   'reviews': 643,
#   'histogram': [100, 40, 70, 140, 793],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 19, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'JCheater: Vice City Edition',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.2322738,
#   'ratings': 4100,
#   'reviews': 1689,
#   'histogram': [1454, 160, 310, 331, 1845],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.7M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 2, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Marvel Pinball',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.7296417,
#   'ratings': 9242,
#   'reviews': 2586,
#   'histogram': [1806, 582, 702, 1365, 4787],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 6, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Sonic Jump Pro',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.830819,
#   'ratings': 9376,
#   'reviews': 4140,
#   'histogram': [2213, 222, 272, 899, 5770],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 21, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'FINAL FANTASY II',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.4790998,
#   'ratings': 3124,
#   'reviews': 1228,
#   'histogram': [713, 201, 341, 613, 1256],
#   'price': 7.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 20, 2012',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Nostalgia.NES Pro (NES Emulator)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.6065574,
#   'ratings': 2460,
#   'reviews': 905,
#   'histogram': [121, 40, 60, 242, 1997],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.7M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 26, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Balance The Beam 2.0',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'GBA.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.564815,
#   'ratings': 1454,
#   'reviews': 662,
#   'histogram': [80, 40, 67, 53, 1214],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 21, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'holedown',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.371901,
#   'ratings': 1220,
#   'reviews': 511,
#   'histogram': [10, 60, 151, 242, 757],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 25, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Double Dragon Trilogy',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.160274,
#   'ratings': 7346,
#   'reviews': 2273,
#   'histogram': [684, 392, 614, 1026, 4630],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.6M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 4, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'METAL SLUG',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8458843,
#   'ratings': 5737,
#   'reviews': 2307,
#   'histogram': [954, 311, 542, 784, 3146],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 19, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'ARC Browser',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.23,
#   'ratings': 458,
#   'reviews': 328,
#   'histogram': [46, 13, 36, 55, 308],
#   'price': 8.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '17M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 26, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'SWORDSHOT',
#   'installs': '50+',
#   'minInstalls': 50,
#   'score': 4.6666665,
#   'ratings': 15,
#   'reviews': 11,
#   'histogram': [1, 0, 0, 1, 13],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 16, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Shopkins Run!',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.46,
#   'ratings': 181,
#   'reviews': 117,
#   'histogram': [38, 16, 25, 27, 75],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 21, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Hyperforma Premium',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.75,
#   'ratings': 32,
#   'reviews': 27,
#   'histogram': [2, 0, 0, 0, 30],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '33M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 6, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Retro8 (NES Emulator)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.72,
#   'ratings': 853,
#   'reviews': 608,
#   'histogram': [179, 17, 136, 51, 470],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 7, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Atomic Bomber Full',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.4928827,
#   'ratings': 9475,
#   'reviews': 2598,
#   'histogram': [556, 168, 455, 1163, 7133],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.6M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 29, 2010',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Pizza Boy GBC Pro',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.68,
#   'ratings': 391,
#   'reviews': 269,
#   'histogram': [15, 0, 7, 47, 322],
#   'price': 4.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '11M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 27, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'SAMURAI SHODOWN II',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2686834,
#   'ratings': 5645,
#   'reviews': 2267,
#   'histogram': [512, 221, 311, 793, 3808],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.8M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 28, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Mupen64Plus AE (N64 Emulator)',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.4527845,
#   'ratings': 4817,
#   'reviews': 1984,
#   'histogram': [1178, 350, 548, 595, 2146],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 18, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Yaba Sanshiro Pro - Sega Saturn Emulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.19,
#   'ratings': 210,
#   'reviews': 152,
#   'histogram': [12, 10, 25, 38, 125],
#   'price': 5.6,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'GBC.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.51,
#   'ratings': 1034,
#   'reviews': 435,
#   'histogram': [62, 20, 51, 93, 808],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 23, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'The World Ends With You',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.7336154,
#   'ratings': 4738,
#   'reviews': 1443,
#   'histogram': [110, 60, 130, 380, 4058],
#   'price': 17.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 25, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'SPACE INVADERS',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.59,
#   'ratings': 208,
#   'reviews': 129,
#   'histogram': [6, 8, 4, 27, 163],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 10, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Robo Defense',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.178641,
#   'ratings': 66712,
#   'reviews': 15579,
#   'histogram': [7772, 3238, 3627, 6736, 45339],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': None,
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Danmaku Unlimited 3',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.21,
#   'ratings': 248,
#   'reviews': 134,
#   'histogram': [27, 5, 22, 27, 167],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '80M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 9, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'R-TYPE',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.671916,
#   'ratings': 8472,
#   'reviews': 3298,
#   'histogram': [200, 111, 233, 1178, 6750],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 12, 2011',
#   'contentRating': 'Everyone'},
#  {'title': "Ghosts'n Goblins MOBILE",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.17,
#   'ratings': 905,
#   'reviews': 537,
#   'histogram': [108, 9, 90, 108, 590],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'METAL SLUG 2',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 2.9575071,
#   'ratings': 3541,
#   'reviews': 1596,
#   'histogram': [1264, 421, 321, 271, 1264],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 6, 2013',
#   'contentRating': 'Teen'},
#  {'title': "Ghouls'n Ghosts MOBILE",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.96,
#   'ratings': 327,
#   'reviews': 216,
#   'histogram': [29, 26, 49, 46, 177],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '49M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 17, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'METAL SLUG X',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.3120916,
#   'ratings': 6146,
#   'reviews': 2840,
#   'histogram': [1567, 713, 683, 602, 2581],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 6, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'PCE.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.28,
#   'ratings': 918,
#   'reviews': 431,
#   'histogram': [101, 36, 18, 110, 653],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 27, 2010',
#   'contentRating': 'Everyone'},
#  {'title': '2600.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.24,
#   'ratings': 603,
#   'reviews': 248,
#   'histogram': [78, 12, 24, 60, 429],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 3, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'NEO.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.43,
#   'ratings': 1156,
#   'reviews': 731,
#   'histogram': [335, 46, 104, 127, 544],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 14, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Miner Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.0419846,
#   'ratings': 2632,
#   'reviews': 535,
#   'histogram': [311, 110, 251, 442, 1518],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '27M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 3, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Death Worm™',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.9320755,
#   'ratings': 7981,
#   'reviews': 1803,
#   'histogram': [1235, 331, 632, 1325, 4458],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '17M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 21, 2011',
#   'contentRating': 'Teen'},
#  {'title': 'Sky Gamblers: Storm Raiders',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.357444,
#   'ratings': 14273,
#   'reviews': 4437,
#   'histogram': [1222, 451, 611, 1704, 10285],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '10M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 22, 2014',
#   'contentRating': 'Everyone 10+'}]

# %%
len(listofdictinfo)
# Out:
# 1000

# %%
listofdictinfo2 = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[1001:2001]))
listofdictinfo2
# Out:
# [{'title': 'WorldCraft Premium: Mine & Craft',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.09,
#   'ratings': 126,
#   'reviews': 83,
#   'histogram': [43, 7, 16, 14, 46],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '78M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 24, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Sky Gamblers: Storm Raiders 2',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.36,
#   'ratings': 122,
#   'reviews': 97,
#   'histogram': [27, 13, 18, 16, 48],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '81M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 3, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Nostalgia.GBA Pro (GBA Emulator)',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.66,
#   'ratings': 108,
#   'reviews': 55,
#   'histogram': [4, 0, 5, 8, 91],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.2M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Space Shooter: Alien vs Galaxy Attack (Premium)',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.8923852,
#   'ratings': 15982,
#   'reviews': 6181,
#   'histogram': [2816, 734, 1378, 1478, 9576],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '108M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 17, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Ordia',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.78,
#   'ratings': 424,
#   'reviews': 184,
#   'histogram': [0, 8, 8, 51, 357],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Star Wars™ Pinball 7',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.5507338,
#   'ratings': 15735,
#   'reviews': 5913,
#   'histogram': [3866, 883, 1235, 2219, 7532],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 27, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'N64 Retro+',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 2.5454545,
#   'ratings': 22,
#   'reviews': 12,
#   'histogram': [12, 1, 1, 1, 7],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '18M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 29, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'The Impossible Game Level Pack',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.179348,
#   'ratings': 6530,
#   'reviews': 1147,
#   'histogram': [840, 224, 319, 686, 4461],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 15, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Defender 1',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 2.935484,
#   'ratings': 31,
#   'reviews': 22,
#   'histogram': [9, 3, 7, 5, 7],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.6M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 5, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Ninja Village',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.575296,
#   'ratings': 5952,
#   'reviews': 868,
#   'histogram': [282, 100, 221, 654, 4695],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 24, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'GAROU: MARK OF THE WOLVES',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.653595,
#   'ratings': 3068,
#   'reviews': 1190,
#   'histogram': [60, 30, 120, 491, 2367],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.1M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 19, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Delver',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.9662027,
#   'ratings': 5691,
#   'reviews': 2101,
#   'histogram': [599, 316, 849, 837, 3090],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 20, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'Galaxy Attack: Alien Shooter (Premium)',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.3168044,
#   'ratings': 7311,
#   'reviews': 2350,
#   'histogram': [765, 171, 392, 634, 5349],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '90M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 25, 2019',
#   'contentRating': 'Everyone'},
#  {'title': "Dragon's Lair",
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 2.8688524,
#   'ratings': 2521,
#   'reviews': 1399,
#   'histogram': [1034, 234, 165, 206, 882],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 2, 2011',
#   'contentRating': 'Everyone 10+'},
#  {'title': '1942 MOBILE',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.04,
#   'ratings': 253,
#   'reviews': 152,
#   'histogram': [28, 17, 20, 38, 150],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 8, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'BattleBears Zombies',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.7438598,
#   'ratings': 570,
#   'reviews': 295,
#   'histogram': [108, 31, 53, 85, 293],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 6, 2010',
#   'contentRating': 'Teen'},
#  {'title': "Lep's World Plus 🍀",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.18,
#   'ratings': 567,
#   'reviews': 254,
#   'histogram': [68, 28, 22, 62, 387],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '33M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 15, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Slendrina: The Cellar',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.38,
#   'ratings': 623,
#   'reviews': 205,
#   'histogram': [56, 6, 50, 43, 468],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '36M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 30, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Chameleon Run',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.450169,
#   'ratings': 11907,
#   'reviews': 4845,
#   'histogram': [643, 251, 774, 1669, 8570],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 7, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Jelly Defense',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.5052085,
#   'ratings': 10385,
#   'reviews': 4704,
#   'histogram': [685, 234, 468, 757, 8241],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '94M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 28, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Vector 2 Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.71,
#   'ratings': 814,
#   'reviews': 378,
#   'histogram': [179, 57, 40, 81, 457],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '96M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 20, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Minos Starfighter VR',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.48,
#   'ratings': 610,
#   'reviews': 378,
#   'histogram': [128, 30, 122, 79, 251],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '55M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 5, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Galaxy Shooter : Falcon Squad Premium',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.174312,
#   'ratings': 1109,
#   'reviews': 437,
#   'histogram': [142, 30, 71, 112, 754],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 26, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Cheats Keyboard for San Andreas',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 3.642857,
#   'ratings': 14,
#   'reviews': 7,
#   'histogram': [4, 1, 0, 0, 9],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.1M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 16, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Boson X',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5961537,
#   'ratings': 2090,
#   'reviews': 310,
#   'histogram': [100, 30, 100, 150, 1710],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '11M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 25, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Ski Safari',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.532231,
#   'ratings': 66407,
#   'reviews': 25526,
#   'histogram': [4097, 1084, 1985, 7449, 51792],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 4, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Pocket Stables',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5607142,
#   'ratings': 2835,
#   'reviews': 430,
#   'histogram': [152, 50, 70, 344, 2219],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 21, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'C64.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.31,
#   'ratings': 535,
#   'reviews': 314,
#   'histogram': [166, 37, 32, 64, 236],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.1M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 1, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'BLAZING STAR',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.281081,
#   'ratings': 2010,
#   'reviews': 820,
#   'histogram': [163, 54, 152, 326, 1315],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 25, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Canabalt HD',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.133858,
#   'ratings': 3388,
#   'reviews': 820,
#   'histogram': [400, 133, 200, 533, 2122],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '14M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 15, 2012',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Unbroken Soul',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.035398,
#   'ratings': 1141,
#   'reviews': 505,
#   'histogram': [131, 30, 151, 182, 647],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 27, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'FATAL FURY SPECIAL',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.9,
#   'ratings': 945,
#   'reviews': 342,
#   'histogram': [170, 37, 66, 113, 559],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '33M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 2, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'AJ Jump: Animal Jam Kangaroos!',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2059803,
#   'ratings': 3026,
#   'reviews': 1423,
#   'histogram': [271, 140, 211, 472, 1932],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '42M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 4, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Feed Usagi For Sailor Moon',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.01,
#   'ratings': 140,
#   'reviews': 77,
#   'histogram': [21, 7, 9, 14, 89],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 11, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Galax Defender',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 2.4418604,
#   'ratings': 43,
#   'reviews': 33,
#   'histogram': [19, 7, 4, 5, 8],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '4.4M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 21, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'House of Slendrina',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.556701,
#   'ratings': 97,
#   'reviews': 36,
#   'histogram': [6, 2, 2, 9, 78],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '32M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 22, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Party Hard Go',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.048,
#   'ratings': 1251,
#   'reviews': 637,
#   'histogram': [310, 250, 130, 190, 371],
#   'price': 6.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '36M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 9, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Space Ace',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.04,
#   'ratings': 618,
#   'reviews': 330,
#   'histogram': [99, 24, 18, 86, 391],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 20, 2012',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Shopkins: Shoppie Dash!',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.23,
#   'ratings': 102,
#   'reviews': 44,
#   'histogram': [14, 2, 4, 7, 75],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '54M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 27, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Beat Hazard Ultra',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.3742857,
#   'ratings': 3759,
#   'reviews': 1508,
#   'histogram': [268, 96, 268, 451, 2676],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '20M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 16, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'GunCrafter Pro',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.0239043,
#   'ratings': 2527,
#   'reviews': 1122,
#   'histogram': [413, 80, 110, 352, 1572],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '59M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 31, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Grow',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.6330276,
#   'ratings': 4364,
#   'reviews': 1487,
#   'histogram': [160, 80, 160, 400, 3564],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 30, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Super8Pro (NE$/FC Emulator)',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.37,
#   'ratings': 292,
#   'reviews': 135,
#   'histogram': [29, 8, 8, 23, 224],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '4.6M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 6, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Monkey Boxing',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 2.8807948,
#   'ratings': 1519,
#   'reviews': 389,
#   'histogram': [735, 30, 70, 50, 634],
#   'price': 1.0,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 7, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Ping or Pong',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '17M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 28, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Arkanoid vs Space Invaders',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.58,
#   'ratings': 489,
#   'reviews': 267,
#   'histogram': [14, 14, 24, 54, 383],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '45M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 17, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Radiant',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.714286,
#   'ratings': 5980,
#   'reviews': 1672,
#   'histogram': [222, 37, 148, 408, 5165],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': None,
#   'contentRating': 'Everyone'},
#  {'title': 'Karateka Classic',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5039372,
#   'ratings': 1278,
#   'reviews': 366,
#   'histogram': [60, 60, 50, 110, 998],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 16, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'IMPOSSIBLE ROAD',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.4259257,
#   'ratings': 4360,
#   'reviews': 663,
#   'histogram': [272, 121, 222, 605, 3140],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '35M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 7, 2014',
#   'contentRating': 'Everyone'},
#  {'title': '7 Wonders:Magical Mystery Tour',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.88,
#   'ratings': 785,
#   'reviews': 250,
#   'histogram': [165, 31, 23, 78, 488],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.2M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 18, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Portal ® Pinball',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.137931,
#   'ratings': 1170,
#   'reviews': 371,
#   'histogram': [131, 40, 111, 141, 747],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 28, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'DARIUSBURST -SP-',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.46,
#   'ratings': 754,
#   'reviews': 385,
#   'histogram': [22, 22, 68, 113, 529],
#   'price': 9.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 22, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Paris Must Be Destroyed',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.3,
#   'ratings': 186,
#   'reviews': 86,
#   'histogram': [18, 3, 11, 22, 132],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 16, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'MasterGear - MasterSystem & GameGear Emulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.31,
#   'ratings': 573,
#   'reviews': 227,
#   'histogram': [51, 5, 34, 103, 380],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.8M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 11, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Atomic Fighter Bomber Pro',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.48,
#   'ratings': 461,
#   'reviews': 241,
#   'histogram': [18, 0, 37, 92, 314],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '35M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 27, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Dauntless',
#   'installs': '50+',
#   'minInstalls': 50,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '62M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 29, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Tilt to Live 2: Redonkulous',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.0825243,
#   'ratings': 2069,
#   'reviews': 352,
#   'histogram': [231, 130, 140, 301, 1267],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '9.1M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 23, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'PUSS!',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.806452,
#   'ratings': 31,
#   'reviews': 24,
#   'histogram': [0, 1, 1, 1, 28],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '140M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Nostalgia.GBC Pro (GBC Emulator)',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.76,
#   'ratings': 323,
#   'reviews': 113,
#   'histogram': [6, 3, 6, 29, 279],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 15, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Radiant HD',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.660494,
#   'ratings': 5491,
#   'reviews': 1689,
#   'histogram': [254, 67, 84, 474, 4612],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 4, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Super Fancy Pants Adventure',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.2,
#   'ratings': 159,
#   'reviews': 104,
#   'histogram': [19, 8, 9, 8, 115],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '95M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 5, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Wolf of the BF:Commando MOBILE',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.6031747,
#   'ratings': 63,
#   'reviews': 45,
#   'histogram': [8, 10, 9, 8, 28],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 23, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Rainbow Dash: Color This World',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.8695652,
#   'ratings': 69,
#   'reviews': 34,
#   'histogram': [12, 4, 5, 8, 40],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 23, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Muffin Knight',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.4666667,
#   'ratings': 5906,
#   'reviews': 2043,
#   'histogram': [337, 182, 309, 633, 4445],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 1, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'PewPew 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.631579,
#   'ratings': 2496,
#   'reviews': 898,
#   'histogram': [131, 18, 112, 112, 2123],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 22, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'The Bug Butcher',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.98,
#   'ratings': 718,
#   'reviews': 404,
#   'histogram': [50, 64, 93, 151, 360],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '22M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 19, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Brick Breaker Classic Plus',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '53M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 26, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Asteroid Storm',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 4.6153846,
#   'ratings': 26,
#   'reviews': 21,
#   'histogram': [0, 1, 2, 3, 20],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '22M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 1, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'fumpop',
#   'installs': '5+',
#   'minInstalls': 5,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 2, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Tower Builder',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 2.99,
#   'ratings': 208,
#   'reviews': 113,
#   'histogram': [71, 23, 25, 16, 73],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '14M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 17, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'North vs South',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 2.409836,
#   'ratings': 1840,
#   'reviews': 729,
#   'histogram': [1037, 90, 110, 130, 473],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '8.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 25, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Happy Color™ – Color by Number',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.60031,
#   'ratings': 2126249,
#   'reviews': 831715,
#   'histogram': [66318, 30148, 91247, 311625, 1626911],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '46M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jan 24, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Tile Master - Classic Triple Match & Puzzle Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4298525,
#   'ratings': 54098,
#   'reviews': 11089,
#   'histogram': [4295, 1576, 2708, 3517, 42002],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Feb 22, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Tile Connect - Free Tile Puzzle & Match Brain Game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.6761365,
#   'ratings': 2124,
#   'reviews': 635,
#   'histogram': [48, 24, 24, 374, 1654],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '41M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Aug 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Paint By Number - Coloring Book & Color by Number',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.5340457,
#   'ratings': 978153,
#   'reviews': 524558,
#   'histogram': [49990, 18950, 44362, 110234, 754617],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '52M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Aug 10, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Colorscapes - Color by Number & Paint by Number',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.7055354,
#   'ratings': 121278,
#   'reviews': 43675,
#   'histogram': [4384, 1663, 3286, 6612, 105333],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '56M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Mar 5, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Onnect - Pair Matching Puzzle',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.405064,
#   'ratings': 203822,
#   'reviews': 66895,
#   'histogram': [13057, 5140, 9379, 34852, 141394],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '37M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Nov 3, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Onet 3D - Classic Link Puzzle',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.53145,
#   'ratings': 18958,
#   'reviews': 7030,
#   'histogram': [727, 293, 818, 3456, 13664],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '74M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Apr 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'YAHTZEE® With Buddies Dice Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2227716,
#   'ratings': 166492,
#   'reviews': 64787,
#   'histogram': [15563, 6988, 10904, 24378, 108659],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '99M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Nov 1, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Bingo Blitz™️ - Bingo Games',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4984045,
#   'ratings': 682139,
#   'reviews': 214671,
#   'histogram': [35403, 14001, 32902, 92735, 507098],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Sep 14, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'Dominoes - Classic Domino Board Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.5317574,
#   'ratings': 28520,
#   'reviews': 9203,
#   'histogram': [1328, 483, 1147, 4297, 21265],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '68M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'May 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Bingo Story – Free Bingo Games',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.4269185,
#   'ratings': 52107,
#   'reviews': 16290,
#   'histogram': [3376, 1446, 3155, 5707, 38423],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Dec 20, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Chess',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.179676,
#   'ratings': 108458,
#   'reviews': 39083,
#   'histogram': [12254, 3909, 7627, 12971, 71697],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '4.2M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jul 30, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Numberzilla - Number Puzzle | Board Game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.3547225,
#   'ratings': 94807,
#   'reviews': 21625,
#   'histogram': [6987, 3734, 5963, 10099, 68024],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '87M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Oct 24, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Chess',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.2722187,
#   'ratings': 1291909,
#   'reviews': 467268,
#   'histogram': [112377, 38309, 92233, 191325, 857665],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '2.9M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jun 25, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Onet - Connect & Match Puzzle',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.5583596,
#   'ratings': 3277,
#   'reviews': 1106,
#   'histogram': [175, 41, 113, 393, 2555],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Aug 26, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Coloring Games -Paint By Number&Free Coloring Book',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.5,
#   'ratings': 10452,
#   'reviews': 4050,
#   'histogram': [783, 185, 453, 628, 8403],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '14M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jan 22, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Solitaire',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.608502,
#   'ratings': 24892,
#   'reviews': 8303,
#   'histogram': [846, 251, 755, 4092, 18948],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jun 21, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Paintist 2020 - Coloring Book & Color by Number',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.4753695,
#   'ratings': 4120,
#   'reviews': 1161,
#   'histogram': [304, 71, 223, 284, 3238],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '17M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Apr 10, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Mahjong City Tours: Free Mahjong Classic Game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.753473,
#   'ratings': 254654,
#   'reviews': 66398,
#   'histogram': [5671, 2404, 6483, 19911, 220185],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '75M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Oct 11, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Yalla Ludo - Ludo&Domino',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2930636,
#   'ratings': 105288,
#   'reviews': 44785,
#   'histogram': [12094, 3238, 4821, 6697, 78438],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Sep 20, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Dominoes',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.635606,
#   'ratings': 801717,
#   'reviews': 337822,
#   'histogram': [35569, 12307, 26428, 60084, 667329],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Aug 14, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Yazy the best yatzy dice game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.6324525,
#   'ratings': 16329,
#   'reviews': 6512,
#   'histogram': [632, 180, 391, 2148, 12978],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '51M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'May 18, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Dominoes',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.548589,
#   'ratings': 6425,
#   'reviews': 1998,
#   'histogram': [302, 130, 181, 936, 4876],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '77M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Dec 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Tap Color- Color by Number Art Coloring Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.566802,
#   'ratings': 244413,
#   'reviews': 95801,
#   'histogram': [13085, 5120, 9659, 18857, 197692],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '57M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Oct 10, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Checkers',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.2448773,
#   'ratings': 476838,
#   'reviews': 179913,
#   'histogram': [44857, 15464, 34753, 64742, 317022],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '3.6M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'May 18, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Dominoes - Best Classic Dominos Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.4520864,
#   'ratings': 25716,
#   'reviews': 8826,
#   'histogram': [1560, 546, 1222, 3766, 18622],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Aug 10, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Ludo King™',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.2580886,
#   'ratings': 6274246,
#   'reviews': 2191626,
#   'histogram': [695784, 156742, 321462, 758645, 4341613],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Dec 17, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Happy Canvas™ - Coloring by Numbers',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.5654764,
#   'ratings': 1709,
#   'reviews': 578,
#   'histogram': [61, 20, 91, 254, 1283],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jul 9, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Chess Free',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.474691,
#   'ratings': 1540828,
#   'reviews': 392635,
#   'histogram': [71896, 24743, 79031, 289531, 1075627],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '21M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Aug 26, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Fun Color by Number Coloring Book Paint Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.8546367,
#   'ratings': 4036,
#   'reviews': 1616,
#   'histogram': [738, 222, 354, 293, 2429],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '25M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Feb 13, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Bingo Treasure - Free Bingo Game',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.7777777,
#   'ratings': 1318,
#   'reviews': 495,
#   'histogram': [0, 31, 52, 94, 1141],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '61M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jun 16, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Tile Craft - Triple Crush: Puzzle matching game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.490534,
#   'ratings': 163009,
#   'reviews': 43832,
#   'histogram': [4211, 2299, 13469, 32365, 110665],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '79M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Dec 24, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Bingo - Offline Free Bingo Games',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.0254955,
#   'ratings': 3710,
#   'reviews': 1324,
#   'histogram': [441, 210, 378, 462, 2219],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jan 21, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Dominoes - Classic Domino Tile Based Game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.4217687,
#   'ratings': 1372,
#   'reviews': 623,
#   'histogram': [74, 9, 102, 261, 926],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '8.7M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'May 11, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Color by Number - Happy Paint',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.728327,
#   'ratings': 19927,
#   'reviews': 6593,
#   'histogram': [693, 261, 381, 1094, 17498],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '141M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jul 1, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Chess - Play and Learn',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.250352,
#   'ratings': 313657,
#   'reviews': 99623,
#   'histogram': [33081, 8542, 17228, 42722, 212084],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Feb 1, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Slots: Epic Jackpot Slots Games Free & Casino Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.8165126,
#   'ratings': 235436,
#   'reviews': 61696,
#   'histogram': [5476, 1634, 3751, 8886, 215689],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '69M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Apr 14, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Bingo Showdown: Free Bingo Games – Bingo Live Game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.638138,
#   'ratings': 591771,
#   'reviews': 197538,
#   'histogram': [18171, 9486, 28459, 56076, 479579],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Dec 11, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'RISK: Global Domination',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.296332,
#   'ratings': 218967,
#   'reviews': 76666,
#   'histogram': [19025, 6485, 13814, 30892, 148751],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Dec 3, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Online Chess - Free online mobile chess 2020',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.1585364,
#   'ratings': 4163,
#   'reviews': 1770,
#   'histogram': [416, 233, 335, 467, 2712],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '21M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Apr 23, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Bingo Bash: Live Bingo Games & Free Slots By GSN',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.450626,
#   'ratings': 623538,
#   'reviews': 183307,
#   'histogram': [34147, 17939, 36244, 79659, 455549],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '72M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Sep 18, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'Connect 3D - Pair Matching Puzzle',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.5897436,
#   'ratings': 1182,
#   'reviews': 355,
#   'histogram': [50, 10, 70, 111, 941],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '57M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jun 22, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Parchisi STAR Online',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.357766,
#   'ratings': 1814401,
#   'reviews': 745922,
#   'histogram': [187964, 35107, 73953, 160183, 1357194],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Feb 17, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'CROSS-STITCH: COLORING BOOK',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.275093,
#   'ratings': 2744,
#   'reviews': 929,
#   'histogram': [306, 81, 142, 234, 1981],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Apr 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Unoo Classic',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.214286,
#   'ratings': 2324,
#   'reviews': 896,
#   'histogram': [207, 124, 145, 332, 1516],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '7.8M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jul 3, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Checkers',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.4396443,
#   'ratings': 839574,
#   'reviews': 348776,
#   'histogram': [50437, 16364, 48612, 122393, 601768],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jan 5, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Mahjong Titan',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.6059613,
#   'ratings': 561227,
#   'reviews': 184937,
#   'histogram': [6462, 3994, 29292, 124727, 396752],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Mar 11, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Bingo Abradoodle - Bingo Games Free to Play!',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.610596,
#   'ratings': 128648,
#   'reviews': 50005,
#   'histogram': [5121, 2165, 4981, 13150, 103231],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '63M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Sep 28, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Bingo on Money free $25 deposit and match 3 to win',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.232456,
#   'ratings': 6958,
#   'reviews': 3078,
#   'histogram': [569, 254, 681, 936, 4518],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Apr 21, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Slots: VIP Deluxe Slot Machines Free - Vegas Slots',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.8238263,
#   'ratings': 373110,
#   'reviews': 102702,
#   'histogram': [8350, 2175, 5393, 15017, 342175],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '65M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jun 15, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Yatzy - Offline Free Dice Games',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.403536,
#   'ratings': 26106,
#   'reviews': 10848,
#   'histogram': [1234, 571, 1886, 5147, 17268],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '29M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Mar 22, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Woody 99 - Sudoku Block Puzzle - Free Mind Games',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.7777348,
#   'ratings': 25773,
#   'reviews': 9822,
#   'histogram': [581, 270, 632, 1324, 22966],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '42M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Nov 26, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Endless Balls 3D',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.6595042,
#   'ratings': 12144,
#   'reviews': 3586,
#   'histogram': [2459, 642, 1345, 1826, 5872],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '23M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'May 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'BINGO!',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.56102,
#   'ratings': 455367,
#   'reviews': 159967,
#   'histogram': [23732, 7786, 20402, 40804, 362643],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '44M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Dec 23, 2011',
#   'contentRating': 'Teen'},
#  {'title': 'Colorfy: Adult Coloring Book - Free Style Color',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0438404,
#   'ratings': 854562,
#   'reviews': 275330,
#   'histogram': [129373, 28838, 57999, 97090, 541262],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Jul 15, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Fleet Battle - Sea Battle',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.261383,
#   'ratings': 134307,
#   'reviews': 58156,
#   'histogram': [9790, 4599, 11136, 23969, 84813],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '61M',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Aug 1, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Ludo Club - Fun Dice Game',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.244498,
#   'ratings': 1028100,
#   'reviews': 444059,
#   'histogram': [126591, 24863, 45114, 105548, 725984],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Board',
#   'genreId': 'GAME_BOARD',
#   'released': 'Sep 6, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Art Number Coloring - Color by Number',
# ...
#   'reviews': 60665,
#   'histogram': [21169, 7968, 12013, 15062, 96198],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '35M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Virtual Families 3',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.2,
#   'ratings': 286,
#   'reviews': 203,
#   'histogram': [74, 28, 43, 46, 95],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '128M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Slope Run Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.08125,
#   'ratings': 6455,
#   'reviews': 2677,
#   'histogram': [998, 211, 343, 615, 4288],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '43M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 16, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Cutie Garden',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.748428,
#   'ratings': 2075,
#   'reviews': 830,
#   'histogram': [39, 39, 39, 169, 1789],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '62M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 15, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Tic Tac Toe Glow',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.14328,
#   'ratings': 583456,
#   'reviews': 208986,
#   'histogram': [65074, 22402, 49384, 73584, 373012],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 6, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Hay Day',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.433753,
#   'ratings': 11667276,
#   'reviews': 3837666,
#   'histogram': [860268, 270663, 567554, 1218388, 8750403],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '127M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 13, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Bang Hero',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.533857,
#   'ratings': 10555,
#   'reviews': 2801,
#   'histogram': [486, 134, 321, 1927, 7687],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '104M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 9, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Barbie Magical Fashion',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 3.9012575,
#   'ratings': 377232,
#   'reviews': 149689,
#   'histogram': [70863, 17865, 23308, 30817, 234379],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '37M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 23, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Bible Coloring - Paint by Number, Free Bible Games',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.770494,
#   'ratings': 139166,
#   'reviews': 70898,
#   'histogram': [2786, 1333, 3448, 9894, 121705],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 23, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Fall Guys Ultimate Knockout Game Guide',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 2.189655,
#   'ratings': 1195,
#   'reviews': 694,
#   'histogram': [815, 10, 10, 51, 309],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '6.6M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 14, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Dobre Dunk',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.7062736,
#   'ratings': 21110,
#   'reviews': 12232,
#   'histogram': [1003, 230, 391, 712, 18774],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 11, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Doodle Run',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.144414,
#   'ratings': 7495,
#   'reviews': 2536,
#   'histogram': [674, 418, 674, 1113, 4616],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '81M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 14, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Dice Dreams™️',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.741059,
#   'ratings': 27820,
#   'reviews': 9101,
#   'histogram': [477, 258, 676, 3164, 23245],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '117M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 27, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Nail & Foot doctor - Knee replacement surgery',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.2639406,
#   'ratings': 2802,
#   'reviews': 1208,
#   'histogram': [917, 229, 177, 156, 1323],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '38M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 22, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'College Girls Team Makeover',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.123582,
#   'ratings': 131792,
#   'reviews': 77443,
#   'histogram': [17368, 5637, 8487, 12144, 88156],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '36M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Arrows!',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.9772727,
#   'ratings': 3127,
#   'reviews': 878,
#   'histogram': [477, 111, 274, 406, 1859],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '32M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 14, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Pet Puppy Love: Girls Craft',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.080672,
#   'ratings': 49323,
#   'reviews': 24400,
#   'histogram': [7918, 2070, 2009, 3443, 33883],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 1, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Barbie™ Fashion Closet',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.917912,
#   'ratings': 191128,
#   'reviews': 97880,
#   'histogram': [34376, 9091, 12793, 16453, 118415],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '81M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 30, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Paint by Number - Pixel Art, Free Coloring Book',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.307481,
#   'ratings': 117159,
#   'reviews': 63992,
#   'histogram': [10847, 3471, 7466, 12397, 82978],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 18, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Collect Cubes',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.5322502,
#   'ratings': 20395,
#   'reviews': 8071,
#   'histogram': [4539, 1878, 2058, 2028, 9892],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '34M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 26, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Candy Crush Friends Saga',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.599179,
#   'ratings': 1545466,
#   'reviews': 541393,
#   'histogram': [45474, 19783, 72476, 233257, 1174476],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Oct 10, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Bubble Shooter',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3110213,
#   'ratings': 792783,
#   'reviews': 301029,
#   'histogram': [64562, 25420, 53566, 104567, 544668],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '40M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 12, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Fishing Food',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.767705,
#   'ratings': 56879,
#   'reviews': 37392,
#   'histogram': [950, 455, 1435, 5176, 48863],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '29M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Police Scanner 5-0 (FREE)',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.1319647,
#   'ratings': 59162,
#   'reviews': 17759,
#   'histogram': [6373, 2348, 4302, 10213, 35926],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '6.1M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 11, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Horse Riding Tales - Ride With Friends',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.1239853,
#   'ratings': 105092,
#   'reviews': 65139,
#   'histogram': [13662, 3814, 6966, 12036, 68614],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '92M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 20, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Shooting Range Sniper: Target Shooting Games Free',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.8096414,
#   'ratings': 8908,
#   'reviews': 2616,
#   'histogram': [143, 44, 165, 660, 7896],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '65M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 26, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Dance Clash: Ballet vs Hip Hop',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1812663,
#   'ratings': 385351,
#   'reviews': 198809,
#   'histogram': [43643, 15116, 26418, 42740, 257434],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '48M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 6, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Knockout Fall Guys Royale 3D: Human Knock Over',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.63,
#   'ratings': 676,
#   'reviews': 507,
#   'histogram': [189, 27, 20, 47, 393],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '51M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 9, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Surprise Eggs Classic',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.779358,
#   'ratings': 24976,
#   'reviews': 13210,
#   'histogram': [5552, 1278, 1380, 1684, 15082],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '14M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Oct 4, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'AntiStress, Relaxing, Anxiety & Stress Relief Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.0990295,
#   'ratings': 35587,
#   'reviews': 20228,
#   'histogram': [5159, 1675, 2183, 2031, 24539],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '37M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 27, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Gacha Studio (Anime Dress Up)',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.838164,
#   'ratings': 437778,
#   'reviews': 257392,
#   'histogram': [80939, 22338, 34967, 47917, 251617],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 21, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Number Coloring – 3D No.Draw',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2546864,
#   'ratings': 62211,
#   'reviews': 31040,
#   'histogram': [6605, 2332, 3619, 5710, 43945],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '46M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 29, 2018',
#   'contentRating': 'Everyone'},
#  {'title': '☢ The Wanderer : A Post-Apocalyptic Survival',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.4388943,
#   'ratings': 30161,
#   'reviews': 12018,
#   'histogram': [833, 522, 2229, 7563, 19014],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 28, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Diner DASH Adventures: a time management game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.1570415,
#   'ratings': 63688,
#   'reviews': 21794,
#   'histogram': [5832, 3387, 5532, 9130, 39807],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '126M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 18, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Bubbu – My Virtual Pet',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.4263186,
#   'ratings': 703188,
#   'reviews': 327345,
#   'histogram': [56704, 17412, 31634, 61080, 536358],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '93M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Oct 30, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Best Fiends Stars - Free Puzzle Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.5980983,
#   'ratings': 71689,
#   'reviews': 26464,
#   'histogram': [2065, 1032, 3167, 11118, 54307],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Kitten Rescue - Pin Pull',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4259257,
#   'ratings': 54,
#   'reviews': 27,
#   'histogram': [3, 3, 2, 6, 40],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '28M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 19, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Jungle Marble Blast',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3330913,
#   'ratings': 138192,
#   'reviews': 40795,
#   'histogram': [10027, 4014, 10569, 18870, 94712],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '29M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 10, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Flip Tumbling',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.401937,
#   'ratings': 4180,
#   'reviews': 1179,
#   'histogram': [303, 151, 162, 506, 3058],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '102M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 13, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Dumb Ways to Die 2: The Games',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3397365,
#   'ratings': 1769976,
#   'reviews': 445207,
#   'histogram': [161194, 41604, 104262, 190534, 1272382],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '60M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 9, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Lucky Winner - Today is your lucky day',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.6739836,
#   'ratings': 12714,
#   'reviews': 4066,
#   'histogram': [651, 113, 320, 558, 11072],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '40M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 20, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Covet Fashion - Dress Up Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.992595,
#   'ratings': 722453,
#   'reviews': 288626,
#   'histogram': [94581, 29720, 57674, 144968, 395510],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '106M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Oct 25, 2013',
#   'contentRating': 'Teen'}]

# %%
len(listofdictinfo2)
# Out:
# 1000

# %%
listofdictinfo3 = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[2001:3001]))
listofdictinfo3
# Out:
# [{'title': 'Idle Army Base',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.8444705,
#   'ratings': 102173,
#   'reviews': 33534,
#   'histogram': [17475, 6005, 8873, 12402, 57418],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '85M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 17, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'My Little Pony Rainbow Runners',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9648643,
#   'ratings': 80754,
#   'reviews': 37588,
#   'histogram': [12818, 4205, 5906, 7888, 49937],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '37M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 27, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'MY LITTLE PONY: Magic Princess',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.2395515,
#   'ratings': 1410873,
#   'reviews': 576924,
#   'histogram': [159778, 43010, 79262, 146229, 982594],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '43M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 8, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Superstar Career - Dress Up Rising Stars',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9678423,
#   'ratings': 39347,
#   'reviews': 23383,
#   'histogram': [6418, 2000, 2836, 3265, 24828],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 13, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Styledoll - 3D Avatar maker',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.0942483,
#   'ratings': 48048,
#   'reviews': 28762,
#   'histogram': [6818, 1916, 2874, 4750, 31690],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 10, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Crayon Epoxy',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 2.5590909,
#   'ratings': 4430,
#   'reviews': 1520,
#   'histogram': [2125, 382, 423, 322, 1178],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '85M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 12, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Nail Salon Manicure - Fashion Girl Game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.79,
#   'ratings': 173,
#   'reviews': 114,
#   'histogram': [45, 7, 3, 1, 117],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 31, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Merge Quest',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.7068062,
#   'ratings': 5778,
#   'reviews': 2126,
#   'histogram': [1240, 252, 625, 504, 3157],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '36M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 20, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Match Masters - Online PVP Match 3 Puzzle Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.5361104,
#   'ratings': 111660,
#   'reviews': 41771,
#   'histogram': [4741, 1550, 6332, 15514, 83523],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 8, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Cooking Games 3D',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.0405865,
#   'ratings': 8955,
#   'reviews': 3114,
#   'histogram': [1272, 454, 747, 646, 5836],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '94M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 31, 2020',
#   'contentRating': 'Everyone'},
#  {'title': '\u200eFlick Chess!',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.9700131,
#   'ratings': 15467,
#   'reviews': 4416,
#   'histogram': [2047, 988, 1401, 1976, 9055],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '52M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 20, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Idle Egypt Tycoon',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.58,
#   'ratings': 950,
#   'reviews': 328,
#   'histogram': [228, 57, 76, 114, 475],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '63M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 10, 2020',
#   'contentRating': 'Everyone'},
#  {'title': "War Wheels - Like a 1980's Tank Game",
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.6679535,
#   'ratings': 1819,
#   'reviews': 466,
#   'histogram': [14, 7, 70, 386, 1342],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '80M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 3, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Farm Heroes Saga',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.6035066,
#   'ratings': 8770032,
#   'reviews': 2243586,
#   'histogram': [271910, 123385, 426410, 1166643, 6781684],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 10, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Pastel Girl : Dress Up Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3602533,
#   'ratings': 227987,
#   'reviews': 117052,
#   'histogram': [17760, 6538, 13628, 27939, 162122],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '65M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 21, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Doodle | Magic Joy',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2486124,
#   'ratings': 152196,
#   'reviews': 76440,
#   'histogram': [14449, 6234, 10739, 16380, 104394],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '10M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 30, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'DC Super Hero Girls Blitz',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.9093313,
#   'ratings': 26648,
#   'reviews': 15525,
#   'histogram': [4621, 1500, 1802, 2476, 16249],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '41M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 1, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Kids Balloon Pop Game Free 🎈',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3263707,
#   'ratings': 53890,
#   'reviews': 15837,
#   'histogram': [3718, 1638, 4140, 8231, 36163],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '17M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 3, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Jelly Shift',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.0882077,
#   'ratings': 288943,
#   'reviews': 116512,
#   'histogram': [37517, 13717, 22323, 27586, 187800],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '41M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 1, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Flip! the Frog - Best of free casual arcade games',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.388646,
#   'ratings': 2337,
#   'reviews': 876,
#   'histogram': [132, 61, 194, 326, 1624],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '53M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 29, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Thomas & Friends Minis',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.108853,
#   'ratings': 22373,
#   'reviews': 8763,
#   'histogram': [3122, 960, 1253, 2061, 14977],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 12, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Harvest Land: Farm & City Building',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.304084,
#   'ratings': 300657,
#   'reviews': 93244,
#   'histogram': [23455, 10113, 22823, 39423, 204843],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '106M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Oct 18, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'The Simpsons™: Tapped Out',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.431747,
#   'ratings': 661472,
#   'reviews': 250747,
#   'histogram': [45763, 15994, 33684, 77479, 488552],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '66M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 6, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'Water Park Craft GO: Waterslide Building Adventure',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.258948,
#   'ratings': 56612,
#   'reviews': 27490,
#   'histogram': [7000, 1935, 2411, 3323, 41943],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 23, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Hidden Through Time',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.51,
#   'ratings': 359,
#   'reviews': 154,
#   'histogram': [10, 7, 36, 39, 267],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '100M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 12, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Melvor Idle: Ad Free',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.65,
#   'ratings': 260,
#   'reviews': 96,
#   'histogram': [2, 10, 13, 23, 212],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.1M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 12, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'My PlayHome : Play Home Doll House',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.372896,
#   'ratings': 11389,
#   'reviews': 7251,
#   'histogram': [1089, 252, 625, 776, 8647],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '68M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 8, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Hidden Folks',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.7375565,
#   'ratings': 2221,
#   'reviews': 977,
#   'histogram': [50, 30, 50, 191, 1900],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '70M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 14, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'My PlayHome Hospital',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.3313255,
#   'ratings': 1669,
#   'reviews': 878,
#   'histogram': [171, 40, 100, 110, 1248],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '45M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 13, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'My PlayHome Stores',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.358885,
#   'ratings': 2884,
#   'reviews': 1454,
#   'histogram': [261, 110, 120, 231, 2162],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '42M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 27, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'FINAL FANTASY',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.536965,
#   'ratings': 8473,
#   'reviews': 3340,
#   'histogram': [1681, 780, 1110, 1110, 3792],
#   'price': 7.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '44M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 26, 2012',
#   'contentRating': 'Everyone'},
#  {'title': "Let's Create! Pottery",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.505751,
#   'ratings': 29797,
#   'reviews': 10657,
#   'histogram': [1628, 578, 1338, 3802, 22451],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '72M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 22, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'My PlayHome School',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2723403,
#   'ratings': 2367,
#   'reviews': 1198,
#   'histogram': [262, 50, 151, 221, 1683],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '43M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 4, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'FPse for Android devices',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.612708,
#   'ratings': 62465,
#   'reviews': 32020,
#   'histogram': [2457, 1122, 2232, 6532, 50122],
#   'price': 3.63,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.8M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 12, 2011',
#   'contentRating': 'Everyone'},
#  {'title': "SpongeBob's Game Frenzy",
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.989899,
#   'ratings': 1988,
#   'reviews': 861,
#   'histogram': [321, 90, 120, 211, 1246],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '24M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 26, 2015',
#   'contentRating': 'Everyone'},
#  {'title': "Jazza's Arty Games",
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.474801,
#   'ratings': 3763,
#   'reviews': 1756,
#   'histogram': [239, 79, 149, 479, 2817],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '38M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 7, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Peppa Pig: Happy Mrs Chicken',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.5503356,
#   'ratings': 1514,
#   'reviews': 616,
#   'histogram': [386, 61, 162, 142, 763],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '48M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 5, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Backflip Madness - Extreme sports flip game',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.4402175,
#   'ratings': 26698,
#   'reviews': 4636,
#   'histogram': [1803, 476, 1388, 3524, 19507],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.7M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 25, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'Sand! Premium',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.3685713,
#   'ratings': 3512,
#   'reviews': 893,
#   'histogram': [341, 40, 160, 411, 2560],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '128k',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 21, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Fieldrunners HD',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.6225297,
#   'ratings': 8606,
#   'reviews': 4582,
#   'histogram': [2347, 221, 459, 884, 4695],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '72M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 6, 2011',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Muddy Heights® 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.08,
#   'ratings': 273,
#   'reviews': 155,
#   'histogram': [46, 8, 5, 30, 184],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 19, 2016',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Little Inferno',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.3140388,
#   'ratings': 15108,
#   'reviews': 4108,
#   'histogram': [1618, 452, 593, 1347, 11098],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 25, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'LEGO® Friends',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.4876032,
#   'ratings': 1213,
#   'reviews': 743,
#   'histogram': [341, 40, 90, 170, 572],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.9M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 28, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Virtual Families',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8,
#   'ratings': 5624,
#   'reviews': 2641,
#   'histogram': [712, 543, 712, 844, 2813],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '21M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 26, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'The Great Easter Egg Hunt',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.9M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 16, 2012',
#   'contentRating': 'Everyone'},
#  {'title': "Sally's Spa",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.34,
#   'ratings': 426,
#   'reviews': 204,
#   'histogram': [42, 17, 12, 34, 321],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '71M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 22, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Game Dev Story',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.682232,
#   'ratings': 63037,
#   'reviews': 17430,
#   'histogram': [1780, 691, 2001, 6829, 51736],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 10, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Hey Duggee: The Exploring App',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.9230769,
#   'ratings': 13,
#   'reviews': 6,
#   'histogram': [2, 0, 1, 4, 6],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 13, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Putt-Putt® Saves the Zoo',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.17,
#   'ratings': 260,
#   'reviews': 109,
#   'histogram': [39, 7, 10, 15, 189],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 9, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Meme Soundboard PRO 2020',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.3819447,
#   'ratings': 1448,
#   'reviews': 1019,
#   'histogram': [90, 30, 90, 261, 977],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 11, 2018',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Freddi Fish 1: The Case of the Missing Kelp Seeds',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 1.82,
#   'ratings': 176,
#   'reviews': 121,
#   'histogram': [137, 1, 5, 1, 32],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 3, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Burger Shop 2 (No Ads)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.66,
#   'ratings': 749,
#   'reviews': 346,
#   'histogram': [37, 7, 7, 67, 631],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '32M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 23, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Fish Tycoon',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.7307692,
#   'ratings': 2243,
#   'reviews': 926,
#   'histogram': [414, 120, 293, 241, 1175],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.7M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 24, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Chicken The Adult Sex Game 2.0',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.94,
#   'ratings': 295,
#   'reviews': 99,
#   'histogram': [35, 8, 44, 56, 152],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '11M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 2, 2014',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Cat Playground - Game for cats',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.34,
#   'ratings': 200,
#   'reviews': 124,
#   'histogram': [12, 10, 10, 34, 134],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '22M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 1, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'My Baby Babsy Playground Gold',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '56M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 27, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Fieldrunners 2',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.999068,
#   'ratings': 10856,
#   'reviews': 3565,
#   'histogram': [1770, 526, 526, 1153, 6881],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 23, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'The Jackbox Party Pack 6',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 29.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 6, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'SpongeBob Tickler',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.27,
#   'ratings': 338,
#   'reviews': 125,
#   'histogram': [108, 23, 27, 27, 153],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '8.9M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 23, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Fairy Tale High',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.523256,
#   'ratings': 86,
#   'reviews': 39,
#   'histogram': [2, 3, 7, 10, 64],
#   'price': 1.0,
#   'free': False,
#   'offersIAP': False,
#   'size': '20M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Domino Dot Counter',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.64,
#   'ratings': 120,
#   'reviews': 78,
#   'histogram': [3, 3, 4, 8, 102],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.4M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 16, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Pajama Sam: No Need to Hide',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.99,
#   'ratings': 306,
#   'reviews': 130,
#   'histogram': [55, 15, 3, 36, 197],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 3, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Enigmatis Hidden Object (Full)',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.194175,
#   'ratings': 5782,
#   'reviews': 2671,
#   'histogram': [584, 190, 348, 1055, 3605],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '13M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Oct 5, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'Pajama Sam 2: Thunder & Lightning',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.13,
#   'ratings': 154,
#   'reviews': 49,
#   'histogram': [23, 3, 10, 10, 108],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 3, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Pajama Sam 3: You Are What You Eat from Your Head',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.46,
#   'ratings': 109,
#   'reviews': 51,
#   'histogram': [6, 2, 11, 4, 86],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'App for GeoGuessr',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.68,
#   'ratings': 143,
#   'reviews': 69,
#   'histogram': [1, 2, 4, 23, 113],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.4M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 29, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Pocket Academy',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.449838,
#   'ratings': 3760,
#   'reviews': 866,
#   'histogram': [158, 133, 231, 572, 2666],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 25, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'FPse64 for Android',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.5666666,
#   'ratings': 30,
#   'reviews': 20,
#   'histogram': [1, 0, 2, 5, 22],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'i Live - Gold Edition',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.0686693,
#   'ratings': 11740,
#   'reviews': 6393,
#   'histogram': [1542, 493, 927, 1431, 7347],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 16, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Sink It!',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 3.0454545,
#   'ratings': 22,
#   'reviews': 18,
#   'histogram': [10, 0, 1, 1, 10],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '10M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 12, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Freddi Fish 3: The Case of the Stolen Conch Shell',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.85,
#   'ratings': 180,
#   'reviews': 86,
#   'histogram': [40, 1, 14, 14, 111],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 3, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Spy Fox 2 "Some Assembly Required"',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.0,
#   'ratings': 32,
#   'reviews': 14,
#   'histogram': [5, 0, 4, 4, 19],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': "Dr. Panda's Swimming Pool",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.0064516,
#   'ratings': 3123,
#   'reviews': 1240,
#   'histogram': [403, 191, 262, 393, 1874],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.3M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 14, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Fix My Car: Classic Muscle Car Restoration',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.4259257,
#   'ratings': 54,
#   'reviews': 34,
#   'histogram': [5, 1, 3, 2, 43],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '98M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 14, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Bigfoot Quest',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.4066668,
#   'ratings': 6211,
#   'reviews': 2318,
#   'histogram': [403, 72, 445, 963, 4328],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '8.7M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 6, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'The Sushi Spinnery',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5547943,
#   'ratings': 1901,
#   'reviews': 489,
#   'histogram': [91, 65, 78, 130, 1537],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 3, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Webkinz™: Cash Cow',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 22, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Cafeteria Nipponica',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2969923,
#   'ratings': 3599,
#   'reviews': 931,
#   'histogram': [297, 108, 311, 392, 2491],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 4, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Fix My Car: Classic Muscle Car',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.137931,
#   'ratings': 1167,
#   'reviews': 500,
#   'histogram': [131, 40, 110, 141, 745],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '30M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 26, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'My Little Work – Garage',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2,
#   'ratings': 579,
#   'reviews': 97,
#   'histogram': [69, 17, 29, 75, 389],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '48M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Oct 23, 2013',
#   'contentRating': 'Everyone'},
#  {'title': "Dr. Panda & Toto's Treehouse",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.3741007,
#   'ratings': 5588,
#   'reviews': 1699,
#   'histogram': [502, 100, 271, 643, 4072],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.5M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 13, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Putt-Putt® Goes to the Moon',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.75,
#   'ratings': 16,
#   'reviews': 8,
#   'histogram': [4, 1, 0, 1, 10],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Life Quest 2:Metropoville Full',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4695654,
#   'ratings': 1150,
#   'reviews': 319,
#   'histogram': [110, 10, 10, 120, 900],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 3, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Air Control 2 - Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.95,
#   'ratings': 945,
#   'reviews': 217,
#   'histogram': [142, 37, 75, 161, 530],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '14M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 17, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Bubble Bliss XL',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 3.8235295,
#   'ratings': 17,
#   'reviews': 14,
#   'histogram': [2, 1, 3, 3, 8],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '40M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 24, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Freddi Fish 4: The Hogfish Rustlers of Briny Gulch',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.1578946,
#   'ratings': 38,
#   'reviews': 18,
#   'histogram': [7, 1, 0, 1, 29],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Life Quest® [Full]',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.52,
#   'ratings': 886,
#   'reviews': 285,
#   'histogram': [17, 35, 62, 124, 648],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '49M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 7, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Air Control',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.6116505,
#   'ratings': 16254,
#   'reviews': 6109,
#   'histogram': [315, 276, 591, 3038, 12034],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': None,
#   'contentRating': 'Everyone'},
#  {'title': 'Dino Dana: Dino Quest',
#   'installs': '50+',
#   'minInstalls': 50,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '66M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jan 10, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Dope Wars (Weed Edition)',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.55,
#   'ratings': 224,
#   'reviews': 97,
#   'histogram': [4, 0, 9, 65, 146],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 26, 2017',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Farm Frenzy: Time management game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8495576,
#   'ratings': 6508,
#   'reviews': 2291,
#   'histogram': [979, 576, 691, 460, 3802],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '12M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': None,
#   'contentRating': 'Everyone'},
#  {'title': 'Pirates and Traders: Gold!',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5964913,
#   'ratings': 1767,
#   'reviews': 644,
#   'histogram': [15, 31, 93, 372, 1256],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 7, 2010',
#   'contentRating': 'Teen'},
#  {'title': 'Putt-Putt® Joins the Parade',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.7222223,
#   'ratings': 18,
#   'reviews': 12,
#   'histogram': [5, 0, 1, 1, 11],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '24M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Dragon, Fly! Full',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.581818,
#   'ratings': 10350,
#   'reviews': 5415,
#   'histogram': [225, 150, 752, 1468, 7755],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 22, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Pango Sheep',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.5510206,
#   'ratings': 49,
#   'reviews': 21,
#   'histogram': [3, 2, 1, 2, 41],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '40M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 10, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Spy Fox in Dry Cereal',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.82,
#   'ratings': 206,
#   'reviews': 88,
#   'histogram': [37, 14, 16, 18, 121],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 1, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'supertype',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.57,
#   'ratings': 229,
#   'reviews': 131,
#   'histogram': [43, 25, 16, 46, 99],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '36M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'May 1, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Fix My Truck: Offroad Pickup Mechanic Simulator!',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.63,
#   'ratings': 501,
#   'reviews': 196,
#   'histogram': [30, 5, 10, 30, 426],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 19, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Azada: Ancient Magic (Full) CE',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.45,
#   'ratings': 735,
#   'reviews': 295,
#   'histogram': [29, 29, 44, 110, 523],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 25, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Freddi Fish 5: The Creature of Coral Cove',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.5454545,
#   'ratings': 33,
#   'reviews': 19,
#   'histogram': [5, 6, 4, 2, 16],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'World Cruise Story',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.46875,
#   'ratings': 2956,
#   'reviews': 826,
#   'histogram': [184, 66, 118, 396, 2192],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 15, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Putt-Putt® Travels Through Time',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.163265,
#   'ratings': 98,
#   'reviews': 44,
#   'histogram': [14, 4, 4, 6, 70],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 3, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Oh!Edo Towns',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.4322033,
#   'ratings': 2685,
#   'reviews': 429,
#   'histogram': [136, 34, 216, 444, 1855],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jul 25, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Elevator Simulator 3D',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.41,
#   'ratings': 549,
#   'reviews': 307,
#   'histogram': [148, 22, 77, 60, 242],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '59M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 19, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Kavel',
#   'installs': '50+',
#   'minInstalls': 50,
#   'score': 4.6923075,
#   'ratings': 13,
#   'reviews': 9,
#   'histogram': [0, 0, 1, 2, 10],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '30M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 13, 2020',
#   'contentRating': 'Everyone'},
#  {'title': "Miner's Idle 3 - Incremental Mining Game",
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.27,
#   'ratings': 871,
#   'reviews': 308,
#   'histogram': [52, 26, 87, 174, 532],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '15M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 6, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Putt-Putt® Enters the Race',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.7142856,
#   'ratings': 63,
#   'reviews': 27,
#   'histogram': [12, 4, 7, 7, 33],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 27, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Spy Fox 3 "Operation Ozone"',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.4166665,
#   'ratings': 48,
#   'reviews': 21,
#   'histogram': [4, 2, 1, 4, 37],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Mia and me - Free the Unicorns',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.801802,
#   'ratings': 1115,
#   'reviews': 581,
#   'histogram': [231, 50, 90, 80, 664],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '13M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 4, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Petting Zoo by Christoph Niemann',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.324786,
#   'ratings': 1184,
#   'reviews': 347,
#   'histogram': [172, 10, 10, 60, 932],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '30M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 30, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Venture Towns',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.260163,
#   'ratings': 4147,
#   'reviews': 582,
#   'histogram': [303, 179, 326, 663, 2676],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '30M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Sep 7, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Mega Mall Story',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.4932737,
#   'ratings': 3128,
#   'reviews': 847,
#   'histogram': [168, 56, 196, 350, 2358],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 29, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Azada [Full]',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.31,
#   'ratings': 966,
#   'reviews': 409,
#   'histogram': [58, 58, 48, 164, 638],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 10, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Putt-Putt® Joins the Circus',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.2222223,
#   'ratings': 90,
#   'reviews': 27,
#   'histogram': [13, 1, 3, 9, 64],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '24M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 26, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Sexy Truth Or Dare 18+',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.380342,
#   'ratings': 234,
#   'reviews': 55,
#   'histogram': [13, 5, 15, 48, 153],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.4M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': None,
#   'contentRating': 'Mature 17+'},
#  {'title': 'Holiday Drops - Match 3 puzzle',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.36,
#   'ratings': 135,
#   'reviews': 34,
#   'histogram': [9, 1, 9, 26, 90],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '11M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Nov 21, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Beast of Lycan Isle CE (Full)',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.1,
#   'ratings': 418,
#   'reviews': 160,
#   'histogram': [151, 25, 33, 50, 159],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '20M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 20, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Empress of the Deep (Full)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 2.17,
#   'ratings': 1014,
#   'reviews': 601,
#   'histogram': [640, 71, 30, 40, 233],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.5M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Jun 28, 2012',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Kids Finger Paint',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.3006535,
#   'ratings': 153,
#   'reviews': 73,
#   'histogram': [10, 5, 9, 34, 95],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.4M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Aug 5, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Hot Springs Story',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.3236995,
#   'ratings': 3414,
#   'reviews': 1022,
#   'histogram': [217, 98, 296, 552, 2251],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Apr 15, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Fix My Car: Mad Road Mechanic - Max Mayhem!',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.66,
#   'ratings': 280,
#   'reviews': 125,
#   'histogram': [11, 2, 11, 19, 237],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '132M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 1, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Anime Face Maker GO',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.5894737,
#   'ratings': 95,
#   'reviews': 60,
#   'histogram': [3, 1, 4, 16, 71],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '21M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Dec 22, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Idle Poo Factory VIP',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.92,
#   'ratings': 252,
#   'reviews': 118,
#   'histogram': [33, 17, 22, 43, 137],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Feb 15, 2019',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Garden Rescue (Full)',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 2.01,
#   'ratings': 922,
#   'reviews': 464,
#   'histogram': [674, 9, 9, 18, 212],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Casual',
#   'genreId': 'GAME_CASUAL',
#   'released': 'Mar 29, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Toca Life World: Build stories & create your world',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.39693,
#   'ratings': 505404,
#   'reviews': 314572,
#   'histogram': [40577, 13360, 25264, 51874, 374329],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '46M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Nov 21, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Toca Kitchen 2',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.143553,
#   'ratings': 1396912,
#   'reviews': 637557,
#   'histogram': [170815, 53309, 96652, 159887, 916249],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '29M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'May 25, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Pepi Hospital',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9986296,
#   'ratings': 102884,
#   'reviews': 55100,
#   'histogram': [16790, 4482, 6415, 9588, 65609],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '41M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Feb 13, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'My Town : Cinema. Fun Movistar Kids Movie Night',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.0418606,
#   'ratings': 8835,
#   'reviews': 5697,
#   'histogram': [1335, 441, 616, 565, 5878],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '67M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Aug 19, 2020',
#   'contentRating': 'Everyone'},
#  {'title': "Baby Panda's First Aid Tips",
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.080357,
#   'ratings': 1210,
#   'reviews': 614,
#   'histogram': [227, 10, 43, 86, 844],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '112M',
#   'genre': 'Educational',
#   'genreId': 'GAME_EDUCATIONAL',
#   'released': 'Jul 28, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Unicorn Chef Carnival Fair Food: Games for Girls',
#   'installs': '1,000,000+',
# ...
#   'price': 5.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '32M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 20, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Lightbot Jr : Coding Puzzles',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.58,
#   'ratings': 283,
#   'reviews': 81,
#   'histogram': [5, 5, 25, 28, 220],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '44M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 8, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Sprinkle Islands',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.5058403,
#   'ratings': 11207,
#   'reviews': 2220,
#   'histogram': [523, 322, 453, 1571, 8338],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 10, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'The Box of Secrets: Extended Escape',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.0,
#   'ratings': 32,
#   'reviews': 20,
#   'histogram': [5, 0, 4, 4, 19],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Doodle Kingdom',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.230769,
#   'ratings': 1955,
#   'reviews': 171,
#   'histogram': [150, 60, 150, 421, 1174],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 21, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Bulb Boy',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.6037736,
#   'ratings': 2123,
#   'reviews': 1038,
#   'histogram': [80, 30, 60, 310, 1643],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '29M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Sep 7, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Isoland',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.351852,
#   'ratings': 1092,
#   'reviews': 403,
#   'histogram': [101, 10, 70, 131, 780],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '33M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 5, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'One Circle',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.72,
#   'ratings': 25,
#   'reviews': 20,
#   'histogram': [1, 0, 0, 3, 21],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 28, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Cosmic Express',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.74,
#   'ratings': 373,
#   'reviews': 147,
#   'histogram': [0, 7, 18, 37, 311],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '78M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 16, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Sadhana - The way back',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.0,
#   'ratings': 5,
#   'reviews': 5,
#   'histogram': [1, 0, 0, 1, 3],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '91M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Sep 16, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Under Leaves',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.65,
#   'ratings': 137,
#   'reviews': 73,
#   'histogram': [0, 2, 5, 29, 101],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '86M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 23, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Dark Echo',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.607067,
#   'ratings': 14200,
#   'reviews': 4026,
#   'histogram': [582, 210, 481, 1656, 11271],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '43M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Feb 17, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Facility 47',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.69,
#   'ratings': 436,
#   'reviews': 195,
#   'histogram': [17, 0, 8, 48, 363],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '21M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 11, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Cut The Cookie',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 5.0,
#   'ratings': 5,
#   'reviews': 4,
#   'histogram': [0, 0, 0, 0, 5],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 29, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Cut the Rope 2 GOLD',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.39,
#   'ratings': 105,
#   'reviews': 61,
#   'histogram': [31, 5, 11, 8, 50],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'The Guides',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.772549,
#   'ratings': 2578,
#   'reviews': 555,
#   'histogram': [50, 20, 50, 222, 2236],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '40M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 16, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Lightbot : Programming Puzzles',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.7539268,
#   'ratings': 1950,
#   'reviews': 468,
#   'histogram': [51, 20, 30, 153, 1696],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '45M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 14, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Mind Games Pro',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.263964,
#   'ratings': 22319,
#   'reviews': 7400,
#   'histogram': [1759, 744, 1699, 3760, 14357],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 29, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Isoland 2: Ashes of Time',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.61,
#   'ratings': 518,
#   'reviews': 249,
#   'histogram': [10, 0, 36, 88, 384],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '32M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 28, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'CrossMe Color Premium Nonogram',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.870968,
#   'ratings': 1655,
#   'reviews': 475,
#   'histogram': [21, 10, 10, 74, 1540],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 18, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Peekaboo Farm & Zoo Ad Free',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 29, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Where Shadows Slumber',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.7,
#   'ratings': 368,
#   'reviews': 206,
#   'histogram': [11, 3, 7, 40, 307],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 20, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Thinkrolls Kings & Queens - Full',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.9,
#   'ratings': 50,
#   'reviews': 23,
#   'histogram': [0, 1, 0, 2, 47],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '59M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 27, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Hook',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.5032063,
#   'ratings': 29959,
#   'reviews': 10630,
#   'histogram': [1526, 626, 1435, 4024, 22348],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 20, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Pango Blocks',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.875,
#   'ratings': 72,
#   'reviews': 37,
#   'histogram': [10, 8, 5, 7, 42],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '34M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 5, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Mars Power Industries',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.41,
#   'ratings': 140,
#   'reviews': 75,
#   'histogram': [5, 5, 8, 27, 95],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '35M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 10, 2018',
#   'contentRating': 'Everyone'},
#  {'title': "Please Don't Touch Anything 3D",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.15,
#   'ratings': 407,
#   'reviews': 207,
#   'histogram': [53, 16, 24, 36, 278],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 7, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'ISOLAND: The Amusement Park',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.5052633,
#   'ratings': 95,
#   'reviews': 35,
#   'histogram': [2, 6, 2, 17, 68],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '30M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 2, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Mahjong 3 (Full)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.61875,
#   'ratings': 1590,
#   'reviews': 699,
#   'histogram': [19, 29, 39, 358, 1145],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '42M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 8, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'A Good Snowman',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.77,
#   'ratings': 513,
#   'reviews': 190,
#   'histogram': [15, 0, 0, 56, 442],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '72M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 9, 2015',
#   'contentRating': 'Everyone'},
#  {'title': '"OXXO"',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.88,
#   'ratings': 297,
#   'reviews': 130,
#   'histogram': [0, 0, 8, 17, 272],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '46M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 6, 2019',
#   'contentRating': 'Everyone'},
#  {'title': "Davey's Mystery 2",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5,
#   'ratings': 1312,
#   'reviews': 474,
#   'histogram': [30, 20, 80, 313, 869],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 19, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Motor Town:Soul of the Machine',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.1782947,
#   'ratings': 1295,
#   'reviews': 426,
#   'histogram': [110, 30, 140, 251, 764],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.7M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 14, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'rymdkapsel',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5525727,
#   'ratings': 4564,
#   'reviews': 945,
#   'histogram': [102, 102, 296, 735, 3329],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '49M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 31, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Magnet Balls PRO: Physics Puzzle',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.3741007,
#   'ratings': 2836,
#   'reviews': 1023,
#   'histogram': [193, 61, 204, 408, 1970],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 13, 2018',
#   'contentRating': 'Everyone'},
#  {'title': "Fantasy Mosaics 41: Wizard's Realm",
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.2,
#   'ratings': 5,
#   'reviews': 4,
#   'histogram': [1, 0, 0, 0, 4],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 1, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'JezzBall Classic',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.17,
#   'ratings': 129,
#   'reviews': 51,
#   'histogram': [11, 7, 9, 19, 83],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 3, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Fantasy Mosaics 42: Fairyland',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '14M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 31, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Evo Explores',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5578036,
#   'ratings': 3482,
#   'reviews': 1653,
#   'histogram': [90, 70, 191, 584, 2547],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '51M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Feb 11, 2016',
#   'contentRating': 'Everyone'},
#  {'title': "Pettson's Inventions Deluxe",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.56,
#   'ratings': 790,
#   'reviews': 128,
#   'histogram': [39, 7, 55, 55, 634],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 4, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Chess',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4903846,
#   'ratings': 1162,
#   'reviews': 530,
#   'histogram': [22, 33, 78, 246, 783],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.9M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Feb 29, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Doodle Kingdom HD',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.09,
#   'ratings': 833,
#   'reviews': 72,
#   'histogram': [58, 75, 58, 183, 459],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '35M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 21, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'The Hidden World',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.535326,
#   'ratings': 3709,
#   'reviews': 1016,
#   'histogram': [131, 70, 161, 665, 2682],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Sep 26, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'The Secret of Crimson Manor',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.1702127,
#   'ratings': 47,
#   'reviews': 11,
#   'histogram': [3, 2, 5, 11, 26],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '98M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 15, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Gears logic puzzles premium',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.7586207,
#   'ratings': 29,
#   'reviews': 13,
#   'histogram': [0, 0, 2, 3, 24],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '13M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 11, 2020',
#   'contentRating': 'Everyone'}]

# %%
len(listofdictinfo3)
# Out:
# 1000

# %%
listofdictinfo4 = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[3001:4001]))
listofdictinfo4
# Out:
# [{'title': 'Remember: A Horror Adventure Puzzle Game',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.51,
#   'ratings': 138,
#   'reviews': 88,
#   'histogram': [5, 2, 11, 15, 105],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '95M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 18, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'G30 - A Memory Maze',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.44,
#   'ratings': 410,
#   'reviews': 213,
#   'histogram': [20, 12, 28, 53, 297],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '15M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Feb 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Minesweeper Pro',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.432665,
#   'ratings': 14018,
#   'reviews': 4509,
#   'histogram': [662, 311, 903, 2561, 9581],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.7M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Dissembler',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.707692,
#   'ratings': 65,
#   'reviews': 25,
#   'histogram': [3, 0, 1, 5, 56],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 8, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Starman',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.5135136,
#   'ratings': 74,
#   'reviews': 32,
#   'histogram': [2, 3, 4, 11, 54],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Rhomb',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.5757575,
#   'ratings': 66,
#   'reviews': 32,
#   'histogram': [1, 0, 4, 16, 45],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 2, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'XON Episode Two',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.523077,
#   'ratings': 1318,
#   'reviews': 323,
#   'histogram': [50, 71, 20, 172, 1005],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '45M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 12, 2014',
#   'contentRating': 'Everyone'},
#  {'title': "Pettson's Inventions 2",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.72,
#   'ratings': 709,
#   'reviews': 149,
#   'histogram': [7, 14, 14, 99, 575],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '95M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Feb 21, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'SpongeBob Marbles & Slides',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.1,
#   'ratings': 182,
#   'reviews': 102,
#   'histogram': [73, 9, 9, 9, 82],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.7M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 4, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Tutti Frutti: NEW! Match 3 Game No Ads Free Lives!',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '46M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 14, 2020',
#   'contentRating': 'Everyone'},
#  {'title': "Slayaway Camp: 1980's Horror Puzzle Fun!",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.3140683,
#   'ratings': 13185,
#   'reviews': 4930,
#   'histogram': [902, 421, 1103, 1965, 8794],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '71M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 12, 2017',
#   'contentRating': 'Mature 17+'},
#  {'title': 'LYNE',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.766234,
#   'ratings': 3142,
#   'reviews': 472,
#   'histogram': [20, 30, 142, 275, 2675],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '48M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 1, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Returner 77',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.248,
#   'ratings': 1253,
#   'reviews': 650,
#   'histogram': [90, 40, 120, 220, 783],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '53M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 11, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Feed Me Oil 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2526317,
#   'ratings': 3815,
#   'reviews': 421,
#   'histogram': [341, 140, 261, 542, 2531],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 10, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Kiwanuka',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2037916,
#   'ratings': 2126,
#   'reviews': 347,
#   'histogram': [100, 80, 292, 464, 1190],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '21M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 6, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Kenshō',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.05,
#   'ratings': 626,
#   'reviews': 291,
#   'histogram': [56, 25, 87, 119, 339],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '126M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 22, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Seven Scrolls',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 4.725,
#   'ratings': 40,
#   'reviews': 18,
#   'histogram': [0, 2, 1, 3, 34],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '88M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 6, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'NABOKI',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.58,
#   'ratings': 940,
#   'reviews': 366,
#   'histogram': [9, 18, 66, 169, 678],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '36M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 12, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'A Foreign Land of Us',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.2105265,
#   'ratings': 19,
#   'reviews': 13,
#   'histogram': [2, 0, 1, 5, 11],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Bleentoro Pro',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.81,
#   'ratings': 309,
#   'reviews': 169,
#   'histogram': [3, 3, 3, 31, 269],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.7M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 19, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Tangram Master Premium',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.75,
#   'ratings': 126,
#   'reviews': 56,
#   'histogram': [2, 1, 1, 15, 107],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 2, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Back to Bed',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.8181818,
#   'ratings': 1668,
#   'reviews': 400,
#   'histogram': [283, 121, 131, 212, 921],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '17M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 28, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search Solver',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 2.409091,
#   'ratings': 22,
#   'reviews': 21,
#   'histogram': [12, 0, 4, 1, 5],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '335k',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 9, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Greedy Spiders',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.78,
#   'ratings': 5622,
#   'reviews': 3272,
#   'histogram': [0, 112, 56, 787, 4667],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '20M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 2, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Fantasy Mosaics 31: First Date',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 5.0,
#   'ratings': 7,
#   'reviews': 3,
#   'histogram': [0, 0, 0, 0, 7],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '97M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 14, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'ELOH',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.39,
#   'ratings': 320,
#   'reviews': 152,
#   'histogram': [25, 3, 25, 32, 235],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Oct 9, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Super Gridland',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.9767442,
#   'ratings': 86,
#   'reviews': 52,
#   'histogram': [5, 6, 15, 20, 40],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 6, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Doodle Tanks™',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.3,
#   'ratings': 214,
#   'reviews': 61,
#   'histogram': [36, 30, 49, 30, 69],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '36M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 10, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Million Onion Hotel',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.72,
#   'ratings': 615,
#   'reviews': 287,
#   'histogram': [0, 24, 12, 74, 505],
#   'price': 4.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '72M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 1, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Road Not Taken',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.24,
#   'ratings': 190,
#   'reviews': 110,
#   'histogram': [1, 21, 23, 28, 117],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 14, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Bring You Home',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.26,
#   'ratings': 163,
#   'reviews': 99,
#   'histogram': [21, 1, 6, 18, 117],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Legacy 3 - The Hidden Relic',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.287582,
#   'ratings': 1546,
#   'reviews': 870,
#   'histogram': [111, 50, 151, 202, 1032],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '99M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 21, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Photographs - Puzzle Stories',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.29,
#   'ratings': 216,
#   'reviews': 104,
#   'histogram': [8, 10, 30, 26, 142],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '100M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Apr 11, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Hangman Premium',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.197647,
#   'ratings': 4266,
#   'reviews': 1489,
#   'histogram': [341, 150, 371, 863, 2541],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '22M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 13, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Gurk III, the 8-bit RPG',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.716981,
#   'ratings': 1613,
#   'reviews': 598,
#   'histogram': [60, 10, 30, 121, 1392],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 5, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': "ROOMS: The Toymaker's Mansion",
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.4950495,
#   'ratings': 234,
#   'reviews': 144,
#   'histogram': [11, 9, 4, 35, 175],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '96M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jun 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'the Sequence [2]',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.8,
#   'ratings': 185,
#   'reviews': 76,
#   'histogram': [0, 0, 7, 22, 156],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '57M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 28, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'CrossMe Nonograms Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.8453608,
#   'ratings': 2078,
#   'reviews': 615,
#   'histogram': [32, 0, 32, 128, 1886],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 29, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Deus Ex GO',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.9422092,
#   'ratings': 13743,
#   'reviews': 4632,
#   'histogram': [1488, 804, 1558, 3056, 6837],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '23M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 17, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'reky',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.0,
#   'ratings': 10,
#   'reviews': 7,
#   'histogram': [0, 2, 1, 2, 5],
#   'price': 4.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '54M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Concrete Jungle',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.56,
#   'ratings': 162,
#   'reviews': 66,
#   'histogram': [4, 6, 4, 23, 125],
#   'price': 4.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '95M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Sep 28, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Mahjong Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.43,
#   'ratings': 375,
#   'reviews': 138,
#   'histogram': [18, 7, 18, 79, 253],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '8.3M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 13, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Sudoku PRO',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.8,
#   'ratings': 1499,
#   'reviews': 618,
#   'histogram': [10, 10, 10, 207, 1262],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 14, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Mekorama VR',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.3818183,
#   'ratings': 55,
#   'reviews': 35,
#   'histogram': [4, 2, 4, 4, 41],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.6M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 8, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Sokodice',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 5.0,
#   'ratings': 6,
#   'reviews': 4,
#   'histogram': [0, 0, 0, 0, 6],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '121M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Sep 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search Premium',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.6506276,
#   'ratings': 4795,
#   'reviews': 1604,
#   'histogram': [50, 30, 321, 742, 3652],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '14M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 13, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Quell Zen',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.44,
#   'ratings': 420,
#   'reviews': 205,
#   'histogram': [42, 0, 12, 42, 324],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '92M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 13, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Dream Machine - The Game',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2268906,
#   'ratings': 1201,
#   'reviews': 482,
#   'histogram': [80, 30, 131, 252, 708],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '49M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 22, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Mr Snoozleberg',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.85,
#   'ratings': 190,
#   'reviews': 69,
#   'histogram': [36, 5, 23, 11, 115],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '49M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Nov 6, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Farm Animals Puzzle by Dave and Ava',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.3186812,
#   'ratings': 91,
#   'reviews': 57,
#   'histogram': [17, 13, 20, 6, 35],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '62M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 4, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Where is cat?',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.55,
#   'ratings': 153,
#   'reviews': 87,
#   'histogram': [6, 4, 7, 15, 121],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 10, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Death Squared',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.5,
#   'ratings': 518,
#   'reviews': 291,
#   'histogram': [161, 20, 10, 52, 275],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 28, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Lyfoes',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.54,
#   'ratings': 321,
#   'reviews': 167,
#   'histogram': [12, 9, 19, 29, 252],
#   'price': 1.0,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 9, 2014',
#   'contentRating': 'Everyone'},
#  {'title': "Please, Don't Touch Anything VR",
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 3.8181818,
#   'ratings': 11,
#   'reviews': 6,
#   'histogram': [1, 2, 1, 1, 6],
#   'price': 8.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '27M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 23, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Fantasy Mosaics 35: Day at the Museum',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jul 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Alt-Frequencies',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.41,
#   'ratings': 109,
#   'reviews': 62,
#   'histogram': [2, 7, 4, 24, 72],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '38M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 15, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Tic tac toe pro',
#   'installs': '5+',
#   'minInstalls': 5,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.3M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Aug 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Hexologic',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.57,
#   'ratings': 465,
#   'reviews': 243,
#   'histogram': [9, 0, 37, 88, 331],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'May 28, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Cut the Rope: Experiments GOLD',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.2582645,
#   'ratings': 15147,
#   'reviews': 5316,
#   'histogram': [1189, 532, 1001, 2879, 9546],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '49M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 17, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Mushroom 11',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.62,
#   'ratings': 516,
#   'reviews': 233,
#   'histogram': [20, 0, 36, 41, 419],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '20M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Mar 8, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Sudoku Samurai HD',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.214286,
#   'ratings': 14,
#   'reviews': 6,
#   'histogram': [0, 3, 0, 2, 9],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '83M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Feb 27, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Kakuro Puzzles',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.36,
#   'ratings': 283,
#   'reviews': 114,
#   'histogram': [17, 8, 22, 42, 194],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '8.6M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Dec 11, 2012',
#   'contentRating': 'Everyone'},
#  {'title': "Ferris Mueller's Day Off -Wild West Adventure Game",
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.4,
#   'ratings': 131,
#   'reviews': 47,
#   'histogram': [6, 1, 13, 22, 89],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Puzzle',
#   'genreId': 'GAME_PUZZLE',
#   'released': 'Jan 15, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Slingshot Stunt Driver',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.811226,
#   'ratings': 38067,
#   'reviews': 10350,
#   'histogram': [6561, 2106, 3810, 5069, 20521],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '106M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 10, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Extreme Car Driving Simulator',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.1900506,
#   'ratings': 3158732,
#   'reviews': 1194185,
#   'histogram': [386911, 113450, 190173, 290070, 2178128],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '53M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 15, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Fun Race 3D',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.163841,
#   'ratings': 1703407,
#   'reviews': 784994,
#   'histogram': [195953, 66753, 125124, 190000, 1125577],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'May 28, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Rebel Racing',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4349647,
#   'ratings': 313257,
#   'reviews': 110024,
#   'histogram': [17837, 7445, 18909, 45495, 223571],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Nov 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Epic Race 3D',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 3.979324,
#   'ratings': 142574,
#   'reviews': 59151,
#   'histogram': [21090, 7725, 11336, 15313, 87110],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jan 5, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Traffic Rider',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3832555,
#   'ratings': 7262885,
#   'reviews': 2492784,
#   'histogram': [556698, 180797, 424361, 861436, 5239593],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '109M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jan 11, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Asphalt 9: Legends - Epic Car Action Racing Game',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.458748,
#   'ratings': 1719470,
#   'reviews': 701745,
#   'histogram': [120506, 36362, 74247, 191058, 1297297],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '96M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 25, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Street Racing 3D',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.291053,
#   'ratings': 1186021,
#   'reviews': 459390,
#   'histogram': [110146, 32576, 76615, 149282, 817402],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '85M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 10, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Happy Wheels',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0583014,
#   'ratings': 190125,
#   'reviews': 73088,
#   'histogram': [24458, 8032, 15874, 25362, 116399],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '30M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jan 25, 2020',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Hill Climb Racing',
#   'installs': '500,000,000+',
#   'minInstalls': 500000000,
#   'score': 4.316961,
#   'ratings': 9849577,
#   'reviews': 2577211,
#   'histogram': [940406, 277519, 577516, 978431, 7075705],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Sep 22, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Earn to Die 2',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.350504,
#   'ratings': 1688985,
#   'reviews': 528636,
#   'histogram': [135984, 44404, 104249, 211340, 1193008],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '75M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'May 4, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'RacerKing',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 2.4,
#   'ratings': 278,
#   'reviews': 164,
#   'histogram': [148, 22, 16, 33, 59],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '57M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Sep 8, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Moto X3M Bike Race Game',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.3166428,
#   'ratings': 283158,
#   'reviews': 123396,
#   'histogram': [27651, 8508, 15718, 25929, 205352],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 18, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Hill Climb Racing 2',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.372041,
#   'ratings': 3890605,
#   'reviews': 1330934,
#   'histogram': [310185, 94597, 207746, 503111, 2774966],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '133M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Nov 27, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Car Driving Simulator',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.1471124,
#   'ratings': 375105,
#   'reviews': 163355,
#   'histogram': [45515, 14726, 26512, 40656, 247696],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Feb 18, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Racing in Car 2',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.0028896,
#   'ratings': 574212,
#   'reviews': 202410,
#   'histogram': [90341, 26979, 38362, 53526, 365004],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Nov 12, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Asphalt 8: Airborne - Fun Real Car Racing Game',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.333059,
#   'ratings': 9325593,
#   'reviews': 3156215,
#   'histogram': [976349, 212029, 401508, 875121, 6860586],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '86M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 20, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Need for Speed™ No Limits',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.080195,
#   'ratings': 4280017,
#   'reviews': 1609260,
#   'histogram': [627618, 142742, 253025, 492031, 2764601],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '59M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Sep 16, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Jumpero',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.652174,
#   'ratings': 1667,
#   'reviews': 595,
#   'histogram': [352, 145, 134, 134, 902],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '49M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 19, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Fast Driver 3D',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 2.71,
#   'ratings': 602,
#   'reviews': 256,
#   'histogram': [253, 72, 60, 30, 187],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '100M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Offroad Outlaws',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2824106,
#   'ratings': 98586,
#   'reviews': 53590,
#   'histogram': [10935, 3076, 4761, 8251, 71563],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '144M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Dec 20, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Turbo Stars',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.393507,
#   'ratings': 683963,
#   'reviews': 287017,
#   'histogram': [54113, 17997, 40322, 63728, 507803],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 30, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Car Stunt Races: Mega Ramps',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.167837,
#   'ratings': 41546,
#   'reviews': 16053,
#   'histogram': [5121, 1398, 2586, 4719, 27722],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '84M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 24, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Wheel Scale!',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.77597,
#   'ratings': 8074,
#   'reviews': 2300,
#   'histogram': [1212, 566, 1192, 950, 4154],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '131M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 20, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Real Bike Racing',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.05268,
#   'ratings': 676272,
#   'reviews': 255632,
#   'histogram': [101242, 27467, 46653, 59970, 440940],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '21M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Sep 20, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Drive Ahead!',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.2928996,
#   'ratings': 1345343,
#   'reviews': 524887,
#   'histogram': [144115, 39689, 68700, 118364, 974475],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '71M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Oct 7, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'CSR Racing 2 – Free Car Racing Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.5965786,
#   'ratings': 4221206,
#   'reviews': 1877242,
#   'histogram': [160457, 61367, 167015, 542961, 3289406],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '77M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jun 29, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Drive for Speed: Simulator',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.09981,
#   'ratings': 401509,
#   'reviews': 157245,
#   'histogram': [60232, 13994, 22476, 33569, 271238],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '116M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Oct 25, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Bike Race Free - Top Motorcycle Racing Games',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.2724266,
#   'ratings': 2885231,
#   'reviews': 931919,
#   'histogram': [301238, 77654, 177583, 306135, 2022621],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '31M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 23, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Hot Wheels: Race Off',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.098159,
#   'ratings': 719235,
#   'reviews': 249466,
#   'histogram': [103496, 24780, 43029, 74251, 473679],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '121M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Dec 21, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Blocky Moto Racing 🏁 - motorcycle rider',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.092042,
#   'ratings': 25173,
#   'reviews': 12093,
#   'histogram': [3885, 971, 1355, 1689, 17273],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '43M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jun 30, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Driving School Sim - 2020',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.409186,
#   'ratings': 14960,
#   'reviews': 6186,
#   'histogram': [1041, 343, 843, 1957, 10776],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '93M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Sep 1, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Car Stunts 3D Free - Extreme City GT Racing',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.017143,
#   'ratings': 45905,
#   'reviews': 15633,
#   'histogram': [7506, 1866, 2835, 3823, 29875],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '75M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Nov 28, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Motorcycle Simulator',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.055252,
#   'ratings': 110607,
#   'reviews': 46729,
#   'histogram': [16159, 5185, 6997, 10309, 71957],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '86M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Apr 5, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Nitro Nation Drag & Drift',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.5472074,
#   'ratings': 1447923,
#   'reviews': 440304,
#   'histogram': [73659, 22862, 59256, 173870, 1118276],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '62M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Apr 2, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Off The Road - OTR Open World Driving',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3938003,
#   'ratings': 181711,
#   'reviews': 88600,
#   'histogram': [15138, 5029, 8600, 17311, 135633],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '15M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 24, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Super High School Bus Driving Simulator 3D - 2020',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1316686,
#   'ratings': 35742,
#   'reviews': 16976,
#   'histogram': [4939, 1328, 2079, 3134, 24262],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '143M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 23, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Fun Run 3 - Multiplayer Games',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2575083,
#   'ratings': 230824,
#   'reviews': 100636,
#   'histogram': [25590, 6349, 12669, 24636, 161580],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '87M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Nov 30, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Stock Car Racing',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0450816,
#   'ratings': 216509,
#   'reviews': 92451,
#   'histogram': [29422, 9027, 17703, 26570, 133787],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '60M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Feb 7, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Trial Xtreme 4: Extreme Bike Racing Champions',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0882115,
#   'ratings': 719399,
#   'reviews': 205180,
#   'histogram': [97985, 25586, 49779, 87682, 458367],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jan 14, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Top Drives – Car Cards Racing',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.4547825,
#   'ratings': 265558,
#   'reviews': 83011,
#   'histogram': [19953, 5266, 10573, 28028, 201738],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 29, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Taxi Run - Crazy Driver',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.351799,
#   'ratings': 21269,
#   'reviews': 7903,
#   'histogram': [1752, 846, 1279, 1681, 15711],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '71M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'May 28, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Wheel Race',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.2519083,
#   'ratings': 1465,
#   'reviews': 471,
#   'histogram': [134, 112, 33, 156, 1030],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '76M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 13, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Racing Fever: Moto',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.2221026,
#   'ratings': 484042,
#   'reviews': 195563,
#   'histogram': [53553, 17171, 30319, 50170, 332829],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '110M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jan 9, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Real Car Race Game 3D: Fun New Car Games 2020',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9886363,
#   'ratings': 53552,
#   'reviews': 27917,
#   'histogram': [9027, 2038, 3610, 4716, 34161],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '37M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Dec 3, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Traffic Tour',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9287322,
#   'ratings': 298486,
#   'reviews': 105081,
#   'histogram': [53968, 12827, 20099, 25204, 186388],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '71M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Aug 31, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Real Racing 3',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.436307,
#   'ratings': 403888,
#   'reviews': 146759,
#   'histogram': [27921, 9065, 17960, 52867, 296075],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '44M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Feb 27, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Demolition Derby 2',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.5724516,
#   'ratings': 772065,
#   'reviews': 524446,
#   'histogram': [38780, 13478, 31213, 72111, 616483],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '94M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'May 20, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Drift Max Pro - Car Drifting Game with Racing Cars',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4896927,
#   'ratings': 1166502,
#   'reviews': 479667,
#   'histogram': [77089, 22064, 53282, 114157, 899910],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '54M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Dec 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Race the Traffic',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.072173,
#   'ratings': 291116,
#   'reviews': 61781,
#   'histogram': [38015, 12918, 25745, 27798, 186640],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 3, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Beach Buggy Racing',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.4129524,
#   'ratings': 1963686,
#   'reviews': 724478,
#   'histogram': [153850, 44437, 96716, 210632, 1458051],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '79M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Sep 16, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Demolition Derby 3',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.609492,
#   'ratings': 214619,
#   'reviews': 153382,
#   'histogram': [9163, 3157, 8992, 19699, 173608],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '128M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Dec 22, 2018',
#   'contentRating': 'Teen'},
#  {'title': '#DRIVE',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.504749,
#   'ratings': 140603,
#   'reviews': 49518,
#   'histogram': [5542, 2610, 7651, 24329, 100471],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '89M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Mar 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Traffic Racer',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.493686,
#   'ratings': 5908754,
#   'reviews': 1569355,
#   'histogram': [365206, 117398, 297086, 584491, 4544573],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '59M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Nov 12, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Racing Clash',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.3555555,
#   'ratings': 45,
#   'reviews': 21,
#   'histogram': [13, 4, 3, 4, 21],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '119M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jun 23, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Trucks Off Road',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.0187306,
#   'ratings': 19330,
#   'reviews': 9655,
#   'histogram': [2846, 844, 1609, 1830, 12201],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Nov 23, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Driving Academy 2: Car Games & Driving School 2020',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.023256,
#   'ratings': 38559,
#   'reviews': 16888,
#   'histogram': [5808, 1742, 2822, 3556, 24631],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '142M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Feb 19, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Race.io',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.21655,
#   'ratings': 214586,
#   'reviews': 106304,
#   'histogram': [24398, 6942, 14416, 20866, 147964],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Apr 26, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Driving Academy - Car School Driver Simulator 2020',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2655225,
#   'ratings': 127240,
#   'reviews': 50971,
#   'histogram': [11473, 4257, 9440, 15911, 86159],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '135M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Dec 15, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'CarX Highway Racing',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.506361,
#   'ratings': 552255,
#   'reviews': 212907,
#   'histogram': [29665, 10302, 24825, 73393, 414070],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '59M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 26, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Dr. Driving',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.2054214,
#   'ratings': 5809843,
#   'reviews': 2231130,
#   'histogram': [694841, 209242, 353194, 502895, 4049671],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '12M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jun 19, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'Uphill Rush Water Park Racing',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.131882,
#   'ratings': 661227,
#   'reviews': 291929,
#   'histogram': [88087, 26031, 41831, 59918, 445360],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '92M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jan 25, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'SUP Multiplayer Racing',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.222216,
#   'ratings': 367753,
#   'reviews': 160798,
#   'histogram': [43681, 12147, 20470, 33923, 257532],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'May 30, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Big Rig Racing',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.5645294,
#   'ratings': 12115,
#   'reviews': 3381,
#   'histogram': [302, 171, 665, 2219, 8758],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '62M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'Jul 15, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Driving School Simulator 2020',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.095261,
#   'ratings': 82731,
#   'reviews': 31459,
#   'histogram': [10297, 3349, 6337, 10939, 51809],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '102M',
#   'genre': 'Racing',
#   'genreId': 'GAME_RACING',
#   'released': 'May 19, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Gravity Rider: Extreme Balance Space Bike Racing',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3200316,
#   'ratings': 63432,
#   'reviews': 23590,
# ...
#  {'title': 'Hunting USA',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.63,
#   'ratings': 395,
#   'reviews': 261,
#   'histogram': [91, 23, 35, 35, 211],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '93M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 9, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Train Simulator PRO 2018',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.8267717,
#   'ratings': 1278,
#   'reviews': 774,
#   'histogram': [201, 80, 181, 90, 726],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '36M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 5, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Dealer’s Life - Pawn Shop Tycoon',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.538983,
#   'ratings': 2953,
#   'reviews': 1297,
#   'histogram': [110, 80, 140, 400, 2223],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '52M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 10, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Fox Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2992425,
#   'ratings': 2655,
#   'reviews': 1672,
#   'histogram': [241, 50, 181, 382, 1801],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 21, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Call For Fire',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.4545455,
#   'ratings': 66,
#   'reviews': 45,
#   'histogram': [2, 1, 2, 21, 40],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '62M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 17, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Ultimate Dinosaur Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.200855,
#   'ratings': 2351,
#   'reviews': 1544,
#   'histogram': [191, 100, 231, 351, 1478],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jan 14, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Scuba Diving Challenge',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 23, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Townsmen 6',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.61,
#   'ratings': 1441,
#   'reviews': 491,
#   'histogram': [288, 115, 144, 216, 678],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '15M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 4, 2011',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'SIMULACRA 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.524272,
#   'ratings': 1031,
#   'reviews': 571,
#   'histogram': [60, 10, 40, 140, 781],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '66M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 11, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Lawgivers',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.57971,
#   'ratings': 1387,
#   'reviews': 514,
#   'histogram': [10, 10, 120, 271, 976],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '50M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 14, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Farming PRO 3',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 2.83,
#   'ratings': 262,
#   'reviews': 160,
#   'histogram': [116, 15, 23, 13, 95],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '54M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 23, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Mega Mall Story2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.627451,
#   'ratings': 1532,
#   'reviews': 827,
#   'histogram': [30, 10, 90, 240, 1162],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '60M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 21, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Solar 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.3667545,
#   'ratings': 3817,
#   'reviews': 594,
#   'histogram': [251, 90, 302, 534, 2640],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '45M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 5, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Wolf Simulator',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.201282,
#   'ratings': 7817,
#   'reviews': 4245,
#   'histogram': [912, 230, 441, 1022, 5212],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 7, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Ultimate Lion Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2491693,
#   'ratings': 3016,
#   'reviews': 1689,
#   'histogram': [280, 90, 230, 411, 2005],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 14, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Passpartout: The Starving Artist',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.320463,
#   'ratings': 2598,
#   'reviews': 1641,
#   'histogram': [200, 60, 190, 401, 1747],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '127M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 30, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Train Sim Pro',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2421055,
#   'ratings': 1913,
#   'reviews': 836,
#   'histogram': [181, 40, 221, 161, 1310],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '116M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 1, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Traffix',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.282486,
#   'ratings': 5323,
#   'reviews': 1786,
#   'histogram': [310, 180, 451, 1133, 3249],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '62M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 12, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Weaphones™ WW2: Firearms Sim',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.65,
#   'ratings': 195,
#   'reviews': 76,
#   'histogram': [5, 1, 9, 19, 161],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 8, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'PicaSim: Flight simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.7234044,
#   'ratings': 1475,
#   'reviews': 740,
#   'histogram': [31, 20, 41, 136, 1247],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '56M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 12, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Pacific Fleet',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.3757725,
#   'ratings': 8134,
#   'reviews': 1554,
#   'histogram': [502, 291, 563, 1066, 5712],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '30M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 13, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'PC Creator PRO - PC Building Simulator',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 4.3076925,
#   'ratings': 181,
#   'reviews': 108,
#   'histogram': [10, 14, 10, 21, 126],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '103M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Space Agency 2138',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.09,
#   'ratings': 157,
#   'reviews': 122,
#   'histogram': [14, 11, 12, 28, 92],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '38M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 15, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Atlantic Fleet',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5013475,
#   'ratings': 3723,
#   'reviews': 1670,
#   'histogram': [150, 140, 120, 592, 2721],
#   'price': 9.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '80M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 20, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Kirikiroid2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.26,
#   'ratings': 459,
#   'reviews': 219,
#   'histogram': [50, 18, 13, 55, 323],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 13, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Gunship III',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.183007,
#   'ratings': 3078,
#   'reviews': 1651,
#   'histogram': [281, 130, 201, 594, 1872],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '24M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 27, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Construction Simulator PRO',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.9166667,
#   'ratings': 1322,
#   'reviews': 566,
#   'histogram': [230, 80, 50, 170, 792],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 2, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'FPV Freerider Recharged',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.35,
#   'ratings': 166,
#   'reviews': 124,
#   'histogram': [11, 5, 13, 20, 117],
#   'price': 6.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 22, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'PC Architect Advanced (PC building simulator)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.48,
#   'ratings': 493,
#   'reviews': 305,
#   'histogram': [14, 19, 19, 99, 342],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '27M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 5, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Station Manager',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4481707,
#   'ratings': 3301,
#   'reviews': 1605,
#   'histogram': [211, 90, 120, 463, 2417],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '43M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 8, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Top Sailor sailing simulator',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.41,
#   'ratings': 307,
#   'reviews': 145,
#   'histogram': [15, 9, 18, 55, 210],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '51M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 22, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Levelhead',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.53,
#   'ratings': 730,
#   'reviews': 370,
#   'histogram': [36, 21, 29, 73, 571],
#   'price': 6.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '266M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 30, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Esports Life Tycoon | Manage your esports team',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.21,
#   'ratings': 168,
#   'reviews': 87,
#   'histogram': [42, 17, 30, 22, 57],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '39M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 13, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Its TITANIC premium',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.37,
#   'ratings': 133,
#   'reviews': 91,
#   'histogram': [9, 8, 4, 14, 98],
#   'price': 2.19,
#   'free': False,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 8, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Cult Manager Tycoon',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.869565,
#   'ratings': 23,
#   'reviews': 15,
#   'histogram': [0, 0, 1, 1, 21],
#   'price': 1.5,
#   'free': False,
#   'offersIAP': False,
#   'size': '32M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 18, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Ant Simulation 3D Full',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.903226,
#   'ratings': 93,
#   'reviews': 55,
#   'histogram': [14, 4, 9, 16, 50],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '120M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 1, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'This Is the Police',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.255682,
#   'ratings': 1774,
#   'reviews': 584,
#   'histogram': [141, 90, 131, 222, 1190],
#   'price': 7.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '29M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 12, 2018',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Planet zoo new world',
#   'installs': '50+',
#   'minInstalls': 50,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '70M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'simLeaf',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.52,
#   'ratings': 100,
#   'reviews': 69,
#   'histogram': [22, 6, 15, 12, 45],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '49M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 19, 2018',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Space Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.84,
#   'ratings': 904,
#   'reviews': 547,
#   'histogram': [163, 36, 81, 126, 498],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '24M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 26, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'F-Sim Space Shuttle',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.382231,
#   'ratings': 5656,
#   'reviews': 2351,
#   'histogram': [502, 175, 198, 561, 4220],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 13, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Farming PRO 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.73,
#   'ratings': 567,
#   'reviews': 318,
#   'histogram': [108, 34, 62, 62, 301],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '27M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 3, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Motor Depot',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2526455,
#   'ratings': 7579,
#   'reviews': 4672,
#   'histogram': [732, 260, 531, 892, 5164],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 20, 2018',
#   'contentRating': 'Everyone'}]

# %%
len(listofdictinfo4)
# Out:
# 1000

# %%
listofdictinfo5 = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[4001:5001]))
listofdictinfo5
# Out:
# [{'title': 'Minecraft: Skin Studio',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8080645,
#   'ratings': 6223,
#   'reviews': 1765,
#   'histogram': [1024, 451, 642, 682, 3424],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.9M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 16, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Oh...Sir! The Insult Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.17,
#   'ratings': 744,
#   'reviews': 389,
#   'histogram': [67, 37, 74, 89, 477],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '93M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 21, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Star Command',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.4974174,
#   'ratings': 19520,
#   'reviews': 4160,
#   'histogram': [3710, 2057, 2490, 3337, 7926],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.8M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 6, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Hmmsim 2 - Train Simulator',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.210412,
#   'ratings': 4620,
#   'reviews': 2563,
#   'histogram': [601, 110, 200, 511, 3198],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '93M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 19, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'HARVEST MOON:Seeds Of Memories',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.7194245,
#   'ratings': 1402,
#   'reviews': 777,
#   'histogram': [343, 40, 90, 121, 808],
#   'price': 9.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 18, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Weaphones™ Antiques Gun Sim',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.0609756,
#   'ratings': 82,
#   'reviews': 27,
#   'histogram': [9, 1, 12, 14, 46],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 30, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Silver Screen Story',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.3152175,
#   'ratings': 1848,
#   'reviews': 937,
#   'histogram': [60, 30, 211, 512, 1035],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '61M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Dragon Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2968035,
#   'ratings': 2205,
#   'reviews': 1306,
#   'histogram': [141, 50, 221, 393, 1400],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 26, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'SimpleRockets',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.3003755,
#   'ratings': 8061,
#   'reviews': 1763,
#   'histogram': [555, 312, 625, 1231, 5338],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '24M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 3, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'FsRadioPanel Pro',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.57,
#   'ratings': 278,
#   'reviews': 204,
#   'histogram': [8, 5, 2, 64, 199],
#   'price': 11.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '13M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 14, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Fiz : Brewery Management Game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.223077,
#   'ratings': 7888,
#   'reviews': 848,
#   'histogram': [485, 515, 748, 1143, 4997],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 12, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'Dr. Panda Mailman',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.4444447,
#   'ratings': 1361,
#   'reviews': 469,
#   'histogram': [111, 40, 60, 70, 1080],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 19, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Weaphones™ Firearms Sim Vol 2',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.4179106,
#   'ratings': 67,
#   'reviews': 18,
#   'histogram': [3, 4, 4, 7, 49],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '22M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 9, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Kids Trains Pro',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 4.6666665,
#   'ratings': 9,
#   'reviews': 3,
#   'histogram': [0, 1, 0, 0, 8],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '45M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 30, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Endless ATC',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.9,
#   'ratings': 670,
#   'reviews': 291,
#   'histogram': [0, 0, 0, 67, 603],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.5M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 12, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Anime Studio Story',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4574466,
#   'ratings': 3773,
#   'reviews': 420,
#   'histogram': [150, 70, 301, 632, 2620],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 2, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Zombie Simulator Z - Premium',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.3939395,
#   'ratings': 99,
#   'reviews': 72,
#   'histogram': [8, 5, 5, 3, 78],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '75M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 18, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Bus Simulator PRO 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.426087,
#   'ratings': 2307,
#   'reviews': 1111,
#   'histogram': [632, 130, 271, 170, 1104],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '27M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 5, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'GeoFS - Flight Simulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.53,
#   'ratings': 123,
#   'reviews': 108,
#   'histogram': [18, 16, 21, 17, 51],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '93M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 27, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Game Studio Tycoon 3',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.881356,
#   'ratings': 2368,
#   'reviews': 1069,
#   'histogram': [301, 60, 321, 622, 1064],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 26, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'F18 Carrier Landing',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.483766,
#   'ratings': 8230,
#   'reviews': 3490,
#   'histogram': [347, 147, 481, 1456, 5799],
#   'price': 12.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 26, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Weapon stripping NoAds',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.81,
#   'ratings': 524,
#   'reviews': 225,
#   'histogram': [10, 5, 5, 31, 473],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 1, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Sifting Thyme: Otome Visual Novel',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.612903,
#   'ratings': 31,
#   'reviews': 22,
#   'histogram': [1, 1, 0, 5, 24],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 14, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Democratic Socialism Simulator',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 4.2352943,
#   'ratings': 51,
#   'reviews': 32,
#   'histogram': [3, 2, 5, 11, 30],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '40M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 21, 2020',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Stray Cat Simulator',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.3378015,
#   'ratings': 3749,
#   'reviews': 2173,
#   'histogram': [281, 110, 211, 603, 2544],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 28, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Farm Simulator',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.39,
#   'ratings': 359,
#   'reviews': 272,
#   'histogram': [79, 36, 50, 54, 140],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '79M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 17, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'The Manga Works',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.3,
#   'ratings': 700,
#   'reviews': 249,
#   'histogram': [42, 28, 56, 126, 448],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '32M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 4, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Zoolax Nights:Evil Clowns Full, Escape Challenge',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.86,
#   'ratings': 239,
#   'reviews': 135,
#   'histogram': [4, 0, 2, 9, 224],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '79M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 3, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Bridge Constructor Medieval',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8708487,
#   'ratings': 8167,
#   'reviews': 1686,
#   'histogram': [1296, 452, 763, 1155, 4501],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 30, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Football Manager 2020 Touch',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.4796748,
#   'ratings': 1241,
#   'reviews': 830,
#   'histogram': [353, 20, 121, 171, 576],
#   'price': 19.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 18, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Truck Simulator PRO 2016',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.9628482,
#   'ratings': 3238,
#   'reviews': 1263,
#   'histogram': [521, 160, 190, 411, 1956],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '25M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 25, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Gunship III - U.S. NAVY',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.216783,
#   'ratings': 1440,
#   'reviews': 684,
#   'histogram': [141, 50, 100, 211, 938],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 12, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Gunship III Vietnam People AF',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.31,
#   'ratings': 849,
#   'reviews': 364,
#   'histogram': [76, 25, 51, 102, 595],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 7, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Air Navy Fighters Xperia TM',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.38,
#   'ratings': 159,
#   'reviews': 38,
#   'histogram': [4, 8, 8, 40, 99],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 20, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'GS-III Heroes of the MIG Alley',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.92,
#   'ratings': 412,
#   'reviews': 227,
#   'histogram': [49, 20, 62, 62, 219],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 19, 2014',
#   'contentRating': 'Everyone'},
#  {'title': "Kitty Powers' Love Life",
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.21,
#   'ratings': 200,
#   'reviews': 114,
#   'histogram': [18, 10, 18, 20, 134],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '55M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 5, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'RESCUE: Heroes in Action',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.7244093,
#   'ratings': 1272,
#   'reviews': 310,
#   'histogram': [240, 60, 180, 120, 672],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '22M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Dr. Panda in Space',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.7,
#   'ratings': 601,
#   'reviews': 172,
#   'histogram': [84, 66, 90, 66, 295],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Shiny Ski Resort',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.45,
#   'ratings': 537,
#   'reviews': 234,
#   'histogram': [32, 5, 37, 75, 388],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': True,
#   'size': '49M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 7, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Gunship III - STRIKE PACKAGE',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.14,
#   'ratings': 908,
#   'reviews': 428,
#   'histogram': [118, 9, 63, 154, 564],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '19M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 5, 2014',
#   'contentRating': 'Everyone'},
#  {'title': '論如何建立一個修仙門派',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.87,
#   'ratings': 330,
#   'reviews': 182,
#   'histogram': [43, 26, 33, 56, 172],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '31M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 5, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Fix My Car: Classic Muscle 2 - Junkyard Blitz!',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.46,
#   'ratings': 668,
#   'reviews': 246,
#   'histogram': [67, 6, 20, 33, 542],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 3, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Falcon Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.203252,
#   'ratings': 1236,
#   'reviews': 604,
#   'histogram': [60, 70, 161, 211, 734],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 10, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Little Crane 2: Mud Play',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.625,
#   'ratings': 16,
#   'reviews': 10,
#   'histogram': [3, 3, 0, 1, 9],
#   'price': 5.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '8.3M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 27, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Pool Slide Story',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.7439446,
#   'ratings': 8679,
#   'reviews': 4686,
#   'histogram': [70, 70, 400, 931, 7208],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '34M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 18, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Autobahn Police Simulator',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.01,
#   'ratings': 386,
#   'reviews': 253,
#   'histogram': [108, 58, 58, 46, 116],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 9, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'My so-called future girlfriend [Visual Novel]',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.72,
#   'ratings': 155,
#   'reviews': 91,
#   'histogram': [1, 1, 7, 17, 129],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 29, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Harvest Master: Farm Sim',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.09,
#   'ratings': 831,
#   'reviews': 509,
#   'histogram': [91, 41, 100, 66, 533],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 1, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Plant Station',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.29,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 8, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Dolphin Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.76,
#   'ratings': 975,
#   'reviews': 463,
#   'histogram': [195, 29, 107, 127, 517],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 23, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Snake Simulator',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2782607,
#   'ratings': 2310,
#   'reviews': 680,
#   'histogram': [221, 70, 150, 271, 1598],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 22, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'TruckSimulation 16',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.5101798,
#   'ratings': 8358,
#   'reviews': 4359,
#   'histogram': [2272, 360, 690, 901, 4135],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '19M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 25, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'SovietCar: Premium',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.49,
#   'ratings': 175,
#   'reviews': 130,
#   'histogram': [10, 3, 3, 30, 129],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '42M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Planet Genesis 2 - 3D solar system sandbox',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.6868687,
#   'ratings': 99,
#   'reviews': 67,
#   'histogram': [20, 7, 10, 9, 53],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '76M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 6, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Silent Depth Submarine Sim',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 3.48,
#   'ratings': 263,
#   'reviews': 175,
#   'histogram': [45, 23, 45, 60, 90],
#   'price': 7.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '78M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 2, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Fractal Combat X (Premium)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4488187,
#   'ratings': 1281,
#   'reviews': 375,
#   'histogram': [60, 50, 80, 151, 940],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '64M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 23, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Emergency Call – The Fire Fighting Simulation',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.9679487,
#   'ratings': 1565,
#   'reviews': 950,
#   'histogram': [150, 170, 150, 201, 894],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '36M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Mar 22, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Hiveswap Friendsim',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.54,
#   'ratings': 291,
#   'reviews': 140,
#   'histogram': [11, 8, 14, 32, 226],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 11, 2018',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Green Project',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.38,
#   'ratings': 303,
#   'reviews': 212,
#   'histogram': [15, 12, 21, 48, 207],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '63M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jan 28, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Doodle Date',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 3.4285715,
#   'ratings': 7,
#   'reviews': 5,
#   'histogram': [0, 1, 3, 2, 1],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '46M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jan 21, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Sky Gamblers: Air Supremacy',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.872449,
#   'ratings': 1966,
#   'reviews': 1014,
#   'histogram': [351, 80, 200, 170, 1165],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '6.0M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jan 25, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Griffin Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2786884,
#   'ratings': 1223,
#   'reviews': 533,
#   'histogram': [110, 30, 110, 130, 843],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Nov 5, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'U-Boat Simulator',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.54,
#   'ratings': 516,
#   'reviews': 217,
#   'histogram': [36, 0, 5, 82, 393],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.5M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 20, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Wolf Craft',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.62,
#   'ratings': 567,
#   'reviews': 285,
#   'histogram': [17, 17, 22, 51, 460],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '33M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 26, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': "There's a Butcher Around Pro",
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 2.7692308,
#   'ratings': 13,
#   'reviews': 7,
#   'histogram': [6, 0, 2, 1, 4],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '35M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 12, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'This Is the Police 2',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.55,
#   'ratings': 558,
#   'reviews': 289,
#   'histogram': [123, 44, 61, 61, 269],
#   'price': 7.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '35M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 12, 2019',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Bus Simulator PRO 2016',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 2.89,
#   'ratings': 533,
#   'reviews': 274,
#   'histogram': [224, 48, 32, 21, 208],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '93M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Bridge Constructor Playground',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.2620192,
#   'ratings': 8377,
#   'reviews': 2159,
#   'histogram': [2598, 473, 896, 956, 3454],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '30M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 7, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Citizen of Rome - Dynasty Ascendant',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.06,
#   'ratings': 271,
#   'reviews': 153,
#   'histogram': [19, 16, 32, 65, 139],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '39M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 28, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Freeways',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.87,
#   'ratings': 406,
#   'reviews': 256,
#   'histogram': [44, 28, 65, 65, 204],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Hyena Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.32,
#   'ratings': 773,
#   'reviews': 409,
#   'histogram': [54, 38, 38, 116, 527],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 15, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'SuperGBC Pro (GBC Emulator)',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.5454545,
#   'ratings': 99,
#   'reviews': 41,
#   'histogram': [5, 0, 5, 15, 74],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.9M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Pango Build Safari',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.5,
#   'ratings': 14,
#   'reviews': 8,
#   'histogram': [1, 0, 1, 1, 11],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '36M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 5, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'In-Flight Assistant',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.0,
#   'ratings': 658,
#   'reviews': 408,
#   'histogram': [85, 46, 46, 85, 396],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '116M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 7, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Lucy -The Eternity She Wished For-',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.9,
#   'ratings': 276,
#   'reviews': 151,
#   'histogram': [0, 0, 8, 11, 257],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 8, 2016',
#   'contentRating': 'Everyone'},
#  {'title': '1000 days to escape',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.2307692,
#   'ratings': 39,
#   'reviews': 24,
#   'histogram': [12, 2, 6, 3, 16],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '89M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 19, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'The Westport Independent',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.04,
#   'ratings': 285,
#   'reviews': 139,
#   'histogram': [25, 14, 31, 66, 149],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '43M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jan 20, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Stray Dog Simulator',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.420749,
#   'ratings': 3475,
#   'reviews': 1725,
#   'histogram': [190, 160, 140, 490, 2495],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 1, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Russian Car Driver  ZIL 130 Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.21,
#   'ratings': 748,
#   'reviews': 431,
#   'histogram': [67, 45, 52, 82, 502],
#   'price': 1.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '93M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Apr 28, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Flight Simulator Night NY HD',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.45,
#   'ratings': 40,
#   'reviews': 10,
#   'histogram': [12, 3, 1, 3, 21],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 18, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Cheetah Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4270835,
#   'ratings': 1925,
#   'reviews': 690,
#   'histogram': [120, 40, 160, 180, 1425],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Sep 29, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Car Simulator Vietnam',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.81,
#   'ratings': 246,
#   'reviews': 177,
#   'histogram': [52, 9, 17, 22, 146],
#   'price': 6.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '82M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Infinite Flight Checklist',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 3.7555556,
#   'ratings': 45,
#   'reviews': 24,
#   'histogram': [10, 1, 4, 5, 25],
#   'price': 2.29,
#   'free': False,
#   'offersIAP': False,
#   'size': '10M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 8, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Cook, Serve, Delicious!',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.57,
#   'ratings': 344,
#   'reviews': 131,
#   'histogram': [13, 10, 6, 48, 267],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '53M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'May 12, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Jurassic Life: Velociraptor',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.38,
#   'ratings': 660,
#   'reviews': 250,
#   'histogram': [39, 13, 59, 92, 457],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 6, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Inverter : Theme Park Simulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.07,
#   'ratings': 105,
#   'reviews': 69,
#   'histogram': [16, 3, 7, 10, 69],
#   'price': 3.89,
#   'free': False,
#   'offersIAP': False,
#   'size': '109M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Oct 1, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Tiger Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.63,
#   'ratings': 484,
#   'reviews': 201,
#   'histogram': [111, 9, 68, 53, 243],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jul 20, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Kamikaze Simulator - Funfair Amusement Parks',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.23,
#   'ratings': 118,
#   'reviews': 67,
#   'histogram': [14, 2, 7, 13, 82],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '61M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 12, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Snow Leopard Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.6282053,
#   'ratings': 1570,
#   'reviews': 679,
#   'histogram': [70, 0, 40, 221, 1239],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 1, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Election 2020 - The Game',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.4M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jan 2, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Viking Ship - Best Ride Simulators',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.329412,
#   'ratings': 85,
#   'reviews': 45,
#   'histogram': [6, 4, 5, 11, 59],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '62M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Aug 22, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Airport Mania: First Flight XP',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.38,
#   'ratings': 4167,
#   'reviews': 1412,
#   'histogram': [166, 166, 542, 333, 2960],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '15M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Dec 16, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Smartphone Tycoon',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.66,
#   'ratings': 595,
#   'reviews': 344,
#   'histogram': [71, 71, 77, 143, 233],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '30M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 10, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'DRS Pro',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.23,
#   'ratings': 116,
#   'reviews': 67,
#   'histogram': [8, 5, 5, 28, 70],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '54M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Feb 12, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Take Off The Flight Simulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.4485981,
#   'ratings': 1073,
#   'reviews': 590,
#   'histogram': [291, 100, 60, 80, 542],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '29M',
#   'genre': 'Simulation',
#   'genreId': 'GAME_SIMULATION',
#   'released': 'Jun 9, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Madden NFL 21 Mobile Football',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.0699835,
#   'ratings': 37077,
#   'reviews': 16228,
#   'histogram': [4906, 1621, 2351, 5291, 22908],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '80M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Aug 4, 2020',
#   'contentRating': 'Everyone'},
#  {'title': '8 Ball Pool',
#   'installs': '500,000,000+',
#   'minInstalls': 500000000,
#   'score': 4.4209104,
#   'ratings': 19634015,
#   'reviews': 6989594,
#   'histogram': [1616548, 369027, 842655, 2111265, 14694520],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '63M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jan 23, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Golf Rival',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.39351,
#   'ratings': 263722,
#   'reviews': 97325,
#   'histogram': [16043, 6152, 14510, 48291, 178726],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '95M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Mar 27, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Guns Master',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.225806,
#   'ratings': 2005,
#   'reviews': 565,
#   'histogram': [172, 53, 194, 313, 1273],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '97M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'May 15, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'FOXBET Super 6',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.6475263,
#   'ratings': 56711,
#   'reviews': 20870,
#   'histogram': [821, 300, 2304, 11192, 42094],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '88M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Sep 6, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Bowling Crew — 3D bowling game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3843384,
#   'ratings': 152141,
#   'reviews': 51114,
#   'histogram': [11007, 4014, 9104, 19385, 108631],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '134M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Dec 18, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Touchgrind BMX',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9107296,
#   'ratings': 648977,
#   'reviews': 177339,
#   'histogram': [105604, 31204, 55917, 79045, 377207],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '126M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Sep 12, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Racing Smash 3D',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.6845765,
#   'ratings': 48750,
#   'reviews': 23175,
#   'histogram': [1284, 616, 1992, 4406, 40452],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '69M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jun 29, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Touchgrind BMX 2',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.2963176,
#   'ratings': 70332,
#   'reviews': 26865,
#   'histogram': [7150, 1543, 4052, 8155, 49432],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '442M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Dec 13, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Hyper Run 3D',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.63,
#   'ratings': 1018,
#   'reviews': 290,
#   'histogram': [30, 20, 51, 91, 826],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '29M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jul 28, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Head Ball 2',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 3.968918,
#   'ratings': 1471048,
#   'reviews': 727000,
#   'histogram': [266588, 50679, 81071, 136238, 936472],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '88M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Apr 16, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Touchgrind Skate 2',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.800679,
#   'ratings': 242654,
#   'reviews': 99724,
#   'histogram': [45674, 12084, 20401, 31269, 133226],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '63M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Dec 10, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Run Race 3D',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.021769,
#   'ratings': 1130064,
#   'reviews': 603280,
#   'histogram': [161975, 51087, 88043, 128211, 700748],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '52M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Mar 8, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Basketball Stars',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.293403,
#   'ratings': 1144011,
#   'reviews': 443182,
#   'histogram': [108072, 28187, 62535, 166433, 778784],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '59M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Mar 16, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Golf Battle',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0040836,
#   'ratings': 451425,
#   'reviews': 184330,
#   'histogram': [59191, 18885, 39804, 76553, 256992],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '52M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Oct 24, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'NBA LIVE Mobile Basketball',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.142647,
#   'ratings': 2299820,
#   'reviews': 961062,
#   'histogram': [300255, 71541, 133522, 289068, 1505434],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jul 5, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'MyNBA2K21',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 1.9675676,
#   'ratings': 1895,
#   'reviews': 1139,
#   'histogram': [1323, 71, 92, 61, 348],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '95M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Aug 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Flip Jump Stack!',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9680617,
#   'ratings': 17903,
#   'reviews': 6891,
#   'histogram': [2573, 1045, 1459, 2129, 10697],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '48M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Apr 30, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Flip Diving',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.567439,
#   'ratings': 840336,
#   'reviews': 309522,
#   'histogram': [41050, 15047, 33916, 86321, 664002],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Aug 17, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Parkour Race - Freerun Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.952082,
#   'ratings': 124862,
#   'reviews': 49655,
#   'histogram': [18985, 6425, 10850, 13927, 74675],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Mar 6, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Ultimate Golf!',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.21381,
#   'ratings': 28622,
#   'reviews': 11140,
#   'histogram': [2066, 943, 2277, 6852, 16484],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '53M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jun 12, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Fanatical Football',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1786456,
#   'ratings': 450870,
#   'reviews': 111564,
#   'histogram': [55417, 12293, 30091, 51591, 301478],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '16M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Oct 25, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Flip Master',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0903387,
#   'ratings': 249824,
#   'reviews': 108030,
#   'histogram': [31160, 11053, 20167, 29120, 158324],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '76M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Aug 29, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Boxing Star',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.400203,
#   'ratings': 679978,
#   'reviews': 240802,
#   'histogram': [45970, 13912, 39424, 103381, 477291],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '84M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jul 11, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'PBA® Bowling Challenge',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4960423,
#   'ratings': 269209,
#   'reviews': 73510,
#   'histogram': [13007, 4837, 12734, 43658, 194973],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '77M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jan 15, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Flip Dunk',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.025309,
#   'ratings': 138549,
#   'reviews': 56520,
#   'histogram': [18444, 6452, 12062, 17783, 83808],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '73M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jul 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Dream League Soccer 2020',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.131758,
#   'ratings': 1237692,
#   'reviews': 656314,
#   'histogram': [157240, 43622, 83162, 148465, 805203],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '349M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jan 14, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Pooking - Billiards City',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.402638,
#   'ratings': 2220679,
#   'reviews': 925824,
#   'histogram': [133737, 56368, 152283, 317928, 1560363],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '41M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'May 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Shooting Battle',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.5884824,
#   'ratings': 90738,
#   'reviews': 33803,
#   'histogram': [3450, 1273, 3981, 11755, 70279],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '48M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jul 30, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'NBC Sports Predictor',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.1636953,
#   'ratings': 6179,
#   'reviews': 2699,
#   'histogram': [801, 220, 240, 821, 4097],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '82M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Dec 12, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Tennis Clash: 1v1 Free Online Sports Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.17943,
#   'ratings': 746389,
#   'reviews': 264991,
#   'histogram': [88618, 27303, 46701, 82677, 501090],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '144M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Oct 23, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Retro Bowl',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.6991663,
#   'ratings': 178950,
#   'reviews': 67127,
#   'histogram': [1382, 1071, 6039, 33012, 137446],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Sports',
#   'genreId': 'GAME_SPORTS',
#   'released': 'Jan 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Flip Skater',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.225038,
#   'ratings': 112394,
#   'reviews': 50349,
#   'histogram': [11062, 3851, 8424, 14451, 74606],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
# ...
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 26, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search - Free Word Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.7983203,
#   'ratings': 268360,
#   'reviews': 110773,
#   'histogram': [6601, 1953, 4447, 12962, 242397],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '3.7M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 25, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Word Puzzle - Word Search Quest',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.91,
#   'ratings': 184,
#   'reviews': 75,
#   'histogram': [0, 1, 3, 3, 177],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '22M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 3, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Bible Word Puzzle - Free Bible Word Games',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.660912,
#   'ratings': 104962,
#   'reviews': 44614,
#   'histogram': [2042, 1611, 4074, 14437, 82798],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 1, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Wordington: Words & Design',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.2843943,
#   'ratings': 145331,
#   'reviews': 43892,
#   'histogram': [11154, 5111, 10212, 23622, 95232],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 25, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Crossword Relax Free',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.78,
#   'ratings': 757,
#   'reviews': 171,
#   'histogram': [22, 7, 0, 53, 675],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '42M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 13, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search Addict - Word Search Puzzle Free',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.7922893,
#   'ratings': 49621,
#   'reviews': 23009,
#   'histogram': [1061, 530, 931, 2604, 44495],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '36M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 12, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Evil Apples: You Against Humanity!',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.157471,
#   'ratings': 147366,
#   'reviews': 46354,
#   'histogram': [14794, 5829, 11708, 24080, 90955],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 23, 2014',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Word Wars - Word Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.3244658,
#   'ratings': 22973,
#   'reviews': 9737,
#   'histogram': [1833, 721, 1172, 3677, 15570],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 29, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Charades!',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3518095,
#   'ratings': 128184,
#   'reviews': 26069,
#   'histogram': [10265, 2717, 7397, 19081, 88724],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '16M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 1, 2013',
#   'contentRating': 'Everyone'},
#  {'title': '4 Pics 1 Word Cookie',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.731579,
#   'ratings': 1785,
#   'reviews': 514,
#   'histogram': [28, 0, 65, 235, 1457],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 19, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Psych! The best party game to play with friends',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.0278077,
#   'ratings': 56007,
#   'reviews': 14147,
#   'histogram': [7194, 2090, 4340, 10721, 31662],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '84M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 8, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Draw N Guess Multiplayer',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.485358,
#   'ratings': 37362,
#   'reviews': 17342,
#   'histogram': [9381, 2492, 3454, 4680, 17355],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '30M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 6, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Relax - Free Word Games & Puzzles',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.0295486,
#   'ratings': 68799,
#   'reviews': 25914,
#   'histogram': [10295, 2884, 4446, 8041, 43133],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '69M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 16, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Infinite Word Search Puzzles',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3266206,
#   'ratings': 56881,
#   'reviews': 18274,
#   'histogram': [3275, 2090, 5134, 8661, 37721],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '41M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 6, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search 2020',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.7087655,
#   'ratings': 10658,
#   'reviews': 4481,
#   'histogram': [321, 90, 432, 683, 9132],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '21M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 11, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Garden of Words - Word game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2144456,
#   'ratings': 281676,
#   'reviews': 79702,
#   'histogram': [18753, 9221, 26282, 66031, 161389],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '98M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 14, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Game of Words: Free Word Games & Puzzles',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.695641,
#   'ratings': 39300,
#   'reviews': 16572,
#   'histogram': [691, 460, 1342, 5129, 31678],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '60M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 3, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Planet',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.7497864,
#   'ratings': 11747,
#   'reviews': 4330,
#   'histogram': [170, 130, 401, 1063, 9983],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '73M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 24, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Bliss',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.6778398,
#   'ratings': 21527,
#   'reviews': 8594,
#   'histogram': [350, 280, 992, 2706, 17199],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '75M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 1, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Wizard of Word',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.652174,
#   'ratings': 87348,
#   'reviews': 32565,
#   'histogram': [4449, 911, 2314, 5220, 74454],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 11, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Scrolling Words-Moving Word Game & Find Words',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.7697654,
#   'ratings': 23081,
#   'reviews': 7446,
#   'histogram': [371, 210, 461, 2276, 19763],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '32M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 16, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'WORD FIRE: FREE WORD GAMES WITHOUT WIFI!',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.6826925,
#   'ratings': 15635,
#   'reviews': 6821,
#   'histogram': [721, 160, 481, 631, 13642],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '54M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 20, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Swipe Pic',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.565566,
#   'ratings': 52469,
#   'reviews': 18847,
#   'histogram': [2884, 1171, 1912, 3916, 42586],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '57M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Words Story - Addictive Word Game',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 3.7308054,
#   'ratings': 490793,
#   'reviews': 207640,
#   'histogram': [103065, 29485, 38344, 45507, 274392],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '72M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 10, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Crossword Explorer',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.4,
#   'ratings': 391,
#   'reviews': 132,
#   'histogram': [19, 3, 23, 98, 248],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '57M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 10, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Aplasta Palabras：Juego de Palabras Gratis sin wifi',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.522359,
#   'ratings': 20480,
#   'reviews': 11679,
#   'histogram': [593, 261, 1217, 4187, 14222],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search Inspiration',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.1894026,
#   'ratings': 8884,
#   'reviews': 3998,
#   'histogram': [851, 340, 641, 1492, 5560],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 17, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Bible Word Story',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.57,
#   'ratings': 146,
#   'reviews': 61,
#   'histogram': [4, 4, 4, 23, 111],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Picnic:Fun Word Games',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.9815729,
#   'ratings': 52991,
#   'reviews': 22015,
#   'histogram': [10500, 1298, 2244, 3583, 35366],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '57M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 16, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Mystery Word Puzzle',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.76,
#   'ratings': 702,
#   'reviews': 235,
#   'histogram': [28, 7, 7, 21, 639],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '104M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 13, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Draw Something Classic',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.183872,
#   'ratings': 1125226,
#   'reviews': 441782,
#   'histogram': [83325, 39035, 102674, 262573, 637619],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 1, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Immortal Taoists-Idle Game of Immortal Cultivation',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.4632034,
#   'ratings': 157458,
#   'reviews': 51901,
#   'histogram': [7728, 2716, 9583, 26293, 111138],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 7, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Blitz',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.3209734,
#   'ratings': 8670,
#   'reviews': 3730,
#   'histogram': [442, 291, 723, 1798, 5416],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '21M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 6, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Classic Words Solo',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4416237,
#   'ratings': 167317,
#   'reviews': 57648,
#   'histogram': [6518, 2544, 10072, 39574, 108609],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 20, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Bouquet of Words - Word game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.282681,
#   'ratings': 39177,
#   'reviews': 12490,
#   'histogram': [2194, 942, 3808, 8880, 23353],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 22, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Cooking',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.084249,
#   'ratings': 14054,
#   'reviews': 4992,
#   'histogram': [1266, 659, 1606, 2615, 7908],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '30M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 14, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Connect - Word Games Puzzle',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.587372,
#   'ratings': 391297,
#   'reviews': 164559,
#   'histogram': [15445, 6555, 19675, 40663, 308959],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 22, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Calm',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.4895134,
#   'ratings': 25326,
#   'reviews': 11596,
#   'histogram': [1102, 511, 1282, 4420, 18011],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '103M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 27, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Sweeper',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.5530305,
#   'ratings': 1327,
#   'reviews': 388,
#   'histogram': [70, 0, 60, 191, 1006],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '74M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 25, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Squares',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.41,
#   'ratings': 500,
#   'reviews': 180,
#   'histogram': [40, 5, 30, 60, 365],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 21, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Ancient Life 古代人生',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.3785715,
#   'ratings': 1427,
#   'reviews': 844,
#   'histogram': [91, 10, 112, 265, 949],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '108M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 14, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Words with Friends: Play Fun Word Puzzle Games',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1643033,
#   'ratings': 734679,
#   'reviews': 226382,
#   'histogram': [68460, 32460, 57308, 128131, 448320],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 8, 2014',
#   'contentRating': 'Everyone'}]

# %%
len(listofdictinfo5)
# Out:
# 1000

# %%
listofdictinfo6 = list(map(lambda appid: givemeinfo(appid), uniqueappidlist[5001:5136]))
listofdictinfo6
# Out:
# [{'title': 'Word Farm Scapes: New Free Word & Puzzle Game',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.49,
#   'ratings': 838,
#   'reviews': 338,
#   'histogram': [58, 16, 42, 58, 664],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 25, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Home Design : Word Life',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.4181185,
#   'ratings': 14408,
#   'reviews': 4799,
#   'histogram': [1184, 301, 632, 1476, 10815],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 7, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Words Words Words - Make Money Free',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.1502347,
#   'ratings': 6661,
#   'reviews': 3044,
#   'histogram': [625, 302, 667, 917, 4150],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '62M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 15, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'كلمات كراش - لعبة تسلية وتحدي من زيتونة',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.6956315,
#   'ratings': 1999948,
#   'reviews': 898101,
#   'histogram': [80199, 25875, 60355, 89586, 1743933],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '57M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 31, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Villas - Fun puzzle game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.139963,
#   'ratings': 54353,
#   'reviews': 25011,
#   'histogram': [4584, 2372, 5685, 9920, 31792],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 5, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Guess The Emoji - Trivia and Guessing Game!',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.1221633,
#   'ratings': 80049,
#   'reviews': 31510,
#   'histogram': [9395, 3370, 6570, 9436, 51278],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '33M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 17, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Spaceteam',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.5858035,
#   'ratings': 63064,
#   'reviews': 12317,
#   'histogram': [3274, 929, 2132, 5972, 50757],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 20, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'WordFinder: Free Word Games Cheats & Helper',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.457317,
#   'ratings': 1654,
#   'reviews': 669,
#   'histogram': [111, 30, 50, 262, 1201],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '38M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 21, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Free Word Search Puzzle - Word Find',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.411005,
#   'ratings': 17882,
#   'reviews': 8346,
#   'histogram': [502, 291, 1596, 4458, 11035],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '5.9M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 22, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Bible Word Search',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.8423915,
#   'ratings': 1851,
#   'reviews': 778,
#   'histogram': [30, 20, 30, 50, 1721],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '36M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 18, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Stop - Categories Word Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.4826796,
#   'ratings': 188232,
#   'reviews': 69875,
#   'histogram': [38220, 15809, 26594, 32111, 75498],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 26, 2014',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Word Find - Word Connect Free Offline Word Games',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.629742,
#   'ratings': 135425,
#   'reviews': 59354,
#   'histogram': [3725, 1502, 6880, 16974, 106344],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 16, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Words Episode',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.794957,
#   'ratings': 30487,
#   'reviews': 13446,
#   'histogram': [6160, 1669, 2346, 2397, 17915],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '7.3M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 14, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Word Board',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.766204,
#   'ratings': 4339,
#   'reviews': 1565,
#   'histogram': [120, 40, 120, 170, 3889],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '46M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Connect - Fun Crossword Puzzle',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.684474,
#   'ratings': 6015,
#   'reviews': 2711,
#   'histogram': [170, 80, 190, 592, 4983],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '25M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 13, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Games',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.2941175,
#   'ratings': 5506,
#   'reviews': 1925,
#   'histogram': [354, 172, 394, 1164, 3422],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '23M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 6, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Wordscapes In Bloom',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.702643,
#   'ratings': 58742,
#   'reviews': 22208,
#   'histogram': [1792, 1101, 1492, 4006, 50351],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '98M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 14, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Word Nature',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.757925,
#   'ratings': 3493,
#   'reviews': 1075,
#   'histogram': [60, 10, 70, 433, 2920],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '66M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 5, 2020',
#   'contentRating': 'Everyone'},
#  {'title': '4 Pics 1 Word',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.512632,
#   'ratings': 1155815,
#   'reviews': 332419,
#   'histogram': [40831, 16756, 66912, 215889, 815427],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '62M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 13, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Magic Word - Find & Connect Words from Letters',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.805714,
#   'ratings': 3534,
#   'reviews': 789,
#   'histogram': [101, 10, 60, 131, 3232],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 25, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.8958335,
#   'ratings': 2451,
#   'reviews': 1407,
#   'histogram': [20, 10, 30, 81, 2310],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '26M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 10, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Words of Wonders: Crossword to Connect Vocabulary',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.515319,
#   'ratings': 1595624,
#   'reviews': 499957,
#   'histogram': [65992, 28056, 86411, 252408, 1162757],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '144M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 10, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1058674,
#   'ratings': 7998,
#   'reviews': 3013,
#   'histogram': [969, 377, 632, 877, 5143],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '17M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 8, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4847445,
#   'ratings': 609796,
#   'reviews': 214892,
#   'histogram': [27698, 13392, 39266, 84698, 444742],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '5.0M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 27, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2483416,
#   'ratings': 143143,
#   'reviews': 62106,
#   'histogram': [12306, 5088, 10796, 21513, 93440],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '5.8M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 11, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Quick Logic Puzzles',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.9960785,
#   'ratings': 2571,
#   'reviews': 560,
#   'histogram': [232, 171, 363, 413, 1392],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '3.8M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 24, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'لعبة كلمة السر : الجزء الثاني',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.667684,
#   'ratings': 735913,
#   'reviews': 313652,
#   'histogram': [28090, 10165, 29233, 43229, 625196],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 19, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Free Time - Crossword Puzzle',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.7271214,
#   'ratings': 6041,
#   'reviews': 2151,
#   'histogram': [231, 100, 100, 221, 5389],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 28, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Scary Teacher : Addictive Word Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.136646,
#   'ratings': 1700,
#   'reviews': 920,
#   'histogram': [264, 63, 84, 52, 1237],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '54M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 23, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Explore: Travel the World',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.7241178,
#   'ratings': 17393,
#   'reviews': 8089,
#   'histogram': [523, 231, 553, 905, 15181],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 2, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Swipe',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.6305904,
#   'ratings': 117393,
#   'reviews': 49779,
#   'histogram': [4779, 1943, 4268, 9879, 96524],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '58M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 2, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Guess The TikTok Star',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.2,
#   'ratings': 1430,
#   'reviews': 663,
#   'histogram': [163, 30, 122, 153, 962],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 23, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Boggle With Friends: Word Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.0996103,
#   'ratings': 18066,
#   'reviews': 7601,
#   'histogram': [2121, 804, 1136, 3096, 10909],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Just Riddles',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.3514085,
#   'ratings': 33085,
#   'reviews': 10649,
#   'histogram': [2155, 932, 2455, 5131, 22412],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '14M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 24, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'CharadesApp - What am I? (Charades and Mimics)',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.31895,
#   'ratings': 62388,
#   'reviews': 29052,
#   'histogram': [5183, 1978, 3897, 8026, 43304],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '24M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 14, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Braindom 2: Riddles Puzzles Brain Games Master',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.48,
#   'ratings': 841,
#   'reviews': 156,
#   'histogram': [67, 33, 8, 50, 683],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '202M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 14, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Crossword Puzzle Free',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.262716,
#   'ratings': 44368,
#   'reviews': 15136,
#   'histogram': [2720, 1541, 3596, 10014, 26497],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '7.1M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 11, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Crossword Quiz - Crossword Puzzle Word Game!',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.067465,
#   'ratings': 18506,
#   'reviews': 6515,
#   'histogram': [1903, 1107, 1591, 3141, 10764],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '66M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 11, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'آمیرزا',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.7437797,
#   'ratings': 139484,
#   'reviews': 71174,
#   'histogram': [4654, 1394, 3300, 6339, 123797],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '52M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 25, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'What Am I? – Family Charades (Guess The Word)',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.154756,
#   'ratings': 209208,
#   'reviews': 85814,
#   'histogram': [22315, 8076, 17686, 27967, 133164],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '5.6M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 22, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Jeopardy! Words',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.490196,
#   'ratings': 1035,
#   'reviews': 420,
#   'histogram': [61, 10, 40, 172, 752],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '44M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 25, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Scroll - Search & Find Word Games',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.57,
#   'ratings': 767,
#   'reviews': 295,
#   'histogram': [23, 30, 30, 84, 600],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 15, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'piggy walkthrough',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.17,
#   'ratings': 163,
#   'reviews': 106,
#   'histogram': [66, 6, 3, 11, 77],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '3.7M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 23, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Colour',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.66,
#   'ratings': 312,
#   'reviews': 104,
#   'histogram': [12, 6, 12, 12, 270],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 7, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Cross Puzzle: Best Free Offline Word Games',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.545679,
#   'ratings': 89223,
#   'reviews': 38572,
#   'histogram': [3264, 1692, 5057, 12287, 66923],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 5, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Bookworm Classic (Expert)',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.428571,
#   'ratings': 2601,
#   'reviews': 1365,
#   'histogram': [100, 0, 261, 562, 1678],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '28M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Bible Word Puzzle - Free Bible Story Game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.6864786,
#   'ratings': 6759,
#   'reviews': 3222,
#   'histogram': [150, 70, 241, 823, 5475],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '66M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 12, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Crossword Puzzles',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.67,
#   'ratings': 701,
#   'reviews': 290,
#   'histogram': [21, 7, 14, 98, 561],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '3.6M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 10, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Bible Verses Puzzle',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.68,
#   'ratings': 977,
#   'reviews': 397,
#   'histogram': [19, 9, 9, 186, 754],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '63M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 1, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Never Have I Ever Game - Dirty',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.273585,
#   'ratings': 117,
#   'reviews': 89,
#   'histogram': [17, 3, 2, 0, 95],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 4, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Word Connect 2020',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.8746595,
#   'ratings': 3712,
#   'reviews': 1570,
#   'histogram': [80, 10, 30, 50, 3542],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '32M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 12, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Cross',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.592754,
#   'ratings': 223103,
#   'reviews': 67883,
#   'histogram': [10557, 3676, 8553, 20493, 179824],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '59M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 30, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Connect- Word Games:Word Search Offline Games',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.59317,
#   'ratings': 88162,
#   'reviews': 37876,
#   'histogram': [4445, 1495, 3321, 6954, 71947],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 21, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Bible Verse Puzzle',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.79,
#   'ratings': 191,
#   'reviews': 89,
#   'histogram': [3, 3, 3, 5, 177],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '33M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 16, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Cryptogram',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.482393,
#   'ratings': 20803,
#   'reviews': 6566,
#   'histogram': [662, 572, 1294, 3813, 14462],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '8.2M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 30, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search: Hidden Words',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.2189093,
#   'ratings': 13773,
#   'reviews': 5282,
#   'histogram': [1312, 460, 1112, 1903, 8986],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '36M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 2, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Season - Connect Crossword Game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.657459,
#   'ratings': 1830,
#   'reviews': 803,
#   'histogram': [60, 0, 60, 263, 1447],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '51M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 23, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Words in Word',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.5298753,
#   'ratings': 52266,
#   'reviews': 8600,
#   'histogram': [1807, 913, 3163, 8274, 38109],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '28M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 1, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Bible Word Crossy',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.828729,
#   'ratings': 1829,
#   'reviews': 755,
#   'histogram': [10, 10, 20, 202, 1587],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 12, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Legend Puzzle - Addictive Cross Word Connect',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.355486,
#   'ratings': 16099,
#   'reviews': 6632,
#   'histogram': [1312, 535, 928, 1665, 11659],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 2, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Fun Libs',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.07,
#   'ratings': 191,
#   'reviews': 58,
#   'histogram': [61, 15, 27, 25, 63],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '2.7M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 27, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'BAIKOH: Words & Brain Challenges',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.076756,
#   'ratings': 13876,
#   'reviews': 5343,
#   'histogram': [1457, 653, 1246, 2532, 7988],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '36M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 5, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Mind: Crossword puzzle',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.391129,
#   'ratings': 4987,
#   'reviews': 2311,
#   'histogram': [241, 130, 382, 915, 3319],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 16, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Cubes - Find Hidden Words',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.51,
#   'ratings': 413,
#   'reviews': 173,
#   'histogram': [33, 4, 8, 41, 327],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '48M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 22, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Pinturillo 2',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.7953813,
#   'ratings': 93450,
#   'reviews': 32643,
#   'histogram': [15147, 4657, 10820, 16371, 46455],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '11M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 24, 2015',
#   'contentRating': 'Everyone'},
#  {'title': '2 Pictures 1 Word - Offline Games',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.0991983,
#   'ratings': 43804,
#   'reviews': 19367,
#   'histogram': [5007, 2217, 3562, 5650, 27368],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 3, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Fall - Brain training search word puzzle game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.617391,
#   'ratings': 1165,
#   'reviews': 446,
#   'histogram': [50, 20, 60, 60, 975],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '36M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 13, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Hangman Master',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.48,
#   'ratings': 814,
#   'reviews': 316,
#   'histogram': [0, 16, 65, 244, 489],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '65M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 9, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.452494,
#   'ratings': 387626,
#   'reviews': 94963,
#   'histogram': [13290, 7036, 29463, 79032, 258805],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 1, 2011',
#   'contentRating': 'Mature 17+'},
#  {'title': 'One Clue Crossword',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.467427,
#   'ratings': 67757,
#   'reviews': 32170,
#   'histogram': [1504, 1033, 5497, 15971, 43752],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '91M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 3, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Peace -  New Word Game & Puzzles',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.6666667,
#   'ratings': 6308,
#   'reviews': 2544,
#   'histogram': [1489, 322, 472, 543, 3482],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 3, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Wordwise - Word Puzzle, Tour 2020',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.6993465,
#   'ratings': 1546,
#   'reviews': 675,
#   'histogram': [91, 10, 20, 30, 1395],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '92M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 18, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search Journey - New Crossword Puzzle',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.554236,
#   'ratings': 48980,
#   'reviews': 18893,
#   'histogram': [3611, 746, 1317, 2513, 40793],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '66M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 12, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'English Crossword puzzle',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.425562,
#   'ratings': 21396,
#   'reviews': 8173,
#   'histogram': [891, 290, 1322, 5209, 13684],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '7.7M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 9, 2017',
#   'contentRating': 'Teen'},
#  {'title': '7 Little Words: A fun twist on crossword puzzles',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.5461974,
#   'ratings': 129027,
#   'reviews': 48836,
#   'histogram': [7920, 3460, 3595, 9299, 104753],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 9, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Blocks',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.504854,
#   'ratings': 1042,
#   'reviews': 298,
#   'histogram': [60, 30, 30, 121, 801],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '101M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 7, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Bonza Word Puzzle',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.558659,
#   'ratings': 41602,
#   'reviews': 10494,
#   'histogram': [1081, 646, 1960, 8175, 29740],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 18, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Text Twist 2',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8929765,
#   'ratings': 3002,
#   'reviews': 1384,
#   'histogram': [331, 251, 371, 502, 1547],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '7.5M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 13, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Catch Phrase : Group Party Game',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.16,
#   'ratings': 734,
#   'reviews': 286,
#   'histogram': [103, 14, 29, 103, 485],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '7.8M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 29, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Hangman Multiplayer - Online Word Game',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.6169724,
#   'ratings': 4376,
#   'reviews': 1878,
#   'histogram': [1054, 220, 391, 391, 2320],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '21M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 27, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Secret: Offline Games, Fun & Free Word Story',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.96875,
#   'ratings': 2921,
#   'reviews': 1037,
#   'histogram': [426, 182, 192, 375, 1746],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '32M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 12, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Word Surf - Word Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.677643,
#   'ratings': 104174,
#   'reviews': 30427,
#   'histogram': [3059, 1063, 2678, 12798, 84576],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '81M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 28, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Crush 2020',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.8398056,
#   'ratings': 2069,
#   'reviews': 890,
#   'histogram': [40, 20, 20, 70, 1919],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '31M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 8, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Wordplay: Exercise your brain',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.372434,
#   'ratings': 3424,
#   'reviews': 1816,
#   'histogram': [150, 70, 311, 713, 2180],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '91M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 16, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Candy Cross Word',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.4906955,
#   'ratings': 10261,
#   'reviews': 2793,
#   'histogram': [663, 110, 432, 1377, 7679],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 15, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search, Play infinite number of word puzzles',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3758082,
#   'ratings': 101132,
#   'reviews': 28165,
#   'histogram': [5583, 2545, 7665, 17826, 67513],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '8.2M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 17, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Bubble Puzzle - Word Search Connect Game',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.66,
#   'ratings': 189,
#   'reviews': 89,
#   'histogram': [9, 3, 1, 11, 165],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 3, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Chums',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.684287,
#   'ratings': 144768,
#   'reviews': 58817,
#   'histogram': [3324, 1134, 3133, 22737, 114440],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '54M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 30, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Beach: Fun Relaxing Word Search Puzzle Games',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.4726663,
#   'ratings': 27018,
#   'reviews': 11342,
#   'histogram': [1175, 542, 1778, 4361, 19162],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '41M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 20, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Word cross - Wordscape connect & link',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.4932737,
#   'ratings': 2241,
#   'reviews': 929,
#   'histogram': [90, 30, 150, 382, 1589],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '75M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 30, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Daily POP Crosswords: Daily Puzzle Crossword Quiz',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.376975,
#   'ratings': 4439,
#   'reviews': 1331,
#   'histogram': [270, 90, 200, 1012, 2867],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '62M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'كلمات متقاطعة',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.650758,
#   'ratings': 753070,
#   'reviews': 235757,
#   'histogram': [29085, 9922, 31200, 54493, 628370],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '38M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 17, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Fill-Ins · Word Fit Puzzles',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.6163344,
#   'ratings': 10568,
#   'reviews': 4003,
#   'histogram': [150, 90, 582, 2017, 7729],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '6.3M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Sep 27, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Cashword by Michigan Lottery',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.123457,
#   'ratings': 1688,
#   'reviews': 600,
#   'histogram': [219, 20, 135, 271, 1043],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 19, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'Faketalk - Chatbot',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.9172778,
#   'ratings': 68779,
#   'reviews': 35802,
#   'histogram': [11571, 2703, 5881, 8312, 40312],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '11M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 3, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'Cryptogram Puzzles',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.616027,
#   'ratings': 6022,
#   'reviews': 2640,
#   'histogram': [120, 90, 241, 1076, 4495],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '5.8M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 14, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'بازی فندق - بازی فکری کلمات',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.621184,
#   'ratings': 69952,
#   'reviews': 35641,
#   'histogram': [3198, 1112, 2837, 4692, 58113],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 29, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Bound - Free Word Puzzle Games',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.7159877,
#   'ratings': 15977,
#   'reviews': 7526,
#   'histogram': [510, 280, 420, 811, 13956],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '38M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 30, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Serene - free word puzzle games',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.21,
#   'ratings': 237,
#   'reviews': 61,
#   'histogram': [26, 9, 19, 16, 167],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '63M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Find Music - Crossword',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.5828757,
#   'ratings': 9183,
#   'reviews': 4112,
#   'histogram': [423, 181, 423, 746, 7410],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '25M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 26, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Clash:Puzzle Journey',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.793103,
#   'ratings': 1169,
#   'reviews': 420,
#   'histogram': [30, 0, 10, 100, 1029],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '47M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 10, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Wordscapes Uncrossed',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.715596,
#   'ratings': 15298,
#   'reviews': 5251,
#   'histogram': [421, 180, 471, 1183, 13043],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '76M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 20, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Word City: Connect Word Game - Free Word Games',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.5719514,
#   'ratings': 8274,
#   'reviews': 2880,
#   'histogram': [433, 131, 242, 928, 6540],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 13, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Escape Room: Mystery Word',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2069917,
#   'ratings': 126907,
#   'reviews': 41844,
#   'histogram': [15683, 4957, 6830, 9373, 90064],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '61M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 22, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Search - Free Puzzles',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.523913,
#   'ratings': 9223,
#   'reviews': 5463,
#   'histogram': [270, 70, 591, 1915, 6377],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jan 20, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Word Search Puzzle 2020',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.991667,
#   'ratings': 1287,
#   'reviews': 879,
#   'histogram': [0, 0, 0, 10, 1277],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '30M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 7, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Make Words',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.3632326,
#   'ratings': 11452,
#   'reviews': 3544,
#   'histogram': [386, 274, 1129, 2665, 6998],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '12M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 25, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Logic Problems - Classic!',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.657754,
#   'ratings': 5647,
#   'reviews': 890,
#   'histogram': [956, 493, 654, 966, 2578],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '6.6M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 18, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Giant Jumble Crosswords',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.738693,
#   'ratings': 2005,
#   'reviews': 1097,
#   'histogram': [40, 40, 20, 201, 1704],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '79M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 24, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Tiles: Relax n Refresh',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.539914,
#   'ratings': 23355,
#   'reviews': 10515,
#   'histogram': [601, 481, 1343, 4210, 16720],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '60M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 22, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Wow - Brain training fun',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.4058957,
#   'ratings': 8880,
#   'reviews': 2988,
#   'histogram': [342, 271, 725, 1641, 5901],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '43M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 13, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Blocks Puzzle - Free Offline Word Games',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.8039217,
#   'ratings': 102,
#   'reviews': 53,
#   'histogram': [3, 2, 0, 2, 95],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '35M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 11, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Words & Ladders: a Trivia Crack game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.7572815,
#   'ratings': 11368,
#   'reviews': 4985,
#   'histogram': [1826, 833, 1384, 1555, 5770],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '94M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Languinis: Word Game',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.554792,
#   'ratings': 158904,
#   'reviews': 48684,
#   'histogram': [3857, 2114, 8947, 31079, 112907],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '131M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 11, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Classic Words Plus',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.680593,
#   'ratings': 7592,
#   'reviews': 3562,
#   'histogram': [112, 61, 143, 1504, 5772],
#   'price': 4.49,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 17, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Wordfeud',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.672392,
#   'ratings': 89568,
#   'reviews': 36973,
#   'histogram': [1214, 599, 2202, 18283, 67270],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 5, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'GuessUp Kids - Family Charades',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.4210525,
#   'ratings': 38,
#   'reviews': 29,
#   'histogram': [3, 1, 1, 5, 28],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '123M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 15, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Crossword',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.6842103,
#   'ratings': 4852,
#   'reviews': 2108,
#   'histogram': [24, 12, 72, 1253, 3491],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Nov 3, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Catchphrase Pro - Fun Party Game',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.28,
#   'ratings': 336,
#   'reviews': 165,
#   'histogram': [20, 6, 37, 67, 206],
#   'price': 9.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.8M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 23, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Logic Puzzles - Brain Fun',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.02,
#   'ratings': 902,
#   'reviews': 245,
#   'histogram': [90, 72, 63, 180, 497],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '3.9M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 9, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Master - Pro',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.6831684,
#   'ratings': 1016,
#   'reviews': 611,
#   'histogram': [10, 0, 60, 161, 785],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '13M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Aug 31, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Pangrams Spelling Bee',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 3.9285715,
#   'ratings': 14,
#   'reviews': 11,
#   'histogram': [2, 1, 1, 2, 8],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '33M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Apr 2, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Draw Something',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.9129097,
#   'ratings': 83957,
#   'reviews': 43976,
#   'histogram': [9935, 4387, 9591, 19183, 40861],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 1, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Games PRO - 92 in 1',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.58,
#   'ratings': 374,
#   'reviews': 216,
#   'histogram': [7, 11, 15, 63, 278],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '58M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 29, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Crossword Puzzles (No Ads)',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.1875,
#   'ratings': 32,
#   'reviews': 9,
#   'histogram': [3, 1, 2, 7, 19],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.2M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 31, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Ruzzle',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.2131877,
#   'ratings': 37868,
#   'reviews': 16131,
#   'histogram': [3549, 1298, 2407, 6886, 23728],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'May 12, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Acrostics Crossword Puzzles',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.35,
#   'ratings': 372,
#   'reviews': 180,
#   'histogram': [18, 11, 33, 67, 243],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '15M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 18, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Pictionary Word Generator - Pro',
#   'installs': '500+',
#   'minInstalls': 500,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 2.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.0M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 30, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Crack (Ad free)',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2259927,
#   'ratings': 16368,
#   'reviews': 7664,
#   'histogram': [1335, 472, 1040, 3829, 9692],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Oct 19, 2011',
#   'contentRating': 'Everyone'},
#  {'title': "The Game Gal's Word Generator",
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.6666665,
#   'ratings': 12,
#   'reviews': 6,
#   'histogram': [0, 1, 0, 1, 10],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.4M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Dec 25, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Dropwords 2',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.452381,
#   'ratings': 42,
#   'reviews': 17,
#   'histogram': [1, 2, 2, 9, 28],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jul 22, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'CrossCraze PRO',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.6761904,
#   'ratings': 1061,
#   'reviews': 627,
#   'histogram': [10, 30, 50, 111, 860],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '21M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Mar 22, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Breaker Full',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.16,
#   'ratings': 1109,
#   'reviews': 588,
#   'histogram': [66, 33, 166, 233, 611],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '14M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Feb 24, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Spelling Challenge PRO',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 18, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Word Plus',
#   'installs': '1+',
#   'minInstalls': 1,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.2M',
#   'genre': 'Word',
#   'genreId': 'GAME_WORD',
#   'released': 'Jun 23, 2020',
#   'contentRating': 'Everyone'}]

# %%
len(listofdictinfo6)
# Out:
# 135

# %%
dictinfofinallist = listofdictinfo + listofdictinfo2 + listofdictinfo3 + listofdictinfo4 + listofdictinfo5 + listofdictinfo6
dictinfofinallist
# Out:
# [{'title': 'Among Us',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.474048,
#   'ratings': 2132693,
#   'reviews': 1101564,
#   'histogram': [154333, 39857, 89011, 206765, 1642727],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '70M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 15, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Scribble Rider',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.8843145,
#   'ratings': 219513,
#   'reviews': 91620,
#   'histogram': [39359, 11409, 15784, 21673, 131288],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '123M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 23, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Call of Duty®: Mobile',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.4783134,
#   'ratings': 10757089,
#   'reviews': 4953322,
#   'histogram': [783831, 203300, 401111, 1064381, 8304466],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '94M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 30, 2019',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Hitmasters',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.090488,
#   'ratings': 280248,
#   'reviews': 98967,
#   'histogram': [39272, 10530, 17919, 30372, 182155],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '85M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Draw Defence',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.91,
#   'ratings': 1080,
#   'reviews': 425,
#   'histogram': [227, 21, 54, 97, 681],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '76M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 27, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Sniper 3D: Fun Free Online FPS Shooting Game',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.379428,
#   'ratings': 13511800,
#   'reviews': 4727488,
#   'histogram': [836062, 308989, 964042, 2185740, 9216967],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 13, 2014',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Smashy Road: Wanted 2',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.1657305,
#   'ratings': 3679,
#   'reviews': 1643,
#   'histogram': [299, 124, 372, 754, 2130],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '119M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'aquapark.io',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 3.946079,
#   'ratings': 1048102,
#   'reviews': 491659,
#   'histogram': [172476, 49435, 76327, 113752, 636112],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '79M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 14, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'slither.io',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.059621,
#   'ratings': 6283044,
#   'reviews': 2609762,
#   'histogram': [842235, 250206, 498604, 791673, 3900326],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 25, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Garena Free Fire: 3volution',
#   'installs': '500,000,000+',
#   'minInstalls': 500000000,
#   'score': 4.0465617,
#   'ratings': 63024309,
#   'reviews': 38262571,
#   'histogram': [11273044, 1912209, 2706676, 3847612, 43284768],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '46M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 7, 2017',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Kick the Buddy',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 3.9639745,
#   'ratings': 2836222,
#   'reviews': 1222887,
#   'histogram': [489959, 120253, 187258, 243285, 1795467],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 22, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Samurai Flash',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9987307,
#   'ratings': 32047,
#   'reviews': 11810,
#   'histogram': [4617, 1749, 2471, 3427, 19783],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '59M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 23, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Johnny Trigger - Sniper Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2502513,
#   'ratings': 70353,
#   'reviews': 24487,
#   'histogram': [5808, 2171, 6050, 10899, 45425],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '74M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 29, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Swipe Fight!',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.86,
#   'ratings': 305,
#   'reviews': 128,
#   'histogram': [55, 15, 30, 21, 184],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '87M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 11, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Mario Kart Tour',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.0398498,
#   'ratings': 1804785,
#   'reviews': 821500,
#   'histogram': [258801, 68898, 120434, 250095, 1106557],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '126M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 24, 2019',
#   'contentRating': 'Everyone'},
#  {'title': '1v1.LOL - Online Building & Shooting Simulator',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.139084,
#   'ratings': 124909,
#   'reviews': 67574,
#   'histogram': [15274, 4338, 9645, 14134, 81518],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 1, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Slice them All! 3D',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.8817022,
#   'ratings': 12400,
#   'reviews': 2156,
#   'histogram': [2089, 580, 1256, 1256, 7219],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '78M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 19, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Fan of Guns',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.1575565,
#   'ratings': 89167,
#   'reviews': 52844,
#   'histogram': [11074, 2723, 5828, 10994, 58548],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 29, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Hunter Assassin',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.1811147,
#   'ratings': 1259612,
#   'reviews': 514968,
#   'histogram': [140928, 47468, 89615, 146129, 835472],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Oct 9, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Spider Rope Hero - Vegas Crime city',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.6957405,
#   'ratings': 5137,
#   'reviews': 2190,
#   'histogram': [1365, 177, 229, 250, 3116],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '80M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 9, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Supreme Duelist Stickman',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.3562512,
#   'ratings': 455371,
#   'reviews': 225973,
#   'histogram': [39105, 12032, 26288, 48049, 329897],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '32M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 16, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'PUBG MOBILE - NEW ERA',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.181501,
#   'ratings': 32705756,
#   'reviews': 15727032,
#   'histogram': [4957891, 795922, 1241010, 2068273, 23642660],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Draw Joust!',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.001171,
#   'ratings': 146261,
#   'reviews': 52811,
#   'histogram': [21299, 7203, 12120, 15042, 90597],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 7, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Traffic Run!',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.066528,
#   'ratings': 207430,
#   'reviews': 83013,
#   'histogram': [25417, 10893, 16867, 25548, 128705],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '64M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 5, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Brawl Stars',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.2763553,
#   'ratings': 13796763,
#   'reviews': 7795996,
#   'histogram': [1683057, 299680, 585851, 1180986, 10047189],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '149M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 12, 2018',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Talking Tom Hero Dash - Run Game',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.2567043,
#   'ratings': 629261,
#   'reviews': 301615,
#   'histogram': [72536, 20441, 31633, 52991, 451660],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '91M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Pocket Sniper!',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.474037,
#   'ratings': 6072,
#   'reviews': 1926,
#   'histogram': [1302, 600, 803, 651, 2716],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '68M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 8, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Dude Theft Wars: Open World Sandbox Simulator BETA',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.210153,
#   'ratings': 322248,
#   'reviews': 173544,
#   'histogram': [39775, 9926, 17557, 30533, 224457],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '97M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 8, 2018',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Bowmasters',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.5153155,
#   'ratings': 4594790,
#   'reviews': 2147708,
#   'histogram': [276757, 83973, 213208, 441656, 3579196],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 10, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'NERF Epic Pranks!',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.086793,
#   'ratings': 106949,
#   'reviews': 45964,
#   'histogram': [14767, 4802, 7002, 10186, 70192],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '135M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 9, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Johnny Trigger - Action Shooting Game',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3011575,
#   'ratings': 1267190,
#   'reviews': 486768,
#   'histogram': [111323, 37651, 85707, 155904, 876605],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '100M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 13, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Talking Tom Gold Run',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3697796,
#   'ratings': 4214464,
#   'reviews': 1799820,
#   'histogram': [384138, 108663, 200652, 392190, 3128821],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '90M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 13, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Snake.io - Fun Addicting Arcade Battle .io Games',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.145872,
#   'ratings': 290121,
#   'reviews': 137615,
#   'histogram': [38389, 10245, 17294, 28917, 195276],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '33M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 14, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Stealth Master - Assassin Ninja Game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.0701013,
#   'ratings': 31096,
#   'reviews': 9923,
#   'histogram': [3589, 1429, 2991, 4289, 18798],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '71M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 22, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Bullet Rush!',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.842427,
#   'ratings': 21520,
#   'reviews': 6078,
#   'histogram': [3563, 1235, 2115, 2723, 11884],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '43M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 2, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Slap Kings',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.1962314,
#   'ratings': 647139,
#   'reviews': 232309,
#   'histogram': [67733, 23185, 46611, 86439, 423171],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '92M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Feb 25, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Tomb of the Mask',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3231797,
#   'ratings': 1261721,
#   'reviews': 606091,
#   'histogram': [109977, 36067, 74401, 157044, 884232],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '62M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 19, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'FRAG Pro Shooter',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3650136,
#   'ratings': 701374,
#   'reviews': 379962,
#   'histogram': [62959, 18379, 36356, 65674, 518006],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '100M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 5, 2019',
#   'contentRating': 'Teen'},
#  {'title': "Knock'em All",
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2955184,
#   'ratings': 164092,
#   'reviews': 58641,
#   'histogram': [14376, 4842, 9945, 23678, 111251],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': "Hide 'N Seek!",
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0238075,
#   'ratings': 113612,
#   'reviews': 45355,
#   'histogram': [15058, 5884, 9668, 13685, 69317],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '72M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 23, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'War Machines: Tank Battle - Army & Military Games',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.0888257,
#   'ratings': 1025975,
#   'reviews': 352964,
#   'histogram': [119047, 39628, 86960, 165847, 614493],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '84M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 16, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Super Mario Run',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 3.6733491,
#   'ratings': 1514594,
#   'reviews': 645319,
#   'histogram': [334900, 84937, 128907, 157112, 808738],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 22, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Agar.io',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 3.9792123,
#   'ratings': 4029094,
#   'reviews': 1345611,
#   'histogram': [677803, 135812, 281520, 431161, 2502798],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '37M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 8, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Zooba: Free-for-all Zoo Combat Battle Royale Games',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2260933,
#   'ratings': 555378,
#   'reviews': 277550,
#   'histogram': [62292, 17572, 34954, 58016, 382544],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '157M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Oct 2, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Netboom -Play Cloud Gaming',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.8663492,
#   'ratings': 35964,
#   'reviews': 27239,
#   'histogram': [9251, 614, 715, 493, 24891],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '18M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 6, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Miraculous Ladybug & Cat Noir',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.277721,
#   'ratings': 690001,
#   'reviews': 357470,
#   'histogram': [78782, 21328, 31551, 56156, 502184],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '49M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 24, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'I, The One - Action Fighting Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1894817,
#   'ratings': 77217,
#   'reviews': 31849,
#   'histogram': [9774, 2640, 4393, 6781, 53629],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '44M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 10, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Archero',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.457535,
#   'ratings': 1336392,
#   'reviews': 515701,
#   'histogram': [77606, 26329, 73049, 189434, 969974],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '104M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 18, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Protect the VIP',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.8372881,
#   'ratings': 6141,
#   'reviews': 1921,
#   'histogram': [1124, 333, 510, 624, 3550],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '77M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 22, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Pixel Gun 3D: FPS Shooter & Battle Royale',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.150195,
#   'ratings': 5519273,
#   'reviews': 2806722,
#   'histogram': [762473, 177049, 303983, 501296, 3774472],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '91M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Feb 21, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Archer Hero 3D',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.008346,
#   'ratings': 13576,
#   'reviews': 5266,
#   'histogram': [1792, 721, 1102, 1926, 8035],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '60M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 12, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Bed Wars',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.264458,
#   'ratings': 540258,
#   'reviews': 303379,
#   'histogram': [64016, 14030, 25630, 47966, 388616],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '127M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 6, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Curvy Punch 3D',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.4858532,
#   'ratings': 22931,
#   'reviews': 9669,
#   'histogram': [5657, 1784, 2321, 2098, 11071],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '78M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 25, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Snowball.io',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0957813,
#   'ratings': 252346,
#   'reviews': 121523,
#   'histogram': [30170, 10735, 21942, 31404, 158095],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 29, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Hurricane Superhero : Wind Tornado Vegas Mafia',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.995041,
#   'ratings': 34752,
#   'reviews': 14691,
#   'histogram': [6011, 1490, 1987, 2433, 22831],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '139M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 3, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Modern Ops - Online FPS (Gun Games Shooter)',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4289846,
#   'ratings': 544210,
#   'reviews': 260549,
#   'histogram': [41009, 11493, 26286, 59663, 405759],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '54M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Crossy Road',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.555462,
#   'ratings': 4428545,
#   'reviews': 1418053,
#   'histogram': [193863, 60618, 222439, 566468, 3385157],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '77M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 7, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'Last Day on Earth: Survival',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.3252273,
#   'ratings': 3888679,
#   'reviews': 1962946,
#   'histogram': [340864, 110224, 214598, 500646, 2722347],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 24, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Temple Run 2',
#   'installs': '500,000,000+',
#   'minInstalls': 500000000,
#   'score': 4.2260504,
#   'ratings': 9334443,
#   'reviews': 2607602,
#   'histogram': [1024774, 316759, 595568, 983880, 6413462],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 23, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Marvel Contest of Champions',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.2595973,
#   'ratings': 3030323,
#   'reviews': 1028591,
#   'histogram': [320312, 81063, 167112, 384996, 2076840],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '97M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 10, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Tomb of the Mask: Color',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.230219,
#   'ratings': 119412,
#   'reviews': 44081,
#   'histogram': [12996, 4221, 7428, 12413, 82354],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Oct 14, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Murder Hornet',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 3.8471112,
#   'ratings': 22674,
#   'reviews': 9094,
#   'histogram': [4394, 1249, 1461, 1894, 13676],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '124M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 24, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'War Robots Multiplayer Battles',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.166083,
#   'ratings': 4092634,
#   'reviews': 1778396,
#   'histogram': [532193, 129603, 224523, 446288, 2760027],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '78M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 26, 2015',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Run Royale 3D',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.17,
#   'ratings': 925,
#   'reviews': 440,
#   'histogram': [111, 27, 55, 129, 603],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '65M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 17, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Football Field Kick',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.344598,
#   'ratings': 22588,
#   'reviews': 7966,
#   'histogram': [1396, 773, 1838, 3224, 15357],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Feb 20, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Rope Hero: Vice Town',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.131836,
#   'ratings': 822330,
#   'reviews': 330623,
#   'histogram': [116261, 30761, 45483, 65622, 564203],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '90M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 14, 2016',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Beat the Boss 4: Stress-Relief Game. Hit the buddy',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.065804,
#   'ratings': 335449,
#   'reviews': 121973,
#   'histogram': [45615, 13865, 27077, 35165, 213727],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '160M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 23, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Worms Zone .io - Voracious Snake',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.30585,
#   'ratings': 1610602,
#   'reviews': 774803,
#   'histogram': [151501, 49865, 98707, 164983, 1145546],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '29M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 2, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Mobile Legends: Bang Bang',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.1405125,
#   'ratings': 22256120,
#   'reviews': 11149929,
#   'histogram': [3212395, 650893, 1118330, 2089932, 15184570],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '99M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Oct 31, 2016',
#   'contentRating': 'Teen'},
#  {'title': 'Golf Hit',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.059096,
#   'ratings': 28222,
#   'reviews': 9626,
#   'histogram': [2381, 1306, 3757, 5596, 15182],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 29, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Neon Iron Stickman Rope Hero City Gangstar Mafia',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.0690556,
#   'ratings': 27174,
#   'reviews': 16095,
#   'histogram': [4179, 1034, 1420, 2637, 17904],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '92M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 26, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Stickman Warriors - Super Dragon Shadow Fight',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.583233,
#   'ratings': 150804,
#   'reviews': 72811,
#   'histogram': [8327, 2318, 5696, 11191, 123272],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '87M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 8, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'StrikeFortressBox',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.3138194,
#   'ratings': 46472,
#   'reviews': 22437,
#   'histogram': [5138, 1324, 1921, 3519, 34570],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '67M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 22, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Hide Online - Hunters vs Props',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.093869,
#   'ratings': 998283,
#   'reviews': 470316,
#   'histogram': [123728, 38409, 78813, 136808, 620525],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 19, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Dinosaur Rampage',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.372508,
#   'ratings': 48033,
#   'reviews': 20767,
#   'histogram': [4294, 1532, 2288, 3790, 36129],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '56M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 29, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Offline Shooting: DEAD TARGET- Free Zombie Games',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.4670696,
#   'ratings': 1874914,
#   'reviews': 702323,
#   'histogram': [118511, 43039, 100024, 195988, 1417352],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 16, 2014',
#   'contentRating': 'Mature 17+'},
#  {'title': 'World War Heroes: WW2 FPS',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.429087,
#   'ratings': 1963254,
#   'reviews': 839146,
#   'histogram': [158213, 46097, 88465, 172770, 1497709],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 22, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Cover Fire: Offline Shooting Games',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.4708223,
#   'ratings': 1786994,
#   'reviews': 698960,
#   'histogram': [116580, 36491, 84590, 200660, 1348673],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 30, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'DRAGON BALL LEGENDS',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4695873,
#   'ratings': 992167,
#   'reviews': 490551,
#   'histogram': [64085, 20587, 46393, 115368, 745734],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '96M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 17, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Brawlhalla',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.2490907,
#   'ratings': 91428,
#   'reviews': 40928,
#   'histogram': [8797, 2710, 6409, 12515, 60997],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '83M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 4, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Dead by Daylight Mobile',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.1431003,
#   'ratings': 159082,
#   'reviews': 77544,
#   'histogram': [16624, 5959, 13022, 25895, 97582],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 15, 2020',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Otherworld Legends',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.339133,
#   'ratings': 34943,
#   'reviews': 19195,
#   'histogram': [1927, 1205, 2906, 5956, 22949],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '62M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 19, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Mask of Stick: Superhero',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.5082507,
#   'ratings': 3082,
#   'reviews': 1373,
#   'histogram': [234, 30, 152, 183, 2483],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '47M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 2, 2020',
#   'contentRating': 'Teen'},
#  {'title': "Push'em all",
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 3.9696789,
#   'ratings': 184008,
#   'reviews': 62837,
#   'histogram': [27385, 9041, 15162, 22598, 109822],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '46M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'Sniper Zombies: Offline Game',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.439596,
#   'ratings': 34008,
#   'reviews': 10393,
#   'histogram': [2533, 858, 1453, 3442, 25722],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '169M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 16, 2020',
#   'contentRating': 'Mature 17+'},
#  {'title': "Chuck E.'s Skate Universe",
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.313466,
#   'ratings': 98820,
#   'reviews': 22258,
#   'histogram': [11156, 2512, 4633, 6412, 74107],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '44M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 29, 2014',
#   'contentRating': 'Everyone'},
#  {'title': 'Stickman Battle',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.110586,
#   'ratings': 42610,
#   'reviews': 18278,
#   'histogram': [5598, 2154, 2789, 3463, 28606],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 6, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Black Hole Hero : Vice Vegas Rope Mafia',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.023313,
#   'ratings': 73795,
#   'reviews': 31443,
#   'histogram': [11891, 3359, 4513, 5404, 48628],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '130M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 29, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Stick Warfare: Blood Strike',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.2641306,
#   'ratings': 9471,
#   'reviews': 4510,
#   'histogram': [813, 360, 648, 1338, 6312],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 10, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Gun Gang',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.3107276,
#   'ratings': 8287,
#   'reviews': 2959,
#   'histogram': [2688, 459, 449, 971, 3720],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '82M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 8, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Truck Driver City Crush',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.074579,
#   'ratings': 126159,
#   'reviews': 55173,
#   'histogram': [19536, 5260, 6636, 9550, 85177],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '94M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 17, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Exploration Lite Craft',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.8389516,
#   'ratings': 301584,
#   'reviews': 130157,
#   'histogram': [59226, 14149, 21386, 28028, 178795],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '15M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 1, 2016',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'MORTAL KOMBAT',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.1973867,
#   'ratings': 4019713,
#   'reviews': 1609045,
#   'histogram': [473850, 132286, 244119, 445777, 2723681],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 4, 2015',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Helix Jump',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.0603323,
#   'ratings': 4235981,
#   'reviews': 1778039,
#   'histogram': [565492, 174727, 330135, 533995, 2631632],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 12, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Real Time Shields',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.7147622,
#   'ratings': 12270,
#   'reviews': 3086,
#   'histogram': [2241, 818, 1412, 1525, 6274],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '109M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 27, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'The Survival Hunter Games 2',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9077623,
#   'ratings': 216849,
#   'reviews': 81207,
#   'histogram': [40033, 10363, 13482, 18663, 134308],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '131M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 9, 2014',
#   'contentRating': 'Teen'},
#  {'title': 'Real Gangster Crime',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.085054,
#   'ratings': 771410,
#   'reviews': 304147,
#   'histogram': [117265, 28367, 44725, 62187, 518866],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '100M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 31, 2015',
#   'contentRating': 'Teen'},
#  {'title': 'Upstream Struggle',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.65,
#   'ratings': 258,
#   'reviews': 157,
#   'histogram': [13, 2, 2, 26, 215],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 5, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Gangstar Vegas: World of Crime',
#   'installs': '50,000,000+',
#   'minInstalls': 50000000,
#   'score': 4.289243,
#   'ratings': 5972163,
#   'reviews': 2613626,
#   'histogram': [653855, 153626, 297937, 572580, 4294165],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '40M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 19, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Diableros: Zombie RPG Shooter',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.8058252,
#   'ratings': 103,
#   'reviews': 50,
#   'histogram': [25, 2, 2, 13, 61],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '85M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 31, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Robbery.io',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.5057473,
#   'ratings': 87,
#   'reviews': 29,
#   'histogram': [5, 1, 6, 8, 67],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '25M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 24, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Bed Diving',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.172131,
#   'ratings': 1269,
#   'reviews': 514,
#   'histogram': [437, 114, 83, 62, 573],
#   'price': 0,
#   'free': True,
#   'offersIAP': False,
#   'size': '66M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 3, 2020',
#   'contentRating': 'Everyone'},
#  {'title': '🐓Chicken Gun🐓',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.365416,
#   'ratings': 74089,
#   'reviews': 39770,
#   'histogram': [7322, 2044, 2820, 5952, 55951],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '73M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Feb 19, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Shadow Fight 2',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.5733514,
#   'ratings': 13332533,
#   'reviews': 4808509,
#   'histogram': [826643, 199104, 422586, 939248, 10944952],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '145M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 22, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Bullet Echo',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.1954875,
#   'ratings': 76043,
#   'reviews': 31146,
#   'histogram': [7377, 2896, 5379, 12221, 48170],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '98M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'May 21, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Stickman 3D - Street Gangster - Street Gangs',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 4.450893,
#   'ratings': 2384,
#   'reviews': 742,
#   'histogram': [170, 53, 127, 213, 1821],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Stick Fight: The Game Mobile',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.966894,
#   'ratings': 123829,
#   'reviews': 58252,
#   'histogram': [18880, 5486, 10369, 15212, 73882],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jul 16, 2019',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Sonic the Hedgehog™ Classic',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.132171,
#   'ratings': 222351,
#   'reviews': 107067,
#   'histogram': [30654, 7623, 12946, 21584, 149544],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '63M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 21, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Creative Destruction',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.1500473,
#   'ratings': 1167115,
#   'reviews': 673536,
#   'histogram': [163887, 34276, 63191, 107230, 798531],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '74M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 19, 2018',
#   'contentRating': 'Teen'},
#  {'title': 'Rage Road',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.01216,
#   'ratings': 58607,
#   'reviews': 20585,
#   'histogram': [7468, 3131, 5741, 7146, 35121],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '76M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 26, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Anger of stick 5 : zombie',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'score': 4.3032002,
#   'ratings': 1065784,
#   'reviews': 450402,
#   'histogram': [106054, 32766, 62462, 95198, 769304],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '33M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 8, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'LegendArya',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.01,
#   'ratings': 113,
#   'reviews': 76,
#   'histogram': [10, 12, 10, 13, 68],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '95M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Sep 9, 2020',
#   'contentRating': 'Teen'},
#  {'title': "Archer's Tale - Adventures of Rogue Archer",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.39172,
#   'ratings': 3302,
#   'reviews': 782,
#   'histogram': [231, 84, 147, 536, 2304],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '93M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 26, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Crowd Bomber',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 2.9268293,
#   'ratings': 1656,
#   'reviews': 660,
#   'histogram': [566, 192, 212, 171, 515],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '55M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 24, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Desert Riders',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.234745,
#   'ratings': 44144,
#   'reviews': 13706,
#   'histogram': [3628, 1839, 4131, 5488, 29058],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '42M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Mar 28, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'NARUTO X BORUTO NINJA VOLTAGE',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.9474807,
#   'ratings': 644976,
#   'reviews': 338018,
#   'histogram': [112926, 26571, 42771, 61889, 400819],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '78M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 21, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Fps Robot Shooting Games – Counter Terrorist Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4539075,
#   'ratings': 21850,
#   'reviews': 13776,
#   'histogram': [1850, 726, 715, 920, 17639],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '45M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 1, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'MaskGun Multiplayer FPS - Free Shooting Game',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.203501,
#   'ratings': 445862,
#   'reviews': 255819,
#   'histogram': [53715, 13953, 25476, 47456, 305262],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 15, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Spider Hero: Superhero Fighting',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 3.880015,
#   'ratings': 27272,
#   'reviews': 11628,
#   'histogram': [5339, 1084, 1843, 2249, 16757],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '146M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Dec 21, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Stick Fight Online: Multiplayer Stickman Battle',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.4569297,
#   'ratings': 118736,
#   'reviews': 60671,
#   'histogram': [8696, 2186, 5733, 11669, 90452],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '37M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Nov 8, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'Garfield™ Rush',
#   'installs': '10,000,000+',
#   'minInstalls': 10000000,
#   'score': 4.2649903,
#   'ratings': 31542,
#   'reviews': 12664,
#   'histogram': [3386, 1250, 1555, 2776, 22575],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '77M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jan 22, 2019',
#   'contentRating': 'Teen'},
#  {'title': 'Food Gang',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.9281712,
#   'ratings': 19837,
#   'reviews': 10398,
#   'histogram': [2961, 1010, 1900, 2587, 11379],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '30M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Apr 29, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Robotics!',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.707331,
#   'ratings': 35113,
#   'reviews': 16394,
#   'histogram': [6224, 2524, 3992, 4937, 17436],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '106M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Aug 5, 2020',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Snow Storm Superhero',
#   'installs': '5,000,000+',
#   'minInstalls': 5000000,
#   'score': 4.042105,
#   'ratings': 10705,
#   'reviews': 4626,
#   'histogram': [1813, 368, 584, 727, 7213],
#   'price': 0,
#   'free': True,
#   'offersIAP': True,
#   'size': '156M',
#   'genre': 'Action',
#   'genreId': 'GAME_ACTION',
#   'released': 'Jun 14, 2020',
#   'contentRating': 'Teen'},
#  {'title': 'Crowd Master 3D',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'score': 3.9815125,
#   'ratings': 12075,
# ...
#   'reviews': 6211,
#   'histogram': [471, 300, 631, 1835, 15384],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '38M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 23, 2017',
#   'contentRating': 'Teen'},
#  {'title': 'The Impossible Game',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 3.9473996,
#   'ratings': 20039,
#   'reviews': 3641,
#   'histogram': [3269, 793, 1610, 2416, 11951],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '2.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 25, 2010',
#   'contentRating': 'Everyone'},
#  {'title': 'Dungeon Village',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.606753,
#   'ratings': 13309,
#   'reviews': 3432,
#   'histogram': [383, 198, 634, 1837, 10257],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 2, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'METAL SLUG 3',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.967678,
#   'ratings': 15937,
#   'reviews': 6489,
#   'histogram': [2407, 830, 1156, 2018, 9526],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 11, 2012',
#   'contentRating': 'Teen'},
#  {'title': "THE KING OF FIGHTERS '97",
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.3865495,
#   'ratings': 15940,
#   'reviews': 5778,
#   'histogram': [1272, 440, 741, 1883, 11604],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 13, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'M64Plus FZ Pro Emulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.49,
#   'ratings': 183,
#   'reviews': 99,
#   'histogram': [9, 7, 7, 20, 140],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '5.4M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 22, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Granny Smith',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.693646,
#   'ratings': 43175,
#   'reviews': 19279,
#   'histogram': [1796, 310, 1094, 2923, 37052],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 29, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'VGBAnext - Universal Console Emulator',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.2982454,
#   'ratings': 1143,
#   'reviews': 643,
#   'histogram': [100, 40, 70, 140, 793],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.0M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 19, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'JCheater: Vice City Edition',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.2322738,
#   'ratings': 4100,
#   'reviews': 1689,
#   'histogram': [1454, 160, 310, 331, 1845],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.7M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 2, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Marvel Pinball',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.7296417,
#   'ratings': 9242,
#   'reviews': 2586,
#   'histogram': [1806, 582, 702, 1365, 4787],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '39M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 6, 2013',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Sonic Jump Pro',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.830819,
#   'ratings': 9376,
#   'reviews': 4140,
#   'histogram': [2213, 222, 272, 899, 5770],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 21, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'FINAL FANTASY II',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 3.4790998,
#   'ratings': 3124,
#   'reviews': 1228,
#   'histogram': [713, 201, 341, 613, 1256],
#   'price': 7.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '9.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 20, 2012',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Nostalgia.NES Pro (NES Emulator)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.6065574,
#   'ratings': 2460,
#   'reviews': 905,
#   'histogram': [121, 40, 60, 242, 1997],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '3.7M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 26, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Balance The Beam 2.0',
#   'installs': '10+',
#   'minInstalls': 10,
#   'score': 0.0,
#   'ratings': None,
#   'reviews': 0,
#   'histogram': [0, 0, 0, 0, 0],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '31M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jan 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'GBA.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.564815,
#   'ratings': 1454,
#   'reviews': 662,
#   'histogram': [80, 40, 67, 53, 1214],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.3M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 21, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'holedown',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.371901,
#   'ratings': 1220,
#   'reviews': 511,
#   'histogram': [10, 60, 151, 242, 757],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '37M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 25, 2018',
#   'contentRating': 'Everyone'},
#  {'title': 'Double Dragon Trilogy',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.160274,
#   'ratings': 7346,
#   'reviews': 2273,
#   'histogram': [684, 392, 614, 1026, 4630],
#   'price': 3.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '7.6M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 4, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'METAL SLUG',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.8458843,
#   'ratings': 5737,
#   'reviews': 2307,
#   'histogram': [954, 311, 542, 784, 3146],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 19, 2012',
#   'contentRating': 'Teen'},
#  {'title': 'ARC Browser',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.23,
#   'ratings': 458,
#   'reviews': 328,
#   'histogram': [46, 13, 36, 55, 308],
#   'price': 8.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '17M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 26, 2015',
#   'contentRating': 'Everyone'},
#  {'title': 'SWORDSHOT',
#   'installs': '50+',
#   'minInstalls': 50,
#   'score': 4.6666665,
#   'ratings': 15,
#   'reviews': 11,
#   'histogram': [1, 0, 0, 1, 13],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 16, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Shopkins Run!',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.46,
#   'ratings': 181,
#   'reviews': 117,
#   'histogram': [38, 16, 25, 27, 75],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '50M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 21, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Hyperforma Premium',
#   'installs': '100+',
#   'minInstalls': 100,
#   'score': 4.75,
#   'ratings': 32,
#   'reviews': 27,
#   'histogram': [2, 0, 0, 0, 30],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '33M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 6, 2020',
#   'contentRating': 'Everyone'},
#  {'title': 'Retro8 (NES Emulator)',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.72,
#   'ratings': 853,
#   'reviews': 608,
#   'histogram': [179, 17, 136, 51, 470],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 7, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'Atomic Bomber Full',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.4928827,
#   'ratings': 9475,
#   'reviews': 2598,
#   'histogram': [556, 168, 455, 1163, 7133],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '1.6M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 29, 2010',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Pizza Boy GBC Pro',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.68,
#   'ratings': 391,
#   'reviews': 269,
#   'histogram': [15, 0, 7, 47, 322],
#   'price': 4.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '11M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 27, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'SAMURAI SHODOWN II',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 4.2686834,
#   'ratings': 5645,
#   'reviews': 2267,
#   'histogram': [512, 221, 311, 793, 3808],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.8M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 28, 2013',
#   'contentRating': 'Mature 17+'},
#  {'title': 'Mupen64Plus AE (N64 Emulator)',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.4527845,
#   'ratings': 4817,
#   'reviews': 1984,
#   'histogram': [1178, 350, 548, 595, 2146],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '12M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 18, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'Yaba Sanshiro Pro - Sega Saturn Emulator',
#   'installs': '1,000+',
#   'minInstalls': 1000,
#   'score': 4.19,
#   'ratings': 210,
#   'reviews': 152,
#   'histogram': [12, 10, 25, 38, 125],
#   'price': 5.6,
#   'free': False,
#   'offersIAP': False,
#   'size': '16M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 4, 2019',
#   'contentRating': 'Everyone'},
#  {'title': 'GBC.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.51,
#   'ratings': 1034,
#   'reviews': 435,
#   'histogram': [62, 20, 51, 93, 808],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 23, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'The World Ends With You',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.7336154,
#   'ratings': 4738,
#   'reviews': 1443,
#   'histogram': [110, 60, 130, 380, 4058],
#   'price': 17.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '13M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jun 25, 2014',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'SPACE INVADERS',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.59,
#   'ratings': 208,
#   'reviews': 129,
#   'histogram': [6, 8, 4, 27, 163],
#   'price': 5.49,
#   'free': False,
#   'offersIAP': False,
#   'size': '26M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Oct 10, 2016',
#   'contentRating': 'Everyone'},
#  {'title': 'Robo Defense',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'score': 4.178641,
#   'ratings': 66712,
#   'reviews': 15579,
#   'histogram': [7772, 3238, 3627, 6736, 45339],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': None,
#   'contentRating': 'Everyone 10+'},
#  {'title': 'Danmaku Unlimited 3',
#   'installs': '5,000+',
#   'minInstalls': 5000,
#   'score': 4.21,
#   'ratings': 248,
#   'reviews': 134,
#   'histogram': [27, 5, 22, 27, 167],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '80M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 9, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'R-TYPE',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.671916,
#   'ratings': 8472,
#   'reviews': 3298,
#   'histogram': [200, 111, 233, 1178, 6750],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '23M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Sep 12, 2011',
#   'contentRating': 'Everyone'},
#  {'title': "Ghosts'n Goblins MOBILE",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.17,
#   'ratings': 905,
#   'reviews': 537,
#   'histogram': [108, 9, 90, 108, 590],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '28M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 15, 2017',
#   'contentRating': 'Everyone'},
#  {'title': 'METAL SLUG 2',
#   'installs': '50,000+',
#   'minInstalls': 50000,
#   'score': 2.9575071,
#   'ratings': 3541,
#   'reviews': 1596,
#   'histogram': [1264, 421, 321, 271, 1264],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 6, 2013',
#   'contentRating': 'Teen'},
#  {'title': "Ghouls'n Ghosts MOBILE",
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.96,
#   'ratings': 327,
#   'reviews': 216,
#   'histogram': [29, 26, 49, 46, 177],
#   'price': 1.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '49M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'May 17, 2017',
#   'contentRating': 'Everyone 10+'},
#  {'title': 'METAL SLUG X',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.3120916,
#   'ratings': 6146,
#   'reviews': 2840,
#   'histogram': [1567, 713, 683, 602, 2581],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': '6.9M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Mar 6, 2013',
#   'contentRating': 'Teen'},
#  {'title': 'PCE.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.28,
#   'ratings': 918,
#   'reviews': 431,
#   'histogram': [101, 36, 18, 110, 653],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Aug 27, 2010',
#   'contentRating': 'Everyone'},
#  {'title': '2600.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.24,
#   'ratings': 603,
#   'reviews': 248,
#   'histogram': [78, 12, 24, 60, 429],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Nov 3, 2011',
#   'contentRating': 'Everyone'},
#  {'title': 'NEO.emu',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 3.43,
#   'ratings': 1156,
#   'reviews': 731,
#   'histogram': [335, 46, 104, 127, 544],
#   'price': 3.99,
#   'free': False,
#   'offersIAP': False,
#   'size': 'Varies with device',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Feb 14, 2012',
#   'contentRating': 'Everyone'},
#  {'title': 'Miner Premium',
#   'installs': '10,000+',
#   'minInstalls': 10000,
#   'score': 4.0419846,
#   'ratings': 2632,
#   'reviews': 535,
#   'histogram': [311, 110, 251, 442, 1518],
#   'price': 0.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '27M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Jul 3, 2013',
#   'contentRating': 'Everyone'},
#  {'title': 'Death Worm™',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 3.9320755,
#   'ratings': 7981,
#   'reviews': 1803,
#   'histogram': [1235, 331, 632, 1325, 4458],
#   'price': 2.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '17M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Apr 21, 2011',
#   'contentRating': 'Teen'},
#  {'title': 'Sky Gamblers: Storm Raiders',
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'score': 4.357444,
#   'ratings': 14273,
#   'reviews': 4437,
#   'histogram': [1222, 451, 611, 1704, 10285],
#   'price': 4.99,
#   'free': False,
#   'offersIAP': True,
#   'size': '10M',
#   'genre': 'Arcade',
#   'genreId': 'GAME_ARCADE',
#   'released': 'Dec 22, 2014',
#   'contentRating': 'Everyone 10+'},
#  ...]

# %%
# 1 entry was lost somewhere.

len(dictinfofinallist)
# Out:
# 5135

# %%
df = pd.DataFrame(dictinfofinallist)
df
# Out:
#                        title      installs  minInstalls     score     ratings  \
# 0                   Among Us  100,000,000+    100000000  4.474048   2132693.0
# 1             Scribble Rider   10,000,000+     10000000  3.884314    219513.0
# 2      Call of Duty®: Mobile  100,000,000+    100000000  4.478313  10757089.0
# 3                 Hitmasters   50,000,000+     50000000  4.090488    280248.0
# 4               Draw Defence      500,000+       500000  3.910000      1080.0
# ...                      ...           ...          ...       ...         ...
# 5130             Dropwords 2        1,000+         1000  4.452381        42.0
# 5131          CrossCraze PRO       10,000+        10000  4.676190      1061.0
# 5132       Word Breaker Full       10,000+        10000  4.160000      1109.0
# 5133  Spelling Challenge PRO          100+          100  0.000000         NaN
# 5134               Word Plus            1+            1  0.000000         NaN
#
#         reviews                                   histogram  price   free  \
# 0     1101564.0     [154333, 39857, 89011, 206765, 1642727]   0.00   True
# 1       91620.0        [39359, 11409, 15784, 21673, 131288]   0.00   True
# 2     4953322.0  [783831, 203300, 401111, 1064381, 8304466]   0.00   True
# 3       98967.0        [39272, 10530, 17919, 30372, 182155]   0.00   True
# 4         425.0                      [227, 21, 54, 97, 681]   0.00   True
# ...         ...                                         ...    ...    ...
# 5130       17.0                            [1, 2, 2, 9, 28]   0.99  False
# 5131      627.0                      [10, 30, 50, 111, 860]   5.49  False
# 5132      588.0                     [66, 33, 166, 233, 611]   2.99  False
# 5133        0.0                             [0, 0, 0, 0, 0]   1.99  False
# 5134        0.0                             [0, 0, 0, 0, 0]   1.99  False
#
#       offersIAP                size   genre      genreId      released  \
# 0          True                 70M  Action  GAME_ACTION  Jun 15, 2018
# 1          True                123M  Action  GAME_ACTION  Jul 23, 2020
# 2          True                 94M  Action  GAME_ACTION  Sep 30, 2019
# 3          True                 85M  Action  GAME_ACTION  Mar 19, 2020
# 4         False                 76M  Action  GAME_ACTION  Aug 27, 2020
# ...         ...                 ...     ...          ...           ...
# 5130      False                 16M    Word    GAME_WORD  Jul 22, 2014
# 5131      False                 21M    Word    GAME_WORD  Mar 22, 2013
# 5132      False                 14M    Word    GAME_WORD  Feb 24, 2011
# 5133      False  Varies with device    Word    GAME_WORD  Jun 18, 2019
# 5134      False                5.2M    Word    GAME_WORD  Jun 23, 2020
#
#      contentRating
# 0     Everyone 10+
# 1         Everyone
# 2       Mature 17+
# 3             Teen
# 4         Everyone
# ...            ...
# 5130      Everyone
# 5131      Everyone
# 5132      Everyone
# 5133      Everyone
# 5134      Everyone
#
# [5135 rows x 15 columns]

# %%
# Pickling this for later

df.to_pickle('reviewfeatures.pkl')

# %%
df = pd.read_pickle('reviewfeatures.pkl')
df.head(2)
# Out:
#             title      installs  minInstalls     score    ratings    reviews  \
# 0        Among Us  100,000,000+    100000000  4.474048  2132693.0  1101564.0
# 1  Scribble Rider   10,000,000+     10000000  3.884314   219513.0    91620.0
#
#                                  histogram  price  free  offersIAP  size  \
# 0  [154333, 39857, 89011, 206765, 1642727]    0.0  True       True   70M
# 1     [39359, 11409, 15784, 21673, 131288]    0.0  True       True  123M
#
#     genre      genreId      released contentRating
# 0  Action  GAME_ACTION  Jun 15, 2018  Everyone 10+
# 1  Action  GAME_ACTION  Jul 23, 2020      Everyone

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# # Getting Reviews for each mobile game

# %%
# If a game does not have 250 reviews, it will return as many reviews as possible

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.nianticlabs.pokemongo',
    lang='en',
    country='us', 
    sort=Sort.MOST_RELEVANT, 
    count=250,
)

result[:4]
# Out:
# [{'reviewId': 'gp:AOqpTOENUlhZrhfqw0YKug7c0H7CNhySmVfTaCt04ri6794ETkfynrUMdYk0LqRRVyrmMhfe163uqTCklvTpipw',
#   'userName': 'john cayton',
#   'userImage': 'https://lh3.googleusercontent.com/a-/AOh14GjBwKD_hCf58Tywg6mBCWYXd1E7ebWIFpoLIngQ',
#   'content': "I've been playing off and on for years and it only gets better. In a weird way, Covid might be the best thing that's happened to Pokemon Go- constant events, increased pokestop/gym range, and discounted items in the shop. I, as well as many others, still get out to play... but it's nice to know that if I go under quarantine, I still have options to continue my progress in the game. So, big thank you to Niantic and the Pokemon company!",
#   'score': 5,
#   'thumbsUpCount': 487,
#   'reviewCreatedVersion': '0.187.1',
#   'at': datetime.datetime(2020, 9, 25, 17, 6, 52),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOG6QtmdPiZgNWcMbI3fSQC6rUJhD6b7P_cSS3SEn4BkZQf8YaWGsikZnJI37wqwgcD6HDUnjH5HTQ2GpWs',
#   'userName': 'Biggie_ stuff',
#   'userImage': 'https://lh3.googleusercontent.com/a-/AOh14Gj4OAlIB2GWMTLqNIOEG4xgnU5SPiTfR24CeMS9pA',
#   'content': 'I really love the game, though the problem i have with it is that it takes quite a while to level up. And the battles costanly tell me i have a weak connection, when the rest of the game is working swell. And it annoys me, cause my data is good. Not to mention it used to work fine, i dont know what happened but i recommend maybe fixing that, other than that the game is a fun time.',
#   'score': 3,
#   'thumbsUpCount': 467,
#   'reviewCreatedVersion': '0.187.1',
#   'at': datetime.datetime(2020, 9, 25, 5, 40, 41),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOH21wR8ib2LU-hq_JNrp_V4s9hOaUsRcyqJg5VjrPe8UC9meItAAMOtVYxe03am7fP2GxtJE3NDw7k70x4',
#   'userName': 'Cory',
#   'userImage': 'https://lh3.googleusercontent.com/a-/AOh14Gime2e0noz81QGt1ItPM221nY_BZg58TzcaVE9XMQ',
#   'content': "I like the game for the most part, but hate that the leveling takes forever. And of course to evolve anything requires an absurd amount of candies and you MIGHT encounter one of said Pokemon once per month, so that's a huge waste. This game requires too much space so that's my main reason for leaving. I might return someday, but there would have to be some significant feature for me to do so.",
#   'score': 2,
#   'thumbsUpCount': 350,
#   'reviewCreatedVersion': '0.185.3',
#   'at': datetime.datetime(2020, 9, 25, 17, 57, 12),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFAHdi2lzglXUUdybs3FZm1X4Uh00LWRre-y7KVKVL8mhIlPXNqRVY_vMEVmF_GIcUHUF2euUeRv4f1Zm4',
#   'userName': 'Agent 7',
#   'userImage': 'https://lh3.googleusercontent.com/a-/AOh14GjJ6AJ8YRE_sfH2bEQfwOjTkM242ZYzmaoFeBmheg',
#   'content': "I'm perfectly fine with everything, except for one thing. The entire online battle thing gives me a bunch of hooey. I have a NEAR-PERFECT 5G connection, and what happens? It tells me that I have a weak connection! I can't even battle my mom without getting upset! I can be tapping the charged attack for 5 seconds straight, but it doesn't work! You really need to work on this, Niantic!",
#   'score': 4,
#   'thumbsUpCount': 87,
#   'reviewCreatedVersion': '0.187.1',
#   'at': datetime.datetime(2020, 9, 24, 20, 21, 42),
#   'replyContent': None,
#   'repliedAt': None}]

# %%
# turn the above into a function

def givemereviews(appids):
    
    # Parts of the review that we are interested in
    keys = {'content', 'score'}
    
    # The function itself
    result, continuation_token = reviews(
    appids,
    lang='en',
    country='us', 
    sort=Sort.MOST_RELEVANT, 
    count=250,
)
    # Filtering the results
    filteredresults = [{k:v for k, v in i.items() if k in keys} for i in result]

    return filteredresults

# %%
# It takes about 1 minute to run 100 games

starttime = datetime.now()

testlist = [item for sublist in list(map(lambda appid: givemereviews(appid), uniqueappidlist[:100])) for item in sublist]

print(datetime.now() - starttime)
print('------------')
print(testlist[:5])
# Out:
# 0:01:03.150205
# ------------
# [{'content': "It is very fun. But the only problem is that you can leave a mach whenever you want. I feel as though you can only leave in the waiting room or if your dead. It would make the game slot more interesting and alot more fair. Here's my experience of this. I was playing a match and within 2 minutes, the game ends and I lost. I found out later that PEOPLE WERE LEAVING! And when people leave that means they gave the imposter 1 less person they have to kill. Please fix this inner sloth.", 'score': 4}, {'content': 'Great game! First, the bad. There are plenty of bugs, and plenty of trolling and hacking. Now the other 4 stars. This game is fun, the tasks are simple, but just different enough to remain interesting. The imposter has some cool toys, and the debates are vicious! (In a good way). I do wish tasks got shifted to players still in the game when one player quits, so the crew could still win that way. Cool down for the imposter abilities make him have to really be clever. Definitely worth play.', 'score': 4}, {'content': "Simple enough game. Gameplay works really well. Great controls, and lovely, retro graphics. Runs smoothly, the game turning on and each time it loads is really fast. There's only one problem and that's the people's behaviour in the game. Too many people are either leaving the game early because they're not the imposter, or too many people are not taking their tasks seriously.", 'score': 5}, {'content': "Very good game but could be better. Ex: there should be a currency and leveling system that you earn from surviving, killing, and completing tasks. Also tasks should have more meaning instead of you complete them then walk around doing nothing for the rest of the game. Sure you could extend the tasks, but what's the point if there's no reward. All in all its a great game and worthy of your time to try it atleast once. It'd also be cool if you could have up to 15-20 players with bigger maps. 👍👌", 'score': 4}, {'content': 'This game is great. I do have a few nitpicks though, main of which is that whenever I win or lose a game I cannot play again or quit. No matter which button I press it just freezes the game and forces me to reopen the app in order to play again. It may just be my device, though. Whilst playing the game, however, there are a couple of problems. Firstly there is the problem of not being able to "friend" a player. Secondly is that the options feel a bit limiting. What if I want to have 15P and 4I?', 'score': 4}]

# %%
# It appears some apps do not give us exactly 500 reviews.

len(testlist)
# Out:
# 24549

# %%
starttime = datetime.now()

bigreviewlist= [item for sublist in list(map(lambda appid: givemereviews(appid), uniqueappidlist)) for item in sublist]

print(datetime.now() - starttime)
print('------------')
print(bigreviewlist[:2])

# %%
len(bigreviewlist)
# Out:
# 1911805

# %%
# However, this file size is much too big for Github (333MB). We must compress it.
# We will pickle it, download it, and store outside of Github in case.

#with open('biglistreview.pkl', 'wb') as h:
#    pickle.dump(bigreviewlist, h)

# %%
# We will use bz2 to compress pickle files to 1/4th the size, which brings us just under the Github limit.

import bz2

# This is to compress it.
def compressed_pickle(title, data):
    with bz2.BZ2File(title + '.pbz2', 'w') as f:
        pickle.dump(data, f)
        
# This is to bring it back.        
def decompress_pickle(file):
    data = bz2.BZ2File(file, 'rb')
    data = pickle.load(data)
    return data

# %%
compressed_pickle('compressedbiglistreview', bigreviewlist)

# %%
# Looks like it worked, and is under 100 mb limit of Github.

testreviewlist = decompress_pickle('compressedbiglistreview.pbz2')
len(testreviewlist)
# Out:
# 1911805
